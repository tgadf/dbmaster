# %% [markdown]
# # Discogs

# %%
## Basic stuff
# %load_ext autoreload
# %autoreload

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))
#IPython.Cell.options_default.cm_config.lineNumbers = true;

################################################################################
## Python Version
################################################################################
import sys
from time import sleep

################################################################################
## General Stuff
################################################################################
from multiprocessing import Pool
from tqdm import tqdm


################################################################################
## Util Stuff
################################################################################
from timeUtils import clock, elapsed
from ioUtils import saveFile, getFile


################################################################################
## Music DB
################################################################################
from mainDB import mainDB
from musicDBMap import musicDBMap
from masterDBMatchClass import masterDBMatchClass
from matchDBArtist import matchDBArtist


################################################################################
## Music Names
################################################################################
from masterArtistNameDB import masterArtistNameDB
from dbArtistsDeezer import dbArtistsDeezer
from dbArtistsLastFM import dbArtistsLastFM
from dbArtistsDiscogs import dbArtistsDiscogs
from dbArtistsAllMusic import dbArtistsAllMusic
from dbArtistsMusicBrainz import dbArtistsMusicBrainz
from dbArtistsAlbumOfTheYear import dbArtistsAlbumOfTheYear
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# /Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # Initialize

# %%
maindb = mainDB(mdb=None, create=False, debug=True)
dbdata = maindb.dbdata
# Out:
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rateyourmusic   =========================
# =========================   deezer   =========================
# =========================   albumoftheyear   =========================
# =========================   genius   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RateYourMusic
#   Creating Database Records for Deezer
#   Creating Database Records for AlbumOfTheYear
#   Creating Database Records for Genius
# ...

# %% [markdown]
# # Credit Downloads

# %%
dbdata["AllMusic"]["Artists"].assertDBModValCreditData(0, test=True)

# %%
from random import shuffle
modVals = list(range(100))
shuffle(modVals)

for modVal in modVals:
    break
    try:
        dbdata["Discogs"]["Artists"].assertDBModValCreditData(modVal)
    except:
        continue

# %%
from random import shuffle
modVals = list(range(100))
shuffle(modVals)

for modVal in modVals:
    break
    try:
        dbdata["Discogs"]["Artists"].assertDBModValUnofficialData(modVal)
    except:
        continue

# %%
dbAP = dbArtistsAlbumOfTheYear()
    
mdbmap = musicDBMap("Top40")
for primaryKey, artistName in mdbmap.getArtists().items():
    try:
        dbAP.searchForArtist(artistName,force=False,maxArtists=2,debug=True)
    except:
        pass
    sleep(3)

# %%
specificDownloads = True
if specificDownloads:

    toget=['Omer Adam', 'Eden Ben Zaken', 'Itay Levi', 'Eden Hason', 'Ishay Ribo', 'Dudi Bar David', 'Stephane legar', 'Moshe Peretz', 'Hanan Ben Ari', 'Peled', 'Cookie Levanna', 'Tamuz', 'Karolina', 'Tuna', 'Fox Blanco', 'Idan Amedi', 'Full Trunk', 'Eviatar Banai', 'Noa Kirel', 'Maor Edri', 'Mooki', 'Ravid Plotnik', 'Marina Maximilian', 'Regev Hod', 'קייט ואור', 'Jane Bordeaux', 'Daniela Spector', 'Shaked Komemy', 'Benaia Barabi', 'Chen Aharoni', 'Beit Habubot', 'Agam Buhbut', 'Lior Narkis', 'Idan Yaniv', 'Gil Vain', 'Elai Botner', 'Dudu Faruk', 'Peer Tasi', 'Talisman', 'Ido Shoam', 'Ofek Hamalach', 'Ori Ben Ari', 'Yam Refaeli', 'Mergui', 'Liran Danino', 'Kobi Peretz', 'Osher Cohen', 'אייל גולן ומשה פרץ', 'Red Band', 'Roni Dalumi', 'Noy Fadlon', 'Gal Adam', 'Moshiko Mor', 'Ron Nesher', 'Rotem Cohen', 'Nofar Salman', 'שבט אחים ואחיות', 'Carakukly', 'Eden Meiri', 'Amir Dadon', 'Adir Getz', 'Mor', 'Miri Mesika', 'Our Part', 'Arutz Hakibud', 'Meir Ariel', 'Eden', 'Jasmin Moallem', 'Akiva', 'Anna Zak', 'Nasrin Kadry', 'Tomer Yosef', 'Idan Rafael Haviv', 'Emanuele Vernarelli', 'Carmen', 'Ella Lee', 'Paulius Jurgaitis', 'רועי סנדלר', 'שם טוב האבי', 'Amir Ve Ben', 'Raviv Kaner', 'Bar Tzabary', 'Geva Alon', 'Yishay Swissa', 'Kobi Maman', 'Lama Lo', 'אמני ישראל', 'Gigolo', 'Atar Mayner', 'GionnyScandal', 'Mina', 'Briga', 'Max Gazzé', 'Mannarino', 'Sergio Sylvestre', 'Lele', 'Bianca Atzei', 'Lodovica Comello', 'Laïoung', 'MINACELENTANO', 'Nerone', 'Gli Autogol', 'LIBERATO', 'Amedeo Preziosi', 'RIKI', 'Shade', 'Luca Maris', 'Highsnob', 'Cromo', 'Reggie Mills', 'Nitro', 'JUNIOR CALLY', 'Samuel Storm', 'Rita Bellanza', 'Gabriele Esposito', 'Canesecco', 'Biondo', 'Noemi', 'Samuel Heron', 'The Legendary Fruitman', 'G.bit', 'Mihail', 'BADA$$ B.', 'Jesto', 'Nashley', 'Naomi', 'Celestal', 'Jamil', 'Geolier', 'DANDY TURNER', 'NDG', 'Peppe Soks', 'AIELLO', 'Alfa', 'CHA CHA', 'Lele Blade', 'PSICOLOGI', 'Ludwig', 'Madame', 'MACHETE', 'Random', 'Holden', 'Il Tre', 'Daniel', 'Chris Viz', 'FSK SATELLITE', 'Samurai Jay', 'Nuela', 'Paky', 'Cicco Sanchez', 'SNIK', 'Gio Montana', 'TY1', 'Nicola Siciliano', 'Emanuele Aloia', 'COMETE', 'VillaBanks', 'Lous and The Yakuza', 'Sofia Tornambene', 'Anto Paga', 'Neves17', 'Nahaze', 'Tredici Pietro', 'Dat Boi Dee', 'Kidd Keo', 'Oro Bianco', 'Bresh', 'Thelonious B.', 'Leon Faun', 'Valerio Mazzei', 'Jayred', 'Giulia Molino', 'Rosa Chemical', 'Astra', '8D Tunes', 'CARA', 'KID VICIOUS', 'ITALIAN ALLSTARS 4 LIFE', 'Vale pain', 'Ivan Granatino', 'LA Vision', 'GELO', 'Coyote Jo Bastard', 'Vaz Tè', 'Skinny', '167 Gang', 'Nuove Strade', 'Nyv', 'Vale Lambo', 'Silent Bob', 'BLOODY VINYL', 'Rondodasosa', 'Casadilego', 'MYDRAMA', 'Melancholia', 'cmqmartina', 'Vergo', 'Little Pieces of Marmelade', 'Will', 'ARIETE', 'Baby Gang', 'Blue Phelix', 'N.A.I.P.', 'Santi', 'Matteo Romano', 'Paris Boy', 'Lortex', 'MV Killa', 'sangiovanni', 'Chema Rivas', 'MORGENSHTERN', 'kizaru', 'Mnogoznaal', 'The Limba', 'Big Baby Tape', "Ramil'", 'FACE', 'Klava Koka', 'GONE.Fludd', 'Markul', 'дора', 'PHARAOH', 'HLEB', 'Intelligency', 'MUKKA', 'LSP', 'HENSY', 'LIZER', 'Платина', 'Poshlaja Molli', 'PORCHY', 'V', 'Dabro', 'FEDUK', 'FILV', 'Husky', 'Korol i Shut', 'ANIKV', 'Rakhim', 'MAYBE BABY', 'Tima Belorusskih', 'pyrokinesis', 'MACAN', 'Dzhizus', 'JEEMBO', 'ssshhhiiittt!', '104', 'Gruppa Skryptonite', 'Mari Kraimbrery', 'maslo chernogo tmina', 'Bi-2', 'SHOOVAL', 'Gafur', 'GUF', 'Pornofilmy', 'Raim', '10AGE', 'Канги', 'DK', 'Basta', 'LXST CXNTURY', 'WENGIE', 'Yanix', 'ФОГЕЛЬ', 'OG Buda', 'Misha Marvin', 'Telly Grave', 'OBLADAET', 'SQWOZ BAB', 'Даня Милохин', 'просто Лера', 'Timran', 'Moses', 'INSTASAMKA', 'Папин Олимпос', 'SLAVA MARLOW', 'Geegun', 'Bula', 'Anet Sai', 'MAYOT', 'КУЧЕР', 'Три дня дождя', 'Monetochka', 'VTORNIK', 'polnalyubvi', 'JILLZAY', 'Xcho', 'TINI LIN', 'Руслан Утюг', 'Alyona Shvets', 'Loqiemean', 'SODA LUV', 'Benedixhion', 'HammAli', 'УННВ', 'I61', 'UncleFlexxx', 'Ваня Дмитриенко', 'Truwer', 'Kim Dracula', 'Дайте Танк (!)', 'PIZZA', 'Molchat Doma', 'CMH', 'LILCAK3', 'Mary Gu', 'PON CHO', 'Run–D.M.C.', 'Vallis Alps', 'Golden Features', 'Dastic', 'SLUMBERJACK', 'Kita Alexander', 'Tyron Hapi', 'Carmouflage Rose', 'Fergus James', 'Mallrat', 'G Flip', 'CXLOE', 'Bene', 'Triple One', 'ONEFOUR', 'Hooligan Hefs', 'Hp Boyz', 'Youngn Lipz', 'No Money Enterprise', 'Chillinit', 'Brothers', 'Day1', 'Stace Cadet', 'Tamer Hosny', 'Mahmoud El Esseily', 'Ahmed Mekky', 'Sharmoofers', 'Yasmine Niazy', 'Mohamed El Sharnouby', 'Oka Wi Ortega', 'Ahmed Kamel', 'Adham Seliman', 'Hamo Bika', 'Ramy Gamal', 'Mohamed Hamaki', 'Ragheb Alama', 'Carole Samaha', 'Adham Nabulsi', 'Moustafa Hagag', 'Street Pound Productions', 'Mohamed Ramadan', 'Deborah Dworshipper', 'Massar Egbari', 'Luc', 'Nico Cartosio', 'George Wassouf', 'Hamza Namira', 'Ahmed Saad', 'Fadel Chaker', 'Majid Almohandis', 'ARNOLD', 'Iam Shamar', 'Jasiel Faraón', 'AJ Salvatore', 'Hamada Hillal', 'Yahia Alaa', 'Tamer Ashour', 'Ramy Ayach', 'KTL Drank', 'Basata Band', 'Trippili', 'Marvinplay67', 'Maximummusic', 'Ahmed Gamal', 'Toneway', 'MASARABOX', 'Alecoti', 'Breadboxx', 'Down88', 'VETILKO', 'AUGUSTOSMUSIC', 'Wegz', 'Ramy Sabry', 'Essam Sasa', 'Saad Lamjarred', 'Figo Eld5lawe', 'Marwan Pablo', 'Ahmed Ezzat', 'Hassan Shakosh', 'Sadat', 'Dyler', 'Abyusif', 'Haytham Shaker', 'Faouzia', 'El Dakhlaweya', 'Shahyn', 'Marwan Moussa', 'El Sawareekh', 'Muhammed Khaled', 'True Damage', 'shaftee pa', 'Dj spin magic', 'Erick Hannah', 'YOUNG REDBULLS', 'Tameem Youness', 'molotof', 'Abo El Anwar', 'Hassan El Shafei', 'Mostafa Shawky', 'Abo El Shouk', 'Ahmed Basyoni', 'Mohammed Saeed', 'Hussain Aljassmi', 'Batistuta', 'El Madfaagya', 'Akram Hosny', 'Afroto', 'Molotof', 'Xiety 7', 'DJ Totti', 'RoxyHits', 'Samer Elmedany', 'L5VAV', 'Wezza Montaser', 'Amjad Jomaa', 'Moscow', '3enba', 'أحمد بسيوني', '7l2olo', 'Omar Kamal', 'Khaled Mokhtar', 'Carmen Soliman', 'أوشا الصغير و عمر حفظي', 'Al Nather', 'Lost Sky', 'Ehab Tawfik', 'Mohamed Nour', 'Double Zuksh', 'MaziteLo', 'Lege-Cy', 'David Sarah UuI', 'فيلو', 'G. Oka', 'مسلم', 'Felo', 'حوده بندق', 'Barry', 'Ahmed Moza', 'Ahmed Abdo', 'Shehab', 'Shabjdeed', 'أوشا الصغير', 'Amir Eid', 'DizzyTooSkinny', 'Rashed', 'Dawin', 'SUD', 'Moira Dela Torre', 'Juris', 'Michael Pangilinan', 'Moonstar88', 'Krissy', 'Mark Carpio', 'MYMP', 'Julie Anne San Jose', '6cyclemind', 'Piolo Pascual', 'Hale', 'Bailey May', 'Angeline Quinto', 'Jericho Rosales', 'Inigo Pascual', 'CHANYEOL', 'Crush', 'Kaye Cal', 'Daniel Padilla', 'KZ Tandingan', 'Jake Zyrus', 'Thyro', 'The Juans', 'Parokya Ni Edgar', 'Ex Battalion', 'Ben&Ben', 'Al James', 'Shanti Dope', 'Bosx1ne', 'Karencitta', 'John Roa', 'December Avenue', 'Kyle Juliano', 'Janine Teñoso', 'The Itchyworms', 'Mayonnaise', 'Unique Salonga', 'I Belong to the Zoo', 'Marion Aunor', 'juan karlos', 'Khel Pangilinan', 'This Band', 'Lavaado', 'TJ Monterde', 'PDL', 'ALLMO$T', 'Rivermaya', 'Just Hush', 'Armi Millare', 'Alisson Shore', 'Join The Club', 'Agsunta', 'CLR', 'Pricetagg', 'LeeHi', 'SOMI', 'Donnalyn Bartolome', 'Caleb Santos', 'Arvey', 'Reneé Dominique', 'Psychedelic Boyz', 'King Badger', 'Skusta Clee', 'VVS Collective', 'Magnus Haven', 'Nik Makino', 'Michael Dutchi Libranda', 'Matthaios', 'Evan Rachel Wood', 'Tatak Pinoy All-Stars', 'ZICO', 'NIKI', 'Flow G', 'Emman', 'Jr Crown', 'MC Einstein', 'Justin Vasquez', 'Gaho', 'Danzz', 'Juan Caoile', 'BAEKHYUN', 'Music Hero', 'Tanya Manalang', 'Gian Magdangal', 'Soulthrll', 'Lil Vinceyy', 'HONNE', 'Arthur Nery', 'Ace Banzuelo', 'Alessandra De Rossi', 'Twenty-Nine Eleven', 'SB19', 'Bandang Lapis', 'Jem Macatuno', 'DJ Noiz', 'Rob Deniel', 'Julian Sean', 'Gagong Rapper', 'Joseph Vincent', 'aespa', 'JM Bales', 'Dear Jane', 'Supper Moment', 'Stephanie Ho', 'Charmaine Fong', 'JW', 'Juno Mak', 'Kwan Gor', 'Eric Chou', 'Phil Lam', 'Ruco Chan', '陳以桐', 'JC 陳詠桐', 'Joker Xue', 'Joyce Cheng', 'Shiga Lin', 'Ronald Cheng', 'Endy Chow', 'Eman Lam', 'Dear John', 'Sam Kim', 'Kayee Tam', 'Alfred Hui', 'SOYOU', 'HEIZE', 'AILEE', 'Eddy Kim', 'ToNick', 'Emma Watson', 'Yue Chun Giu', 'HANA', 'G-DRAGON', 'Vincent Wong', 'Hubert Wu', 'LaLa Hsu', 'Apink', 'Yanki Din', 'KARD', 'Feanna Wong', 'SUNMI', '蔡一傑', 'Deep Ng', 'Candy Lo', 'Vivian Koo', 'At17', 'Yoyo Sham', 'Jinny Ng', 'E-Kids', 'Wang Jun Qi', 'Kelly Yu', 'Calvert Fu', '歐陽靖', 'Ron Ng', '(G)I-DLE', 'Tang Siu Hau', 'TWINS', 'Keeva Mak', 'RubberBand', 'BOYZ', 'Louis Koo', 'EXID', 'Kaho Hung', '梁釗峰', 'CLC', '黃齡', 'Ekin Cheng', 'Hebe Tien', 'Shirley Chen', '陳健安', 'Chilam', '湯瑪仕與眾香港人', 'AKMU', '香港人', '高爾宣 OSN', 'JUDE', 'EVERGLOW', 'GFRIEND', '李靖筠', '831', 'Yoon Mirae', 'Yerin Baek', 'Davichi', '10cm', '陳卓賢', 'Wu Bai', 'TomFatKi', 'Killa Ben', 'Leekthough', 'Eclectic Fuller', 'ismooh', 'WINNER', 'Candre', 'Rowdy860', 'Angela Hui', 'Solar', 'Sita Chan', 'Fouad', 'Agatha', 'FogClawz', '戴祖儀', 'Lil’ Ashes', 'SSAK3', 'Jace Chan', 'Ren Ran', 'Alien Huang', '許光漢', 'REFUND SISTERS', 'Jay Fung', '陳卓賢 Ian', '姜濤', 'Jer 柳應廷', 'Phan Mạnh Quỳnh', 'Đen', 'Hoang Thuy Linh', 'Chillies', 'Sơn Tùng M-TP', 'Bich Phuong', 'Da LAB', 'Ngọt', 'BigDaddy', 'Vu Cat Tuong', 'Noo Phước Thịnh', 'Stephanie Poetri', 'Vũ.', 'Ngô Kiến Huy', 'Tien Tien', 'Mỹ Tâm', 'Truc Nhan', 'Lê Hiếu', 'Nguyễn Trọng Tài', 'Đạt G', 'Lynk Lee', 'Thái Đinh', 'Andiez', 'Nguyen Ha', 'Bùi Lan Hương', 'Đức Phúc', 'Rhymastic', 'MIN', 'Miu Lê', 'Soobin Hoang Son', 'ERIK', 'Binz', 'Phùng Khánh Linh', 'Thịnh Suy', 'Huỳnh Tú', 'Masew', 'JustaTee', 'Trinh Thang Binh', 'Younha', 'HuyR', 'Hien Ho', 'Hoàng Yến Chibi', 'Kimmese', 'Tóc Tiên', 'Orange', 'JUUN D', 'Ngơ', 'Kha', 'Jadu Jadu', 'CHROMANCE', 'TaynguyenSound', 'AMEE', 'T Team', 'Hoài Lâm', 'MANBO', 'Hoang Dung', 'HIEUTHUHAI', '2T', 'Phuong Ly', 'Hồ Ngọc Hà', 'Văn Mai Hương', 'Táo', 'Landon Austin', 'Jack - J97', 'Trung Quan', 'Wean', 'William Laura IiO', 'Quân A.P', 'Tlinh', 'TREASURE', 'Độ Mixi', 'Logan Harris', 'RAP VIỆT', 'Thùy Chi', 'Thiều Bảo Trâm', 'Khoi Vu', 'Quang Đăng Trần', 'King Of Rap', 'demxntia', 'MINO', 'Hiền Hồ', 'Lyly', 'Wowy', 'PhucXP', 'hooligan.', 'Emcee L (Da LAB)', 'Andree Right Hand', 'Uyên Linh', 'JGKiD (Da LAB)', '7UPPERCUTS', 'VY Jacko', 'Ha Anh Tuan', '14 Casper', 'Tuấn Hưng', 'Mr T', 'Tố My', 'Khac Viet', 'Hồ Quỳnh Hương', 'Thu Minh', 'Hồ Quang Hiếu', 'Duong Hong Loan', 'Son Tuyen', 'Mỹ Linh', 'Axel Johansson', 'Strange Imagining', 'Cao Thai Son', 'Anh Khang', 'Đông Nhi', 'Samuel Lindon', 'Lê Cát Trọng Lý', 'Enno Aare', 'Bela Nemeth', 'Huong Tram', "Josie O'Connor", 'Akira Phan', 'Quang Huy', 'Duy Khanh', 'Ngoc Dolil', 'Dan Nguyen', 'Nguyen Dinh Vu', 'Xesi', 'Phuong Linh', 'Quynh Trang', 'Hien Thuc', 'YanBi', 'Quoc-Bao', 'Chau Dang Khoa', 'Vo Vinh Du', 'BATE', 'Tim Binker', 'Ung Hoang Phuc', 'Osad', 'SPACESPEAKERS', 'Nhiều người hát', 'Dai Nhan', 'Dinh Huong', 'Tien Cookie', 'K-ICM', 'SEUNGRI', 'Nguyễn Trần Trung Quân', 'Rum', "Girls' Generation-Oh!GG", 'Jasmine Sokko', 'Loco', 'Isaac', 'SEULGI', 'RM', 'Bao Anh', 'TLDK', 'Trong Hieu', 'Jun Phạm', 'Hari Won', 'LyLy', 'Lee So Ra', 'Touliver', 'B Ray', 'Suboi', 'Am Mi', 'Khanh Phuong', 'KANG DANIEL', 'Phát Hồ', 'Thùy Trang', 'Le Mousche', 'Trance Demon', 'Klasico', 'Alzate', 'Mueka', 'JENCARLOS', 'Kevin Florez', "Billo's", 'Kraken', 'El Gran Martín Elías', 'Ventino', 'Los Corraleros De Majagual', 'Pastor Lopez', 'Fredy Montoya', 'Diomedes Diaz', 'Jessi Uribe', 'Lary Over', 'Andy Rivera', 'Nicolas Mayorca', 'Bomby', 'Sky Rompiendo', 'Juanpis Gonzalez', 'Pacho El Antifeka', 'Legarda', 'Yeison Jimenez', 'Eladio Carrion', 'Luigi 21 Plus', 'Casper Magico', 'Fumaratto', 'Beéle', 'Luis Eduardo Acústico', 'Montano', 'Llane', 'Jhonny Rivera', 'Néstor Zavarce', 'Ovy On The Drums', 'KILATE TESLA', 'Lyanno', 'Nibal', 'Ryan Castro', 'Randy', 'Flow La Movie', 'Otto Serge', 'CHANO', 'Mano Arriba', 'Los Bonnitos', 'Agapornis', 'Pijama Party', '#TocoParaVos', 'LOAN', 'Papichamp', 'aLee DJ', 'CantoParaBailar', 'Marka Akme', 'El Villano', 'Rafaga', 'Los Totora', 'Las Pastillas del Abuelo', 'AX 13', 'Pase Libre', 'Danny Paz', 'El Super Hobby', 'Olvidate!', 'Dame 5', 'Julián Serrano', 'La Reserva', 'VAS', 'DJ Tetraguy', 'Ulises Bueno', 'Oriana', 'De La Calle', 'Los Turros', 'j mena', 'Trap Capos', 'Midel', 'El Apache Ness', 'Zato DJ', 'Ecko', 'Seven Kayne', 'Natalie Perez', 'Iacho', 'Drefquila;Bizarrap', 'Mueva Records', 'Dj Lauuh', 'Interpreti dello spettacolo "Bella Ciao"', 'DJ Cobra Monterrey', 'Turf', 'Cazzu', 'Frijo', 'Neo Pistea', 'Wolty', 'YSY A', 'Yashua', 'Khea;Omar Varela', 'Numa', 'Coscu', 'Eladio Carrion;Seven Kayne', 'Tobi', 'Luck Ra;Seven Kayne', 'Panter Music', 'Dj Brasil Mix', 'Sander Wazz', 'Agus Padilla', 'Marcianos Crew', 'Rodrigo', 'DJ Alan Gomez', 'La Champions Liga', 'Lucho SSJ', 'DJ Alex', 'Los Charros', 'FIESTA!', 'Fer Palacio', 'Pekeño 77', 'Modo Diablo', 'Cazu', 'Axel Caram', 'MDBCrew', '0-600', 'CA7RIEL', 'Bardero$', 'Felp 22', 'Pilar Pascual', 'Acru', 'Alex Rouse', 'Ke Personajes', 'Maffio', 'Dillom', 'Fito Paez', 'Mariah Angeliq', 'John C', 'Oscu', 'Kevo DJ', 'Maria Becerra', 'Los Nota Lokos', 'Mesita', 'Javiielo', 'Airbag', 'El Dipy', 'Rodrigo Tapari', 'Blunted Vato', 'The La Planta', 'Moonkey', 'LiL CaKe', 'La Banda De Lechuga', 'Tiago PZK', 'Bruno Cabrera Dj', 'Los Huayra', 'La Ross Maria', 'El Reja', 'Jeeiph', 'DANI', 'Bebe DJ', 'Papu DJ', 'Rusherking', 'L-Gante', "La K'onga", 'La Delio Valdez', 'Nestor En Bloque', 'Çağatay Akman', 'Kalben', 'Buray', 'Oğuzhan Koç', 'Emrah Karaduman', 'emre aydın', 'Model', 'Duman', 'Pinhani', 'mor ve ötesi', 'Sancak', 'Can Güngör', 'Ümit Besen', 'Mithat Can Özer', 'Edis', 'Adamlar', 'Simge', 'Mümin Sarıkaya', 'Ersan Er', 'Kaan Tangöze', 'Athena', 'yirmi7', 'Can Gox', 'Fatih Bogalar', 'Yüksek Sadakat', 'Son Feci Bisiklet', 'Norm Ender', 'Derya Uluğ', 'The Secret Trio', 'Serkan Kaya', 'Mustafa Ceceli', 'Ayse Hatun Onal', 'Ece Seçkin', 'Hayki', 'Emir', 'Bilge Nihan', 'Furkan Özsan', 'Heijan', 'Soner Sarıkabadayı', 'Can Bonomo', 'Ersay Üner', 'INNA', 'Bağzıları', 'Çağatay Ulusoy', 'Ferman Akgül', 'Berkay', 'Sinan Ceceli', 'Feride Hilal Akın', 'Deniz Tekin', 'Rober Hatemo', 'MFÖ', 'Deeperise', 'No Method', 'Aydın Kurtoğlu', 'Bengü', 'Yaşar Gaga', 'Turac Berkay', 'İdo Tatlıses', 'Can Yüce', 'Aleyna Tilki', 'Güven Yüreyi', 'Bahadır Tatlıöz', 'Koray Avcı', 'Mehmet Erdem', 'Ebru Polat', 'Ece Mumay', 'Vega', 'Mehmet Güreli', 'Reynmen', 'Tuğba Yurt', 'Berkcan Güven', 'Elvan Günaydın', 'Gazapizm', 'Cihan Mürtezaoğlu', 'Şehinşah', 'Onur Can Özcan', 'Pera', 'Ahmet Şafak', 'Artz', 'Can Oflaz', 'Bilal Sonses', 'Xir', 'Bilal Hancı', 'Sufle', 'Patron', 'Pamela', 'Seyfi Yerlikaya', 'K.I.Z', 'Şebnem Ferah', 'Kezzo', 'Dolu Kadehi Ters Tut', 'Cengiz Özkan', 'Ceg', 'Şanışer', 'Fikri Karayel', 'Şimal', 'Khontkar', 'Tolga Kahraman', 'Ufuk Beydemir', 'Melek Mosso', 'Velet', 'Gece Yolcuları', 'ikikardesh', 'Eli Türkoğlu', 'Istanbul Trip', 'Balti', 'Levent Yüksel', 'Merve Özbey', 'Asil Gök', 'Kubilay Aka', 'İyi Olacak', 'Umut Timur', 'Sokrat St', 'Büyük Ev Ablukada', 'Serhat Durmus', 'Anıl Piyancı', 'Tuğçe Kandemir', 'Ados', 'Joker', 'Ben Fero', 'Baneva', 'Ilkay Sencan', 'Karsu', 'Abdullah İnal', 'Burry Soprano', 'Misha', 'Metth', 'Defkhan', 'Gülden', 'Kaan Boşnak', 'Motive', 'RUBY', 'Tuğkan', 'Cengiz Ateş', 'Emir Can İğrek', 'Kahraman Deniz', 'Muşta', 'Server Uraz', 'Aynur Aydın', 'İkiye On Kala', 'Nilipek.', 'Sedef Sebüktekin', 'Yaşlı Amca', 'Ozbi', 'Kubilay Karça', 'Tepki', 'Hande Ünsal', 'Sansar Salvo', 'Ender Balkır', 'Santiz', 'Delimine', 'Maestro', 'Elçin Orçun', 'Sura İskenderli', 'Zeynep Baksi Karatağ', 'Aga B', 'Berk Coşkun', 'Irmak Arıcı', 'Heja', 'Mert Şenel', 'Stabil', 'Keişan', 'Ati242', 'Emre Kaya', 'Bossy', 'Banu Parlak', 'BEGE', 'Melike Şahin', 'Zeynep Bastık', 'Rozz Kalliope', 'Aspova', 'Gringo', 'Elanur', 'Hasibe', 'Fatih Bulut', 'Alper Ayyıldız', 'No. 1', 'Grogi', 'KÖK$VL', 'Sehabe', 'Farazi', 'Taladro', 'Lil Zey', 'Narkoz', 'BRADO', 'UZI', 'Enes Batur', 'Perdenin Ardındakiler', 'kimbureyhan', 'Nahide Babashlı', 'Kozmos', 'Yung Ouzo', 'Ece Ronay', 'Kaya Giray', 'KADR', 'Kamufle', 'Canozan', 'Günay Aksoy', 'Mert Kıyak', 'Madrigal', 'Sakorphe', 'Mavi Gri', 'Rota', 'Bahadır Sağlam', 'Ali Biçim', 'Merdiven Crew', 'Bedo', 'Zen-G', 'Тайпан', 'Mil Savior', 'Evdeki Saat', 'Zehra', 'Arem Ozguc', 'Didomido', 'Saian', 'Batuhan Kordel', 'Diyar Pala', 'emir taha', 'Lia Shine', 'MEG', 'Cemre Solmaz', 'Ayaz Erdoğan', 'Deesmi', 'Ayça Özefe', 'Ravend', 'Resit Kemal', 'Batuflex', 'İkilem', 'cakal', 'Sakiler', 'Güneş', 'Kendimden Hallice', 'Arda Gezer', 'Mustafa Taş', 'Waa Wei', 'Andrew Tan', 'A-Mei Chang', 'Miss Ko', 'Leo王', 'Tia Lee', 'Kenji Wu', 'Diana Wang', 'Maggie Fu', 'Eli Hsieh', 'Starr Chen', '思衛', 'Good Band', 'Sodagreen', 'Ricky Hsiao', 'Naiwen Yang', 'Shadya Lan', 'Van Ness Wu', 'GBOYSWAG', 'Rosie Yang', 'Della', 'Lin Hsin Yi', '姚亦晴', 'Roy Kim', 'Sandrine Pinna', '玖壹壹', 'Kim Kyung Hee', 'JOONIL JUNG', 'Jocie Guo', '李千那', 'Han Suji', 'The Freshman', 'Tangerine Wong', 'Huang Yali', 'Hsiao Hung-Jen', 'Zhong Yu Lin', 'Namewee', 'Xiao Qiu', 'Sticky Rice', '潘裕文', '汪睿', '蔡詩蕓', 'J.Sheon', 'Zhang Bichen', 'MinChen', '張傑', 'Frandé', 'A-do', '吳亦帆', 'Jia Jia', 'Grady Guan', '廖竟淳', 'Cheer Chen', '詹雯婷', 'Hung Pei-Yu', '李崗霖', '「四分衛」樂團主唱阿山', 'Yvonne', 'No Party For Cao Dong', 'Evangeline Wong', 'Guo Ding', 'A Da', 'Hu Xia', 'Ellen Loo', 'Luantan Ascent', 'SISTAR', 'Yisa Yu', 'Fire EX.', 'Dadado Huang', '慢慢說', 'Miu Chu', 'Bae Lin', 'Kelly Pan', 'Jeffrey Kung', 'Maggie Chiang', 'Victor Wong', 'Cyndi Wang', 'LION', 'Abin Fang', 'Nan Quan Mama', 'Cosmos People', 'Penny Tai', 'Koala Liu', '二珂', 'Henry', 'Nicky Lee', 'xumingming', 'Rachel Liang', 'Kumachan', 'SMTOWN', 'Tiger Hu', 'Angela Chang', 'EggPlantEgg', 'Tia Ray', 'Nicholas Teo', 'Outlander', '老王樂隊', '張粹方', 'Under Lover', '韓紅', 'Matzka', '李振源', 'Hyolyn', 'Rose Liu', '蕭秉治', '熊仔 | BOWZ 豹子膽', '陳欣斈', 'WONFU', 'ØZI', 'Bii', 'Julia Wu', '阿信', '宋楚琳', 'Wanfang', 'Kimberley Chen', 'S.H.E.', 'BCW', 'Lara Liang', '柯文哲', 'Quarterback', 'DJ Didilong', '告五人', 'Ann Bai', '頑童Mj116', 'Bisiugroup', 'Gordon', 'Show Luo', 'Yo Lee', '馬念先', '劉芷融', '何夏', '黃莉', '刘人语', '張若凡', 'HAOR', 'Claire Kuo', 'Nine Chen', 'Mary See the Future 先知瑪莉', '张紫豪', 'Shi Shi', '9m88', '鳥屎', 'Pets Tseng', 'Punch', 'Pika Chiu', '音阙诗听', 'Vicky Chen', '盧子杰 James Lu', 'A Si', 'Feng Ze', 'Janice Yan', '理想混蛋', '守夜人', '屁孩 Ryan', 'Kelly Cheng', 'Karencici', 'TANK 呂建忠', '阿冗', '演唱：蘇打綠', '婁峻碩', '黃宣', '阿涵', 'KIM JAE HWAN', 'Song Ga In', 'Marz23', 'April 2nd', '鄧福如 AFÜ', 'Ha Hyun Woo', 'Vivian Hsu', 'Sondia', 'Lee Chan Sol', 'Woosung', 'E.SO', '四堅情WOLF (邱鋒澤、陳零九、黃偉晉、賴晏駒)', '李浩瑋 Howard Lee', '梦然', 'DAY6', '張語噥', 'G22', '林凡', 'BANG YE DAM', '五堅情WOLF(S) (邱鋒澤、陳零九、黃偉晉、賴晏駒、婁峻碩)', '李杰明 W.M.L', '胡66', 'Silence Wang', '江靜 Jiang Jing', 'Gentle Bones', '棉子', 'Ariel Tsai', 'YELLOW黃宣', 'Huang Hong Sheng (Xiao Gui)', 'Boon Hui Lu', '卓文萱', 'LINION', 'Chih Siou', 'Mixer', '九澤CP', '小男孩樂團', '艾薇', 'Don Chu', 'Rain', 'WeiBird', 'Hitimpulse', 'SRTW', 'Whethan', 'filous', 'Fake Pictures', 'FlowRag', 'Cornerstone', 'Rin', 'SDP', 'SpongeBOZZ', 'Naaz', 'Fler', 'Sol Calor', 'TJ_beastboy', 'Joshi Mizu', 'JAZN', 'Jala Brat', 'SXTN', 'Stupid Goldfish', 'YONII', 'ApoRed', 'Payy', 'Tom Gregory', 'XATAR', 'JURI', 'Yassazin', 'Harris & Ford', 'POWERKRYNER', 'Tolay', 'Hardjack', 'Art Storm', 'Nightcall', 'Nura', 'Jay Samuelz', 'King Khalil', 'HUGEL', 'GENT', 'Play69', 'Mois', 'Qzeng', 'AVEC', 'Anastasija', 'Lil Lano', 'Raf Camor', 'Undacava', 'reezy', 'KUMMER', 'Kyd the Band', 'Ghetto Phénomène', 'Stefan Rauch', 'Hemso', 'Knossi', 'JIGGO', 'Dhurata Dora', 'Ahmad Amin', 'MASN', 'NGEE', 'KAYEF', 'CÉLINE', 'Ali471', 'FOURTY', 'Sarah Lombardi', 'Lucky Luke', 'GReeeN', 'Garagen Larrys', 'Monet192', 'Kynda Gray', 'MC Stojan', 'Alle Achtung', 'badmómzjay', 'LIZOT', 'Devito', 'Sarhad', 'CRISPIE', 'Kidda', 'Relja', 'Chris Steger', 'Asche', 'Georg Stengel', 'Monk', 'Delara', 'Bozza', 'ELIF', 'Lune', 'Sääftig', 'Casar', 'Nazar', 'Paula Dalla Corte', 'Konstantinos Argyros', 'Padelis Padelidis', 'Sondr', 'Vasilis Dimas', 'The Main Level', 'Saske', 'Rina', 'Mad Clip', 'Fy', 'iLLEOo', 'Sin Boy', 'Nino Xypolitas', 'Hawk', 'TOQUEL', 'Katerine Duska', 'Above The Hood', 'LEX', 'Baghdad', 'Billy Sio', 'Slogan', 'Manos', 'Ypo', 'GODSQUAD', 'Lil Barty', 'Ν.Ο.Ε.', 'VLOSPA', 'Sadam', 'Tus', 'Logos Timis', 'Bloody Hawk', '2J', 'EPITHE', 'Lena Zevgara', 'Pepe Frantik', 'Moose', 'Mef', 'G0YARD', 'Sele', 'Tsaki', 'Thitis', 'Anastasios Rammos', 'DJ Stephan', 'Display', 'Sigma', 'Tzamal', 'Long3', 'Liak', 'Dof Twogee', 'Natasa Theodoridou', 'Ivan Greko', 'Kings', 'Lil PoP', 'Spine', 'Mikros Kleftis', 'Kareem Kalokoh', 'Sin Laurent', 'Strat', 'Negros Tou Moria', 'Trannos', 'Lamanif', 'GAB', 'Night Grind', 'Dani Gambino', 'FLY LO', 'Bossikan', 'HGEMONA$', 'GAMEBOY', 'Lil Koni', 'Thug Slime', 'RICTA', 'Immune', 'Vremya i Steklo', 'DAVA', 'Sergey Babkin', 'VERBEE', 'FRENSH', 'Anthony Rocket', 'Ex Rated Lover', 'Mot', 'Dlexer', 'Jayden Valentine', 'Dyne Crush', 'Billie Martin', 'Elijah Ing', 'Mons Taka', 'Bastard!', 'JackOPepsico', '4v4X1d', 'DOROFEEVA', 'KALUSH', 'ROSS', 'Aseel Hameem', 'Mahmoud Al Turky', 'Husam Al Rassam', 'Bader AlShuaibi', 'Fahed Bin Fasla', 'Mohamed AlSalim', 'Fahed Al Aref', 'شيمي', 'Rahma Riad', 'علي جاسم ومحمود التركي ومصطفى العبدالله', 'Assala Al Magdi', 'Abdullah Alshahe', 'Tareq Al Harbi', 'Ali Saber', 'Saif Amer', 'Ali Arnoos', 'Ahmed Al Maslawi', 'ريكلس', 'Faisal Abdulkareem', 'Queen G', 'معاذ الحربي', 'Dr. Sus', 'Habeeb Ali', 'DJ-MK', 'RØNIN', 'Badda TD', 'Abdullah Al Farwan', 'Bbnbooda', 'Anji', 'Rizky Febian', 'Hivi!', 'Payung Teduh', 'Dipha Barus', 'Ten2Five', 'Yura Yunita', 'Young Lex', 'Sheila On 7', 'RAN', 'Monita Tahalea', 'GAC (Gamaliél Audrey Cantika)', 'Andre Hehanussa', 'TheOvertunes', 'Float', 'Peterpan', 'Rivan', 'Mario G klau', 'Pasto', 'Dengarkan Dia', 'Adhitia Sofyan', 'SAMSONS', 'Kerispatih', 'Saxx in the City', "D'Cinnamons", 'Tangga', 'Trisouls', 'Fourtwnty', 'Rendy Pandugo', 'Adera', 'Vadi Akbar', 'Vidi Aldiano', 'Aldy Maldini', 'Sons of People', 'Ecoutez', 'Rayi Putra', 'Cakra Khan', 'Endah N Rhesa', 'Banda Neira', 'Nella Kharisma', 'Hanin Dhiya', 'Weird Genius', 'Marcell', 'Nino', 'Ari Lasso', 'Rossa', 'Virgoun', 'Stars and Rabbit', 'The Panasdalam Bank', 'DOLF', 'Rahmania Astrini', 'Tompi', 'Maudy Ayunda', 'Tata Janeeta', 'Arsy Widianto', 'Sabyan Gambus', 'Siti Badriah', 'Gloria Jessica', 'Virzha', 'Trio Lestari', 'Marion Jola', 'Sabyan', 'Ben Sihombing', 'Rio Febrian', 'Ardhito Pramono', 'Energy 18', 'Kunto Aji', 'Nadin Amizah', 'Fiersa Besari', 'AVIWKILA', 'Brisia Jodie', 'Near', 'Lalahuta', 'Devano Danendra', 'Wahyu Selow', 'Juicy Luicy', 'Andmesh', '3 Composers', 'Padi', 'Eclat Story', 'Danilla', 'gamaliél', 'Sal Priadi', 'Budi Doremi', 'Langit Sore', 'Reza Artamevia', '.Feast', 'Naif', 'Potret', 'Skinnyfabs', 'Pamungkas', 'Feby Putri', 'NaFF', 'Chintya Gabriella', 'Ilir7', 'L.Y.O.N', 'Hindia', 'Denny Caknan', 'D’MASIV', 'ILUX', 'Mawar De Jongh', 'Mahen', 'The Macarons Project', 'Didi Kempot', 'SALES', 'Nosstress', 'The Panturas', 'Agatha Chelsea', 'Tiara Andini', 'Lyodra', 'Jeff Bernat', 'Diskoria', 'Anna Hamilton', 'Woro Widowati', 'Honey Jemlan', 'Ocan Siagian', 'Alex Porat', 'Happy Asmara', 'Guyon Waton', 'SECRET NUMBER', 'Cherrybelle', 'Ziva Magnolya', 'Arash Buana', 'cinnamons', 'Elmatu', 'BOL4', 'HYO', 'Dialog Senja', 'Alika', 'Kalia Siska', 'Rey Mbayang', 'Jessi', 'DAY6 (Even of Day)', 'Remember of Today', 'Anneth', 'Mahalini', 'Terry', 'Bondan Prakoso', 'Petra Sihombing', 'GANGGA', 'Jung Seung Hwan', 'Ade Govinda', 'Daun Jatuh', 'Idgitaf', 'NCT 2020', 'KAI', 'Louisa', 'WHTKD', 'OFFAIAH', 'Ryan Blyth', 'Chasing Abbey', '5 After Midnight', 'Mick Konstantin', 'Sunset Bros', 'One Bit', 'The Academic', 'Josh Dylan', 'Hugh Skinner', 'Colin Firth', 'Jeremy Irvine', 'The Crystals', 'Soulé', 'Tiagz', 'Lil Xxel', 'Irish Women In Harmony', 'Robert Grace', 'LYRA', 'Helgi Björnsson', 'Laddi', 'Í svörtum fötum', 'Friðrik Dór', 'Aron Can', 'Birgitta Haukdal', 'Gunnar Ólason', 'Baggalútur', 'Sniglabandið', 'Íslensku dívurnar', 'HLH flokkurinn', 'Stuðkompaníið', 'Kór Öldutúnsskóla', 'Eirikur Hauksson', 'Svanhildur Jakobsdóttir', 'Siggi Pálma', 'XXX Rottweiler hundar', 'Þú og ég', 'Sturla Atlas', 'Land og synir', 'Kór Bústaðarkirkju', 'GKR', 'Diddú', 'Alexander Jarl', 'Herra Hnetusmjör', 'Andreas Weise', 'Returning Visitors', 'Friðrikl Ómar', 'Erna Gunnarsdóttir', 'Made Of Snow', 'Stefán Hilmarsson', 'Hulda Björk Garðarsdóttir', 'The Snowy Hill Singers', 'Helga Möller', 'The Seasonals', 'Úlfur Úlfur', 'Sverrir Bergmann', 'Sálin hans Jóns míns', 'Rjóminn', 'Aron Hannes', 'Hildur', 'Jón Jónsson', 'Dwayne Johnson', 'Aron Brink', 'Birnir', '12:00', 'Rollan', 'Huginn', 'Ilinca', 'Joey Christ', 'Floni', 'Króli', 'UNICEF Iceland', 'JóiPé', 'Kristmundur Axel', 'Fjallabræður', 'Chase Anthony', 'Bergsveinn', 'Skítamórall', 'FM95BLÖ', 'Geisha Cartel', 'kef LAVÍK', 'Völli', 'Michel Dida', 'Landaboi$', 'Góði Úlfurinn', 'Young Karin', 'SZK', 'Auður', "Yung Nigo Drippin'", 'Katla María', 'Hafdís Huld', 'Logi Pedro', 'Arion Banki', 'Albatross', 'BRÍET', 'Heimilistónar', 'Dagur Sigurðsson', 'Guðmundur Þórarinsson', 'Fókus hópurinn', 'Þórir Geir Guðmundsson', 'Ágústa Eva Erlendsdóttir', 'Rari Boys', 'Svanur', 'Aron Mex', 'Þorri', 'Klaka Boys', 'YKKUR', 'Cristofer Reyes', 'Trap City', 'Gísli Pálmi', 'ClubDub;Ra:tio', 'GDRN', 'ClubDub', 'Halldór Gunnar', 'Jóhanna Guðrún', 'Birgir Hákon', 'ZINNIA', 'CAMY', 'EGO', 'Wonayd', 'Haki', 'Prince Fendi', 'Séra Bjössi', 'Izleifur', 'SviMA', 'Plasticboy', 'Drengur', 'Sdóri', 'Friðrik Ómar', 'Daniil', 'Ezekiel Carl', 'Skaði', 'Lukku Láki', 'Luigi', 'Krabba Mane', 'Michela', 'Biigo', 'Chingiz', 'TwickBeats', 'Loopickz', 'DJ Muscleboy', 'Ingi Bauer', 'Gaten Matarazzo', 'M Can', 'Sælan', 'Ingó Veðurguð', 'Á Móti Sól', 'Bjartmar Guðlaugsson', 'Oli Geir', 'Hipsumhaps', 'Eivør', 'Ríó tríó', 'DIMMA', 'Kid Isak', 'Cookiee Kawaii', 'Nína Dagbjört', 'KK', 'Spoky1911', 'Lagualair', 'Lil Binni', 'Breiðablik', 'King MCG', 'Cast of Eurovision Song Contest: The Story of Fire Saga', 'Veðurguðirnir', 'Erik Mjönes', 'Ragga Gröndal', 'Upplyfting', 'Jülevenner', 'Hermann Gunnarsson']
    
    toget1=set(['AMAL', 'PASSION', 'Omer Adam', 'Eden Ben Zaken', 'Itay Levi', 'Eden Hason', 'Static & Ben El', 'Ishay Ribo', 'Dudi Bar David', 'Stephane legar', 'Moshe Peretz', 'Hanan Ben Ari', 'Peled', 'Cookie Levanna', 'Tamuz', 'Tuna', 'Idan Amedi', 'Full Trunk', 'Eviatar Banai', 'Noa Kirel', 'Maor Edri', 'Mooki', 'Ravid Plotnik', 'Marina Maximilian', 'Regev Hod', 'קייט ואור', 'Jane Bordeaux', 'Daniela Spector', 'Shaked Komemy', 'Benaia Barabi', 'Chen Aharoni', 'Beit Habubot', 'Agam Buhbut', 'Lior Narkis', 'Idan Yaniv', 'Gil Vain', 'Elai Botner', 'Dudu Faruk', 'Peer Tasi', 'Talisman', 'Ido Shoam', 'Ofek Hamalach', 'Ori Ben Ari', 'Yam Refaeli', 'Mergui', 'Liran Danino', 'Kobi Peretz', 'Osher Cohen', 'אייל גולן ומשה פרץ', 'Red Band', 'Roni Dalumi', 'Noy Fadlon', 'Gal Adam', 'Moshiko Mor', 'Ron Nesher', 'Rotem Cohen', 'Nofar Salman', 'שבט אחים ואחיות', 'Carakukly', 'Eden Meiri', 'Amir Dadon', 'Adir Getz', 'Mor', 'Miri Mesika', 'Doli & Penn', 'Our Part', 'Arutz Hakibud', 'Meir Ariel', 'Eden', 'Jasmin Moallem', 'Akiva', 'Anna Zak', 'Nasrin Kadry', 'Tomer Yosef', 'Idan Rafael Haviv', 'Emanuele Vernarelli', 'Carmen', 'Ella Lee', 'Paulius Jurgaitis', 'רועי סנדלר', 'שם טוב האבי', 'Amir Ve Ben', 'Raviv Kaner', 'Bar Tzabary', 'Geva Alon', 'Yishay Swissa', 'Kobi Maman', 'Lama Lo', 'אמני ישראל', 'Gigolo', 'Atar Mayner', 'MORGENSHTERN', 'kizaru', 'Mnogoznaal', 'The Limba', 'Big Baby Tape', "Ramil'", 'FACE', 'Klava Koka', 'GONE.Fludd', 'Markul', 'дора', 'PHARAOH', 'HLEB', 'Intelligency', 'MUKKA', 'LSP', 'HENSY', 'LIZER', 'Платина', 'Poshlaja Molli', 'PORCHY', 'V', 'Dabro', 'FEDUK', 'FILV', 'Husky', 'Korol i Shut', 'ANIKV', 'Rakhim', 'MAYBE BABY', 'Tima Belorusskih', 'pyrokinesis', 'MACAN', 'Dzhizus', 'JEEMBO', 'ssshhhiiittt!', '104', 'Gruppa Skryptonite', 'Mari Kraimbrery', 'maslo chernogo tmina', 'Bi-2', 'SHOOVAL', 'Gafur', 'GUF', 'Pornofilmy', 'Raim', '10AGE', 'Канги', 'DK', 'Basta', 'LXST CXNTURY', 'WENGIE', 'Yanix', 'ФОГЕЛЬ', 'OG Buda', 'Misha Marvin', 'Telly Grave', 'OBLADAET', 'SQWOZ BAB', 'Даня Милохин', 'просто Лера', 'Timran', 'Moses', 'INSTASAMKA', 'Папин Олимпос', 'SLAVA MARLOW', 'Geegun', 'Bula', 'Anet Sai', 'MAYOT', 'КУЧЕР', 'Три дня дождя', 'Monetochka', 'VTORNIK', 'polnalyubvi', 'JILLZAY', 'Xcho', 'TINI LIN', 'Руслан Утюг', 'Alyona Shvets', 'Loqiemean', 'SODA LUV', 'Benedixhion', 'HammAli', 'УННВ', 'I61', 'UncleFlexxx', 'Ваня Дмитриенко', 'Truwer', 'Kim Dracula', 'Дайте Танк (!)', 'PIZZA', 'Molchat Doma', 'CMH', 'LILCAK3', 'Mary Gu', 'Tamer Hosny', 'Mahmoud El Esseily', 'Ahmed Mekky', 'Sharmoofers', 'Yasmine Niazy', 'Mohamed El Sharnouby', 'Oka Wi Ortega', 'Ahmed Kamel', 'Adham Seliman', 'Hamo Bika', 'Ramy Gamal', 'Mohamed Hamaki', 'Ragheb Alama', 'Carole Samaha', 'Adham Nabulsi', 'Moustafa Hagag', 'Street Pound Productions', 'Mohamed Ramadan', 'Deborah Dworshipper', 'Massar Egbari', 'Luc', 'Nico Cartosio', 'George Wassouf', 'Hamza Namira', 'Ahmed Saad', 'Fadel Chaker', 'Majid Almohandis', 'ARNOLD', 'Iam Shamar', 'Jasiel Faraón', 'AJ Salvatore', 'Hamada Hillal', 'Yahia Alaa', 'Tamer Ashour', 'Ramy Ayach', 'KTL Drank', 'Basata Band', 'Trippili', 'Marvinplay67', 'Maximummusic', 'Ahmed Gamal', 'Toneway', 'MASARABOX', 'Alecoti', 'Breadboxx', 'Down88', 'VETILKO', 'AUGUSTOSMUSIC', 'Wegz', 'Ramy Sabry', 'Essam Sasa', 'Saad Lamjarred', 'Figo Eld5lawe', 'Marwan Pablo', 'Ahmed Ezzat', 'Hassan Shakosh', 'Sadat', 'Dyler', 'Abyusif', 'Haytham Shaker', 'Faouzia', 'El Dakhlaweya', 'Shahyn', 'Marwan Moussa', 'El Sawareekh', 'Muhammed Khaled', 'True Damage', 'shaftee pa', 'Dj spin magic', 'Erick Hannah', 'YOUNG REDBULLS', 'Tameem Youness', 'molotof', 'Abo El Anwar', 'Hassan El Shafei', 'Mostafa Shawky', 'Abo El Shouk', 'Ahmed Basyoni', 'Mohammed Saeed', 'Hussain Aljassmi', 'Batistuta', 'El Madfaagya', 'Akram Hosny', 'Afroto', 'Molotof', 'Xiety 7', 'DJ Totti', 'RoxyHits', 'Samer Elmedany', 'L5VAV', 'Wezza Montaser', 'Amjad Jomaa', 'Moscow', '3enba', 'أحمد بسيوني', '7l2olo', 'Omar Kamal', 'Khaled Mokhtar', 'Carmen Soliman', 'أوشا الصغير و عمر حفظي', 'Al Nather', 'Lost Sky', 'Ehab Tawfik', 'Mohamed Nour', 'Double Zuksh', 'MaziteLo', 'Lege-Cy', 'David Sarah UuI', 'فيلو', 'G. Oka', 'مسلم', 'Felo', 'حوده بندق', 'Barry', 'Ahmed Moza', 'Ahmed Abdo', 'Shehab', 'Shabjdeed', 'أوشا الصغير', 'Amir Eid', 'DizzyTooSkinny', 'Rashed', 'Çağatay Akman', 'Kalben', 'Buray', 'Oğuzhan Koç', 'Emrah Karaduman', 'emre aydın', 'Model', 'Duman', 'Pinhani', 'mor ve ötesi', 'Sancak', 'Can Güngör', 'Ümit Besen', 'Mithat Can Özer', 'Edis', 'Adamlar', 'Simge', 'Mümin Sarıkaya', 'Ersan Er', 'Kaan Tangöze', 'Athena', 'yirmi7', 'Can Gox', 'Fatih Bogalar', 'Yüksek Sadakat', 'Son Feci Bisiklet', 'Norm Ender', 'Derya Uluğ', 'The Secret Trio', 'Serkan Kaya', 'Mustafa Ceceli', 'Ayse Hatun Onal', 'Ece Seçkin', 'Hayki', 'Emir', 'Bilge Nihan', 'Furkan Özsan', 'Heijan', 'Soner Sarıkabadayı', 'Can Bonomo', 'Ersay Üner', 'INNA', 'Bağzıları', 'Çağatay Ulusoy', 'Ferman Akgül', 'Berkay', 'Sinan Ceceli', 'Feride Hilal Akın', 'Deniz Tekin', 'Rober Hatemo', 'MFÖ', 'Deeperise', 'No Method', 'Aydın Kurtoğlu', 'Bengü', 'Yaşar Gaga', 'Turac Berkay', 'İdo Tatlıses', 'Can Yüce', 'Aleyna Tilki', 'Güven Yüreyi', 'Bahadır Tatlıöz', 'Koray Avcı', 'Mehmet Erdem', 'Ebru Polat', 'Ece Mumay', 'Mehmet Güreli', 'Tuğba Yurt', 'Berkcan Güven', 'Elvan Günaydın', 'Gazapizm', 'Cihan Mürtezaoğlu', 'Şehinşah', 'Onur Can Özcan', 'Pera', 'Ahmet Şafak', 'Artz', 'Can Oflaz', 'Bilal Sonses', 'Xir', 'Bilal Hancı', 'Sufle', 'Pamela', 'Seyfi Yerlikaya', 'K.I.Z', 'Şebnem Ferah', 'Interpreti dello spettacolo "Bella Ciao"', 'Kezzo', 'Dolu Kadehi Ters Tut', 'Cengiz Özkan', 'Ceg', 'Şanışer', 'Fikri Karayel', 'Şimal', 'Khontkar', 'Tolga Kahraman', 'Ufuk Beydemir', 'Melek Mosso', 'Velet', 'Gece Yolcuları', 'ikikardesh', 'Eli Türkoğlu', 'Istanbul Trip', 'Balti', 'Levent Yüksel', 'Merve Özbey', 'Asil Gök', 'Kubilay Aka', 'İyi Olacak', 'Umut Timur', 'Sokrat St', 'Büyük Ev Ablukada', 'Serhat Durmus', 'Anıl Piyancı', 'Tuğçe Kandemir', 'Ados', 'Joker', 'Ben Fero', 'Baneva', 'Ilkay Sencan', 'Karsu', 'Abdullah İnal', 'Burry Soprano', 'Misha', 'Metth', 'Defkhan', 'Gülden', 'Kaan Boşnak', 'Motive', 'RUBY', 'Tuğkan', 'Cengiz Ateş', 'Emir Can İğrek', 'Kahraman Deniz', 'Muşta', 'Server Uraz', 'Aynur Aydın', 'İkiye On Kala', 'Nilipek.', 'Sedef Sebüktekin', 'Yaşlı Amca', 'Ozbi', 'Kubilay Karça', 'Tepki', 'Hande Ünsal', 'Sansar Salvo', 'Ender Balkır', 'Santiz', 'Delimine', 'Elçin Orçun', 'Sura İskenderli', 'Zeynep Baksi Karatağ', 'Aga B', 'Berk Coşkun', 'Irmak Arıcı', 'Heja', 'Mert Şenel', 'Stabil', 'Keişan', 'Ati242', 'Emre Kaya', 'Bossy', 'Banu Parlak', 'BEGE', 'Melike Şahin', 'Zeynep Bastık', 'Rozz Kalliope', 'Aspova', 'Elanur', 'Hasibe', 'Fatih Bulut', 'Alper Ayyıldız', 'No. 1', 'Grogi', 'KÖK$VL', 'Sehabe', 'Farazi', 'Taladro', 'Lil Zey', 'UZI', 'Enes Batur', 'Perdenin Ardındakiler', 'kimbureyhan', 'Kozmos', 'Ece Ronay', 'KADR', 'Kamufle', 'Mert Kıyak', 'Madrigal', 'Sakorphe', 'Mavi Gri', 'Rota', 'Bahadır Sağlam', 'Ali Biçim', 'Merdiven Crew', 'Bedo', 'Zen-G', 'Тайпан', 'Mil Savior', 'Evdeki Saat', 'Zehra', 'Arem Ozguc', 'Didomido', 'Saian', 'Batuhan Kordel', 'Diyar Pala', 'emir taha', 'Lia Shine', 'MEG', 'Cemre Solmaz', 'Ayaz Erdoğan', 'Deesmi', 'Ayça Özefe', 'Ravend', 'Resit Kemal', 'Batuflex', 'İkilem', 'cakal', 'Sakiler', 'Güneş', 'Kendimden Hallice', 'Arda Gezer', 'Mustafa Taş', 'Vremya i Steklo', 'DAVA', 'Sergey Babkin', 'VERBEE', 'FRENSH', 'Anthony Rocket', 'Ex Rated Lover', 'Mot', 'Dlexer', 'Jayden Valentine', 'Dyne Crush', 'Logan Harris', 'Billie Martin', 'Elijah Ing', 'Mons Taka', 'Bastard!', 'JackOPepsico', '4v4X1d', 'DOROFEEVA', 'KALUSH', 'ROSS', 'December Avenue', 'juan karlos', 'Ben&Ben', 'I Belong to the Zoo', 'Hale', 'This Band', 'Moira Dela Torre', 'PDL', 'Janine Teñoso', 'Moonstar88', 'Aseel Hameem', 'ALLMO$T', 'Mahmoud Al Turky', 'Husam Al Rassam', 'Bader AlShuaibi', 'Fahed Bin Fasla', 'Mohamed AlSalim', 'Fahed Al Aref', 'شيمي', 'Rahma Riad', 'علي جاسم ومحمود التركي ومصطفى العبدالله', 'Assala Al Magdi', 'Abdullah Alshahe', 'Tareq Al Harbi', 'Ali Saber', 'Skusta Clee', 'Saif Amer', 'Nik Makino', 'Daniel Padilla', 'The Juans', 'Michael Dutchi Libranda', 'Ali Arnoos', 'Matthaios', 'Ahmed Al Maslawi', 'Magnus Haven', 'ريكلس', 'Faisal Abdulkareem', 'Jr Crown', 'Queen G', 'معاذ الحربي', 'Juan Caoile', 'Dr. Sus', 'Habeeb Ali', 'DJ-MK', 'Emman', 'RØNIN', 'Badda TD', 'Lil Vinceyy', 'Music Hero', 'Bandang Lapis', 'Abdullah Al Farwan', 'Bbnbooda', 'Helgi Björnsson', 'Laddi', 'Í svörtum fötum', 'Friðrik Dór', 'Birgitta Haukdal', 'Gunnar Ólason', 'Baggalútur', 'Sniglabandið', 'Íslensku dívurnar', 'HLH flokkurinn', 'Stuðkompaníið', 'Kór Öldutúnsskóla', 'Eirikur Hauksson', 'Svanhildur Jakobsdóttir', 'Siggi Pálma', 'XXX Rottweiler hundar', 'Þú og ég', 'Sturla Atlas', 'Land og synir', 'Kór Bústaðarkirkju', 'GKR', 'Diddú', 'Alexander Jarl', 'Andreas Weise', 'Returning Visitors', 'Friðrikl Ómar', 'Erna Gunnarsdóttir', 'Made Of Snow', 'Stefán Hilmarsson', 'Hulda Björk Garðarsdóttir', 'The Snowy Hill Singers', 'Helga Möller', 'The Seasonals', 'Úlfur Úlfur', 'Sverrir Bergmann', 'Sálin hans Jóns míns', 'Rjóminn', 'Aron Hannes', 'Hildur', 'Jón Jónsson', 'Dwayne Johnson', 'Aron Brink', 'Birnir', '12:00', 'Rollan', 'Huginn', 'Ilinca', 'Floni', 'Króli', 'UNICEF Iceland', 'Kristmundur Axel', 'Fjallabræður', 'Chase Anthony', 'Bergsveinn', 'Skítamórall', 'FM95BLÖ', 'Geisha Cartel', 'kef LAVÍK', 'Völli', 'Michel Dida', 'Landaboi$', 'Góði Úlfurinn', 'Young Karin', 'SZK', 'Auður', "Yung Nigo Drippin'", 'Katla María', 'Hafdís Huld', 'Logi Pedro', 'Arion Banki', 'Albatross', 'BRÍET', 'Heimilistónar', 'Dagur Sigurðsson', 'Guðmundur Þórarinsson', 'Fókus hópurinn', 'Þórir Geir Guðmundsson', 'Ágústa Eva Erlendsdóttir', 'Rari Boys', 'Svanur', 'Aron Mex', 'Þorri', 'Klaka Boys', 'YKKUR', 'Cristofer Reyes', 'Trap City', 'Gísli Pálmi', 'ClubDub;Ra:tio', 'GDRN', 'ClubDub', 'Halldór Gunnar', 'Jóhanna Guðrún', 'Birgir Hákon', 'ZINNIA', 'CAMY', 'EGO', 'Wonayd', 'Haki', 'Prince Fendi', 'Séra Bjössi', 'Izleifur', 'SviMA', 'Plasticboy', 'Drengur', 'Sdóri', 'Friðrik Ómar', 'Daniil', 'Ezekiel Carl', 'Skaði', 'Lukku Láki', 'Luigi', 'Krabba Mane', 'Michela', 'Biigo', 'Chingiz', 'TwickBeats', 'Loopickz', 'DJ Muscleboy', 'Ingi Bauer', 'Gaten Matarazzo', 'M Can', 'Sælan', 'Ingó Veðurguð', 'Á Móti Sól', 'Bjartmar Guðlaugsson', 'Oli Geir', 'Hipsumhaps', 'Eivør', 'Ríó tríó', 'DIMMA', 'Kid Isak', 'Cookiee Kawaii', 'Nína Dagbjört', 'KK', 'Spoky1911', 'Lagualair', 'Lil Binni', 'Breiðablik', 'King MCG', 'Cast of Eurovision Song Contest: The Story of Fire Saga', 'Veðurguðirnir', 'Erik Mjönes', 'Ragga Gröndal', 'Upplyfting', 'Jülevenner', 'Hermann Gunnarsson', 'SkandaU', 'Stefan Valdobrev', 'Andrea', 'Aleete', 'WOLFE', 'Nick Dean', 'Dubioza kolektiv', '4Magic', 'Equinox', 'The Legendary Fruitman', 'ToTo H', 'MurdaBoyz', 'Boro Purvi', 'Jluch', 'Monoir', 'Лъчо', 'Yanitsa', 'V:RGO', 'Galin', 'Party in Backyard', 'Tsvetelina Yaneva', 'Djena', 'Preslava', 'Itzo Hazarta', 'pewdiepie', 'Nebezao', 'Mascota', 'Secta', 'Malkata', 'Slatkaristika', 'Anelia', 'Dessita', 'FYRE', 'Alisia', 'EMIL TRF', 'Gringod', 'Mila Robert', 'Dara Ekimova', 'Suzanitta', 'Fiki', 'JayBe', 'Boris Dali', 'Lorena', 'Mayel Jimenez', 'Babek Mamedrzaev', 'DENIS TEOFIKOV', '2bona', 'Lidia', 'Aria', 'Vanya', 'Desi Slava', 'Susanu', 'Azis', 'Danna', 'Diona', 'Marso', 'Konstantin', 'Djulia', 'Ballan', 'Michele Morrone', 'Connor Bvrns', 'Singltn', 'Kendra Royal', 'Van', 'Djordan', 'Tsvetelina Grahich', 'Константин', 'Tsvetina', 'RM', 'Abdullah Alkhashrmi', 'Mohammad Assaf', 'Rashed Al-Majed', 'EXID', 'Melhem Zein', 'Hala Al Turk', 'Nawal', 'Essa El Waad', 'Balqees', 'Esraa El Aseel', 'Shamma Hamdan', '(G)I-DLE', 'Mustafa Al Rabeii', 'Zayed Al Saleh', 'بندر بن عوير', 'Unknown Brain', 'Gaziy Bin Sahab', 'Mohamed Al Shehhi', "Badr Al Sh'aefany", 'Rabeh Saqer', 'Elmuanna', 'Bander Bin Oweer', 'غريب ال مخلص', 'Hassan Alattar', 'Mustafa Al-Abdullah', 'Majed Al Esa', 'Yosra Saouf', 'Jassem Mohammed', 'Fahad Alsaad', 'فلاح المسردي', 'Saif Nabeel', 'Yasser Abd Alwahab', 'Dalia', 'Yasser Abdulwahab', 'Eissa Al Marzouk', 'Sultan El Omani', 'Emna Fakher', 'Mashael', '$kinny', 'بو خطيف', 'Mohammed Bin Grman Al Omari', 'Salah Al Zadjali', 'Diana Haddad', 'Evan Naji', 'Cheriimoya', 'deadman 死人', 'EdwardeddnyKing', 'Bo Ateej', 'Mohammed Alsahli', 'ARmusicHIT', 'YNW BSlime', 'Bassam Mahdi', 'Osama Naji', 'Dj Zeki', 'منصور الوايلي', 'علي خالد', 'Daffy', 'Ember Island', 'Bessan Ismail', 'Ali 3arnoos', 'بدر العزي', 'SafahMusic', 'Adel Ebrahim', 'فالح الطوق', 'Mohammed Bin Grman', 'Reckless', 'Mamun Alnattah', 'Rajaa Belmir', 'Ali Majid', 'Dumooa Tahseen', 'دحوم الطلاسي', 'Ayed', 'Alremmas', 'سلطان الفهادي', 'مونستر', 'Assala Al Majidi', 'DJ Smemo', 'Meteb Alshalan', 'Fawaz Ben Awad', 'Naser Albhar', 'Yousif Al Sumaidaie', 'A1 Awesome', 'Omar Naghmet Wattar', 'Issam Alnajjar', 'Beyjan Beatz', 'Nizr | نايزر', 'Trafi', 'Edo Yag', 'شبل الدواسر', 'Pete Parkkonen', 'Hotelli Vantaa', 'Robin', 'BACALL', 'SANNI', 'Samson', 'Marko Hietala', 'Tony Deans', 'Pää-äijät', 'Joulupukki', 'Annie Leigh', 'Ville Tuomi', 'DEM', 'Antti Railio', 'Donald Shoenberg', 'JP Leppäluoto', 'ILARI', 'Alex Mattson', 'Janne Ordén', 'SINI YASEMIN', 'Pihlaja', 'JXO', 'YOUNGHEARTED', 'BESS', 'Ollie', 'Lila', 'Paleface', 'Stepa', 'Oliver', 'SAARA', 'STIG', 'PastoriPike', 'Irina', 'Pykäri', 'The Second Level', 'Daniel Okas', 'Xuitcasecity', 'Hurja', 'Sima', 'Elias Gould', 'Juulia', 'LGNDRY', 'Mr. Elämänpeli', 'Seksikäs-Suklaa', 'Bassbros', 'Jimi Pääkallo', 'Miro Miikael', 'IKE', 'Pesso', 'ABREU', 'Leevi', 'Prinssi Jusuf', 'Anni Lahe', 'Iisa', 'costee', 'Terhi Kokkonen', 'Mira Luoti', 'Sani', 'Jemme', 'Lidl Stingy', 'OPIUM', 'Lukas Leon', 'MEGA-Ertsi', 'Bizi', 'Faija', 'DJ Oku Luukkainen', 'Etta', 'Ruusut', 'Vesterinen yhtyeineen', 'eetu', 'Dilemma', 'Leo Pakarinen', 'Robin Packalen', 'STEREO', 'ibe', 'F', 'edi', 'Jeremie', 'MELO', 'KUUMAA', 'Maustetytöt', 'UNDRESSD', 'pins.ku', 'NCO', 'Erin', 'Tarharyhmä', 'Sara Siipola', 'Tulisielu', 'Sexmane', 'Aksel', 'Lauri Haav', 'Topi Latukka', 'Ahti', 'william', 'Le Fvbelos', 'Intiaanikesä', 'Tinze', 'Emma Gun', 'Tume', 'LEHTISET', 'LILBRO', 'VIIVI', 'Niilo22', 'Slummikoira', 'Bleak Purdy', 'Hassan Maikal', 'Leo Luthando', 'Jon-Jon', 'Olli Antonio', 'Herra Ylppö', 'SHRTY', 'Galwaro', 'Pyrythekid', 'Cavallini', 'Axel Kala', 'Nelma U', 'Heviteemu', 'Petter', 'kent', 'Emil Assergård', 'Madden', 'Parham', 'mansionz', 'Gee Dixon', 'Nano', 'Mariette', 'Axel Schylström', 'Sondr', 'Adrijana', 'Krista Siegfrids', 'Dismissed', 'Rhys', 'Callum Beattie', 'Tonsatt', 'Blizzy', 'JLC', 'Dr Kärlek', 'KIDDO', 'Frank Pierce', 'Lao Ra', 'LBSB', 'Martin Masarov', 'Sigrid Bernson', 'Labyrint', 'Davai', 'Clueless Swede', 'NONONO', 'Aden', 'Elias Abbas', 'Yasin', 'Alida', 'Triad', 'Pablo Paz', 'Werner & Werner', 'Bruno Wintzell', 'Troll', 'Paul Rey', 'Davay', 'FELIX SANDMAN', 'Olivia Eliasson', 'Benislav', 'Edward Blom', 'Emmi Christensson', 'Mimi Werner', 'Ahdam', 'Osman', 'Fricky', 'Macky', 'Mares', 'Lani Mo', 'Pidde P', 'Naod', 'Bolat Nurimov', 'Karim Alger', 'Glenmark Eriksson Strömstedt', 'Fotbollshuliganen', 'Theoz', 'Fakkboiz', 'Matinbum', 'Kevin Faye', 'KONO', 'Nineb Youk', 'Sophie Francis', 'The Waked', 'Donel', 'Hasti B', 'Ben Mitkus', 'Achee Flips', 'Saliboy', 'Reyn', 'STOR', 'SINAN', 'Sebastian Walldén', 'Kadiatou', 'Babblarna', 'Zeana', 'Alex Ceesay', 'Jeano', 'Blacky', 'ADAAM', 'Hanna Ferm', 'High15', 'The Lovers Of Valdaro', 'Pagan Fury', 'BENIM', 'Cimón', '24K', 'Timbuktu', 'Molly Hammar', 'William Segerdahl', 'Ozzy', 'Hogland', 'Rozh', 'Adouli', 'Bolaget', 'BlackJack', 'Amarill', 'Shotgun Willy', 'Nilo', 'Grannen Måns', 'Black Moose', 'Filip Dikmen', 'DON V', 'Dizzy', 'GIDDE', 'Lov1', '24SJU', 'Tusse', 'C.Gambino', 'Unga Scener', 'DANO', 'William Stridh', 'KD', 'B.Baby', 'Klara Hammarström', 'HAVAL', 'Albin Johnsén', 'Amanda Aasa', 'Faith Kakembo', 'Lelo', 'Fungz', 'El Papi', 'Rasmus Gozzi', 'Lil Gemi', 'SVEA', 'Kids of revolution', 'Alex Järvi', 'Oberg', 'Den svenska björnstammen', 'Helion', 'MishCatt', 'Rymdpojken', 'lovad', 'Maximus', 'Ivory', 'E4an', 'L1NA', '4yye', 'Nikotinhora', 'Oscar Ahlgren', 'Shiro', 'My Marianne', 'Judit', 'Barnens favoriter', 'Jaffar Byn', 'Foster', 'Lear', 'the Hound', 'Føx', 'Andy Panda', 'Endspiel', 'Khanza', 'Dzharo', 'V PRiNCE', 'V $', 'Navai', 'Rauf', 'Faik', '25', 'Wolker', 'Canbay', 'Methaq', 'Raad', '7', '24', 'Vladi', 'Ryan Marciano', 'Sunnery James', 'Bader Al Shaibiii', 'Dj Oopss', 'the Serpent', 'Royal', 'VG', 'Päivän Sankarit', 'Ideaali', 'Jay Who?', 'Artem', 'Yonas', 'Sjöroos', 'Agents', 'Shrty', 'Lili', 'Kilian', 'Jo', 'O', 'Bella', 'Filippa', 'BEK', 'Falk', 'Sonja', 'Lagola', 'Creature', 'Lance', 'Brookz', 'Robbz', 'Karo', 'Parana'])
    toget2=set(['GionnyScandal', 'Mina', 'Briga', 'Max Gazzé', 'Mannarino', 'Sergio Sylvestre', 'Lele', 'Bianca Atzei', 'Lodovica Comello', 'Laïoung', 'MINACELENTANO', 'Nerone', 'Gli Autogol', 'LIBERATO', 'Amedeo Preziosi', 'RIKI', 'Shade', 'Luca Maris', 'Highsnob', 'Cromo', 'Reggie Mills', 'Nitro', 'JUNIOR CALLY', 'Samuel Storm', 'Rita Bellanza', 'Gabriele Esposito', 'Canesecco', 'Biondo', 'Noemi', 'Samuel Heron', 'The Legendary Fruitman', 'G.bit', 'Mihail', 'BADA$$ B.', 'Jesto', 'Nashley', 'Naomi', 'Celestal', 'Jamil', 'Geolier', 'DANDY TURNER', 'NDG', 'Peppe Soks', 'AIELLO', 'Alfa', 'CHA CHA', 'Lele Blade', 'PSICOLOGI', 'Ludwig', 'Madame', 'MACHETE', 'Random', 'Holden', 'Il Tre', 'Daniel', 'Chris Viz', 'FSK SATELLITE', 'Samurai Jay', 'Nuela', 'Paky', 'Cicco Sanchez', 'SNIK', 'Gio Montana', 'TY1', 'Nicola Siciliano', 'Emanuele Aloia', 'COMETE', 'VillaBanks', 'Lous and The Yakuza', 'Sofia Tornambene', 'Anto Paga', 'Neves17', 'Nahaze', 'Tredici Pietro', 'Dat Boi Dee', 'Kidd Keo', 'Oro Bianco', 'Bresh', 'Thelonious B.', 'Dayvi', 'Leon Faun', 'Valerio Mazzei', 'Jayred', 'Giulia Molino', 'Rosa Chemical', 'Astra', '8D Tunes', 'CARA', 'KID VICIOUS', 'ITALIAN ALLSTARS 4 LIFE', 'Vale pain', 'Ivan Granatino', 'GELO', 'Coyote Jo Bastard', 'Vaz Tè', 'Skinny', '167 Gang', 'Nuove Strade', 'Nyv', 'Vale Lambo', 'Silent Bob', 'BLOODY VINYL', 'Rondodasosa', 'Casadilego', 'MYDRAMA', 'Melancholia', 'cmqmartina', 'Vergo', 'Little Pieces of Marmelade', 'Will', 'ARIETE', 'Baby Gang', 'Blue Phelix', 'N.A.I.P.', 'Santi', 'Matteo Romano', 'Paris Boy', 'Lortex', 'MV Killa', 'sangiovanni', 'Chema Rivas', 'FlowRag', 'Tolay', 'Hardjack', 'Art Storm', 'Nightcall', 'Boostee', 'KeBlack', 'Sadek', 'MRC', 'MZ', 'SIYYU', 'Tess', 'Hayce Lemsi', 'Hooss', 'Walid Sevran', 'HEDIA', 'Lorenzo', 'Ateyaba', 'S.Pri Noir', 'Scridge', 'DTF', 'MAI LAN', 'RIDSA', 'Andrelli', 'Greg June', 'BMYE', 'DJ Sem', 'Timal', "Keen' V", 'Amir', 'Eddy de Pretto', 'Doks', 'Dry', 'Lefa', 'Interpreti dello spettacolo "Bella Ciao"', 'DJ Erise', 'Caballero & JeanJass', 'RK', 'La Synesia', 'Hoshi', 'S-Pion', 'KIKESA', 'BRVMSOO', 'Boulevard des Airs', 'Josman', 'Elams', 'Franglish', 'Landy', 'Maesic', 'Juicy P', 'Redbone', 'Frenetics', 'Bolémvn', 'T2R', 'Kaza', 'Lynda', 'Diddi Trix', 'Joé Dwèt Filé', '100 Blaze', 'Souf', 'Hiro', 'Vladimir Cauchemar', 'Squeezie', 'D.A.V', 'Larry', 'OBOY', 'Hös Copperfield', 'Dinor rdt', 'Alkpote', 'Shotas', 'Chily', 'Inoxtag', 'The Faim', 'NKD', 'Kidaki', "N'seven7", 'Tsew The Kid', 'Gato', 'Doums', 'Tayc', 'Laylow', 'SDM', 'Yuzmv', 'Soso Maness', 'Moha K', 'Dubdogz', 'Tibz', 'Hugo Nogam', 'Et demain ? Le collectif', 'Klem Schen', 'Wejdene', 'Sifax', 'HMZ', 'Nakry', 'Benab', 'UZI', 'Jnr Slice', 'Freeze corleone', 'Le Motif', 'Smily', 'Gazo', 'Carbozo', 'Michou', 'Sasso', 'Ronisia', 'Green Montana', 'PRIME', 'GS', 'Alrima', 'Lyna Mahyem', 'Unité', 'Cinco', '1PLIKÉ140', 'JSX', 'Jeune Loup', 'SUPER-Hi', 'Giusy', 'Elettra', 'Polo', 'Pan', 'Moji', 'Sboy'])
    
    toget3=set(['Harnoor', 'Sukima Switch', 'SPITZ', 'J SOUL BROTHERS III', 'balloon', 'GeG', 'DISH//', "SHE'S", 'SANARI', 'Yamazaru', 'negoto', 'QUEEN BEE', 'KIRA', 'POLKADOT STINGRAY', 'PornoGraffitti', 'Panteon Rococo', 'Virlan Garcia', 'Chris Jedi', 'Jd Pantoja', 'ChiChi Peralta', 'Dayvi', 'Carin Leon', 'Nanpa Básico', 'WOS', 'Marca MP', 'DJ Pedro Fuentes', 'Kim Loaiza', 'Sonideros de MEX USA', 'Mike Bahía', 'Flyboiz', 'Leon Leiden', 'Serge', 'Kevin Kaarl', 'Los 2 de la S', 'Luis Angel "El Flaco"', 'Mc Sapao', 'MC Gudan', 'Mc Denny', 'Mc Leléto', 'Dj Henrique de Ferraz', 'DJ Dollynho Da Lapa', 'Mc Brunyn', 'MC Ws', 'MC Mari', 'Dawin', 'SUD', 'Moira Dela Torre', 'Juris', 'Michael Pangilinan', 'Moonstar88', 'Krissy', 'Mark Carpio', 'MYMP', 'Julie Anne San Jose', '6cyclemind', 'Piolo Pascual', 'Hale', 'Bailey May', 'Angeline Quinto', 'Jericho Rosales', 'Inigo Pascual', 'CHANYEOL', 'Crush', 'Kaye Cal', 'Daniel Padilla', 'KZ Tandingan', 'Jake Zyrus', 'Thyro', 'The Juans', 'Parokya Ni Edgar', 'Ex Battalion', 'Ben&Ben', 'Al James', 'Shanti Dope', 'Bosx1ne', 'Karencitta', 'John Roa', 'December Avenue', 'Kyle Juliano', 'Janine Teñoso', 'The Itchyworms', 'Mayonnaise', 'Unique Salonga', 'I Belong to the Zoo', 'Marion Aunor', 'juan karlos', 'Khel Pangilinan', 'This Band', 'Lavaado', 'TJ Monterde', 'PDL', 'ALLMO$T', 'Rivermaya', 'Just Hush', 'Armi Millare', 'Alisson Shore', 'Join The Club', 'Agsunta', 'CLR', 'Pricetagg', 'LeeHi', 'SOMI', 'Donnalyn Bartolome', 'Caleb Santos', 'Arvey', 'Reneé Dominique', 'Psychedelic Boyz', 'King Badger', 'Skusta Clee', 'VVS Collective', 'Magnus Haven', 'Nik Makino', 'Michael Dutchi Libranda', 'Matthaios', 'Evan Rachel Wood', 'Tatak Pinoy All-Stars', 'ZICO', 'NIKI', 'Flow G', 'Emman', 'Jr Crown', 'MC Einstein', 'Justin Vasquez', 'Gaho', 'Danzz', 'Juan Caoile', 'BAEKHYUN', 'Music Hero', 'Tanya Manalang', 'Gian Magdangal', 'Soulthrll', 'Lil Vinceyy', 'HONNE', 'Arthur Nery', 'Ace Banzuelo', 'Alessandra De Rossi', 'Twenty-Nine Eleven', 'SB19', 'Bandang Lapis', 'Jem Macatuno', 'DJ Noiz', 'Rob Deniel', 'Julian Sean', 'Gagong Rapper', 'Joseph Vincent', 'aespa', 'JM Bales', 'Dear Jane', 'Supper Moment', 'Stephanie Ho', 'Charmaine Fong', 'JW', 'Juno Mak', 'Kwan Gor', 'Eric Chou', 'Phil Lam', 'Ruco Chan', '陳以桐', 'JC 陳詠桐', 'Joker Xue', 'Joyce Cheng', 'Shiga Lin', 'Ronald Cheng', 'Endy Chow', 'Eman Lam', 'Dear John', 'Sam Kim', 'Kayee Tam', 'Alfred Hui', 'SOYOU', 'HEIZE', 'AILEE', 'Eddy Kim', 'ToNick', 'Emma Watson', 'Yue Chun Giu', 'HANA', 'G-DRAGON', 'Vincent Wong', 'Hubert Wu', 'LaLa Hsu', 'Apink', 'Yanki Din', 'KARD', 'Feanna Wong', 'SUNMI', '蔡一傑', 'Deep Ng', 'Candy Lo', 'Vivian Koo', 'At17', 'Yoyo Sham', 'Jinny Ng', 'E-Kids', 'Wang Jun Qi', 'Kelly Yu', 'Calvert Fu', '歐陽靖', 'Ron Ng', '(G)I-DLE', 'Tang Siu Hau', 'TWINS', 'Keeva Mak', 'RubberBand', 'BOYZ', 'Louis Koo', 'EXID', 'Kaho Hung', '梁釗峰', 'CLC', '黃齡', 'Ekin Cheng', 'Hebe Tien', 'Shirley Chen', '陳健安', 'Chilam', '湯瑪仕與眾香港人', 'AKMU', '香港人', '高爾宣 OSN', 'JUDE', 'EVERGLOW', 'GFRIEND', '李靖筠', '831', 'Yoon Mirae', 'Yerin Baek', 'Davichi', '10cm', '陳卓賢', 'Wu Bai', 'TomFatKi', 'Killa Ben', 'Leekthough', 'V', 'Eclectic Fuller', 'ismooh', 'WINNER', 'Candre', 'Rowdy860', 'Angela Hui', 'Solar', 'Sita Chan', 'Fouad', 'Agatha', 'FogClawz', '戴祖儀', 'Lil’ Ashes', 'SSAK3', 'Jace Chan', 'Ren Ran', 'Alien Huang', '許光漢', 'REFUND SISTERS', 'Jay Fung', '陳卓賢 Ian', '姜濤', 'Jer 柳應廷', 'Phan Mạnh Quỳnh', 'Đen', 'Hoang Thuy Linh', 'Chillies', 'Sơn Tùng M-TP', 'Bich Phuong', 'Da LAB', 'Ngọt', 'BigDaddy', 'Vu Cat Tuong', 'Noo Phước Thịnh', 'Stephanie Poetri', 'Vũ.', 'Ngô Kiến Huy', 'Tien Tien', 'Mỹ Tâm', 'Truc Nhan', 'Lê Hiếu', 'Nguyễn Trọng Tài', 'Đạt G', 'Lynk Lee', 'Thái Đinh', 'Andiez', 'Nguyen Ha', 'Bùi Lan Hương', 'Đức Phúc', 'Rhymastic', 'MIN', 'Miu Lê', 'Soobin Hoang Son', 'ERIK', 'Binz', 'Phùng Khánh Linh', 'Thịnh Suy', 'Huỳnh Tú', 'Masew', 'JustaTee', 'Trinh Thang Binh', 'Younha', 'HuyR', 'Hien Ho', 'Hoàng Yến Chibi', 'Kimmese', 'Tóc Tiên', 'Orange', 'JUUN D', 'Ngơ', 'Kha', 'Jadu Jadu', 'CHROMANCE', 'TaynguyenSound', 'AMEE', 'T Team', 'Hoài Lâm', 'MANBO', 'Hoang Dung', 'HIEUTHUHAI', '2T', 'Phuong Ly', 'Hồ Ngọc Hà', 'Văn Mai Hương', 'Táo', 'Landon Austin', 'Jack - J97', 'Trung Quan', 'MaziteLo', 'Wean', 'William Laura IiO', 'David Sarah UuI', 'Quân A.P', 'Tlinh', 'CARA', 'TREASURE', 'Độ Mixi', 'Logan Harris', 'RAP VIỆT', 'Thùy Chi', 'Thiều Bảo Trâm', 'Khoi Vu', 'Quang Đăng Trần', 'King Of Rap', 'demxntia', 'MINO', 'Hiền Hồ', 'Lyly', 'Wowy', 'PhucXP', 'hooligan.', 'Emcee L (Da LAB)', 'Andree Right Hand', 'Uyên Linh', 'JGKiD (Da LAB)', '7UPPERCUTS', 'VY Jacko', 'Ha Anh Tuan', '14 Casper', 'Tuấn Hưng', 'Mr T', 'Tố My', 'Khac Viet', 'Hồ Quỳnh Hương', 'Thu Minh', 'Hồ Quang Hiếu', 'Duong Hong Loan', 'Son Tuyen', 'Mỹ Linh', 'Axel Johansson', 'Strange Imagining', 'Cao Thai Son', 'Anh Khang', 'Đông Nhi', 'Samuel Lindon', 'Lê Cát Trọng Lý', 'Enno Aare', 'Bela Nemeth', 'Huong Tram', "Josie O'Connor", 'Akira Phan', 'Quang Huy', 'Duy Khanh', 'Ngoc Dolil', 'Dan Nguyen', 'Nguyen Dinh Vu', 'Xesi', 'Phuong Linh', 'Quynh Trang', 'Hien Thuc', 'YanBi', 'Quoc-Bao', 'Chau Dang Khoa', 'Vo Vinh Du', 'BATE', 'Tim Binker', 'Ung Hoang Phuc', 'Osad', 'SPACESPEAKERS', 'Nhiều người hát', 'Dai Nhan', 'Dinh Huong', 'Tien Cookie', 'K-ICM', 'SEUNGRI', 'Nguyễn Trần Trung Quân', 'Rum', "Girls' Generation-Oh!GG", 'Jasmine Sokko', 'Loco', 'Isaac', 'SEULGI', 'RM', 'Bao Anh', 'TLDK', 'Trong Hieu', 'Jun Phạm', 'Hari Won', 'LyLy', 'Lee So Ra', 'Touliver', 'B Ray', 'Suboi', 'Am Mi', 'Khanh Phuong', 'KANG DANIEL', 'Phát Hồ', 'Thùy Trang', 'Le Mousche', 'Trance Demon', 'True Damage', 'Klasico', 'Alzate', 'Mueka', 'JENCARLOS', 'Kevin Florez', "Billo's", 'Kraken', 'El Gran Martín Elías', 'Ventino', 'Los Corraleros De Majagual', 'Pastor Lopez', 'Fredy Montoya', 'Diomedes Diaz', 'Jessi Uribe', 'Lary Over', 'Andy Rivera', 'Nicolas Mayorca', 'Bomby', 'Sky Rompiendo', 'Juanpis Gonzalez', 'Pacho El Antifeka', 'Legarda', 'Yeison Jimenez', 'Eladio Carrion', 'Luigi 21 Plus', 'Fumaratto', 'Beéle', 'Luis Eduardo Acústico', 'Montano', 'Llane', 'Jhonny Rivera', 'Néstor Zavarce', 'Ovy On The Drums', 'KILATE TESLA', 'Lyanno', 'Nibal', 'Ryan Castro', 'Randy', 'Flow La Movie', 'Otto Serge', 'CHANO', 'Mano Arriba', 'Los Bonnitos', 'Agapornis', 'Pijama Party', '#TocoParaVos', 'LOAN', 'Papichamp', 'aLee DJ', 'CantoParaBailar', 'Marka Akme', 'El Villano', 'Rafaga', 'Los Totora', 'Las Pastillas del Abuelo', 'AX 13', 'Pase Libre', 'Danny Paz', 'El Super Hobby', 'Olvidate!', 'Dame 5', 'Julián Serrano', 'La Reserva', 'VAS', 'DJ Tetraguy', 'Ulises Bueno', 'Oriana', 'De La Calle', 'Los Turros', 'j mena', 'Trap Capos', 'Midel', 'El Apache Ness', 'Zato DJ', 'Ecko', 'Seven Kayne', 'Natalie Perez', 'Iacho', 'Drefquila;Bizarrap', 'Mueva Records', 'Dj Lauuh', 'Interpreti dello spettacolo "Bella Ciao"', 'DJ Cobra Monterrey', 'Turf', 'Cazzu', 'Frijo', 'Kidd Keo', 'Neo Pistea', 'Wolty', 'YSY A', 'Yashua', 'Khea;Omar Varela', 'Numa', 'Coscu', 'Eladio Carrion;Seven Kayne', 'Tobi', 'Luck Ra;Seven Kayne', 'Panter Music', 'Dj Brasil Mix', 'Sander Wazz', 'Agus Padilla', 'Marcianos Crew', 'Rodrigo', 'DJ Alan Gomez', 'Lucho SSJ', 'DJ Alex', 'Los Charros', 'FIESTA!', 'Fer Palacio', 'Pekeño 77', 'Modo Diablo', 'Cazu', 'Axel Caram', 'MDBCrew', '0-600', 'CA7RIEL', 'Bardero$', 'Felp 22', 'Pilar Pascual', 'Acru', 'Alex Rouse', 'Ke Personajes', 'Maffio', 'Chris Viz', 'Dillom', 'Fito Paez', 'Mariah Angeliq', 'John C', 'Oscu', 'Kevo DJ', 'Maria Becerra', 'Los Nota Lokos', 'Mesita', 'Javiielo', 'Airbag', 'El Dipy', 'Rodrigo Tapari', 'Blunted Vato', 'The La Planta', 'Moonkey', 'LiL CaKe', 'La Banda De Lechuga', 'Tiago PZK', 'Bruno Cabrera Dj', 'Los Huayra', 'La Ross Maria', 'El Reja', 'Jeeiph', 'DANI', 'Bebe DJ', 'Papu DJ', 'Rusherking', 'L-Gante', "La K'onga", 'La Delio Valdez', 'Nestor En Bloque', 'Waa Wei', 'Andrew Tan', 'A-Mei Chang', 'Miss Ko', 'Leo王', 'Tia Lee', 'Kenji Wu', 'Diana Wang', 'Maggie Fu', 'Eli Hsieh', 'Starr Chen', '思衛', 'Good Band', 'Sodagreen', 'Ricky Hsiao', 'Naiwen Yang', 'Shadya Lan', 'Van Ness Wu', 'GBOYSWAG', 'Rosie Yang', 'Della', 'Lin Hsin Yi', '姚亦晴', 'Roy Kim', 'Sandrine Pinna', '玖壹壹', 'Kim Kyung Hee', 'JOONIL JUNG', 'Jocie Guo', '李千那', 'Han Suji', 'The Freshman', 'Tangerine Wong', 'Huang Yali', 'Hsiao Hung-Jen', 'Zhong Yu Lin', 'Namewee', 'Xiao Qiu', 'Sticky Rice', '潘裕文', '汪睿', '蔡詩蕓', 'J.Sheon', 'Zhang Bichen', 'MinChen', '張傑', 'Frandé', 'A-do', '吳亦帆', 'Jia Jia', 'Grady Guan', '廖竟淳', 'Cheer Chen', '詹雯婷', 'Hung Pei-Yu', '李崗霖', '「四分衛」樂團主唱阿山', 'Yvonne', 'No Party For Cao Dong', 'Evangeline Wong', 'Guo Ding', 'A Da', 'Hu Xia', 'Ellen Loo', 'Luantan Ascent', 'SISTAR', 'Yisa Yu', 'Fire EX.', 'Dadado Huang', '慢慢說', 'Miu Chu', 'Bae Lin', 'Kelly Pan', 'Jeffrey Kung', 'Maggie Chiang', 'Victor Wong', 'Cyndi Wang', 'LION', 'Abin Fang', 'Nan Quan Mama', 'Cosmos People', 'Penny Tai', 'Koala Liu', '二珂', 'Henry', 'Nicky Lee', 'xumingming', 'Rachel Liang', 'Kumachan', 'SMTOWN', 'Tiger Hu', 'Angela Chang', 'EggPlantEgg', 'Tia Ray', 'Nicholas Teo', 'Outlander', '老王樂隊', '張粹方', 'Under Lover', '韓紅', 'Matzka', '李振源', 'Hyolyn', 'Rose Liu', '蕭秉治', '熊仔 | BOWZ 豹子膽', '陳欣斈', 'WONFU', 'ØZI', 'Bii', 'Julia Wu', '阿信', '宋楚琳', 'Wanfang', 'Kimberley Chen', 'S.H.E.', 'BCW', 'Lara Liang', '柯文哲', 'Quarterback', 'DJ Didilong', '告五人', 'Ann Bai', '頑童Mj116', 'Bisiugroup', 'Gordon', 'Show Luo', 'Yo Lee', '馬念先', '劉芷融', '何夏', '黃莉', '刘人语', '張若凡', 'HAOR', 'Claire Kuo', 'Nine Chen', 'Mary See the Future 先知瑪莉', '张紫豪', 'Shi Shi', '9m88', '鳥屎', 'Pets Tseng', 'Punch', 'Pika Chiu', '音阙诗听', 'Vicky Chen', '盧子杰 James Lu', 'A Si', 'Feng Ze', 'Janice Yan', '理想混蛋', '守夜人', '屁孩 Ryan', 'Kelly Cheng', 'Karencici', 'TANK 呂建忠', '阿冗', '演唱：蘇打綠', '婁峻碩', '黃宣', '阿涵', 'KIM JAE HWAN', 'Song Ga In', 'Marz23', 'April 2nd', '鄧福如 AFÜ', 'Ha Hyun Woo', 'Vivian Hsu', 'Sondia', 'Lee Chan Sol', 'Woosung', 'E.SO', '四堅情WOLF (邱鋒澤、陳零九、黃偉晉、賴晏駒)', '李浩瑋 Howard Lee', '梦然', 'DAY6', '張語噥', 'G22', '林凡', 'BANG YE DAM', '五堅情WOLF(S) (邱鋒澤、陳零九、黃偉晉、賴晏駒、婁峻碩)', '李杰明 W.M.L', '胡66', 'Silence Wang', '江靜 Jiang Jing', 'Gentle Bones', '棉子', 'Ariel Tsai', 'YELLOW黃宣', 'Huang Hong Sheng (Xiao Gui)', 'Boon Hui Lu', '卓文萱', 'LINION', 'Chih Siou', 'Mixer', '九澤CP', '小男孩樂團', '艾薇', 'Don Chu', 'Rain', 'WeiBird', 'SNIK', 'Konstantinos Argyros', 'Padelis Padelidis', 'Sondr', 'Vasilis Dimas', 'The Main Level', 'Rina', 'Mad Clip', 'Fy', 'iLLEOo', 'Sin Boy', 'Nino Xypolitas', 'Hawk', 'TOQUEL', 'Katerine Duska', 'Above The Hood', 'LEX', 'Baghdad', 'Billy Sio', 'Slogan', 'Manos', 'Ypo', 'GODSQUAD', 'Lil Barty', 'Ν.Ο.Ε.', 'VLOSPA', 'Sadam', 'Tus', 'Logos Timis', 'Bloody Hawk', '2J', 'EPITHE', 'Lena Zevgara', 'Pepe Frantik', 'Moose', 'Mef', 'G0YARD', 'Sele', 'Tsaki', 'Thitis', 'Anastasios Rammos', 'DJ Stephan', 'Display', 'Tzamal', 'Long3', 'Liak', 'Dof Twogee', 'Natasa Theodoridou', 'Ivan Greko', 'Kings', 'Lil PoP', 'Spine', 'Mikros Kleftis', 'Kareem Kalokoh', 'Sin Laurent', 'Strat', 'Negros Tou Moria', 'Trannos', 'Lamanif', 'GAB', 'Night Grind', 'Dani Gambino', 'FLY LO', 'Bossikan', 'HGEMONA$', 'GAMEBOY', 'Lil Koni', 'Thug Slime', 'RICTA', 'Immune', 'Anji', 'Rizky Febian', 'Hivi!', 'Payung Teduh', 'Dipha Barus', 'Ten2Five', 'Yura Yunita', 'Young Lex', 'Sheila On 7', 'RAN', 'Monita Tahalea', 'GAC (Gamaliél Audrey Cantika)', 'Andre Hehanussa', 'TheOvertunes', 'Float', 'Peterpan', 'Rivan', 'Mario G klau', 'Pasto', 'Dengarkan Dia', 'Adhitia Sofyan', 'SAMSONS', 'Kerispatih', 'Saxx in the City', "D'Cinnamons", 'Tangga', 'Trisouls', 'Fourtwnty', 'Rendy Pandugo', 'Adera', 'Vadi Akbar', 'Vidi Aldiano', 'Aldy Maldini', 'Sons of People', 'Ecoutez', 'Rayi Putra', 'Cakra Khan', 'Endah N Rhesa', 'Banda Neira', 'Nella Kharisma', 'Hanin Dhiya', 'Weird Genius', 'Marcell', 'Nino', 'Ari Lasso', 'Rossa', 'Virgoun', 'Stars and Rabbit', 'The Panasdalam Bank', 'DOLF', 'Rahmania Astrini', 'Tompi', 'Maudy Ayunda', 'The Legendary Fruitman', 'Tata Janeeta', 'Arsy Widianto', 'Sabyan Gambus', 'Siti Badriah', 'Gloria Jessica', 'Virzha', 'Trio Lestari', 'Marion Jola', 'Sabyan', 'Ben Sihombing', 'Rio Febrian', 'Ardhito Pramono', 'Energy 18', 'Kunto Aji', 'Nadin Amizah', 'Fiersa Besari', 'AVIWKILA', 'Brisia Jodie', 'Near', 'Lalahuta', 'Devano Danendra', 'Wahyu Selow', 'Juicy Luicy', 'Andmesh', '3 Composers', 'Padi', 'Eclat Story', 'Danilla', 'gamaliél', 'Sal Priadi', 'Budi Doremi', 'Langit Sore', 'Reza Artamevia', '.Feast', 'Naif', 'Potret', 'Skinnyfabs', 'Pamungkas', 'Feby Putri', 'NaFF', 'Chintya Gabriella', 'Ilir7', 'L.Y.O.N', 'Hindia', 'Denny Caknan', 'D’MASIV', 'ILUX', 'Mawar De Jongh', 'Mahen', 'The Macarons Project', 'Didi Kempot', 'SALES', 'Nosstress', 'The Panturas', 'Agatha Chelsea', 'Tiara Andini', 'Lyodra', 'Jeff Bernat', 'Diskoria', 'Anna Hamilton', 'Woro Widowati', 'Honey Jemlan', 'Ocan Siagian', 'Alex Porat', 'Happy Asmara', 'Guyon Waton', 'SECRET NUMBER', 'Cherrybelle', 'Ziva Magnolya', 'Arash Buana', 'cinnamons', 'Elmatu', 'BOL4', 'HYO', 'Dialog Senja', 'Alika', 'Kalia Siska', 'Rey Mbayang', 'Jessi', 'DAY6 (Even of Day)', 'Remember of Today', 'Anneth', 'Mahalini', 'Terry', 'Bondan Prakoso', 'Petra Sihombing', 'GANGGA', 'Jung Seung Hwan', 'Ade Govinda', 'Daun Jatuh', 'Idgitaf', 'NCT 2020', 'KAI', 'UrboyTJ', 'Jaonaay', 'Getsunova', 'The Toys', 'Atom Chanakan', 'Violette Wautier', 'Jazz Spooknickpapiyongkookkook', 'Lipta', 'Thaitanium', 'SCRUBB', 'TOR Saksit', 'YOUNGOHM', 'Ploychompoo', 'Potato', 'Cocktail', 'Blue Shade', 'Mint Pattarasaya', 'Mild', 'Songkarn Rangsant', 'Marc Tatchapon', 'BNK48', 'Namm Ronnadet', 'MEAN', 'ลำไย ไหทองคำ', 'The Mousses', 'Singto Numchok', 'KLEAR', 'Buddha Bless', 'Lula', 'PORTRAIT', 'Zeal', 'Boyd Kosiyabong', 'SIN', 'PCHY', '25 hours', 'TAEYANG', 'Sugar Eyes', 'The Others', 'Ton Thanasit', 'Ice Tamonwan', 'Oat Pramote', 'Pang Nakarin', 'Chart Suchart', 'BANKK CA$H', 'เพชร-แตน', 'Stamp', 'Keng Tachaya', 'S.D.F', 'Earth Patravee', 'Non Tanon', 'Palaphol', 'Pun Basher', 'Fymme Bongkot', 'Two Popetorn', 'Season Five', 'Whatcharawale', 'ETC.', 'Ae Jirakorn', "JETSET'ER", 'Paradox', 'Opor Praput', 'Sofa', 'Matteo', 'La Ong Fong', 'Bedroom Audio', 'JBJ', 'Bird Thongchai', 'Wonderframe', 'Clockwork Motionless', 'Gypso Ariigantha', 'Max Jenmana', 'The Parkinson', 'แดน วรเวช', 'D Gerrard', 'Playground', 'Kacha Nontanun', 'Oui', 'Polycat', 'Rose Sirintip', 'Mushroom Hunter', 'MEYOU', 'Oaker', 'Better Weather', 'PILLS', 'The Yers', 'Bell Supol', 'Boy Peacemaker', 'Somkiat', 'Nann', 'Num KALA', 'F.HERO', 'O-Pavee', 'Pete Pol', 'Ice Sarunyu', '60Miles', 'Nan Vatiya', 'เต้ ดาวิชญ์ กรีพลฤกษ์', 'Twopee Southside', 'Pause', 'Poppy ชัชชญา', 'Ornly You', 'ตูน อาทิวราห์', 'Image Suthita', 'Bodyslam', 'Prem', 'P-Hot', 'Folly Rae', 'Earn Piyada', 'Illslick', 'Moving and Cut', 'Atip', 'Gunn Junhavat', 'electric.neon.lamp', 'GENA DESOUZA', 'LOTTE Thakorn', 'PRISTIN V', 'FIIXD', 'Wanna One - Triple Position', 'Wanna One - The Heal', 'คริส พีรวัส', 'Burin Boonvisut', 'Gavin D', 'De Flamingo', 'M YOSS', 'Phum Viphurit', 'IRONBOY', 'Indigo', 'OG-ANIC', 'Ammy The Bottom Blues', 'DABOYWAY', 'Tony Phee', 'JA The Mousses', 'สมอารมณ์', 'Love Potion', 'H.I.N.P (Hot Issue of Ntl. Producers)', 'Stoondio', 'Gtk', 'ACTART', 'CYANIDE', 'Mindset', 'Maiyarap', 'NAP A LEAN', 'KH', 'KS"', 'Slur', 'Rap Against Dictatorship', 'Safeplanet', 'KOB FLAT BOY', 'Younggu', 'Kong Huayrai', 'fellow fellow', 'Sirpoppa', 'Ninja', 'NICECNX', 'THE OLD ISE', 'Silly Fools', 'Chilling Sunday', 'theBOYKOR', 'PARK WOO JIN', 'CHITSWIFT', 'YENTED', 'NINE BY NINE', 'อุ๋ย บุดดาเบลส', 'Namfon Indee', 'BOTCASH', 'Lazyloxy', 'VARINZ', 'นายนะ', 'Rooftop', 'Sun Rai', 'Ben Bizzy', 'LOONA', 'PARK JI HOON', 'NANA', 'Mirrr', 'Wanyai', 'ลิลลี่ ได้หมดถ้าสดชื่น', 'Lomosonic', 'AB6IX', 'BOWKYLION', 'Three Man Down', 'Zommarie', 'DIAMOND MQT', 'p n v .', 'Mon Monik', 'BUMKEY', 'หนามเตย สะแบงบิน', 'DTK BOY BAND', 'CIX', 'GOT U', 'Gene Kasidit', 'TAEYONG', 'เล็ก พงษธร', 'SIXC (6 crazy)', 'PARIS', '2T FLOW', 'Pramote Vilepana', 'YERM', 'Billkin', 'ซันนี่ สุวรรณเมธานนท์', 'Musketeers', 'เขียนไขและวานิช', 'ต้าเหนิง กัญญาวีร์', 'คิงส์ ชนาวิทย์', 'JAOKHUN', 'Tom Isara', 'Anatomy Rabbit', '1MILL', 'AUTTA', 'COLORPiTCH', 'TangBadVoice', 'ALLY', 'JAYLERR', 'Tilly Birds', 'MILLI', 'GUNGUN', 'Bright Vachirawit', 'Instinct', 'slchld', 'RINI', 'Finding Hope', 'keshi', 'QUIN', 'Praw Kanitkul', 'Numcha', 'Pancake', 'Dane Amar', 'WOODZ', 'Morvasu', 'SERIOUS BACON', 'H 3 F', 'Patrickananda', 'Hers', 'First Anuwat', 'CAPTAIN', 'Copter', 'NINEW', 'Jannine Weigel', 'MVL', 'GULF', 'เอ๋ยเอ้ย', 'Pearwah', 'Blackbeans', 'BamBam (GOT7)', 'Finn Askew', 'Natherine Dusita', 'Qler', 'SOYBAD', 'VANGOE', 'Pepe Quintana', 'Bulin 47', 'Crazy Design', 'Kelmitt', 'Nfasis', 'Techy Fatule', 'Ceky Viciny', 'Vicente Garcia', 'Gabriel Pagan', 'Tali', 'El Nene la Amenazzy', 'La Insuperable', 'Goldy Boy', 'Musicologo The Libro', 'Riccie Oriach', 'Shadow Blow', 'Lo Blanquito', 'Salim', 'RMT', 'Rasputin', 'Flow Mafia', 'TYS Musica', 'Redimi2', 'Secreto "El Famoso Biberon"', 'Covi Quintana', 'Alfa Records', 'Milo K', 'Francisco Loría', 'Santana the Golden Boy', 'SHELOW', 'Alajaza', 'Bulova', 'Ceky Vicini', 'Yomel El Meloso', 'Kapuchino', 'Carlos Montesquieu', 'Diamond la Mafia', 'El Tonto', 'RobGz', 'El Fecho RD', 'Los Rivera Destino', 'Omy de Oro', 'Chucky73', 'Rochy RD', 'El Cherry Scom', 'Kiko el Crazy', 'Rochi Errede', 'Urbanda', 'Los Solteroski', 'Grupo Serpiente', 'El Mayor Clasico', 'Dj Scuff', 'Haraca Kiko', 'Sujeto Oro 24', 'Nino Freestyle', 'Yailin la Mas Viral', 'El Boke', 'Tokischa', 'Young Martino', 'Carmen Mena', 'Musica-Musica', 'Medicen R', 'Ghettospm', 'Yan Block', 'Naara', 'Lemons', 'ericka', 'krissy', '陳輝陽', '女聲合唱', 'W', 'Thah Tuyen', 'Che Linh', 'Sus Tesos', 'Poché', 'Lil Silvio', 'Dalmata', 'Su Combo', 'Alexis', 'Fido', 'los Persas', 'Ciro', 'sus Redonditos de Ricota', 'Patricio Rey', 'Kim', 'DA 阿達', '赵方婧', 'Buzz', 'Zoro', 'MALIQ', "D'Essentials", 'Andra', 'The Backbone', 'The Coffee Theory', 'Abdul', '101', 'PRODUCE', 'Yovie', 'Jiew', 'New', 'Urboy TJ', 'Whal', 'STAMP', 'PUNG TUNTEK', 'YAYA', 'มิน พีชญา', 'เบล สุพล', 'Adexe'])
    
    toget=toget1.difference(toget2)
    toget=['METRICKZ', 'Mudi', 'filous', 'Brothers', 'Soulé', 'Cornerstone']
               
    
    print(len(toget))
    #dbs = ['Discogs', 'MusicBrainz', 'LastFM']
    dbs = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
    dbs = ['Discogs', 'MusicBrainz', 'LastFM']
    #dbs = ['MusicBrainz']
    #dbs = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
    #dbs = ['Discogs', 'AllMusic']
    dbs = ["AllMusic", "MusicBrainz", "Discogs"]
    dbs = ["Deezer", "LastFM"]
    #dbs = ["Discogs", "MusicBrainz"]
    #dbs = ["AllMusic"]
    #dbs = ["AllMusic", "MusicBrainz", "Discogs", "LastFM"]
    #dbs = ["Discogs", "MusicBrainz"]
    #dbs = ["MusicBrainz"]

    
    ### Deezer
    for i,artist in enumerate(toget):
        print("\n\n\n\n")
        print("="*50,artist,' ({0}/{1})'.format(i,len(toget)),"="*50)

        dbAP = dbArtistsDeezer()
        try:
            dbAP.searchForArtist(artist,force=False,maxArtists=2,debug=True)
        except:
            pass
        sleep(1.5)

        
        
    
    ### AlbumOfTheYear
    for i,artist in enumerate(toget):
        print("\n\n\n\n")
        print("="*50,artist,' ({0}/{1})'.format(i,len(toget)),"="*50)
        dbAP = dbArtistsAlbumOfTheYear()
        try:
            dbAP.searchForArtist(artist,force=False,maxArtists=2,debug=True)
        except:
            pass
        sleep(1.5)
        
        
    ### LastFM
    for i,artist in enumerate(toget):
        print("\n\n\n\n")
        print("="*50,artist,' ({0}/{1})'.format(i,len(toget)),"="*50)
        dbAP = dbArtistsLastFM()
        try:
            dbAP.searchForArtist(artist,force=False,maxArtists=2,debug=True)
        except:
            pass
        sleep(1.5)
        
    
    ### Discogs
    for i,artist in enumerate(toget):
        print("\n\n\n\n")
        print("="*50,artist,' ({0}/{1})'.format(i,len(toget)),"="*50)
        dbAP = dbArtistsDiscogs()
        try:
            dbAP.searchForArtist(artist,force=False,maxArtists=20,debug=True)
        except:
            pass
        sleep(1.5)
        
        
    ### MusicBrainz
    for i,artist in enumerate(toget):
        print("\n\n\n\n")
        print("="*50,artist,' ({0}/{1})'.format(i,len(toget)),"="*50)
        dbAP = dbArtistsMusicBrainz()
        try:
            dbAP.searchForArtist(artist,force=False,maxArtists=20,debug=True)
        except:
            pass
        sleep(1.5)
        
        
    ### AllMusic
    for i,artist in enumerate(toget):
        print("\n\n\n\n")
        print("="*50,artist,' ({0}/{1})'.format(i,len(toget)),"="*50)
        dbAP = dbArtistsAllMusic()
        try:
            dbAP.searchForArtist(artist,force=False,maxArtists=20,debug=True)
        except:
            pass
        sleep(1.5)
        
        
        
    if False:

        maindb = mainDB(mdb=None, create=True, debug=True)
        pdb = parseDBArtistsData(maindb=maindb)


        from time import sleep
        maxI = -1
        for db in dbs:        
            print(db)
            noMatches = toget
            #noMatches = toget
            #noMatches = toget.get(db)
            if noMatches is None:
                continue
            for i,artist in enumerate(noMatches):
                print("="*100)
                print("="*100)
                print(i,'/',len(noMatches),'\t',artist)
                print("="*100)
                print(i,'/',len(noMatches),'\t',artist,'===>',db)
                try:
                    maindb.dbdata[db]["Artists"].searchForArtist(artist, force=False, maxArtists=1,debug=True)
                except:
                    sleep(10)
# Out:
# 6
#
#
#
#
#
# ================================================== METRICKZ  (0/6) ==================================================
# =========================   deezer   =========================
#
#
# ===================== Searching For METRICKZ =====================
# 1 / 4 	: 249599 	 Jason Derulo 	 /Volumes/Piggy/Discog/artists-deezer/99/249599.p
# 2 / 4 	: 5592916 	 Metrickz 	 /Volumes/Piggy/Discog/artists-deezer/16/5592916.p
#
#
#
#
#
# ================================================== Mudi  (1/6) ==================================================
# =========================   deezer   =========================
#
#
# ===================== Searching For Mudi =====================
# 1 / 20 	: 5867324 	 Mudi 	 /Volumes/Piggy/Discog/artists-deezer/24/5867324.p
# 2 / 20 	: 107041552 	 Mudi 	 /Volumes/Piggy/Discog/artists-deezer/52/107041552.p
#
#
#
#
#
# ================================================== filous  (2/6) ==================================================
# ...

# %% [markdown]
# # Download Credit (AllMusic)

# %%
data = getFile("creditToDownload.p")
len(data)

# %%
for artistID,artist in data.items():
    break
    maindb.dbdata["AllMusic"]["Artists"].searchForArtistCredit(artist, artistID)

# %% [markdown]
# # Download Extra Data

# %%
bsdata = getHTML("/Volumes/Piggy/Discog/artists-musicbrainz/13/134347080492261077195869941664563052313.p")
pages  = bsdata.find("ul", {"class": "pagination"})
lis    = pages.findAll("li")
txts   = [li.text for li in lis]
npages = 0
for item in txts:
    try:
        npages = max([npages, int(item)])
    except:
        continue
npages

# %%
 = dbdata["MusicBrainz"]["Artists"].getData('314779112728565924209805500016231841915')

# %%
#dbdata["LastFM"]["Artists"].assertDBModValExtraData(15, test=False)

# %%
for modVal in range(100):
    dbdata["MusicBrainz"]["Artists"].assertDBModValExtraData(str(modVal), test=False, maxPages=20)

# %%
from random import randint, shuffle
modVals = list(range(100))
shuffle(modVals)
for modVal in modVals:
    dbdata["MusicBrainz"]["Artists"].assertDBModValExtraData(modVal, test=False, maxPages=2)

# %%
from random import randint, shuffle
modVals = list(range(100))
shuffle(modVals)
for modVal in modVals:
    break
    dbdata["LastFM"]["Artists"].assertDBModValExtraData(modVal, test=False, maxPages=20)

# %% [markdown]
# # Download Artist Data

# %%
artsDC.downloadArtistUnofficialFromID(144998)

# %%
maindb.getBasicArtistInfo("Black Sabbath")

# %%
dbdata["Discogs"]["Artists"].downloadArtistUnofficialFromID('144998', '/artist/144998-Black-Sabbath')
#/artist/144998-Black-Sabbath?type=Unofficial&subtype=Albums&filter_anv=0"
#/artist/144998-Black-Sabbath?sort=year%2Casc&limit=500&type=Unofficial&subtype=Albums&filter_anv=0&page=1

# %%
retval = dbdata["Discogs"]["Artist"].getData("/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p")

# %%
bsdata = getHTML("/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p")

# %%
retval.get()

# %%
retval.get()['artist'].get()

# %% [markdown]
# # Music DB

# %%
https://www.discogs.com/artist/144998-Black-Sabbath?sort=year%2Casc&limit=500?type=Unofficial&subtype=Albums&filter_anv=0
https://www.discogs.com/artist/144998-Black-Sabbath?sort=year%2Casc&limit=500&type=Unofficial&subtype=Albums&filter_anv=0&page=1
    
artistIDToRef = disc.getArtistIDToRefData()

# %%
myMusicAlbumIDMap = getFile("/Users/tgadfort/Documents/code/music/musicDiscogsMap.p")

# %%
dR=0.2
rC=0.8

# %%
from time import sleep
N = len(myMusicAlbumIDMap)
for i,(artistName,artistVals) in enumerate(myMusicAlbumIDMap.items()):
    if artistName.startswith("Levl") is False:
        continue
    artistID,discogsName = artistVals
    print(i,N,'\t',artistName)
    artsDC.searchDiscogForArtist(artistName)
    artsAM.searchAllMusicForArtist(artistName)
    artsMB.searchMusicBrainzForArtist(artistName)
    sleep(3)

# %%
artistIDs = [v[0] for k,v in myMusicAlbumIDMap.items()]
arts.rmIDsFromDBs(artistIDs)

# %%
arts.parseArtistModValFiles(96, force=False)
arts.parseArtistModValExtraFiles(96)

# %%
files = [savename]
from glob import glob
from os.path import join
from fileUtils import getDirname
files += glob(join(getDirname(savename), "extra", "{0}-*.p".format(artistID)))
files

# %% [markdown]
# # Download Missing Artists

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
from discogsBase import discogs

disc  = discogs()
albs  = albums(disc)
toget = albs.findMissingArtistsFromAlbums()

from ioUtils import saveFile
saveFile(idata=toget, ifile="missingArtistsFromAlbums.p")

# %%
# %load_ext autoreload
# %autoreload
disc = discogs()
arts = artists(disc)

from ioUtils import getFile

toget = getFile(ifile="missingArtistsFromAlbums.p")

from time import sleep
togetmap  = toget['togetmap']
refstoget = toget['toget']
for ia,item in enumerate(refstoget.most_common()):
    artistID, cnt = item[0], item[1]
    ref      = togetmap[artistID]
    url      = arts.getArtistURL(ref)
    savename = arts.getArtistSavename(artistID)
    if not isFile(savename):
        try:
            print('\n{0}/{1}'.format(ia,len(refstoget)))
            retval = arts.downloadArtistURL(url, savename, debug=True)
            sleep(3)
        except:
            continue
    else:
        print("{0} known".format(savename))
            
    #print(item)
#len(togetmap)

# %% [markdown]
# # Redownload Known Artist

# %%
myMusicMap = getFile("/Users/tgadfort/Documents/code/music/myMusicMap.p")

# %%
musicMap = myMusicMap["Ladies of Soul"]
musicMap

# %%
discDCIDToRef = discDC.getArtistIDToRefData()

# %%
artistID  = musicMap['Discogs']['ID']
artistRef = discDCIDToRef.get(artistID)
artsDC.downloadArtistFromID(artistID=artistID, artistRef=artistRef, force=True)

# %% [markdown]
# # Download Unmatched Artists

# %%
matchedResults = getFile("/Users/tgadfort/Documents/code/music/multiArtists.p")

# %%
searchForArtist = {"Discogs": artsDC.searchDiscogForArtist, "AllMusic": artsAM.searchAllMusicForArtist, "MusicBrainz": artsMB.searchMusicBrainzForArtist}

# %%
from time import sleep
for i,(artistName,artistValues) in enumerate(matchedResults["PartiallyUnknown"].items()):
    if i <= 83:
        continue
    print("=========== {0} [{1}/{2}] ===========".format(artistName, i, len(matchedResults["PartiallyUnknown"])))
    for dbKey, dirval in artistValues.items():
        print(artistName,'\t',searchForArtist[dbKey])
        searchForArtist[dbKey](artistName)
        sleep(1)
    sleep(1)

# %% [markdown]
# # Missing Artists From Albums

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
from discogsBase import discogs

disc  = discogs()
albs  = albums(disc)
toget = albs.findMissingArtistsFromAlbums()

# %%
# %load_ext autoreload
# %autoreload
disc = discogs()
arts = artists(disc)

from time import sleep
togetmap  = toget['togetmap']
refstoget = toget['toget']
for ia,item in enumerate(refstoget.most_common()):
    artistID, cnt = item[0], item[1]
    ref      = togetmap[artistID]
    url      = arts.getArtistURL(ref)
    savename = arts.getArtistSavename(artistID)
    if not isFile(savename):
        try:
            _, _ = clock('\n{0}/{1}'.format(ia,len(refstoget)))
            retval = arts.downloadArtistURL(url, savename, debug=True)
        except:
            continue
    else:
        print("{0} known".format(savename))
            
    #print(item)
#len(togetmap)

# %% [markdown]
# # Artists From Search

# %%
# %load_ext autoreload
# %autoreload
disc = discogs()
arts = artists(disc)
arts.searchDiscogForArtist("World of Our Own")
#arts.searchDiscogForArtist("Continental Divide")

# %%
from ioUtils import getFile

# %%
toGet = getFile(ifile="/Users/tgadfort/Documents/code/charts/chartCounter.p", debug=True)

# %%
toGet = getFile("~/code/charts/toget.p")

# %%
for i,val in enumerate(toGet):
    if i <= 206:
        continue
    print('='*30,val,'(',i,'/',len(toGet),')','='*30)
    arts.searchDiscogForArtist(val)
    print("\n\n\n")
    sleep(2)

# %%
from time import sleep
vals  = ["The Souvenirs", "The Stand", f"The Suicide Kings", "The Supremes", "The Temptations", "The Tomcats", "The Tone", "The Tourists", "The Unseen", "The Ventures", "The Vikings", "The Violents", "The Wailers", "The Want", "The Washingtonians", "The Witches", "UB40", "Underdog", "Unearth", "Unk", "Unscarred", "Up Front", "Up In Arms", "Urban Legends"]
vals += ["The Pits", "The Pressure", "The Pretenders", "The Prodigy", "The Product", "The Receptionists", "The Retardos", "The Revelers", "The Romancers", "The Roots", "The Rosehips", "The Ruiners", "The Runaways", "The Scholars", "The Seeds", "The Shams", "The Sights", "The Sillies", "The Skunks", "The Snowmen"]
vals += ["The Invisible Men", "The Israelites", "The Ivory Coast", "The Killers", "The Manatees", "The Marquees", "The Masters", "The Matrix", "The Mixtures", "The Moves", "The Noisettes", "The Nomads", "The Orange Peels", "The Outcasts"]
vals += ["The Game", "The Generics", "The Gits", "The Go-Betweens", "The Goblins", "The Godz", "The Great Society", "The Haters", "The Hilltops", "The Hookers", "The Immortals", "The Impacts", "The Inspector", "The Invaders"]
vals += ["The Diamonds", "The Diplomats", "The Dramatics", "The Drifters", "The Dust Brothers", "The Eagles", "The Exceptions", "The Fiends", "The Fixtures", "The Frantics", "The Freeze", "The Frogs", "The Fumes"]
vals += ["The Cardigans", "The Casualties", "The Challengers", "The Chameleons", "The Cheaters", "The Chicken Hawks", "The Crash", "The Crusaders", "The Cure", "The Darts", "The Deuce Coupes"]
vals += ["The Beat", "The Beatles", "The Blood Brothers", "The Blow Up", "The Bollweevils", "The Brentwoods", "The Broadways", "The Brood", "The Business", "The Busy Signals"]
vals += ["You", "Young Money", "Young Pioneers", "Zero Zero"]
for val in vals:
    print('='*30,val,'='*30)
    try:
        arts.searchDiscogForArtist(val)
    except:
        continue
    print("\n\n\n")
    sleep(10)

# %% [markdown]
# # New Artists From Albums

# %%
# %load_ext autoreload
# %autoreload
from albums import albums

disc = discogs()
albs = albums(disc)
toget = albs.findMissingArtistsFromAlbums()

# %%
from time import sleep
togetmap  = toget['togetmap']
refstoget = toget['toget']
for ia,item in enumerate(refstoget.most_common()):
    print('\n{0}/{1}'.format(ia,len(refstoget)))
    artistID, cnt = item[0], item[1]
    ref      = togetmap[artistID]
    url      = arts.getArtistURL(ref)
    savename = arts.getArtistSavename(artistID)
    if not isFile(savename):
        try:
            arts.downloadArtistURL(url, savename, debug=True)
        except:
            continue
        sleep(2)
    #print(item)
#len(togetmap)

# %% [markdown]
# # Albums From Known People

# %%
data = getFile("/Volumes/Music/MusicDB/toget.p")

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
disc = discogs()
discdf = disc.getMasterDiscogsDB()
print(discdf.shape)
discdf = discdf[~discdf['Name'].isna()]
print(discdf.shape)

artists = list(discdf["Artist"])

_ = clock("Last Run")

# %%
def getMusicData(key, artist):
    retval = discdf[discdf[key] == artist]
    if retval.shape[0] > 0:
        return retval
    else:
        return None
    
toget={}
known={}

for ia,artistName in enumerate(data):
    #artistID = artistName
    artistID = None
    if artistID is None:
        retval = getMusicData('Name', artistName)
        if retval is not None:
            artistID = retval.index.values[0]
    modValue  = dutils.getDiscIDHashMod(discID=artistID, modval=disc.getMaxModVal())
    if toget.get(modValue) is None:
        toget[modValue] = {}
    toget[modValue][artistID] = True
        
    if ia % 100 == 0:
        print(ia,'/',len(data))

# %%
for modVal in toget.keys():
    artistIDs = toget[modVal]
    print(modVal,'\t',len(artistIDs))
    dbdata = disc.getArtistsDBModValData(modVal)
    for artistID in artistIDs:
        print(' ',artistID)
        artistData = dbdata[artistID]
        albs.downloadAlbumFromArtistData(artistID=artistID, artistData=artistData, mediaTypes=None)

# %% [markdown]
# # Albums From All Artists

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
disc = discogs()
albs = albums(disc)
albs.downloadAlbumsFromArtists(maxAlbums=1, mediaTypes=None, rand=True)

# %%
maindb = mainDB(mdb=mdb, create=False)
#maindb.setDBFull() ## Do this to recreate everything
maindb.setDBKnown()
artistDBs = maindb.getKnownArtistDBs()

# %% [markdown]
# # Discogs

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsDiscogs import dbArtistsDiscogs
ad = dbArtistsDiscogs(debug=True)
#ad.searchForArtist("Dave Matthews")
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/70/420570.p"
ifile="/Users/tgadfort/Music/Discog/artists-discogs/34/386834.p"
retval = ad.getData(ifile)
print(retval.get()['artist'].get())
#ad.searchForArtist("Niel Diamond")

# %% [markdown]
# # AllMusic

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsAllMusic import dbArtistsAllMusic
am = dbArtistsAllMusic(debug=True)
#am.searchForArtist("Dave Matthews")
ifile="/Users/tgadfort/Music/Discog/artists-allmusic/61/0000687561.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/70/420570.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/34/386834.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # MusicBrainz

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsMusicBrainz import dbArtistsMusicBrainz
am = dbArtistsMusicBrainz(debug=True)
#am.searchForArtist("Dave Matthews")
ifile="/Users/tgadfort/Music/Discog/artists-musicbrainz/71/100112022548628725831976514629370881371.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # LastFM

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsLastFM import dbArtistsLastFM
am = dbArtistsLastFM(debug=True)
#am.searchForArtist("Dave Matthews Band")
ifile="/Users/tgadfort/Music/Discog/artists-lastfm/14/64101467014.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # RockCorner

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsRockCorner import dbArtistsRockCorner
am = dbArtistsRockCorner(debug=True)
#am.searchForArtist("Dave Matthews Band")
ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # RateYourMusic

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsRockCorner import dbArtistsRockCorner
am = dbArtistsRockCorner(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # CDandLP

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsCDandLP import dbArtistsCDandLP
am = dbArtistsCDandLP(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # AceBootlegs

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsAceBootlegs import dbArtistsAceBootlegs
am = dbArtistsAceBootlegs(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # DatPiff

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsDatPiff import dbArtistsDatPiff
am = dbArtistsDatPiff(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # MusicStack

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsMusicStack import dbArtistsMusicStack
am = dbArtistsMusicStack(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %%
ad = artistsDiscogs(debug=True)

# %%
ad = artistsDiscogs(debug=True)
ifile="/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p"
retval = ad.getData(ifile)
retval.get()['artist'].get()
ad.searchForArtist("Niel Diamond")

# %%
retval = ad.getData(ifile)
retval.get()['artist'].get()

# %%
ad.searchForArtist("Niel Diamond")

# %%
from artistAM import artistAM
from discogsUtils import allmusicUtils

class artistsAllMusic(artistsBase):
    def __init__(self, debug=False):
        self.db     = "AllMusic"
        self.disc   = discogs(self.db.lower())
        self.artist = artistAM(self.disc)
        self.dutils = allmusicUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        url = "{0}/discography/all".format(artistRef)
        return url
        
        if artistRef.startswith("http"):
            return artistRef
        else:
            baseURL = self.disc.discogURL
            url     = urllib.parse.urljoin(baseURL, quote(artistRef))
            return url

            
        if artistRef.startswith("/artist/") is False:
            print("Artist Ref needs to start with /artist/")
            return None
        
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, quote(artistRef))
        url     = urllib.parse.urljoin(url, "?sort=year%2Casc&limit=500") ## Make sure we get 500 entries)
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("artists/", quote(artist)))
                  
                    
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}
        
        uls = bsdata.findAll("ul", {"class": "search-results"})
        for ul in uls:
            lis = ul.findAll("li", {"class": "artist"})
            for li in lis:
                divs = li.findAll("div", {"class": "name"})
                for div in divs:
                    link     = div.find("a")
                    href     = link.attrs['href']
                    tooltip  = link.attrs['data-tooltip']
                    try:
                        from json import loads
                        tooltip = loads(tooltip)
                        artistID = tooltip['id']
                    except:
                        artistID = None
            
                    if artistDB.get(href) is None:
                        artistDB[href] = {"N": 0, "Name": artist}
                    artistDB[href]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1
        
            discID   = self.dutils.getArtistID(href)
            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
am = artistsAllMusic(debug=True)
#am.searchForArtist("Niel Diamond")

# %%
from artistMB import artistMB
from discogsUtils import musicbrainzUtils
from hashlib import md5

class artistsMusicBrainz(artistsBase):
    def __init__(self, debug=False):
        self.db     = "MusicBrainz"
        self.disc   = discogs(self.db.lower())
        self.artist = artistMB(self.disc)
        self.dutils = musicbrainzUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = "https://musicbrainz.org/"
        extra = "search?query={0}&type=artist&limit=100&method=indexed".format(quote(artist))

        url = urllib.parse.urljoin(baseURL, extra)         
                    
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}

        tables = bsdata.findAll("table")
        for table in tables:
            ths = table.findAll("th")
            headers = [x.text for x in ths]
            trs = table.findAll("tr")
            for tr in trs[1:]:
                tds    = tr.findAll("td")
                name   = tds[0].find('a').text
                href   = tds[0].find('a').attrs['href']
            
                if artistDB.get(href) is None:
                    artistDB[href] = {"N": 0, "Name": name}
                artistDB[href]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1

            discID   = self.dutils.getArtistID(href)
            
            uuid = href.split('/')[-1]

            m = md5()
            for val in uuid.split("-"):
                m.update(val.encode('utf-8'))
            hashval = m.hexdigest()
            discID  = str(int(hashval, 16))

            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
am = artistsMusicBrainz(debug=True)
#am.searchForArtist("Niel Diamond")

# %%
from artistLM import artistLM
from discogsUtils import lastfmUtils

class artistsLastFM(artistsBase):
    def __init__(self, debug=False):
        self.db     = "LastFM"
        self.disc   = discogs(self.db.lower())
        self.artist = artistLM(self.disc)
        self.dutils = lastfmUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        #print("getArtistURL(",artistRef,")")
        if artistRef.startswith("http"):
            url = artistRef
        else:
            baseURL = self.disc.discogURL
            if artistRef.startswith("/") is True:
                #print("Join", end="\t")
                url     = urllib.parse.urljoin(baseURL, quote(artistRef[1:]))
                #print(url)
            else:
                url     = urllib.parse.urljoin(baseURL, quote(artistRef))
            #print(url)
                
            if url.endswith("/") is False:
                url     = "{0}{1}".format(url, "/+albums?order=release_date")
            else:
                url     = "{0}{1}".format(url, "+albums?order=release_date")
                
            #print(url)
        
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("artists?q=", quote(artist)))
                    
            
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}
        
        uls = bsdata.findAll("ul", {"class": "artist-results"})
        for ul in uls:
            lis = ul.findAll("li", {"class": "artist-result"})
            for li in lis:
                h4 = li.find("h4")
                if h4 is None:
                    raise ValueError("No h4 in list")
                ref = h4.find('a')
                if ref is None:
                    raise ValueError("No ref in h4")

                name = ref.attrs['title']
                url  = ref.attrs['href']
                artistID = self.dutils.getArtistID(name)
        
                #print(name,'\t',url,'\t',artistID)
                if artistDB.get(url) is None:
                    artistDB[url] = {"N": 0, "Name": name}
                artistDB[url]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1
        
            name     = hrefData["Name"]
            discID   = self.dutils.getArtistID(name)
            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)
                
    
    def assertDBModValExtraData(self, modVal, maxPages=None):
        mulArts             = multiartist()        
        
        print("assertDBModValExtraData(",modVal,")")
        artistDBDir = self.disc.getArtistsDBDir()
        dbname  = setFile(artistDBDir, "{0}-DB.p".format(modVal))     
        dbdata  = getFile(dbname)
        nerrs = 0
        
        for artistID,artistData in dbdata.items():
            pages = artistData.pages
            if pages.more is True:
                npages = pages.tot
                if maxPages is not None:
                    npages = min([npages, maxPages])
                artistRef = artistData.url.url
                print(artistID,'\t',artistData.artist.name)
                multiValues = mulArts.getArtistNames(artistData.artist.name)
                if len(multiValues) > 1:
                    print("\tNot downloading multis: {0}".format(multiValues.keys()))
                    continue
                for p in range(2, npages+1):
                    url      = self.getArtistURL(artistRef, p)
                    savename = self.getArtistSavename(artistID, p)
                    print(artistID,'\t',url,'\t',savename)
                    if not isFile(savename):
                        self.downloadArtistURL(url=url, savename=savename, force=True, debug=True)
                        sleep(3)

# %%
al = artistsLastFM(debug=True)

# %%
#al.searchForArtist("Neil Diamond")

# %%
from artistRC import artistRC
from discogsUtils import rockcornerUtils

class artistsRockCorner(artistsBase):
    def __init__(self, debug=False):
        self.db     = "RockCorner"
        self.disc   = discogs(self.db.lower())
        self.artist = artistRC(self.disc)
        self.dutils = rockcornerUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        if artistRef.startswith("http"):
            url = artistRef
        else:
            baseURL = self.disc.discogURL
            if artistRef.startswith("/") is True:
                #print("Join", end="\t")
                url     = urllib.parse.urljoin(baseURL, quote(artistRef[1:]))
                #print(url)
            else:
                url     = urllib.parse.urljoin(baseURL, quote(artistRef))
                        
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):

        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("search?q=", quote(artist)))
                    

        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}

        songs = bsdata.findAll("article", {"class": "bgl0"}) + bsdata.findAll("article", {"class": "bgl1"})
        for i,song in enumerate(songs):
            label     = song.find("label")
            if label is None:
                continue
            name      = label.text
            ref       = song.find("a").attrs['href']
            artistURL = "/".join(ref.split("/")[:2])

            #print(name,'\t',url,'\t',artistID)
            if artistDB.get(artistURL) is None:
                artistDB[artistURL] = {"N": 0, "Name": name}
            artistDB[artistURL]["N"] += 1


        if self.debug:
            print("Found {0} artists".format(len(artistDB)))

        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1

            name     = hrefData["Name"]
            discID   = self.dutils.getArtistID(name)
            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
ar = artistsRockCorner(debug=True)

# %%
#ar.searchForArtist("Neil Diamond")

# %%
from artistRM import artistRM
from discogsUtils import rateyourmusicUtils

class artistsRateYourMusic(artistsBase):
    def __init__(self, debug=False):
        self.db     = "RateYourMusic"
        self.disc   = discogs(self.db.lower())
        self.artist = artistRM(self.disc)
        self.dutils = rateyourmusicUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        return

# %%
am = artistsRateYourMusic(debug=True)

# %%
from artistCL import artistCL
from discogsUtils import cdandlpUtils

class artistsCDandLP(artistsBase):
    def __init__(self, debug=False):
        self.db     = "CDandLP"
        self.disc   = discogs(self.db.lower())
        self.artist = artistCL(self.disc)
        self.dutils = cdandlpUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        #print("getArtistURL(",artistRef,")")
        if artistRef.startswith("http"):
            url = artistRef
        else:
            baseURL = self.disc.discogURL
            if artistRef.startswith("/") is True:
                #print("Join", end="\t")
                url     = urllib.parse.urljoin(baseURL, quote(artistRef[1:]))
                #print(url)
            else:
                url     = urllib.parse.urljoin(baseURL, quote(artistRef))
        
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("?q=", quote(artist)))


        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}
        
        descrs = bsdata.findAll("div", {"class": "listingDescription"})
        for descr in descrs:
            refs = descr.findAll("a", {"class": "listingTitle"})
            for ref in refs:
                url      = ref.attrs['href']
                fullurl  = "/".join(url.split("/")[:-4])
                fullurl  = "{0}/artist".format(fullurl)
                artistID = self.dutils.getArtistID(fullurl)
                if artistDB.get(fullurl) is None:
                    artistDB[fullurl] = {"N": 0, "ID": artistID}
                artistDB[fullurl]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1
        
            discID   = hrefData["ID"]
            url      = href
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url,'\t',savename)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
ac = artistsCDandLP(debug=True)

# %%
#ac.searchForArtist("Neil Diamond")

# %%
from artistCL import artistCL
from discogsUtils import acebootlegsUtils

class artistsAceBootlegs(artistsBase):
    def __init__(self, debug=False):
        self.db     = "AceBootlegs"
        self.disc   = discogs(self.db.lower())
        self.artist = artistAB(self.disc)
        self.dutils = acebootlegsUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url
    
    def getMainSavename(self):
        artistDir = self.disc.getArtistsDir()
        savename  = setFile(artistDir, "main.p")
        return savename
    
    
    ##################################################################################################################
    # Main
    ##################################################################################################################
    def downloadMainArtists(self, force=False, debug=False, sleeptime=2):        
        savename = self.getMainSavename()
        
        ## Parse data
        bsdata = getHTML(savename)        
        artistDB  = {}
        
        
        ## Find and Download Artists
        categories = bsdata.find("div", {"class": "sidebar-widget widget_categories"})
        if categories is None:
            raise ValueError("Cannot find categories!")
        uls = categories.findAll("ul")
        for ul in uls:
            lis = ul.findAll("li")
            for i, li in enumerate(lis):
                try:
                    catitem = li.attrs["class"][1]
                except:
                    raise ValueError("Cannot find list class item: {0}".format(li))
                ref  = li.find("a")
                if ref is None:
                    raise ValueError("Cannot find list link!")
                try:
                    href = ref.attrs['href']
                except:
                    raise ValueError("Cannot find list href!")

                # check for artist
                artistName = href.split('/')[-2]
                try:
                    int(artistName)
                    continue
                except:
                    if artistName.find("parent-category-ii") == -1:
                        pass
                    else:
                        continue

                # get artist ID
                artistID = catitem.split('-')[-1]
                try:
                    int(artistID)
                except:
                    continue


                if force is False and isFile(savename):
                    print("{0} exists.".format(savename))
                    continue
            
                url = href
                savename = self.getArtistSavename(artistID)
                print(i,'\t',artistID,'\t',artistName,'\t',savename)
                self.downloadArtistURL(url=url, savename=savename, parse=False)

                
        
        

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        return

# %%
aa = artistsAceBootlegs(debug=True)

# %%
from artistDP import artistDP
from discogsUtils import datpiffUtils

class artistsDatPiff(artistsBase):
    def __init__(self, debug=False):
        self.db     = "DatPiff"
        self.disc   = discogs(self.db.lower())
        self.artist = artistDP(self.disc)
        self.dutils = datpiffUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url
    

    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        
        baseURL = "https://www.datpiff.com/"
        extra   = "mixtapes-search?criteria={0}&sort=relevance".format(quote(artist))

        url = urllib.parse.urljoin(baseURL, extra)
        print("\tSearch URL: {0}".format(url))
                    
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = []

        contentdivs = bsdata.findAll("div", {"class": "contentItem"})
        for i,contentdiv in enumerate(contentdivs):
            artistDiv = contentdiv.find("div", {"class": "artist"})
            if artistDiv is None:
                continue
            artistName = artistDiv.text

            albumDiv = contentdiv.find("div", {"class": "title"})
            if albumDiv is None:
                continue
            albumName = albumDiv.text
            try:
                albumURL  = albumDiv.find("a").attrs['href']
            except:
                albumURL  = None
                
            #artistID = self.discogsUtils.getArtistID(artistName)

            artistDB.append({"ArtistName": artistName, "AlbumName": albumName, "AlbumURL": albumURL})
        

        artistID = self.discogsUtils.getArtistID(artist)
        page     = 1
        savename = self.getArtistSavename(artistID, page)
        while isFile(savename):
            page += 1
            savename = self.getArtistSavename(artistID, page)
        print("Saving {0} new artist media to {1}".format(len(artistDB), savename))
        saveJoblib(data=artistDB, filename=savename, compress=True)

# %%
ad = artistsDatPiff(debug=True)

# %%
from artistMS import artistMS
from discogsUtils import musicstackUtils
from searchUtils import findPatternExt
from fileUtils import getBaseFilename


class artistsMusicStack(artistsBase):
    def __init__(self, debug=False):
        self.db     = "MusicStack"
        self.disc   = discogs(self.db.lower())
        self.artist = artistMS(self.disc)
        self.dutils = musicstackUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url
    

    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist=None):
        files = findPatternExt("/Users/tgadfort/Downloads/", pattern="MusicStack", ext=".html")
        for ifile in files:
            fname  = getBaseFilename(ifile)
            artist = fname[:fname.find(" Vinyl Records")]
            self.parseSearchForArtist(artist=artist, ifile=ifile)
    
    def parseSearchForArtist(self, artist, ifile):

        ## Parse data
        bsdata = getHTML(ifile)
        
        artistDB  = []

        tables = bsdata.findAll("table")
        if self.debug:
            print("Found {0} tables".format(len(tables)))
        for i,table in enumerate(tables):
            trs = table.findAll("tr")
            jj = 0
            headers = None
            values  = []
            for j,tr in enumerate(trs):
                tds  = tr.findAll("td")
                #print('\t',len(tds))
                #tds  = [list(td.strings) for td in tds]
                if len(tds) == 8:
                    if jj == 0:
                        headers = tds
                        if self.debug:
                            print("  Found Header: {0}".format(headers))
                    else:
                        values.append(tds)
                        if self.debug:
                            print("  Found Value: {0}".format(tds))

                    jj += 1

            if headers is not None:
                keys = []
                for header in headers:
                    b = header.find("b")
                    if b is None:
                        keys.append(str(len(keys)))
                    else:
                        txt = b.text.strip()
                        keys.append(txt)
                        
                if self.debug:
                    print("  Keys: {0}".format(keys))
                    print("  Values: {0}".format(len(values)))


                for value in values:
                    value = [x for ix,x in enumerate(value) if keys[ix] in ["Artist", "Title"]]
                    album = dict(zip(["Artist", "Title"], value))
                    album["Artist"] = album["Artist"].text
                    album["Album"]  = {"Name": album["Title"].text}
                    try:
                        album["Album"]["URL"] = album["Title"].find("a").attrs['href']
                    except:
                        album["Album"]["URL"] = None
                    del album["Title"]
                    artistDB.append({"ArtistName": album["Artist"], "AlbumName": album["Album"]["Name"], "AlbumURL": album["Album"]["URL"]})
                break

        artistID = self.dutils.getArtistID(artist)
        page     = 1
        savename = self.getArtistSavename(artistID, page)
        while isFile(savename) and False:
            page += 1
            savename = self.getArtistSavename(artistID, page)
        print("Saving {0} new artist media to {1}".format(len(artistDB), savename))
        saveJoblib(data=artistDB, filename=savename, compress=True)

# %%
am = artistsMusicStack(debug=False)
am.searchForArtist()
