# %% [markdown]
# # Discogs

# %%
######################################################
# Juypter
######################################################
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))


######################################################
# General
######################################################
from ioUtils import saveJoblib, loadJoblib, saveFile, getFile
import urllib
from urllib.parse import quote
from timeUtils import clock, elapsed
from fsUtils import moveFile, setFile, setDir, setSubDir, isFile, isDir, mkDir
from ioUtils import getFile, saveFile
from fileUtils import getFileBasics, getBasename
from webUtils import getWebData, getHTML, getURL
from time import sleep
import time
from multiprocessing import Pool


######################################################
# Music Stuff
######################################################
from dbBase import dbBase
from multiArtist import multiartist
from myMusicDBMap import myMusicDBMap
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData


######################################################
# Versions
######################################################
import sys
print("Python: {0}".format(sys.version))
import datetime as dt
start = dt.datetime.now()
print("Notebook Last Run Initiated: "+str(start))
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# /Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# Python: 3.7.7 (default, Mar 26 2020, 10:32:53)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# Notebook Last Run Initiated: 2021-01-01 16:02:24.053587

# %% [markdown]
# # Initialize

# %%
maindb = mainDB(mdb=None, create=False, debug=True)
dbdata = maindb.dbdata
# Out:
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RockCorner
#   Creating Database Records for AceBootlegs
#   Creating Database Records for CDandLP
#   Creating Database Records for RateYourMusic
#   Creating Database Records for MusicStack
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RockCorner, AceBootlegs, CDandLP, RateYourMusic, MusicStack

# %% [markdown]
# # Credit Downloads

# %%
dbdata["AllMusic"]["Artists"].assertDBModValCreditData(0, test=True)
# Out:
# assertDBModValCreditData(0, test=True)

# %%
from random import shuffle
modVals = list(range(100))
shuffle(modVals)

for modVal in modVals:
    break
    try:
        dbdata["Discogs"]["Artists"].assertDBModValCreditData(modVal)
    except:
        continue

# %%
from random import shuffle
modVals = list(range(100))
shuffle(modVals)

for modVal in modVals:
    break
    try:
        dbdata["Discogs"]["Artists"].assertDBModValUnofficialData(modVal)
    except:
        continue

# %%
specificDownloads = True
if specificDownloads:
    
    toget=['DJ Luciano',
  'Deftones',
  'Dione Taylor',
  'Herbert Grönemeyer',
  'Junior Kimbrough',
  'A R I Z O N A',
  'Demis Roussos',
  'Pablo Alborán',
  'Santo & Johnny',
  'Yannick Noah',
  'Ghosts Of Paraguay',
  'Jim Lea',
  'Afroman',
  'Asking Alexandria',
  'Sarah Connor',
  'Sisqo',
  'Metric']
    
    toget=['BØRNS',
  'Kaiser Chiefs',
  'Meshuggah',
  'Ben Rector',
  'Chris Webby',
  'Clannad',
  'Hatik',
  "Heuss L'enfoiré",
  'Lionheart',
  'Médine',
  'Ninho',
  'The Avalanches',
  'Zola',
  'Master KG',
  'Maître Gims']
    
    print(len(toget))
    #dbs = ['Discogs', 'MusicBrainz', 'LastFM']
    dbs = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
    dbs = ['Discogs', 'MusicBrainz', 'LastFM']
    #dbs = ['MusicBrainz']
    #dbs = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
    #dbs = ['Discogs', 'AllMusic']
    dbs = ["AllMusic"]
    #dbs = ["MusicBrainz", "Discogs", "LastFM"]
    dbs = ["AllMusic", "MusicBrainz", "Discogs", "LastFM"]
    #dbs = ["Discogs"]
    #dbs = ["MusicBrainz"]

    maindb = mainDB(mdb=None, create=True, debug=True)
    pdb = parseDBArtistsData(maindb=maindb)

    from time import sleep
    maxI = -1
    for db in dbs:
        print(db)
        noMatches = toget
        #noMatches = toget.get(db)
        if noMatches is None:
            continue
        for i,artist in enumerate(noMatches):
            print("="*100)
            print("="*100)
            print(i,'/',len(noMatches),'\t',artist)
            print("="*100)
            print(i,'/',len(noMatches),'\t',artist,'===>',db)
            try:
                maindb.dbdata[db]["Artists"].searchForArtist(artist, force=False)
            except:
                sleep(10)
# Out:
# 15
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RockCorner
#   Creating Database Records for AceBootlegs
#   Creating Database Records for CDandLP
#   Creating Database Records for RateYourMusic
#   Creating Database Records for MusicStack
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RockCorner, AceBootlegs, CDandLP, RateYourMusic, MusicStack
# AllMusic
# ====================================================================================================
# ====================================================================================================
# 0 / 15 	 BØRNS
# ====================================================================================================
# 0 / 15 	 BØRNS ===> AllMusic
#
#
# ===================== Searching For BØRNS =====================
# 1 / 20 	: 0003323342 	 https://www.allmusic.com/artist/b%C3rns-mn0003323342/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/42/0003323342.p (force=True)
#   --> This file is 18.2kB.
# Done. Sleeping for 2 seconds
# 2 / 20 	: 0001457392 	 https://www.allmusic.com/artist/uwe-borns-mn0001457392/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/92/0001457392.p (force=True)
#   --> This file is 14.2kB.
# Done. Sleeping for 2 seconds
# 3 / 20 	: 0001983597 	 https://www.allmusic.com/artist/nattyflo-mn0001983597/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/97/0001983597.p (force=True)
#   --> This file is 15.6kB.
# Done. Sleeping for 2 seconds
# 4 / 20 	: 0002127523 	 https://www.allmusic.com/artist/aaron-borns-mn0002127523/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/23/0002127523.p (force=True)
#   --> This file is 13.7kB.
# Done. Sleeping for 2 seconds
# 5 / 20 	: 0003315049 	 https://www.allmusic.com/artist/garrett-borns-mn0003315049/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/49/0003315049.p (force=True)
#   --> This file is 14.3kB.
# Done. Sleeping for 2 seconds
# 6 / 20 	: 0003406210 	 https://www.allmusic.com/artist/garret-borns-mn0003406210/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/10/0003406210.p (force=True)
#   --> This file is 13.9kB.
# Done. Sleeping for 2 seconds
# 7 / 20 	: 0003866754 	 https://www.allmusic.com/artist/katja-borns-mn0003866754/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/54/0003866754.p (force=True)
#   --> This file is 13.9kB.
# Done. Sleeping for 2 seconds
# 8 / 20 	: 0003886476 	 https://www.allmusic.com/artist/betsy-borns-mn0003886476/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/76/0003886476.p (force=True)
#   --> This file is 14.0kB.
# Done. Sleeping for 2 seconds
# 9 / 20 	: 0000128099 	 https://www.allmusic.com/artist/james-brown-mn0000128099/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/99/0000128099.p (force=True)
#   --> This file is 95.5kB.
# Done. Sleeping for 2 seconds
# 10 / 20 	: 0000130689 	 https://www.allmusic.com/artist/jackson-browne-mn0000130689/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/89/0000130689.p (force=True)
#   --> This file is 26.7kB.
# Done. Sleeping for 2 seconds
# 11 / 20 	: 0000625736 	 https://www.allmusic.com/artist/brian-wilson-mn0000625736/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/36/0000625736.p (force=True)
#   --> This file is 25.7kB.
# Done. Sleeping for 2 seconds
# 12 / 20 	: 0000617196 	 https://www.allmusic.com/artist/brian-eno-mn0000617196/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/96/0000617196.p (force=True)
#   --> This file is 37.8kB.
# Done. Sleeping for 2 seconds
# 13 / 20 	: 0000197364 	 https://www.allmusic.com/artist/david-byrne-mn0000197364/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/64/0000197364.p (force=True)
#   --> This file is 26.6kB.
# Done. Sleeping for 2 seconds
# 14 / 20 	: 0000242861 	 https://www.allmusic.com/artist/dennis-brown-mn0000242861/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/61/0000242861.p (force=True)
#   --> This file is 49.1kB.
# Done. Sleeping for 2 seconds
# 15 / 20 	: 0000343940 	 https://www.allmusic.com/artist/ray-brown-mn0000343940/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/40/0000343940.p (force=True)
#   --> This file is 34.7kB.
# Done. Sleeping for 2 seconds
# 16 / 20 	: 0000630882 	 https://www.allmusic.com/artist/brownie-mcghee-mn0000630882/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/82/0000630882.p (force=True)
#   --> This file is 31.7kB.
# Done. Sleeping for 2 seconds
# 17 / 20 	: 0000805298 	 https://www.allmusic.com/artist/charles-brown-mn0000805298/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/98/0000805298.p (force=True)
#   --> This file is 30.7kB.
# Done. Sleeping for 2 seconds
# 18 / 20 	: 0000129547 	 https://www.allmusic.com/artist/clarence-gatemouth-brown-mn0000129547/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/47/0000129547.p (force=True)
#   --> This file is 27.7kB.
# Done. Sleeping for 2 seconds
# 19 / 20 	: 0001032082 	 https://www.allmusic.com/artist/bruno-mars-mn0001032082/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/82/0001032082.p (force=True)
#   --> This file is 20.3kB.
# Done. Sleeping for 2 seconds
# 20 / 20 	: 0000789775 	 https://www.allmusic.com/artist/clifford-brown-mn0000789775/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/75/0000789775.p (force=True)
#   --> This file is 37.1kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 1 / 15 	 Kaiser Chiefs
# ====================================================================================================
# 1 / 15 	 Kaiser Chiefs ===> AllMusic
#
#
# ===================== Searching For Kaiser Chiefs =====================
# 1 / 20 	: 0000932328 	 https://www.allmusic.com/artist/kaiser-chiefs-mn0000932328/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/28/0000932328.p (force=True)
#   --> This file is 23.4kB.
# Done. Sleeping for 2 seconds
# 2 / 20 	: 0002662272 	 https://www.allmusic.com/artist/kaiser-chief-mn0002662272/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/72/0002662272.p (force=True)
#   --> This file is 14.3kB.
# Done. Sleeping for 2 seconds
# 3 / 20 	: 0000673577 	 https://www.allmusic.com/artist/henry-kaiser-mn0000673577/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/77/0000673577.p (force=True)
#   --> This file is 33.1kB.
# Done. Sleeping for 2 seconds
# 4 / 20 	: 0000842421 	 https://www.allmusic.com/artist/secret-chiefs-3-mn0000842421/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/21/0000842421.p (force=True)
#   --> This file is 19.2kB.
# Done. Sleeping for 2 seconds
# 5 / 20 	: 0002340239 	 https://www.allmusic.com/artist/karl-kaiser-mn0002340239/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/39/0002340239.p (force=True)
#   --> This file is 17.2kB.
# Done. Sleeping for 2 seconds
# 6 / 20 	: 0002225336 	 https://www.allmusic.com/artist/hans-j%C3%BCrgen-kaiser-mn0002225336/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/36/0002225336.p (force=True)
#   --> This file is 17.0kB.
# Done. Sleeping for 2 seconds
# 7 / 20 	: 0002343534 	 https://www.allmusic.com/artist/barbel-kaiser-mn0002343534/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/34/0002343534.p (force=True)
#   --> This file is 14.0kB.
# Done. Sleeping for 2 seconds
# 8 / 20 	: 0002110754 	 https://www.allmusic.com/artist/the-rhythm-chiefs-mn0002110754/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/54/0002110754.p (force=True)
#   --> This file is 14.3kB.
# Done. Sleeping for 2 seconds
# 9 / 20 	: 0000111566 	 https://www.allmusic.com/artist/chiefs-prairie-mn0000111566/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/66/0000111566.p (force=True)
#   --> This file is 14.1kB.
# Done. Sleeping for 2 seconds
# 10 / 20 	: 0000320616 	 https://www.allmusic.com/artist/chiefs-tale-mn0000320616/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/16/0000320616.p (force=True)
#   --> This file is 14.3kB.
# Done. Sleeping for 2 seconds
# 11 / 20 	: 0000663827 	 https://www.allmusic.com/artist/glenn-kaiser-mn0000663827/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/27/0000663827.p (force=True)
#   --> This file is 16.9kB.
# Done. Sleeping for 2 seconds
# 12 / 20 	: 0001486613 	 https://www.allmusic.com/artist/susann-kaiser-mn0001486613/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/13/0001486613.p (force=True)
#   --> This file is 14.8kB.
# Done. Sleeping for 2 seconds
# 13 / 20 	: 0000111239 	 https://www.allmusic.com/artist/chiefs-mn0000111239/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/39/0000111239.p (force=True)
#   --> This file is 14.4kB.
# Done. Sleeping for 2 seconds
# 14 / 20 	: 0003161364 	 https://www.allmusic.com/artist/the-chiefs-mn0003161364/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/64/0003161364.p (force=True)
#   --> This file is 14.3kB.
# Done. Sleeping for 2 seconds
# 15 / 20 	: 0003486112 	 https://www.allmusic.com/artist/chiefs-mn0003486112/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/12/0003486112.p (force=True)
#   --> This file is 14.3kB.
# Done. Sleeping for 2 seconds
# 16 / 20 	: 0003613478 	 https://www.allmusic.com/artist/chiefs-mn0003613478/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/78/0003613478.p (force=True)
#   --> This file is 14.6kB.
# Done. Sleeping for 2 seconds
# 17 / 20 	: 0000124928 	 https://www.allmusic.com/artist/kaiser-souzai-mn0000124928/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/28/0000124928.p (force=True)
#   --> This file is 15.1kB.
# Done. Sleeping for 2 seconds
# 18 / 20 	: 0000296107 	 https://www.allmusic.com/artist/kaiser-soza-mn0000296107/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/7/0000296107.p (force=True)
#   --> This file is 14.1kB.
# Done. Sleeping for 2 seconds
# 19 / 20 	: 0000355393 	 https://www.allmusic.com/artist/kaiser-clifton-mn0000355393/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/93/0000355393.p (force=True)
#   --> This file is 14.4kB.
# Done. Sleeping for 2 seconds
# 20 / 20 	: 0000768716 	 https://www.allmusic.com/artist/the-kaiser-singers-mn0000768716/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/16/0000768716.p (force=True)
#   --> This file is 14.5kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 2 / 15 	 Meshuggah
# ====================================================================================================
# 2 / 15 	 Meshuggah ===> AllMusic
#
#
# ===================== Searching For Meshuggah =====================
# 1 / 19 	: 0000453041 	 https://www.allmusic.com/artist/meshuggah-mn0000453041/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/41/0000453041.p (force=True)
#   --> This file is 20.0kB.
# Done. Sleeping for 2 seconds
# 2 / 19 	: 0000765683 	 https://www.allmusic.com/artist/jimmy-mchugh-mn0000765683/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/83/0000765683.p (force=True)
#   --> This file is 16.8kB.
# Done. Sleeping for 2 seconds
# 3 / 19 	: 0000421871 	 https://www.allmusic.com/artist/mishka-mn0000421871/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/71/0000421871.p (force=True)
#   --> This file is 18.2kB.
# Done. Sleeping for 2 seconds
# 4 / 19 	: 0002204527 	 https://www.allmusic.com/artist/michiko-tsuda-mn0002204527/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/27/0002204527.p (force=True)
#   --> This file is 15.7kB.
# Done. Sleeping for 2 seconds
# 5 / 19 	: 0000977672 	 https://www.allmusic.com/artist/mooshock-mn0000977672/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/72/0000977672.p (force=True)
#   --> This file is 14.2kB.
# Done. Sleeping for 2 seconds
# 6 / 19 	: 0001467203 	 https://www.allmusic.com/artist/moshic-mn0001467203/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/3/0001467203.p (force=True)
#   --> This file is 17.3kB.
# Done. Sleeping for 2 seconds
# 7 / 19 	: 0003516032 	 https://www.allmusic.com/artist/meshiaak-mn0003516032/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/32/0003516032.p (force=True)
#   --> This file is 16.0kB.
# Done. Sleeping for 2 seconds
# 8 / 19 	: 0000736993 	 https://www.allmusic.com/artist/mishka-shubaly-mn0000736993/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/93/0000736993.p (force=True)
#   --> This file is 16.5kB.
# Done. Sleeping for 2 seconds
# 9 / 19 	: 0000479616 	 https://www.allmusic.com/artist/michiko-ogawa-mn0000479616/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/16/0000479616.p (force=True)
#   --> This file is 14.7kB.
# Done. Sleeping for 2 seconds
# 10 / 19 	: 0000733290 	 https://www.allmusic.com/artist/mishka-stein-mn0000733290/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/90/0000733290.p (force=True)
#   --> This file is 14.2kB.
# Done. Sleeping for 2 seconds
# 11 / 19 	: 0000997179 	 https://www.allmusic.com/artist/mishka-adams-mn0000997179/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/79/0000997179.p (force=True)
#   --> This file is 15.2kB.
# Done. Sleeping for 2 seconds
# 12 / 19 	: 0002727010 	 https://www.allmusic.com/artist/lisa-mchugh-mn0002727010/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/10/0002727010.p (force=True)
#   --> This file is 16.9kB.
# Done. Sleeping for 2 seconds
# 13 / 19 	: 0002265366 	 https://www.allmusic.com/artist/michiko-otaki-mn0002265366/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/66/0002265366.p (force=True)
#   --> This file is 15.3kB.
# Done. Sleeping for 2 seconds
# 14 / 19 	: 0003462800 	 https://www.allmusic.com/artist/machiko-suto-mn0003462800/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/0/0003462800.p (force=True)
#   --> This file is 14.9kB.
# Done. Sleeping for 2 seconds
# 15 / 19 	: 0000109622 	 https://www.allmusic.com/artist/chris-mchugh-mn0000109622/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/22/0000109622.p (force=True)
#   --> This file is 14.7kB.
# Done. Sleeping for 2 seconds
# 16 / 19 	: 0000277633 	 https://www.allmusic.com/artist/phil-mchugh-mn0000277633/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/33/0000277633.p (force=True)
#   --> This file is 14.6kB.
# Done. Sleeping for 2 seconds
# 17 / 19 	: 0000656617 	 https://www.allmusic.com/artist/jim-mchugh-mn0000656617/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/17/0000656617.p (force=True)
#   --> This file is 14.3kB.
# Done. Sleeping for 2 seconds
# 18 / 19 	: 0000937736 	 https://www.allmusic.com/artist/mat-mchugh-mn0000937736/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/36/0000937736.p (force=True)
#   --> This file is 15.4kB.
# Done. Sleeping for 2 seconds
# 19 / 19 	: 0001247020 	 https://www.allmusic.com/artist/machiko-kobialka-mn0001247020/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/20/0001247020.p (force=True)
#   --> This file is 13.7kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 3 / 15 	 Ben Rector
# ====================================================================================================
# 3 / 15 	 Ben Rector ===> AllMusic
#
#
# ===================== Searching For Ben Rector =====================
# 1 / 20 	: 0002536650 	 https://www.allmusic.com/artist/ben-rector-mn0002536650/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/50/0002536650.p (force=True)
#   --> This file is 18.1kB.
# Done. Sleeping for 2 seconds
# 2 / 20 	: 0000793227 	 https://www.allmusic.com/artist/ben-webster-mn0000793227/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/27/0000793227.p (force=True)
#   --> This file is 49.8kB.
# Done. Sleeping for 2 seconds
# 3 / 20 	: 0000164594 	 https://www.allmusic.com/artist/ben-e-king-mn0000164594/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/94/0000164594.p (force=True)
#   --> This file is 33.4kB.
# Done. Sleeping for 2 seconds
# 4 / 20 	: 0000215584 	 https://www.allmusic.com/artist/jorge-ben-mn0000215584/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/84/0000215584.p (force=True)
#   --> This file is 30.9kB.
# Done. Sleeping for 2 seconds
# 5 / 20 	: 0000162197 	 https://www.allmusic.com/artist/ben-folds-mn0000162197/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/97/0000162197.p (force=True)
#   --> This file is 25.8kB.
# Done. Sleeping for 2 seconds
# 6 / 20 	: 0000792733 	 https://www.allmusic.com/artist/ben-harper-mn0000792733/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/33/0000792733.p (force=True)
#   --> This file is 28.1kB.
# Done. Sleeping for 2 seconds
# 7 / 20 	: 0000163339 	 https://www.allmusic.com/artist/ben-goldberg-mn0000163339/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/39/0000163339.p (force=True)
#   --> This file is 19.4kB.
# Done. Sleeping for 2 seconds
# 8 / 20 	: 0000164686 	 https://www.allmusic.com/artist/ben-folds-five-mn0000164686/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/86/0000164686.p (force=True)
#   --> This file is 20.6kB.
# Done. Sleeping for 2 seconds
# 9 / 20 	: 0000793210 	 https://www.allmusic.com/artist/ben-sidran-mn0000793210/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/10/0000793210.p (force=True)
#   --> This file is 25.3kB.
# Done. Sleeping for 2 seconds
# 10 / 20 	: 0001954449 	 https://www.allmusic.com/artist/ben-frost-mn0001954449/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/49/0001954449.p (force=True)
#   --> This file is 20.0kB.
# Done. Sleeping for 2 seconds
# 11 / 20 	: 0000168126 	 https://www.allmusic.com/artist/ben-kweller-mn0000168126/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/26/0000168126.p (force=True)
#   --> This file is 18.4kB.
# Done. Sleeping for 2 seconds
# 12 / 20 	: 0000165248 	 https://www.allmusic.com/artist/ben-vaughn-mn0000165248/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/48/0000165248.p (force=True)
#   --> This file is 20.2kB.
# Done. Sleeping for 2 seconds
# 13 / 20 	: 0000279288 	 https://www.allmusic.com/artist/ben-klock-mn0000279288/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/88/0000279288.p (force=True)
#   --> This file is 17.5kB.
# Done. Sleeping for 2 seconds
# 14 / 20 	: 0000158090 	 https://www.allmusic.com/artist/ben-colder-mn0000158090/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/90/0000158090.p (force=True)
#   --> This file is 17.5kB.
# Done. Sleeping for 2 seconds
# 15 / 20 	: 0002284390 	 https://www.allmusic.com/artist/ben-johnston-mn0002284390/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/90/0002284390.p (force=True)
#   --> This file is 16.2kB.
# Done. Sleeping for 2 seconds
# 16 / 20 	: 0000163570 	 https://www.allmusic.com/artist/ben-lee-mn0000163570/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/70/0000163570.p (force=True)
#   --> This file is 21.2kB.
# Done. Sleeping for 2 seconds
# 17 / 20 	: 0001530452 	 https://www.allmusic.com/artist/ben-howard-mn0001530452/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/52/0001530452.p (force=True)
#   --> This file is 18.5kB.
# Done. Sleeping for 2 seconds
# 18 / 20 	: 0000213936 	 https://www.allmusic.com/artist/ben-heppner-mn0000213936/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/36/0000213936.p (force=True)
#   --> This file is 18.8kB.
# Done. Sleeping for 2 seconds
# 19 / 20 	: 0000794156 	 https://www.allmusic.com/artist/ben-selvin-mn0000794156/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/56/0000794156.p (force=True)
#   --> This file is 17.0kB.
# Done. Sleeping for 2 seconds
# 20 / 20 	: 0000793256 	 https://www.allmusic.com/artist/ben-tankard-mn0000793256/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/56/0000793256.p (force=True)
#   --> This file is 19.5kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 4 / 15 	 Chris Webby
# ====================================================================================================
# 4 / 15 	 Chris Webby ===> AllMusic
#
#
# ===================== Searching For Chris Webby =====================
# 1 / 20 	: 0002782041 	 https://www.allmusic.com/artist/chris-webby-mn0002782041/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/41/0002782041.p (force=True)
#   --> This file is 17.8kB.
# Done. Sleeping for 2 seconds
# 2 / 20 	: 0000615021 	 https://www.allmusic.com/artist/chris-webb-mn0000615021/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/21/0000615021.p (force=True)
#   --> This file is 14.8kB.
# Done. Sleeping for 2 seconds
# 3 / 20 	: 0001494947 	 https://www.allmusic.com/artist/chris-webb-mn0001494947/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/47/0001494947.p (force=True)
#   --> This file is 13.8kB.
# Done. Sleeping for 2 seconds
# 4 / 20 	: 0002119322 	 https://www.allmusic.com/artist/chris-webb-mn0002119322/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/22/0002119322.p (force=True)
#   --> This file is 13.8kB.
# Done. Sleeping for 2 seconds
# 5 / 20 	: 0002554622 	 https://www.allmusic.com/artist/chris-wiebe-mn0002554622/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/22/0002554622.p (force=True)
#   --> This file is 14.3kB.
# Done. Sleeping for 2 seconds
# 6 / 20 	: 0003007352 	 https://www.allmusic.com/artist/chris-webb-mn0003007352/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/52/0003007352.p (force=True)
#   --> This file is 13.8kB.
# Done. Sleeping for 2 seconds
# 7 / 20 	: 0003305395 	 https://www.allmusic.com/artist/chris-webb-mn0003305395/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/95/0003305395.p (force=True)
#   --> This file is 14.2kB.
# Done. Sleeping for 2 seconds
# 8 / 20 	: 0003342085 	 https://www.allmusic.com/artist/chris-webbe-mn0003342085/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/85/0003342085.p (force=True)
#   --> This file is 14.1kB.
# Done. Sleeping for 2 seconds
# 9 / 20 	: 0003519415 	 https://www.allmusic.com/artist/chris-webb-mn0003519415/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/15/0003519415.p (force=True)
#   --> This file is 13.8kB.
# Done. Sleeping for 2 seconds
# 10 / 20 	: 0003649525 	 https://www.allmusic.com/artist/chris-webb-mn0003649525/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/25/0003649525.p (force=True)
#   --> This file is 13.8kB.
# Done. Sleeping for 2 seconds
# 11 / 20 	: 0001766237 	 https://www.allmusic.com/artist/chris-stapleton-mn0001766237/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/37/0001766237.p (force=True)
#   --> This file is 19.2kB.
# Done. Sleeping for 2 seconds
# 12 / 20 	: 0000776337 	 https://www.allmusic.com/artist/chris-connor-mn0000776337/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/37/0000776337.p (force=True)
#   --> This file is 30.3kB.
# Done. Sleeping for 2 seconds
# 13 / 20 	: 0000096944 	 https://www.allmusic.com/artist/chris-hillman-mn0000096944/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/44/0000096944.p (force=True)
#   --> This file is 22.1kB.
# Done. Sleeping for 2 seconds
# 14 / 20 	: 0000100575 	 https://www.allmusic.com/artist/chris-tomlin-mn0000100575/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/75/0000100575.p (force=True)
#   --> This file is 27.7kB.
# Done. Sleeping for 2 seconds
# 15 / 20 	: 0000266063 	 https://www.allmusic.com/artist/chris-brown-mn0000266063/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/63/0000266063.p (force=True)
#   --> This file is 25.6kB.
# Done. Sleeping for 2 seconds
# 16 / 20 	: 0000114459 	 https://www.allmusic.com/artist/chris-potter-mn0000114459/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/59/0000114459.p (force=True)
#   --> This file is 23.2kB.
# Done. Sleeping for 2 seconds
# 17 / 20 	: 0000775323 	 https://www.allmusic.com/artist/chris-isaak-mn0000775323/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/23/0000775323.p (force=True)
#   --> This file is 24.0kB.
# Done. Sleeping for 2 seconds
# 18 / 20 	: 0001379627 	 https://www.allmusic.com/artist/chris-young-mn0001379627/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/27/0001379627.p (force=True)
#   --> This file is 18.9kB.
# Done. Sleeping for 2 seconds
# 19 / 20 	: 0000115739 	 https://www.allmusic.com/artist/chris-rock-mn0000115739/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/39/0000115739.p (force=True)
#   --> This file is 17.6kB.
# Done. Sleeping for 2 seconds
# 20 / 20 	: 0000114605 	 https://www.allmusic.com/artist/chris-rice-mn0000114605/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/5/0000114605.p (force=True)
#   --> This file is 18.3kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 5 / 15 	 Clannad
# ====================================================================================================
# 5 / 15 	 Clannad ===> AllMusic
#
#
# ===================== Searching For Clannad =====================
# 1 / 17 	: 0000781732 	 https://www.allmusic.com/artist/clannad-mn0000781732/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/32/0000781732.p (force=True)
#   --> This file is 26.9kB.
# Done. Sleeping for 2 seconds
# 2 / 17 	: 0000458162 	 https://www.allmusic.com/artist/clannad-bono-mn0000458162/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/62/0000458162.p (force=True)
#   --> This file is 14.1kB.
# Done. Sleeping for 2 seconds
# 3 / 17 	: 0000792370 	 https://www.allmusic.com/artist/clint-black-mn0000792370/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/70/0000792370.p (force=True)
#   --> This file is 24.5kB.
# Done. Sleeping for 2 seconds
# 4 / 17 	: 0000160428 	 https://www.allmusic.com/artist/clint-eastwood-mn0000160428/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/28/0000160428.p (force=True)
#   --> This file is 17.9kB.
# Done. Sleeping for 2 seconds
# 5 / 17 	: 0002913530 	 https://www.allmusic.com/artist/galantis-mn0002913530/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/30/0002913530.p (force=True)
#   --> This file is 20.7kB.
# Done. Sleeping for 2 seconds
# 6 / 17 	: 0002048980 	 https://www.allmusic.com/artist/europa-galante-mn0002048980/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/80/0002048980.p (force=True)
#   --> This file is 28.3kB.
# Done. Sleeping for 2 seconds
# 7 / 17 	: 0003413511 	 https://www.allmusic.com/artist/gallant-mn0003413511/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/11/0003413511.p (force=True)
#   --> This file is 17.9kB.
# Done. Sleeping for 2 seconds
# 8 / 17 	: 0000133988 	 https://www.allmusic.com/artist/clint-mansell-mn0000133988/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/88/0000133988.p (force=True)
#   --> This file is 22.1kB.
# Done. Sleeping for 2 seconds
# 9 / 17 	: 0000162988 	 https://www.allmusic.com/artist/foetus-mn0000162988/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/88/0000162988.p (force=True)
#   --> This file is 21.9kB.
# Done. Sleeping for 2 seconds
# 10 / 17 	: 0000199838 	 https://www.allmusic.com/artist/two-gallants-mn0000199838/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/38/0000199838.p (force=True)
#   --> This file is 18.5kB.
# Done. Sleeping for 2 seconds
# 11 / 17 	: 0000126636 	 https://www.allmusic.com/artist/client-mn0000126636/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/36/0000126636.p (force=True)
#   --> This file is 19.0kB.
# Done. Sleeping for 2 seconds
# 12 / 17 	: 0000081282 	 https://www.allmusic.com/artist/the-glands-mn0000081282/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/82/0000081282.p (force=True)
#   --> This file is 16.1kB.
# Done. Sleeping for 2 seconds
# 13 / 17 	: 0000775668 	 https://www.allmusic.com/artist/kolinda-mn0000775668/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/68/0000775668.p (force=True)
#   --> This file is 15.8kB.
# Done. Sleeping for 2 seconds
# 14 / 17 	: 0000778968 	 https://www.allmusic.com/artist/jg-thirlwell-mn0000778968/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/68/0000778968.p (force=True)
#   --> This file is 16.6kB.
# Done. Sleeping for 2 seconds
# 15 / 17 	: 0001951470 	 https://www.allmusic.com/artist/marianne-beate-kielland-mn0001951470/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/70/0001951470.p (force=True)
#   --> This file is 20.7kB.
# Done. Sleeping for 2 seconds
# 16 / 17 	: 0000417124 	 https://www.allmusic.com/artist/glint-mn0000417124/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/24/0000417124.p (force=True)
#   --> This file is 17.8kB.
# Done. Sleeping for 2 seconds
# 17 / 17 	: 0001022925 	 https://www.allmusic.com/artist/chris-galland-mn0001022925/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/25/0001022925.p (force=True)
#   --> This file is 14.5kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 6 / 15 	 Hatik
# ====================================================================================================
# 6 / 15 	 Hatik ===> AllMusic
#
#
# ===================== Searching For Hatik =====================
# 1 / 19 	: 0003786582 	 https://www.allmusic.com/artist/hatik-mn0003786582/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/82/0003786582.p (force=True)
#   --> This file is 17.1kB.
# Done. Sleeping for 2 seconds
# 2 / 19 	: 0000949143 	 https://www.allmusic.com/artist/dj-krush-mn0000949143/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/43/0000949143.p (force=True)
#   --> This file is 22.2kB.
# Done. Sleeping for 2 seconds
# 3 / 19 	: 0001878017 	 https://www.allmusic.com/artist/hadouk-trio-mn0001878017/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/17/0001878017.p (force=True)
#   --> This file is 16.6kB.
# Done. Sleeping for 2 seconds
# 4 / 19 	: 0000543630 	 https://www.allmusic.com/artist/kate-miller-heidke-mn0000543630/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/30/0000543630.p (force=True)
#   --> This file is 19.1kB.
# Done. Sleeping for 2 seconds
# 5 / 19 	: 0001066799 	 https://www.allmusic.com/artist/hdk-mn0001066799/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/99/0001066799.p (force=True)
#   --> This file is 15.1kB.
# Done. Sleeping for 2 seconds
# 6 / 19 	: 0002140599 	 https://www.allmusic.com/artist/richard-skelton-mn0002140599/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/99/0002140599.p (force=True)
#   --> This file is 16.0kB.
# Done. Sleeping for 2 seconds
# 7 / 19 	: 0002942097 	 https://www.allmusic.com/artist/heidika-mn0002942097/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/97/0002942097.p (force=True)
#   --> This file is 14.2kB.
# Done. Sleeping for 2 seconds
# 8 / 19 	: 0000777436 	 https://www.allmusic.com/artist/jiri-hudec-mn0000777436/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/36/0000777436.p (force=True)
#   --> This file is 14.8kB.
# Done. Sleeping for 2 seconds
# 9 / 19 	: 0000015412 	 https://www.allmusic.com/artist/taraf-de-ha%C3%AFdouks-mn0000015412/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/12/0000015412.p (force=True)
#   --> This file is 18.6kB.
# Done. Sleeping for 2 seconds
# 10 / 19 	: 0000657650 	 https://www.allmusic.com/artist/hadag-nahash-mn0000657650/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/50/0000657650.p (force=True)
#   --> This file is 12.8kB.
# Done. Sleeping for 2 seconds
# 11 / 19 	: 0001477850 	 https://www.allmusic.com/artist/hadiqa-kiani-mn0001477850/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/50/0001477850.p (force=True)
#   --> This file is 13.6kB.
# Done. Sleeping for 2 seconds
# 12 / 19 	: 0002014678 	 https://www.allmusic.com/artist/hadag-nachash-mn0002014678/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/78/0002014678.p (force=True)
#   --> This file is 12.8kB.
# Done. Sleeping for 2 seconds
# 13 / 19 	: 0002984797 	 https://www.allmusic.com/artist/hideki-taniuchi-mn0002984797/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/97/0002984797.p (force=True)
#   --> This file is 14.4kB.
# Done. Sleeping for 2 seconds
# 14 / 19 	: 0003208195 	 https://www.allmusic.com/artist/hadouk-quartet-mn0003208195/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/95/0003208195.p (force=True)
#   --> This file is 14.6kB.
# Done. Sleeping for 2 seconds
# 15 / 19 	: 0000210457 	 https://www.allmusic.com/artist/hideko-udagawa-mn0000210457/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/57/0000210457.p (force=True)
#   --> This file is 17.7kB.
# Done. Sleeping for 2 seconds
# 16 / 19 	: 0000678449 	 https://www.allmusic.com/artist/hideki-yamaya-mn0000678449/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/49/0000678449.p (force=True)
#   --> This file is 15.9kB.
# Done. Sleeping for 2 seconds
# 17 / 19 	: 0001315070 	 https://www.allmusic.com/artist/hideki-yamazaki-mn0001315070/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/70/0001315070.p (force=True)
#   --> This file is 13.6kB.
# Done. Sleeping for 2 seconds
# 18 / 19 	: 0002177920 	 https://www.allmusic.com/artist/hideko-kobayashi-mn0002177920/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/20/0002177920.p (force=True)
#   --> This file is 14.5kB.
# Done. Sleeping for 2 seconds
# 19 / 19 	: 0002193352 	 https://www.allmusic.com/artist/hideki-nagano-mn0002193352/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/52/0002193352.p (force=True)
#   --> This file is 14.6kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 7 / 15 	 Heuss L'enfoiré
# ====================================================================================================
# 7 / 15 	 Heuss L'enfoiré ===> AllMusic
#
#
# ===================== Searching For Heuss L'enfoiré =====================
# 1 / 1 	: 0003707565 	 https://www.allmusic.com/artist/heuss-lenfoir%C3%A9-mn0003707565/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/65/0003707565.p (force=True)
#   --> This file is 15.3kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 8 / 15 	 Lionheart
# ====================================================================================================
# 8 / 15 	 Lionheart ===> AllMusic
#
#
# ===================== Searching For Lionheart =====================
# 1 / 20 	: 0000520457 	 https://www.allmusic.com/artist/lionheart-mn0000520457/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/57/0000520457.p (force=True)
#   --> This file is 18.0kB.
# Done. Sleeping for 2 seconds
# 2 / 20 	: 0003014770 	 https://www.allmusic.com/artist/lionheart-mn0003014770/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/70/0003014770.p (force=True)
#   --> This file is 16.4kB.
# Done. Sleeping for 2 seconds
# 3 / 20 	: 0002326595 	 https://www.allmusic.com/artist/the-lionheart-brothers-mn0002326595/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/95/0002326595.p (force=True)
#   --> This file is 15.6kB.
# Done. Sleeping for 2 seconds
# 4 / 20 	: 0000095405 	 https://www.allmusic.com/artist/the-lionheart-band-mn0000095405/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/5/0000095405.p (force=True)
#   --> This file is 14.6kB.
# Done. Sleeping for 2 seconds
# 5 / 20 	: 0002063867 	 https://www.allmusic.com/artist/ferraby-lionheart-mn0002063867/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/67/0002063867.p (force=True)
#   --> This file is 16.0kB.
# Done. Sleeping for 2 seconds
# 6 / 20 	: 0002048907 	 https://www.allmusic.com/artist/roselyn-lionheart-mn0002048907/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/7/0002048907.p (force=True)
#   --> This file is 13.6kB.
# Done. Sleeping for 2 seconds
# 7 / 20 	: 0002057193 	 https://www.allmusic.com/artist/richard-lionheart-mn0002057193/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/93/0002057193.p (force=True)
#   --> This file is 14.5kB.
# Done. Sleeping for 2 seconds
# 8 / 20 	: 0002396575 	 https://www.allmusic.com/artist/jeff-lionheart-mn0002396575/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/75/0002396575.p (force=True)
#   --> This file is 14.5kB.
# Done. Sleeping for 2 seconds
# 9 / 20 	: 0002572194 	 https://www.allmusic.com/artist/project-lionheart-mn0002572194/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/94/0002572194.p (force=True)
#   --> This file is 14.7kB.
# Done. Sleeping for 2 seconds
# 10 / 20 	: 0002885778 	 https://www.allmusic.com/artist/monica-lionheart-mn0002885778/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/78/0002885778.p (force=True)
#   --> This file is 15.3kB.
# Done. Sleeping for 2 seconds
# 11 / 20 	: 0003203424 	 https://www.allmusic.com/artist/jah-lionheart-mn0003203424/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/24/0003203424.p (force=True)
#   --> This file is 13.9kB.
# Done. Sleeping for 2 seconds
# 12 / 20 	: 0002884827 	 https://www.allmusic.com/artist/%C3yvind-lionheart-larsen-mn0002884827/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/27/0002884827.p (force=True)
#   --> This file is 12.6kB.
# Done. Sleeping for 2 seconds
# 13 / 20 	: 0003442637 	 https://www.allmusic.com/artist/richard-the-lionheart-mn0003442637/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/37/0003442637.p (force=True)
#   --> This file is 14.2kB.
# Done. Sleeping for 2 seconds
# 14 / 20 	: 0000220603 	 https://www.allmusic.com/artist/jay-leonhart-mn0000220603/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/3/0000220603.p (force=True)
#   --> This file is 20.1kB.
# Done. Sleeping for 2 seconds
# 15 / 20 	: 0000528435 	 https://www.allmusic.com/artist/buzzy-linhart-mn0000528435/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/35/0000528435.p (force=True)
#   --> This file is 18.7kB.
# Done. Sleeping for 2 seconds
# 16 / 20 	: 0003615138 	 https://www.allmusic.com/artist/lionhearts-mn0003615138/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/38/0003615138.p (force=True)
#   --> This file is 14.7kB.
# Done. Sleeping for 2 seconds
# 17 / 20 	: 0001358438 	 https://www.allmusic.com/artist/leonhard-lechner-mn0001358438/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/38/0001358438.p (force=True)
#   --> This file is 13.9kB.
# Done. Sleeping for 2 seconds
# 18 / 20 	: 0002220314 	 https://www.allmusic.com/artist/leonhard-paul-mn0002220314/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/14/0002220314.p (force=True)
#   --> This file is 14.5kB.
# Done. Sleeping for 2 seconds
# 19 / 20 	: 0001694378 	 https://www.allmusic.com/artist/leonhard-roczek-mn0001694378/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/78/0001694378.p (force=True)
#   --> This file is 13.6kB.
# Done. Sleeping for 2 seconds
# 20 / 20 	: 0003595320 	 https://www.allmusic.com/artist/kyle-lionhart-mn0003595320/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/20/0003595320.p (force=True)
#   --> This file is 15.7kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 9 / 15 	 Médine
# ====================================================================================================
# 9 / 15 	 Médine ===> AllMusic
#
#
# ===================== Searching For Médine =====================
# 1 / 17 	: 0001579425 	 https://www.allmusic.com/artist/m%C3%A9dine-mn0001579425/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/25/0001579425.p (force=True)
#   --> This file is 16.6kB.
# Done. Sleeping for 2 seconds
# 2 / 17 	: 0002461142 	 https://www.allmusic.com/artist/medine-zaouiche-mn0002461142/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/42/0002461142.p (force=True)
#   --> This file is 13.1kB.
# Done. Sleeping for 2 seconds
# 3 / 17 	: 0002045702 	 https://www.allmusic.com/artist/david-medine-mn0002045702/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/2/0002045702.p (force=True)
#   --> This file is 14.2kB.
# Done. Sleeping for 2 seconds
# 4 / 17 	: 0002198391 	 https://www.allmusic.com/artist/donna-davidson-medine-mn0002198391/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/91/0002198391.p (force=True)
#   --> This file is 12.8kB.
# Done. Sleeping for 2 seconds
# 5 / 17 	: 0003334083 	 https://www.allmusic.com/artist/donna-medine-mn0003334083/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/83/0003334083.p (force=True)
#   --> This file is 14.2kB.
# Done. Sleeping for 2 seconds
# 6 / 17 	: 0003151153 	 https://www.allmusic.com/artist/peter-e-medine-mn0003151153/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/53/0003151153.p (force=True)
#   --> This file is 12.9kB.
# Done. Sleeping for 2 seconds
# 7 / 17 	: 0000237205 	 https://www.allmusic.com/artist/madonna-mn0000237205/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/5/0000237205.p (force=True)
#   --> This file is 48.3kB.
# Done. Sleeping for 2 seconds
# 8 / 17 	: 0000098465 	 https://www.allmusic.com/artist/iron-maiden-mn0000098465/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/65/0000098465.p (force=True)
#   --> This file is 40.6kB.
# Done. Sleeping for 2 seconds
# 9 / 17 	: 0000129652 	 https://www.allmusic.com/artist/bennie-moten-mn0000129652/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/52/0000129652.p (force=True)
#   --> This file is 18.7kB.
# Done. Sleeping for 2 seconds
# 10 / 17 	: 0000951683 	 https://www.allmusic.com/artist/matana-roberts-mn0000951683/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/83/0000951683.p (force=True)
#   --> This file is 17.8kB.
# Done. Sleeping for 2 seconds
# 11 / 17 	: 0000889750 	 https://www.allmusic.com/artist/the-maytones-mn0000889750/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/50/0000889750.p (force=True)
#   --> This file is 17.5kB.
# Done. Sleeping for 2 seconds
# 12 / 17 	: 0002857943 	 https://www.allmusic.com/artist/madeon-mn0002857943/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/43/0002857943.p (force=True)
#   --> This file is 16.0kB.
# Done. Sleeping for 2 seconds
# 13 / 17 	: 0000665908 	 https://www.allmusic.com/artist/good-charlotte-mn0000665908/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/8/0000665908.p (force=True)
#   --> This file is 24.2kB.
# Done. Sleeping for 2 seconds
# 14 / 17 	: 0000013393 	 https://www.allmusic.com/artist/tower-of-power-mn0000013393/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/93/0000013393.p (force=True)
#   --> This file is 26.9kB.
# Done. Sleeping for 2 seconds
# 15 / 17 	: 0001747693 	 https://www.allmusic.com/artist/medina-mn0001747693/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/93/0001747693.p (force=True)
#   --> This file is 20.5kB.
# Done. Sleeping for 2 seconds
# 16 / 17 	: 0002888019 	 https://www.allmusic.com/artist/joan-shelley-mn0002888019/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/19/0002888019.p (force=True)
#   --> This file is 17.5kB.
# Done. Sleeping for 2 seconds
# 17 / 17 	: 0000537601 	 https://www.allmusic.com/artist/the-mutton-birds-mn0000537601/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/1/0000537601.p (force=True)
#   --> This file is 18.5kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 10 / 15 	 Ninho
# ====================================================================================================
# 10 / 15 	 Ninho ===> AllMusic
#
#
# ===================== Searching For Ninho =====================
# 1 / 20 	: 0003012259 	 https://www.allmusic.com/artist/ninho-mn0003012259/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/59/0003012259.p (force=True)
#   --> This file is 17.6kB.
# Done. Sleeping for 2 seconds
# 2 / 20 	: 0004007194 	 https://www.allmusic.com/artist/ninho-borges-mn0004007194/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/94/0004007194.p (force=True)
#   --> This file is 14.0kB.
# Done. Sleeping for 2 seconds
# 3 / 20 	: 0003149625 	 https://www.allmusic.com/artist/el-ninho-mn0003149625/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/25/0003149625.p (force=True)
#   --> This file is 14.8kB.
# Done. Sleeping for 2 seconds
# 4 / 20 	: 0001559132 	 https://www.allmusic.com/artist/pardais-ao-ninho-mn0001559132/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/32/0001559132.p (force=True)
#   --> This file is 14.3kB.
# Done. Sleeping for 2 seconds
# 5 / 20 	: 0003647440 	 https://www.allmusic.com/artist/mc-ninho-da-gr-mn0003647440/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/40/0003647440.p (force=True)
#   --> This file is 14.3kB.
# Done. Sleeping for 2 seconds
# 6 / 20 	: 0001891173 	 https://www.allmusic.com/artist/tim-nienhuis-mn0001891173/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/73/0001891173.p (force=True)
#   --> This file is 14.5kB.
# Done. Sleeping for 2 seconds
# 7 / 20 	: 0000415414 	 https://www.allmusic.com/artist/ninha-mn0000415414/discography/all
# ...
#   --> This file is 26.9kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 13 / 15 	 Master KG
# ====================================================================================================
# 13 / 15 	 Master KG ===> LastFM
#
#
# ===================== Searching For Master KG =====================
# 1 / 30 	: 7602656441 	 https://www.last.fm/music/Master%2BKG/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/41/7602656441.p (force=True)
#   --> This file is 25.9kB.
# Done. Sleeping for 2 seconds
# 2 / 30 	: 60860534226 	 https://www.last.fm/music/Master%2BKG%2Bfeat.%2BNomcebo%2BZikode/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/26/60860534226.p (force=True)
#   --> This file is 27.2kB.
# Done. Sleeping for 2 seconds
# 3 / 30 	: 23414813848 	 https://www.last.fm/music/Master%2BKG%2C%2BNomcebo%2BZikode/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/48/23414813848.p (force=True)
#   --> This file is 25.9kB.
# Done. Sleeping for 2 seconds
# 4 / 30 	: 59744170136 	 https://www.last.fm/music/Master%2BKG%2B%28feat.%2BNomcebo%2BZikode%29/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/36/59744170136.p (force=True)
#   --> This file is 25.0kB.
# Done. Sleeping for 2 seconds
# 5 / 30 	: 12064895617 	 https://www.last.fm/music/Master%2BKG%2BFeat.%2BBurna%2BBoy%2B%26%2BNomcebo%2BZikode/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/17/12064895617.p (force=True)
#   --> This file is 26.3kB.
# Done. Sleeping for 2 seconds
# 6 / 30 	: 87904075369 	 https://www.last.fm/music/Master%2BKG%2C%2BBurna%2BBoy%2C%2BNomcebo%2BZikode/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/69/87904075369.p (force=True)
#   --> This file is 24.9kB.
# Done. Sleeping for 2 seconds
# 7 / 30 	: 55196235550 	 https://www.last.fm/music/Master%2BKG%2Bft.%2BNomcebo%2BZikode/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/50/55196235550.p (force=True)
#   --> This file is 23.9kB.
# Done. Sleeping for 2 seconds
# 8 / 30 	: 21440044091 	 https://www.last.fm/music/MASTER%2BKG%2B%26%2BNOMCEBO/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/91/21440044091.p (force=True)
#   --> This file is 21.0kB.
# Done. Sleeping for 2 seconds
# 9 / 30 	: 50010924535 	 https://www.last.fm/music/Master%2BKG%2C%2BIndlovukazi/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/35/50010924535.p (force=True)
#   --> This file is 23.9kB.
# Done. Sleeping for 2 seconds
# 10 / 30 	: 77397568738 	 https://www.last.fm/music/Master%2BKG%2Bft.%2BNomcebo/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/38/77397568738.p (force=True)
#   --> This file is 24.3kB.
# Done. Sleeping for 2 seconds
# 11 / 30 	: 91269871689 	 https://www.last.fm/music/Master%2BKG%2C%2BLebb%2BSimons%2C%2BMakhadzi/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/89/91269871689.p (force=True)
#   --> This file is 23.2kB.
# Done. Sleeping for 2 seconds
# 12 / 30 	: 75584079442 	 https://www.last.fm/music/Master%2BKG%2C%2BMakhadzi/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/42/75584079442.p (force=True)
#   --> This file is 23.6kB.
# Done. Sleeping for 2 seconds
# 13 / 30 	: 89367648633 	 https://www.last.fm/music/Master%2BKG%2B%28feat.%2BBurna%2BBoy%2C%2BNomcebo%2BZikode%29/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/33/89367648633.p (force=True)
#   --> This file is 22.9kB.
# Done. Sleeping for 2 seconds
# 14 / 30 	: 22126790025 	 https://www.last.fm/music/Master%2BKG%2BFeat.%2BNomcebo/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/25/22126790025.p (force=True)
#   --> This file is 23.9kB.
# Done. Sleeping for 2 seconds
# 15 / 30 	: 1211698333 	 https://www.last.fm/music/Master%2BKG%2C%2BMr%2BBrown/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/33/1211698333.p (force=True)
#   --> This file is 23.9kB.
# Done. Sleeping for 2 seconds
# 16 / 30 	: 84154690029 	 https://www.last.fm/music/Master%2BKG%2C%2BMakhadzi%2C%2BZanda%2BZakuza/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/29/84154690029.p (force=True)
#   --> This file is 24.0kB.
# Done. Sleeping for 2 seconds
# 17 / 30 	: 60586640484 	 https://www.last.fm/music/Master%2BKG%2Bfeat.%2BBurna%2BBoy%2C%2BNomcebo%2BZikode/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/84/60586640484.p (force=True)
#   --> This file is 22.0kB.
# Done. Sleeping for 2 seconds
# 18 / 30 	: 73364586702 	 https://www.last.fm/music/Master%2BKG%2C%2BMicro%2BTDH%2C%2BGreeicy%2C%2BNomcebo%2BZikode/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/2/73364586702.p (force=True)
#   --> This file is 21.9kB.
# Done. Sleeping for 2 seconds
# 19 / 30 	: 14687315050 	 https://www.last.fm/music/Master%2BKG%2C%2BMaxy/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/50/14687315050.p (force=True)
#   --> This file is 23.6kB.
# Done. Sleeping for 2 seconds
# 20 / 30 	: 96116611912 	 https://www.last.fm/music/MASTER%2BKG%2Bfeat%2BBURNA%2BBOY%2B%26%2BNOMCEBO%2BZIKODE/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/12/96116611912.p (force=True)
#   --> This file is 20.4kB.
# Done. Sleeping for 2 seconds
# 21 / 30 	: 96624096969 	 https://www.last.fm/music/Master%2BKG%252FNomcebo%2BZikode/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/69/96624096969.p (force=True)
#   --> This file is 21.4kB.
# Done. Sleeping for 2 seconds
# 22 / 30 	: 38027808680 	 https://www.last.fm/music/Master%2BKG%2C%2BMakhadzi%2C%2BMaxy/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/80/38027808680.p (force=True)
#   --> This file is 23.7kB.
# Done. Sleeping for 2 seconds
# 23 / 30 	: 8036831638 	 https://www.last.fm/music/Master%2BKG%2Bfeat.%2BIndlovukazi/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/38/8036831638.p (force=True)
#   --> This file is 22.1kB.
# Done. Sleeping for 2 seconds
# 24 / 30 	: 15455341537 	 https://www.last.fm/music/Master%2BKG%2BFt%2BNomcebo/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/37/15455341537.p (force=True)
#   --> This file is 21.4kB.
# Done. Sleeping for 2 seconds
# 25 / 30 	: 5750903278 	 https://www.last.fm/music/Master%2BKG%3B%2BNomcebo%2BZikode/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/78/5750903278.p (force=True)
#   --> This file is 21.4kB.
# Done. Sleeping for 2 seconds
# 26 / 30 	: 70283194485 	 https://www.last.fm/music/Master%2BKG%2B%26%2BNomcebo%2BZikode/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/85/70283194485.p (force=True)
#   --> This file is 21.5kB.
# Done. Sleeping for 2 seconds
# 27 / 30 	: 845370713 	 https://www.last.fm/music/Master%2BKG%2Bft.%2BZanda%2BZakuza/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/13/845370713.p (force=True)
#   --> This file is 23.1kB.
# Done. Sleeping for 2 seconds
# 28 / 30 	: 39396937729 	 https://www.last.fm/music/Master%2BKG%2Bfeat.%2BMr%2BBrown/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/29/39396937729.p (force=True)
#   --> This file is 21.4kB.
# Done. Sleeping for 2 seconds
# 29 / 30 	: 80522810275 	 https://www.last.fm/music/MASTER%2BKG%3BNOMCEBO%2BZIKODE/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/75/80522810275.p (force=True)
#   --> This file is 21.6kB.
# Done. Sleeping for 2 seconds
# 30 / 30 	: 27199516200 	 https://www.last.fm/music/Master%2BKG%2Bfeat.%2BMakhadzi%2B%26%2BZanda%2BZakuza/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/0/27199516200.p (force=True)
#   --> This file is 21.4kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 14 / 15 	 Maître Gims
# ====================================================================================================
# 14 / 15 	 Maître Gims ===> LastFM
#
#
# ===================== Searching For Maître Gims =====================
# 1 / 30 	: 13291871861 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/61/13291871861.p (force=True)
#   --> This file is 28.6kB.
# Done. Sleeping for 2 seconds
# 2 / 30 	: 4842877153 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2B%26%2BMaluma/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/53/4842877153.p (force=True)
#   --> This file is 27.2kB.
# Done. Sleeping for 2 seconds
# 3 / 30 	: 35848615431 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2B%26%2BVianney/+albums?order=release_date
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-lastfm/31/35848615431.p (force=True)
#   --> This file is 27.1kB.
# Done. Sleeping for 2 seconds
# 4 / 30 	: 18244595816 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2Bfeat.%2BDry/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/16/18244595816.p (force=True)
#   --> This file is 25.9kB.
# Done. Sleeping for 2 seconds
# 5 / 30 	: 16502011255 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2Bfeat.%2BSia/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/55/16502011255.p (force=True)
#   --> This file is 26.7kB.
# Done. Sleeping for 2 seconds
# 6 / 30 	: 11060165424 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2Bfeat.%2BDany%2BSynth%25C3%25A9/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/24/11060165424.p (force=True)
#   --> This file is 26.9kB.
# Done. Sleeping for 2 seconds
# 7 / 30 	: 83637091253 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2C%2BMaluma/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/53/83637091253.p (force=True)
#   --> This file is 25.0kB.
# Done. Sleeping for 2 seconds
# 8 / 30 	: 9322847457 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2Bfeat.%2BNiska/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/57/9322847457.p (force=True)
#   --> This file is 27.3kB.
# Done. Sleeping for 2 seconds
# 9 / 30 	: 97446897243 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2B%26%2BSting/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/43/97446897243.p (force=True)
#   --> This file is 26.8kB.
# Done. Sleeping for 2 seconds
# 10 / 30 	: 22907408174 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2B%26%2BAlvaro%2BSoler/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/74/22907408174.p (force=True)
#   --> This file is 24.5kB.
# Done. Sleeping for 2 seconds
# 11 / 30 	: 1997211634 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2B%26%2BSuper%2BSako/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/34/1997211634.p (force=True)
#   --> This file is 26.6kB.
# Done. Sleeping for 2 seconds
# 12 / 30 	: 98172048985 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2Bfeat.%2BThe%2BShin%2BSeka%25C3%25AF/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/85/98172048985.p (force=True)
#   --> This file is 25.3kB.
# Done. Sleeping for 2 seconds
# 13 / 30 	: 85642952340 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2Bfeat.%2BH%2BMagnum/+albums?order=release_date
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-lastfm/40/85642952340.p (force=True)
#   --> This file is 25.8kB.
# Done. Sleeping for 2 seconds
# 14 / 30 	: 52717721354 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2Bfeat.%2BMaska/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/54/52717721354.p (force=True)
#   --> This file is 24.4kB.
# Done. Sleeping for 2 seconds
# 15 / 30 	: 10158140786 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2C%2BVianney%2C%2BMa%25C3%25AEtre%2BGims%2Ben%2Bduo%2Bavec%2BVianney/+albums?order=release_date
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-lastfm/86/10158140786.p (force=True)
#   --> This file is 26.7kB.
# Done. Sleeping for 2 seconds
# 16 / 30 	: 68444599009 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2C%2BVianney/+albums?order=release_date
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-lastfm/9/68444599009.p (force=True)
#   --> This file is 24.4kB.
# Done. Sleeping for 2 seconds
# 17 / 30 	: 49684874267 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2Bfeat.%2BPitbull/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/67/49684874267.p (force=True)
#   --> This file is 23.9kB.
# Done. Sleeping for 2 seconds
# 18 / 30 	: 7112321664 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2C%2BSia/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/64/7112321664.p (force=True)
#   --> This file is 23.7kB.
# Done. Sleeping for 2 seconds
# 19 / 30 	: 3829569420 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2Bfeat.%2BDadju/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/20/3829569420.p (force=True)
#   --> This file is 26.0kB.
# Done. Sleeping for 2 seconds
# 20 / 30 	: 58784049419 	 https://www.last.fm/music/Vitaa%2Bfeat.%2BMa%25C3%25AEtre%2BGims/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/19/58784049419.p (force=True)
#   --> This file is 26.6kB.
# Done. Sleeping for 2 seconds
# 21 / 30 	: 58379682307 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2C%2BSting/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/7/58379682307.p (force=True)
#   --> This file is 25.0kB.
# Done. Sleeping for 2 seconds
# 22 / 30 	: 65441581109 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2Bfeat.%2BBlack%2BM%2B%2BJR%2BO%2BCrom/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/9/65441581109.p (force=True)
#   --> This file is 23.6kB.
# Done. Sleeping for 2 seconds
# 23 / 30 	: 95480728105 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2Bfeat.%2BVianney/+albums?order=release_date
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-lastfm/5/95480728105.p (force=True)
#   --> This file is 24.5kB.
# Done. Sleeping for 2 seconds
# 24 / 30 	: 55351563448 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2Bfeat.%2BBeidjik%2B-%2BDadju%2B%28The%2BShin%2BSeka%25C3%25AF%29%2B-%2BXgangs/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/48/55351563448.p (force=True)
#   --> This file is 24.3kB.
# Done. Sleeping for 2 seconds
# 25 / 30 	: 4234235360 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2B%28Feat.%2BSia%29/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/60/4234235360.p (force=True)
#   --> This file is 21.8kB.
# Done. Sleeping for 2 seconds
# 26 / 30 	: 55697094615 	 https://www.last.fm/music/OrelSan%2Bfeat.%2BMa%25C3%25AEtre%2BGims/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/15/55697094615.p (force=True)
#   --> This file is 25.7kB.
# Done. Sleeping for 2 seconds
# 27 / 30 	: 57777181932 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2Bfeat.%2BDjuna%2BFamily/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/32/57777181932.p (force=True)
#   --> This file is 25.4kB.
# Done. Sleeping for 2 seconds
# 28 / 30 	: 87000031360 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2Bfeat.%2BDany%2BSynth%25C3%25A9%2C%2BsoFly%2B%26%2BNius/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/60/87000031360.p (force=True)
#   --> This file is 24.6kB.
# Done. Sleeping for 2 seconds
# 29 / 30 	: 78368996209 	 https://www.last.fm/music/Ma%25C3%25AEtre%2BGims%2C%2BAlvaro%2BSoler/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/9/78368996209.p (force=True)
#   --> This file is 24.4kB.
# Done. Sleeping for 2 seconds
# 30 / 30 	: 68106913799 	 https://www.last.fm/music/Kendji%2BGirac%2B%26%2BMa%25C3%25AEtre%2BGims/+albums?order=release_date
# Saving /Volumes/Piggy/Discog/artists-lastfm/99/68106913799.p (force=True)
#   --> This file is 23.7kB.
# Done. Sleeping for 2 seconds

# %% [markdown]
# # Download Credit (AllMusic)

# %%
data = getFile("creditToDownload.p")
len(data)

# %%
for artistID,artist in data.items():
    break
    maindb.dbdata["AllMusic"]["Artists"].searchForArtistCredit(artist, artistID)

# %% [markdown]
# # Download Extra Data

# %%
bsdata = getHTML("/Volumes/Piggy/Discog/artists-musicbrainz/13/134347080492261077195869941664563052313.p")
pages  = bsdata.find("ul", {"class": "pagination"})
lis    = pages.findAll("li")
txts   = [li.text for li in lis]
npages = 0
for item in txts:
    try:
        npages = max([npages, int(item)])
    except:
        continue
npages

# %%
 = dbdata["MusicBrainz"]["Artists"].getData('314779112728565924209805500016231841915')

# %%
#dbdata["LastFM"]["Artists"].assertDBModValExtraData(15, test=False)

# %%
for modVal in range(100):
    dbdata["MusicBrainz"]["Artists"].assertDBModValExtraData(str(modVal), test=False, maxPages=20)

# %%
from random import randint, shuffle
modVals = list(range(100))
shuffle(modVals)
for modVal in modVals:
    dbdata["MusicBrainz"]["Artists"].assertDBModValExtraData(modVal, test=False, maxPages=2)

# %%
from random import randint, shuffle
modVals = list(range(100))
shuffle(modVals)
for modVal in modVals:
    break
    dbdata["LastFM"]["Artists"].assertDBModValExtraData(modVal, test=False, maxPages=20)

# %% [markdown]
# # Download Artist Data

# %%
artsDC.downloadArtistUnofficialFromID(144998)

# %%
maindb.getBasicArtistInfo("Black Sabbath")

# %%
dbdata["Discogs"]["Artists"].downloadArtistUnofficialFromID('144998', '/artist/144998-Black-Sabbath')
#/artist/144998-Black-Sabbath?type=Unofficial&subtype=Albums&filter_anv=0"
#/artist/144998-Black-Sabbath?sort=year%2Casc&limit=500&type=Unofficial&subtype=Albums&filter_anv=0&page=1

# %%
retval = dbdata["Discogs"]["Artist"].getData("/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p")

# %%
bsdata = getHTML("/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p")

# %%
retval.get()

# %%
retval.get()['artist'].get()

# %% [markdown]
# # Music DB

# %%
https://www.discogs.com/artist/144998-Black-Sabbath?sort=year%2Casc&limit=500?type=Unofficial&subtype=Albums&filter_anv=0
https://www.discogs.com/artist/144998-Black-Sabbath?sort=year%2Casc&limit=500&type=Unofficial&subtype=Albums&filter_anv=0&page=1
    
artistIDToRef = disc.getArtistIDToRefData()

# %%
myMusicAlbumIDMap = getFile("/Users/tgadfort/Documents/code/music/musicDiscogsMap.p")

# %%
dR=0.2
rC=0.8

# %%
from time import sleep
N = len(myMusicAlbumIDMap)
for i,(artistName,artistVals) in enumerate(myMusicAlbumIDMap.items()):
    if artistName.startswith("Levl") is False:
        continue
    artistID,discogsName = artistVals
    print(i,N,'\t',artistName)
    artsDC.searchDiscogForArtist(artistName)
    artsAM.searchAllMusicForArtist(artistName)
    artsMB.searchMusicBrainzForArtist(artistName)
    sleep(3)

# %%
artistIDs = [v[0] for k,v in myMusicAlbumIDMap.items()]
arts.rmIDsFromDBs(artistIDs)

# %%
arts.parseArtistModValFiles(96, force=False)
arts.parseArtistModValExtraFiles(96)

# %%
files = [savename]
from glob import glob
from os.path import join
from fileUtils import getDirname
files += glob(join(getDirname(savename), "extra", "{0}-*.p".format(artistID)))
files

# %% [markdown]
# # Download Missing Artists

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
from discogsBase import discogs

disc  = discogs()
albs  = albums(disc)
toget = albs.findMissingArtistsFromAlbums()

from ioUtils import saveFile
saveFile(idata=toget, ifile="missingArtistsFromAlbums.p")

# %%
# %load_ext autoreload
# %autoreload
disc = discogs()
arts = artists(disc)

from ioUtils import getFile

toget = getFile(ifile="missingArtistsFromAlbums.p")

from time import sleep
togetmap  = toget['togetmap']
refstoget = toget['toget']
for ia,item in enumerate(refstoget.most_common()):
    artistID, cnt = item[0], item[1]
    ref      = togetmap[artistID]
    url      = arts.getArtistURL(ref)
    savename = arts.getArtistSavename(artistID)
    if not isFile(savename):
        try:
            print('\n{0}/{1}'.format(ia,len(refstoget)))
            retval = arts.downloadArtistURL(url, savename, debug=True)
            sleep(3)
        except:
            continue
    else:
        print("{0} known".format(savename))
            
    #print(item)
#len(togetmap)

# %% [markdown]
# # Redownload Known Artist

# %%
myMusicMap = getFile("/Users/tgadfort/Documents/code/music/myMusicMap.p")

# %%
musicMap = myMusicMap["Ladies of Soul"]
musicMap

# %%
discDCIDToRef = discDC.getArtistIDToRefData()

# %%
artistID  = musicMap['Discogs']['ID']
artistRef = discDCIDToRef.get(artistID)
artsDC.downloadArtistFromID(artistID=artistID, artistRef=artistRef, force=True)

# %% [markdown]
# # Download Unmatched Artists

# %%
matchedResults = getFile("/Users/tgadfort/Documents/code/music/multiArtists.p")

# %%
searchForArtist = {"Discogs": artsDC.searchDiscogForArtist, "AllMusic": artsAM.searchAllMusicForArtist, "MusicBrainz": artsMB.searchMusicBrainzForArtist}

# %%
from time import sleep
for i,(artistName,artistValues) in enumerate(matchedResults["PartiallyUnknown"].items()):
    if i <= 83:
        continue
    print("=========== {0} [{1}/{2}] ===========".format(artistName, i, len(matchedResults["PartiallyUnknown"])))
    for dbKey, dirval in artistValues.items():
        print(artistName,'\t',searchForArtist[dbKey])
        searchForArtist[dbKey](artistName)
        sleep(1)
    sleep(1)

# %% [markdown]
# # Missing Artists From Albums

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
from discogsBase import discogs

disc  = discogs()
albs  = albums(disc)
toget = albs.findMissingArtistsFromAlbums()

# %%
# %load_ext autoreload
# %autoreload
disc = discogs()
arts = artists(disc)

from time import sleep
togetmap  = toget['togetmap']
refstoget = toget['toget']
for ia,item in enumerate(refstoget.most_common()):
    artistID, cnt = item[0], item[1]
    ref      = togetmap[artistID]
    url      = arts.getArtistURL(ref)
    savename = arts.getArtistSavename(artistID)
    if not isFile(savename):
        try:
            _, _ = clock('\n{0}/{1}'.format(ia,len(refstoget)))
            retval = arts.downloadArtistURL(url, savename, debug=True)
        except:
            continue
    else:
        print("{0} known".format(savename))
            
    #print(item)
#len(togetmap)

# %% [markdown]
# # Artists From Search

# %%
# %load_ext autoreload
# %autoreload
disc = discogs()
arts = artists(disc)
arts.searchDiscogForArtist("World of Our Own")
#arts.searchDiscogForArtist("Continental Divide")

# %%
from ioUtils import getFile

# %%
toGet = getFile(ifile="/Users/tgadfort/Documents/code/charts/chartCounter.p", debug=True)

# %%
toGet = getFile("~/code/charts/toget.p")

# %%
for i,val in enumerate(toGet):
    if i <= 206:
        continue
    print('='*30,val,'(',i,'/',len(toGet),')','='*30)
    arts.searchDiscogForArtist(val)
    print("\n\n\n")
    sleep(2)

# %%
from time import sleep
vals  = ["The Souvenirs", "The Stand", f"The Suicide Kings", "The Supremes", "The Temptations", "The Tomcats", "The Tone", "The Tourists", "The Unseen", "The Ventures", "The Vikings", "The Violents", "The Wailers", "The Want", "The Washingtonians", "The Witches", "UB40", "Underdog", "Unearth", "Unk", "Unscarred", "Up Front", "Up In Arms", "Urban Legends"]
vals += ["The Pits", "The Pressure", "The Pretenders", "The Prodigy", "The Product", "The Receptionists", "The Retardos", "The Revelers", "The Romancers", "The Roots", "The Rosehips", "The Ruiners", "The Runaways", "The Scholars", "The Seeds", "The Shams", "The Sights", "The Sillies", "The Skunks", "The Snowmen"]
vals += ["The Invisible Men", "The Israelites", "The Ivory Coast", "The Killers", "The Manatees", "The Marquees", "The Masters", "The Matrix", "The Mixtures", "The Moves", "The Noisettes", "The Nomads", "The Orange Peels", "The Outcasts"]
vals += ["The Game", "The Generics", "The Gits", "The Go-Betweens", "The Goblins", "The Godz", "The Great Society", "The Haters", "The Hilltops", "The Hookers", "The Immortals", "The Impacts", "The Inspector", "The Invaders"]
vals += ["The Diamonds", "The Diplomats", "The Dramatics", "The Drifters", "The Dust Brothers", "The Eagles", "The Exceptions", "The Fiends", "The Fixtures", "The Frantics", "The Freeze", "The Frogs", "The Fumes"]
vals += ["The Cardigans", "The Casualties", "The Challengers", "The Chameleons", "The Cheaters", "The Chicken Hawks", "The Crash", "The Crusaders", "The Cure", "The Darts", "The Deuce Coupes"]
vals += ["The Beat", "The Beatles", "The Blood Brothers", "The Blow Up", "The Bollweevils", "The Brentwoods", "The Broadways", "The Brood", "The Business", "The Busy Signals"]
vals += ["You", "Young Money", "Young Pioneers", "Zero Zero"]
for val in vals:
    print('='*30,val,'='*30)
    try:
        arts.searchDiscogForArtist(val)
    except:
        continue
    print("\n\n\n")
    sleep(10)

# %% [markdown]
# # New Artists From Albums

# %%
# %load_ext autoreload
# %autoreload
from albums import albums

disc = discogs()
albs = albums(disc)
toget = albs.findMissingArtistsFromAlbums()

# %%
from time import sleep
togetmap  = toget['togetmap']
refstoget = toget['toget']
for ia,item in enumerate(refstoget.most_common()):
    print('\n{0}/{1}'.format(ia,len(refstoget)))
    artistID, cnt = item[0], item[1]
    ref      = togetmap[artistID]
    url      = arts.getArtistURL(ref)
    savename = arts.getArtistSavename(artistID)
    if not isFile(savename):
        try:
            arts.downloadArtistURL(url, savename, debug=True)
        except:
            continue
        sleep(2)
    #print(item)
#len(togetmap)

# %% [markdown]
# # Albums From Known People

# %%
data = getFile("/Volumes/Music/MusicDB/toget.p")

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
disc = discogs()
discdf = disc.getMasterDiscogsDB()
print(discdf.shape)
discdf = discdf[~discdf['Name'].isna()]
print(discdf.shape)

artists = list(discdf["Artist"])

_ = clock("Last Run")

# %%
def getMusicData(key, artist):
    retval = discdf[discdf[key] == artist]
    if retval.shape[0] > 0:
        return retval
    else:
        return None
    
toget={}
known={}

for ia,artistName in enumerate(data):
    #artistID = artistName
    artistID = None
    if artistID is None:
        retval = getMusicData('Name', artistName)
        if retval is not None:
            artistID = retval.index.values[0]
    modValue  = dutils.getDiscIDHashMod(discID=artistID, modval=disc.getMaxModVal())
    if toget.get(modValue) is None:
        toget[modValue] = {}
    toget[modValue][artistID] = True
        
    if ia % 100 == 0:
        print(ia,'/',len(data))

# %%
for modVal in toget.keys():
    artistIDs = toget[modVal]
    print(modVal,'\t',len(artistIDs))
    dbdata = disc.getArtistsDBModValData(modVal)
    for artistID in artistIDs:
        print(' ',artistID)
        artistData = dbdata[artistID]
        albs.downloadAlbumFromArtistData(artistID=artistID, artistData=artistData, mediaTypes=None)

# %% [markdown]
# # Albums From All Artists

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
disc = discogs()
albs = albums(disc)
albs.downloadAlbumsFromArtists(maxAlbums=1, mediaTypes=None, rand=True)

# %%
maindb = mainDB(mdb=mdb, create=False)
#maindb.setDBFull() ## Do this to recreate everything
maindb.setDBKnown()
artistDBs = maindb.getKnownArtistDBs()

# %% [markdown]
# # Discogs

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsDiscogs import dbArtistsDiscogs
ad = dbArtistsDiscogs(debug=True)
#ad.searchForArtist("Dave Matthews")
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/70/420570.p"
ifile="/Users/tgadfort/Music/Discog/artists-discogs/34/386834.p"
retval = ad.getData(ifile)
print(retval.get()['artist'].get())
#ad.searchForArtist("Niel Diamond")

# %% [markdown]
# # AllMusic

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsAllMusic import dbArtistsAllMusic
am = dbArtistsAllMusic(debug=True)
#am.searchForArtist("Dave Matthews")
ifile="/Users/tgadfort/Music/Discog/artists-allmusic/61/0000687561.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/70/420570.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/34/386834.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # MusicBrainz

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsMusicBrainz import dbArtistsMusicBrainz
am = dbArtistsMusicBrainz(debug=True)
#am.searchForArtist("Dave Matthews")
ifile="/Users/tgadfort/Music/Discog/artists-musicbrainz/71/100112022548628725831976514629370881371.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # LastFM

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsLastFM import dbArtistsLastFM
am = dbArtistsLastFM(debug=True)
#am.searchForArtist("Dave Matthews Band")
ifile="/Users/tgadfort/Music/Discog/artists-lastfm/14/64101467014.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # RockCorner

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsRockCorner import dbArtistsRockCorner
am = dbArtistsRockCorner(debug=True)
#am.searchForArtist("Dave Matthews Band")
ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # RateYourMusic

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsRockCorner import dbArtistsRockCorner
am = dbArtistsRockCorner(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # CDandLP

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsCDandLP import dbArtistsCDandLP
am = dbArtistsCDandLP(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # AceBootlegs

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsAceBootlegs import dbArtistsAceBootlegs
am = dbArtistsAceBootlegs(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # DatPiff

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsDatPiff import dbArtistsDatPiff
am = dbArtistsDatPiff(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # MusicStack

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsMusicStack import dbArtistsMusicStack
am = dbArtistsMusicStack(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %%
ad = artistsDiscogs(debug=True)

# %%
ad = artistsDiscogs(debug=True)
ifile="/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p"
retval = ad.getData(ifile)
retval.get()['artist'].get()
ad.searchForArtist("Niel Diamond")

# %%
retval = ad.getData(ifile)
retval.get()['artist'].get()

# %%
ad.searchForArtist("Niel Diamond")

# %%
from artistAM import artistAM
from discogsUtils import allmusicUtils

class artistsAllMusic(artistsBase):
    def __init__(self, debug=False):
        self.db     = "AllMusic"
        self.disc   = discogs(self.db.lower())
        self.artist = artistAM(self.disc)
        self.dutils = allmusicUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        url = "{0}/discography/all".format(artistRef)
        return url
        
        if artistRef.startswith("http"):
            return artistRef
        else:
            baseURL = self.disc.discogURL
            url     = urllib.parse.urljoin(baseURL, quote(artistRef))
            return url

            
        if artistRef.startswith("/artist/") is False:
            print("Artist Ref needs to start with /artist/")
            return None
        
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, quote(artistRef))
        url     = urllib.parse.urljoin(url, "?sort=year%2Casc&limit=500") ## Make sure we get 500 entries)
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("artists/", quote(artist)))
                  
                    
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}
        
        uls = bsdata.findAll("ul", {"class": "search-results"})
        for ul in uls:
            lis = ul.findAll("li", {"class": "artist"})
            for li in lis:
                divs = li.findAll("div", {"class": "name"})
                for div in divs:
                    link     = div.find("a")
                    href     = link.attrs['href']
                    tooltip  = link.attrs['data-tooltip']
                    try:
                        from json import loads
                        tooltip = loads(tooltip)
                        artistID = tooltip['id']
                    except:
                        artistID = None
            
                    if artistDB.get(href) is None:
                        artistDB[href] = {"N": 0, "Name": artist}
                    artistDB[href]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1
        
            discID   = self.dutils.getArtistID(href)
            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
am = artistsAllMusic(debug=True)
#am.searchForArtist("Niel Diamond")

# %%
from artistMB import artistMB
from discogsUtils import musicbrainzUtils
from hashlib import md5

class artistsMusicBrainz(artistsBase):
    def __init__(self, debug=False):
        self.db     = "MusicBrainz"
        self.disc   = discogs(self.db.lower())
        self.artist = artistMB(self.disc)
        self.dutils = musicbrainzUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = "https://musicbrainz.org/"
        extra = "search?query={0}&type=artist&limit=100&method=indexed".format(quote(artist))

        url = urllib.parse.urljoin(baseURL, extra)         
                    
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}

        tables = bsdata.findAll("table")
        for table in tables:
            ths = table.findAll("th")
            headers = [x.text for x in ths]
            trs = table.findAll("tr")
            for tr in trs[1:]:
                tds    = tr.findAll("td")
                name   = tds[0].find('a').text
                href   = tds[0].find('a').attrs['href']
            
                if artistDB.get(href) is None:
                    artistDB[href] = {"N": 0, "Name": name}
                artistDB[href]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1

            discID   = self.dutils.getArtistID(href)
            
            uuid = href.split('/')[-1]

            m = md5()
            for val in uuid.split("-"):
                m.update(val.encode('utf-8'))
            hashval = m.hexdigest()
            discID  = str(int(hashval, 16))

            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
am = artistsMusicBrainz(debug=True)
#am.searchForArtist("Niel Diamond")

# %%
from artistLM import artistLM
from discogsUtils import lastfmUtils

class artistsLastFM(artistsBase):
    def __init__(self, debug=False):
        self.db     = "LastFM"
        self.disc   = discogs(self.db.lower())
        self.artist = artistLM(self.disc)
        self.dutils = lastfmUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        #print("getArtistURL(",artistRef,")")
        if artistRef.startswith("http"):
            url = artistRef
        else:
            baseURL = self.disc.discogURL
            if artistRef.startswith("/") is True:
                #print("Join", end="\t")
                url     = urllib.parse.urljoin(baseURL, quote(artistRef[1:]))
                #print(url)
            else:
                url     = urllib.parse.urljoin(baseURL, quote(artistRef))
            #print(url)
                
            if url.endswith("/") is False:
                url     = "{0}{1}".format(url, "/+albums?order=release_date")
            else:
                url     = "{0}{1}".format(url, "+albums?order=release_date")
                
            #print(url)
        
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("artists?q=", quote(artist)))
                    
            
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}
        
        uls = bsdata.findAll("ul", {"class": "artist-results"})
        for ul in uls:
            lis = ul.findAll("li", {"class": "artist-result"})
            for li in lis:
                h4 = li.find("h4")
                if h4 is None:
                    raise ValueError("No h4 in list")
                ref = h4.find('a')
                if ref is None:
                    raise ValueError("No ref in h4")

                name = ref.attrs['title']
                url  = ref.attrs['href']
                artistID = self.dutils.getArtistID(name)
        
                #print(name,'\t',url,'\t',artistID)
                if artistDB.get(url) is None:
                    artistDB[url] = {"N": 0, "Name": name}
                artistDB[url]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1
        
            name     = hrefData["Name"]
            discID   = self.dutils.getArtistID(name)
            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)
                
    
    def assertDBModValExtraData(self, modVal, maxPages=None):
        mulArts             = multiartist()        
        
        print("assertDBModValExtraData(",modVal,")")
        artistDBDir = self.disc.getArtistsDBDir()
        dbname  = setFile(artistDBDir, "{0}-DB.p".format(modVal))     
        dbdata  = getFile(dbname)
        nerrs = 0
        
        for artistID,artistData in dbdata.items():
            pages = artistData.pages
            if pages.more is True:
                npages = pages.tot
                if maxPages is not None:
                    npages = min([npages, maxPages])
                artistRef = artistData.url.url
                print(artistID,'\t',artistData.artist.name)
                multiValues = mulArts.getArtistNames(artistData.artist.name)
                if len(multiValues) > 1:
                    print("\tNot downloading multis: {0}".format(multiValues.keys()))
                    continue
                for p in range(2, npages+1):
                    url      = self.getArtistURL(artistRef, p)
                    savename = self.getArtistSavename(artistID, p)
                    print(artistID,'\t',url,'\t',savename)
                    if not isFile(savename):
                        self.downloadArtistURL(url=url, savename=savename, force=True, debug=True)
                        sleep(3)

# %%
al = artistsLastFM(debug=True)

# %%
#al.searchForArtist("Neil Diamond")

# %%
from artistRC import artistRC
from discogsUtils import rockcornerUtils

class artistsRockCorner(artistsBase):
    def __init__(self, debug=False):
        self.db     = "RockCorner"
        self.disc   = discogs(self.db.lower())
        self.artist = artistRC(self.disc)
        self.dutils = rockcornerUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        if artistRef.startswith("http"):
            url = artistRef
        else:
            baseURL = self.disc.discogURL
            if artistRef.startswith("/") is True:
                #print("Join", end="\t")
                url     = urllib.parse.urljoin(baseURL, quote(artistRef[1:]))
                #print(url)
            else:
                url     = urllib.parse.urljoin(baseURL, quote(artistRef))
                        
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):

        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("search?q=", quote(artist)))
                    

        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}

        songs = bsdata.findAll("article", {"class": "bgl0"}) + bsdata.findAll("article", {"class": "bgl1"})
        for i,song in enumerate(songs):
            label     = song.find("label")
            if label is None:
                continue
            name      = label.text
            ref       = song.find("a").attrs['href']
            artistURL = "/".join(ref.split("/")[:2])

            #print(name,'\t',url,'\t',artistID)
            if artistDB.get(artistURL) is None:
                artistDB[artistURL] = {"N": 0, "Name": name}
            artistDB[artistURL]["N"] += 1


        if self.debug:
            print("Found {0} artists".format(len(artistDB)))

        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1

            name     = hrefData["Name"]
            discID   = self.dutils.getArtistID(name)
            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
ar = artistsRockCorner(debug=True)

# %%
#ar.searchForArtist("Neil Diamond")

# %%
from artistRM import artistRM
from discogsUtils import rateyourmusicUtils

class artistsRateYourMusic(artistsBase):
    def __init__(self, debug=False):
        self.db     = "RateYourMusic"
        self.disc   = discogs(self.db.lower())
        self.artist = artistRM(self.disc)
        self.dutils = rateyourmusicUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        return

# %%
am = artistsRateYourMusic(debug=True)

# %%
from artistCL import artistCL
from discogsUtils import cdandlpUtils

class artistsCDandLP(artistsBase):
    def __init__(self, debug=False):
        self.db     = "CDandLP"
        self.disc   = discogs(self.db.lower())
        self.artist = artistCL(self.disc)
        self.dutils = cdandlpUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        #print("getArtistURL(",artistRef,")")
        if artistRef.startswith("http"):
            url = artistRef
        else:
            baseURL = self.disc.discogURL
            if artistRef.startswith("/") is True:
                #print("Join", end="\t")
                url     = urllib.parse.urljoin(baseURL, quote(artistRef[1:]))
                #print(url)
            else:
                url     = urllib.parse.urljoin(baseURL, quote(artistRef))
        
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("?q=", quote(artist)))


        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}
        
        descrs = bsdata.findAll("div", {"class": "listingDescription"})
        for descr in descrs:
            refs = descr.findAll("a", {"class": "listingTitle"})
            for ref in refs:
                url      = ref.attrs['href']
                fullurl  = "/".join(url.split("/")[:-4])
                fullurl  = "{0}/artist".format(fullurl)
                artistID = self.dutils.getArtistID(fullurl)
                if artistDB.get(fullurl) is None:
                    artistDB[fullurl] = {"N": 0, "ID": artistID}
                artistDB[fullurl]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1
        
            discID   = hrefData["ID"]
            url      = href
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url,'\t',savename)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
ac = artistsCDandLP(debug=True)

# %%
#ac.searchForArtist("Neil Diamond")

# %%
from artistCL import artistCL
from discogsUtils import acebootlegsUtils

class artistsAceBootlegs(artistsBase):
    def __init__(self, debug=False):
        self.db     = "AceBootlegs"
        self.disc   = discogs(self.db.lower())
        self.artist = artistAB(self.disc)
        self.dutils = acebootlegsUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url
    
    def getMainSavename(self):
        artistDir = self.disc.getArtistsDir()
        savename  = setFile(artistDir, "main.p")
        return savename
    
    
    ##################################################################################################################
    # Main
    ##################################################################################################################
    def downloadMainArtists(self, force=False, debug=False, sleeptime=2):        
        savename = self.getMainSavename()
        
        ## Parse data
        bsdata = getHTML(savename)        
        artistDB  = {}
        
        
        ## Find and Download Artists
        categories = bsdata.find("div", {"class": "sidebar-widget widget_categories"})
        if categories is None:
            raise ValueError("Cannot find categories!")
        uls = categories.findAll("ul")
        for ul in uls:
            lis = ul.findAll("li")
            for i, li in enumerate(lis):
                try:
                    catitem = li.attrs["class"][1]
                except:
                    raise ValueError("Cannot find list class item: {0}".format(li))
                ref  = li.find("a")
                if ref is None:
                    raise ValueError("Cannot find list link!")
                try:
                    href = ref.attrs['href']
                except:
                    raise ValueError("Cannot find list href!")

                # check for artist
                artistName = href.split('/')[-2]
                try:
                    int(artistName)
                    continue
                except:
                    if artistName.find("parent-category-ii") == -1:
                        pass
                    else:
                        continue

                # get artist ID
                artistID = catitem.split('-')[-1]
                try:
                    int(artistID)
                except:
                    continue


                if force is False and isFile(savename):
                    print("{0} exists.".format(savename))
                    continue
            
                url = href
                savename = self.getArtistSavename(artistID)
                print(i,'\t',artistID,'\t',artistName,'\t',savename)
                self.downloadArtistURL(url=url, savename=savename, parse=False)

                
        
        

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        return

# %%
aa = artistsAceBootlegs(debug=True)

# %%
from artistDP import artistDP
from discogsUtils import datpiffUtils

class artistsDatPiff(artistsBase):
    def __init__(self, debug=False):
        self.db     = "DatPiff"
        self.disc   = discogs(self.db.lower())
        self.artist = artistDP(self.disc)
        self.dutils = datpiffUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url
    

    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        
        baseURL = "https://www.datpiff.com/"
        extra   = "mixtapes-search?criteria={0}&sort=relevance".format(quote(artist))

        url = urllib.parse.urljoin(baseURL, extra)
        print("\tSearch URL: {0}".format(url))
                    
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = []

        contentdivs = bsdata.findAll("div", {"class": "contentItem"})
        for i,contentdiv in enumerate(contentdivs):
            artistDiv = contentdiv.find("div", {"class": "artist"})
            if artistDiv is None:
                continue
            artistName = artistDiv.text

            albumDiv = contentdiv.find("div", {"class": "title"})
            if albumDiv is None:
                continue
            albumName = albumDiv.text
            try:
                albumURL  = albumDiv.find("a").attrs['href']
            except:
                albumURL  = None
                
            #artistID = self.discogsUtils.getArtistID(artistName)

            artistDB.append({"ArtistName": artistName, "AlbumName": albumName, "AlbumURL": albumURL})
        

        artistID = self.discogsUtils.getArtistID(artist)
        page     = 1
        savename = self.getArtistSavename(artistID, page)
        while isFile(savename):
            page += 1
            savename = self.getArtistSavename(artistID, page)
        print("Saving {0} new artist media to {1}".format(len(artistDB), savename))
        saveJoblib(data=artistDB, filename=savename, compress=True)

# %%
ad = artistsDatPiff(debug=True)

# %%
from artistMS import artistMS
from discogsUtils import musicstackUtils
from searchUtils import findPatternExt
from fileUtils import getBaseFilename


class artistsMusicStack(artistsBase):
    def __init__(self, debug=False):
        self.db     = "MusicStack"
        self.disc   = discogs(self.db.lower())
        self.artist = artistMS(self.disc)
        self.dutils = musicstackUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url
    

    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist=None):
        files = findPatternExt("/Users/tgadfort/Downloads/", pattern="MusicStack", ext=".html")
        for ifile in files:
            fname  = getBaseFilename(ifile)
            artist = fname[:fname.find(" Vinyl Records")]
            self.parseSearchForArtist(artist=artist, ifile=ifile)
    
    def parseSearchForArtist(self, artist, ifile):

        ## Parse data
        bsdata = getHTML(ifile)
        
        artistDB  = []

        tables = bsdata.findAll("table")
        if self.debug:
            print("Found {0} tables".format(len(tables)))
        for i,table in enumerate(tables):
            trs = table.findAll("tr")
            jj = 0
            headers = None
            values  = []
            for j,tr in enumerate(trs):
                tds  = tr.findAll("td")
                #print('\t',len(tds))
                #tds  = [list(td.strings) for td in tds]
                if len(tds) == 8:
                    if jj == 0:
                        headers = tds
                        if self.debug:
                            print("  Found Header: {0}".format(headers))
                    else:
                        values.append(tds)
                        if self.debug:
                            print("  Found Value: {0}".format(tds))

                    jj += 1

            if headers is not None:
                keys = []
                for header in headers:
                    b = header.find("b")
                    if b is None:
                        keys.append(str(len(keys)))
                    else:
                        txt = b.text.strip()
                        keys.append(txt)
                        
                if self.debug:
                    print("  Keys: {0}".format(keys))
                    print("  Values: {0}".format(len(values)))


                for value in values:
                    value = [x for ix,x in enumerate(value) if keys[ix] in ["Artist", "Title"]]
                    album = dict(zip(["Artist", "Title"], value))
                    album["Artist"] = album["Artist"].text
                    album["Album"]  = {"Name": album["Title"].text}
                    try:
                        album["Album"]["URL"] = album["Title"].find("a").attrs['href']
                    except:
                        album["Album"]["URL"] = None
                    del album["Title"]
                    artistDB.append({"ArtistName": album["Artist"], "AlbumName": album["Album"]["Name"], "AlbumURL": album["Album"]["URL"]})
                break

        artistID = self.dutils.getArtistID(artist)
        page     = 1
        savename = self.getArtistSavename(artistID, page)
        while isFile(savename) and False:
            page += 1
            savename = self.getArtistSavename(artistID, page)
        print("Saving {0} new artist media to {1}".format(len(artistDB), savename))
        saveJoblib(data=artistDB, filename=savename, compress=True)

# %%
am = artistsMusicStack(debug=False)
am.searchForArtist()
