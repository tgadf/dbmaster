# %%
## Basic stuff
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))

## Python Version
import sys
print("Python: {0}".format(sys.version))


################################################################################
## General Stuff
################################################################################
from ioUtils import saveJoblib, loadJoblib, saveFile, getFile
from timeUtils import clock, elapsed
from fsUtils import moveFile, setFile, setDir, setSubDir, isFile, isDir, mkDir
from fileUtils import getFileBasics, getBasename
from webUtils import getHTML
from multiprocessing import Pool


######################################################
# Music Stuff
######################################################
from dbBase import dbBase
from multiArtist import multiartist
from myMusicDBMap import myMusicDBMap
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData




import datetime as dt
start = dt.datetime.now()
print("Notebook Last Run Initiated: "+str(start))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# Python: 3.7.7 (default, Mar 26 2020, 10:32:53)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# Notebook Last Run Initiated: 2021-01-03 18:00:50.171800

# %% [markdown]
# # MusicBrainz

# %%
files = maindb.dbdata["MusicBrainz"]["Artists"].getArtistModValFiles(0)

# %%
bsdata = getHTML("/Volumes/Piggy/Discog/artists-musicbrainz/0/6144800262646015459972430895745946300.p")

# %%
ifile="/Volumes/Piggy/Discog/artists-musicbrainz/0/6144800262646015459972430895745946300.p"
data = maindb.dbdata["MusicBrainz"]["Artists"].getData(ifile)
data.show()

# %%
for ifile in files:
    print(ifile)
    print(data.show())

# %%
data.show()

# %% [markdown]
# ## Parse Artists Base

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData
maindb = mainDB(mdb=None, create=True, debug=False)
pdb    = parseDBArtistsData(maindb=maindb)
dbdata = maindb.dbdata
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================

# %%
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBFull("MusicBrainz")
elapsed(start, cmt)
# Out:
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RockCorner
#   Creating Database Records for AceBootlegs
#   Creating Database Records for CDandLP
#   Creating Database Records for RateYourMusic
#   Creating Database Records for MusicStack
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RockCorner, AceBootlegs, CDandLP, RateYourMusic, MusicStack
# ========================= masterArtistNameDB =========================
#   Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicnames/mainArtistNameDB.p
#   There are currently 6660 artist keys.
#   There are currently 7707 renamed artist keys.
# Adding 1 known multi delim artists.
# Current Time is Sun Jan 03, 2021 18:04:45 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/6-Metadata.p  	0 1689
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/94-Metadata.p  	1 3349
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/77-Metadata.p  	2 5165
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/40-Metadata.p  	3 6945
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/15-Metadata.p  	4 8645
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/22-Metadata.p  	5 10322
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/88-Metadata.p  	6 12042
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/99-Metadata.p  	7 13795
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/33-Metadata.p  	8 15483
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/51-Metadata.p  	9 17197
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/66-Metadata.p  	10 18843
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/85-Metadata.p  	11 20513
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/18-Metadata.p  	12 22238
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/36-Metadata.p  	13 23990
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/63-Metadata.p  	14 25706
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/54-Metadata.p  	15 27431
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/48-Metadata.p  	16 29119
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/80-Metadata.p  	17 30857
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/91-Metadata.p  	18 32595
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/3-Metadata.p  	19 34335
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/59-Metadata.p  	20 36022
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/45-Metadata.p  	21 37772
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/72-Metadata.p  	22 39520
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/27-Metadata.p  	23 41233
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/10-Metadata.p  	24 42935
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/42-Metadata.p  	25 44691
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/75-Metadata.p  	26 46420
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/20-Metadata.p  	27 48143
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/17-Metadata.p  	28 49835
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/69-Metadata.p  	29 51517
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/4-Metadata.p  	30 53225
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/96-Metadata.p  	31 54886
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/87-Metadata.p  	32 56659
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/78-Metadata.p  	33 58405
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/9-Metadata.p  	34 60133
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/31-Metadata.p  	35 61839
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/64-Metadata.p  	36 63532
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/53-Metadata.p  	37 65285
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/28-Metadata.p  	38 67032
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/82-Metadata.p  	39 68831
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/34-Metadata.p  	40 70546
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/56-Metadata.p  	41 72247
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/61-Metadata.p  	42 73962
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/70-Metadata.p  	43 75626
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/47-Metadata.p  	44 77314
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/12-Metadata.p  	45 79026
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/25-Metadata.p  	46 80807
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/93-Metadata.p  	47 82515
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/1-Metadata.p  	48 84178
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/39-Metadata.p  	49 85884
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/37-Metadata.p  	50 87462
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/62-Metadata.p  	51 89166
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/55-Metadata.p  	52 90894
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/81-Metadata.p  	53 92567
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/49-Metadata.p  	54 94277
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/58-Metadata.p  	55 96005
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/90-Metadata.p  	56 97688
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/2-Metadata.p  	57 99399
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/44-Metadata.p  	58 101220
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/73-Metadata.p  	59 102917
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/26-Metadata.p  	60 104628
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/11-Metadata.p  	61 106402
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/7-Metadata.p  	62 108144
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/95-Metadata.p  	63 109865
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/89-Metadata.p  	64 111517
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/76-Metadata.p  	65 113213
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/41-Metadata.p  	66 114894
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/14-Metadata.p  	67 116607
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/23-Metadata.p  	68 118296
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/32-Metadata.p  	69 119966
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/50-Metadata.p  	70 121622
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/67-Metadata.p  	71 123367
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/98-Metadata.p  	72 125087
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/19-Metadata.p  	73 126813
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/84-Metadata.p  	74 128584
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/83-Metadata.p  	75 130285
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/29-Metadata.p  	76 132032
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/35-Metadata.p  	77 133817
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/57-Metadata.p  	78 135530
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/60-Metadata.p  	79 137305
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/71-Metadata.p  	80 139045
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/46-Metadata.p  	81 140758
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/13-Metadata.p  	82 142524
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/24-Metadata.p  	83 144274
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/38-Metadata.p  	84 145990
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/92-Metadata.p  	85 147756
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/0-Metadata.p  	86 149498
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/43-Metadata.p  	87 151196
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/74-Metadata.p  	88 152905
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/21-Metadata.p  	89 154680
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/16-Metadata.p  	90 156375
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/5-Metadata.p  	91 158149
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/97-Metadata.p  	92 159904
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/68-Metadata.p  	93 161625
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/79-Metadata.p  	94 163260
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/86-Metadata.p  	95 164917
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/30-Metadata.p  	96 166620
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/65-Metadata.p  	97 168320
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/52-Metadata.p  	98 170027
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/8-Metadata.p  	99 171712
#
#
# ==============================================
#
# Saving 171712 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToRef.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToRef.p
#   --> This file is 8.8MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToRef.p
#   --> This file is 8.8MB.
# Saving 171712 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToName.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToName.p
#   --> This file is 6.3MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToName.p
#   --> This file is 6.3MB.
# Saving 171712 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToVariations.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToVariations.p
#   --> This file is 6.8MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToVariations.p
#   --> This file is 6.8MB.
# Current Time is Sun Jan 03, 2021 18:04:57 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 11 seconds.
# Current Time is Sun Jan 03, 2021 18:04:57 for
# =================================== Creating Artist DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 171712 Artists
# 	Shape --> (171712, 1)
# 	Shape --> (171712, 2)
#   Finding Real Artist Name
# 	Shape --> (171712, 4)
#   Removing None Artist
# 	Shape --> (171712, 4)
#   Finding Disc Artist Name
# 	Shape --> (171712, 5)
#   Cleaning Disc Artist Name (MusicBrainz Only)
# 	Shape --> (171712, 5)
# DataFrame Shape is (171712, 7)
# Current Time is Sun Jan 03, 2021 18:05:01 for Done with
# =================================== Creating Artist DB ===================================
# Process [Done with
# =================================== Creating Artist DB ===================================] took 4 seconds.
# Saving Master Artist DB File: /Users/tgadfort/Music/Discog/db-musicbrainz/MasterSlimArtistDB.p
#   --> This file is 28.3MB.
# Current Time is Sun Jan 03, 2021 18:05:04 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/51-MediaMetadata.p 	1714      0         7706
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/6-MediaMetadata.p 	3403      0         15164
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/16-MediaMetadata.p 	5098      0         22522
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/32-MediaMetadata.p 	6768      0         30386
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/94-MediaMetadata.p 	8428      0         37598
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/75-MediaMetadata.p 	10157     0         45659
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/48-MediaMetadata.p 	11845     0         52853
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/47-MediaMetadata.p 	13533     0         60399
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/63-MediaMetadata.p 	15249     0         67953
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/82-MediaMetadata.p 	17048     0         75320
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/19-MediaMetadata.p 	18774     0         82299
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/9-MediaMetadata.p 	20502     0         90432
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/24-MediaMetadata.p 	22252     0         97778
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/23-MediaMetadata.p 	23941     0         105518
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/85-MediaMetadata.p 	25611     0         113491
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/64-MediaMetadata.p 	27304     0         121118
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/59-MediaMetadata.p 	28991     0         128840
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/40-MediaMetadata.p 	30771     0         136485
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/72-MediaMetadata.p 	32519     0         144017
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/93-MediaMetadata.p 	34227     0         151628
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/35-MediaMetadata.p 	36012     0         159694
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/11-MediaMetadata.p 	37786     0         167966
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/1-MediaMetadata.p 	39449     0         175798
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/56-MediaMetadata.p 	41150     0         184021
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/65-MediaMetadata.p 	42850     0         192171
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/58-MediaMetadata.p 	44578     0         199540
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/22-MediaMetadata.p 	46255     0         206902
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/84-MediaMetadata.p 	48026     0         215076
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/41-MediaMetadata.p 	49707     0         222318
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/92-MediaMetadata.p 	51473     0         230609
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/34-MediaMetadata.p 	53188     0         238103
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/73-MediaMetadata.p 	54885     0         246079
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/57-MediaMetadata.p 	56598     0         252824
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/10-MediaMetadata.p 	58300     0         260591
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/0-MediaMetadata.p 	60042     0         269345
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/7-MediaMetadata.p 	61784     0         276608
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/17-MediaMetadata.p 	63476     0         284116
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/50-MediaMetadata.p 	65132     0         290892
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/74-MediaMetadata.p 	66841     0         298272
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/49-MediaMetadata.p 	68551     0         306256
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/33-MediaMetadata.p 	70239     0         313994
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/95-MediaMetadata.p 	71960     0         321414
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/46-MediaMetadata.p 	73673     0         329452
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/83-MediaMetadata.p 	75374     0         337091
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/18-MediaMetadata.p 	77099     0         344731
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/8-MediaMetadata.p 	78784     0         353849
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/25-MediaMetadata.p 	80565     0         361506
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/62-MediaMetadata.p 	82269     0         369339
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/39-MediaMetadata.p 	83975     0         376879
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/43-MediaMetadata.p 	85673     0         384554
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/67-MediaMetadata.p 	87418     0         392141
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/86-MediaMetadata.p 	89075     0         400239
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/20-MediaMetadata.p 	90798     0         407983
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/68-MediaMetadata.p 	92519     0         415655
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/55-MediaMetadata.p 	94247     0         423139
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/89-MediaMetadata.p 	95899     0         430813
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/2-MediaMetadata.p 	97610     0         438583
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/12-MediaMetadata.p 	99322     0         445862
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/36-MediaMetadata.p 	101074    0         454240
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/90-MediaMetadata.p 	102757    0         461301
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/71-MediaMetadata.p 	104497    0         469342
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/76-MediaMetadata.p 	106193    0         477149
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/97-MediaMetadata.p 	107948    0         484953
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/31-MediaMetadata.p 	109654    0         492872
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/15-MediaMetadata.p 	111354    0         499999
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/5-MediaMetadata.p 	113128    0         508369
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/28-MediaMetadata.p 	114875    0         515970
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/52-MediaMetadata.p 	116582    0         523864
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/27-MediaMetadata.p 	118295    0         531329
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/81-MediaMetadata.p 	119968    0         538932
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/60-MediaMetadata.p 	121743    0         546981
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/79-MediaMetadata.p 	123378    0         554063
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/44-MediaMetadata.p 	125199    0         562214
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/98-MediaMetadata.p 	126919    0         570306
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/96-MediaMetadata.p 	128580    0         577617
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/30-MediaMetadata.p 	130283    0         584809
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/77-MediaMetadata.p 	132099    0         592540
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/53-MediaMetadata.p 	133852    0         600329
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/14-MediaMetadata.p 	135565    0         608347
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/4-MediaMetadata.p 	137273    0         616060
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/29-MediaMetadata.p 	139020    0         624176
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/61-MediaMetadata.p 	140735    0         631812
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/26-MediaMetadata.p 	142446    0         639149
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/80-MediaMetadata.p 	144184    0         647030
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/99-MediaMetadata.p 	145937    0         654926
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/78-MediaMetadata.p 	147683    0         663124
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/45-MediaMetadata.p 	149433    0         670848
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/42-MediaMetadata.p 	151189    0         678974
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/38-MediaMetadata.p 	152905    0         686841
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/87-MediaMetadata.p 	154678    0         695171
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/21-MediaMetadata.p 	156453    0         702552
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/66-MediaMetadata.p 	158099    0         710558
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/88-MediaMetadata.p 	159819    0         717625
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/3-MediaMetadata.p 	161559    0         725317
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/13-MediaMetadata.p 	163325    0         734168
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/69-MediaMetadata.p 	165007    0         741865
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/54-MediaMetadata.p 	166732    0         749051
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/70-MediaMetadata.p 	168396    0         756524
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/37-MediaMetadata.p 	169974    0         763794
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/91-MediaMetadata.p 	171712    0         771271
#
#
# ==============================================
#
# Saving 171712 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumNames.p
#   --> This file is 35.6MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumNames.p
#   --> This file is 35.6MB.
# Saving 171712 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumRefs.p
#   --> This file is 31.6MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumRefs.p
#   --> This file is 31.6MB.
# Saving 171712 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumNames.p
#   --> This file is 4.3MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumNames.p
#   --> This file is 4.3MB.
# Saving 171712 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumRefs.p
#   --> This file is 4.3MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumRefs.p
#   --> This file is 4.3MB.
# Current Time is Sun Jan 03, 2021 18:05:58 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 53 seconds.
# Current Time is Sun Jan 03, 2021 18:05:58 for
# =================================== Creating Artist Album DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 171712 Artists
# 	Shape --> (171712, 1)
# DataFrame Shape is (171712, 1)
# Saving Master Artist Albums DB File: /Users/tgadfort/Music/Discog/db-musicbrainz/MasterSlimArtistAlbumsDB.p
#   --> This file is 64.3MB.
# Current Time is Sun Jan 03, 2021 18:06:12 for Done with
# =================================== Creating Artist Album DB ===================================
# Process [Done with
# =================================== Creating Artist Album DB ===================================] took 13 seconds.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f50a903869b8> in <module>
#       1 maindb = mainDB(mdb=None, create=True, debug=True)
#       2 maindb.setDBFull("MusicBrainz")
# ----> 3 elapsed(start, cmt)
#
# NameError: name 'cmt' is not defined

# %% [markdown]
# ## Create Metadata (Only)

# %%
dbs    = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
dbs    = ['AllMusic']
dbs    = []
if len(dbs) > 0:
    start,cmt=clock("Parsing Metadata")
    for db in dbs:
        pdb.parseMetadata(db=db, nProcs=3, modVals=list(range(100)), force=True) 
    elapsed(start, cmt)

# %% [markdown]
# # Parse Downloads

# %%
dbs = ["RateYourMusic", "MusicStack"]
dbs = ["RateYourMusic"]
if len(dbs) > 0:
    start,cmt=clock("Parsing Downloads")
    for db in dbs:
        pdb.parseDownloads(db)
    elapsed(start, cmt)

# %% [markdown]
# # Parse Everything

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData
maindb = mainDB(mdb=None, create=True, debug=False)
pdb    = parseDBArtistsData(maindb=maindb)


dbs    = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
#dbs = ['MusicBrainz', 'LastFM']
dbs = ["Discogs"]
#dbs = ["Discogs", "MusicBrainz"]
dbs = ["AllMusic"]
#dbs = ["RateYourMusic"]
#dbs = ["MusicBrainz"]
#dbs = []
start,cmt=clock("Parsing Everything")
for db in dbs:
    s = 10
    #pdb.parse(db, nProcs=3, modVals=list(range(s,s+9)), force=False)
    #pdb.parse(db, nProcs=4, modVals=list(range(10,100)), force=True)
    #pdb.parse(db, nProcs=3, modVals=list(range(100)), force=False, extra=False)
    #pdb.parse(db, nProcs=3, modVals=[88,89,87,37,98,97], force=True, extra=False)
    #pdb.parse(db, nProcs=1, modVals=[9], force=True)
    pdb.parse(db, nProcs=3, modVals=list(range(100)), force=False, primary=True)
    #pdb.parse(db, nProcs=2, modVals=list(range(100)), force=False)
elapsed(start, cmt)

# %% [markdown]
# # Parse Extra Data

# %%
dbs = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
dbs = ['MusicBrainz']

# %load_ext autoreload
# %autoreload
from parseDBArtistsData import parseDBArtistsData
pdb    = parseDBArtistsData(maindb=maindb)

start,cmt=clock("Parsing Everything")
for db in dbs:
    #pdb.parse(db, nProcs=3, modVals=list(range(100)), force=False, extra=True)
    #pdb.parse(db, nProcs=1, modVals=list(range(80,100)), force=False, extra=True)
    #pdb.parse(db, nProcs=1, modVals=list(range(80)), force=False, extra=True)
    pdb.parse(db, nProcs=1, modVals=[79], force=False, extra=True)
elapsed(start, cmt)

# %% [markdown]
# # Parse Credit Data

# %%
dbs = ['AllMusic']
#dbs = []

# %load_ext autoreload
# %autoreload
from parseDBArtistsData import parseDBArtistsData
pdb    = parseDBArtistsData(maindb=maindb)

start,cmt=clock("Parsing Everything")
for db in dbs:
    #pdb.parse(db, nProcs=1, modVals=[9], force=False, credit=True)
    pdb.parse(db, nProcs=3, modVals=list(range(100)), force=False, credit=True)
elapsed(start, cmt)

# %% [markdown]
# # LastFM

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData

def parseLastFM(modVals=list(range(100)), force=False, primary=False, extra=False, fulldb=False):
    db = "LastFM"
    if isinstance(modVals, int):
        modVals = [modVals]
    nProcs = min(3, len(modVals))

    start,cmt=clock("Parsing Everything for {0}".format(db))
    if primary is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, primary=True)  ## Primary

    if extra is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, extra=True)  ## Extra
    
    if fulldb is True:
        maindb = mainDB(mdb=None, create=True, debug=True)
        maindb.setDBFull(db)
        elapsed(start, cmt)    
    
parseLastFM(primary=True, fulldb=True)

# %% [markdown]
# # MusicBrainz

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData

def parseMusicBrainz(modVals=list(range(100)), force=False, primary=False, credit=False, extra=False, fulldb=False):
    db = "MusicBrainz"
    previousDays=4
    if isinstance(modVals, int):
        modVals = [modVals]
    nProcs = min(3, len(modVals))

    start,cmt=clock("Parsing Everything for {0}".format(db))
    if primary is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, previousDays=previousDays, force=force, primary=True)  ## Primary

    if extra is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, extra=True)  ## Extra
    

    if fulldb is True:
        maindb = mainDB(mdb=None, create=True, debug=True)
        maindb.setDBFull(db)
        elapsed(start, cmt)    
    
parseMusicBrainz(primary=True, force=True)

# %%
data=getFile("/Users/tgadfort/Music/Discog/artists-musicbrainz-db/0-DB.p")

# %%
data['100442956818207492535169252608810699800'].profile.external

# %% [markdown]
# # Discogs

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData

def parseDiscogs(modVals=list(range(100)), force=False, primary=False, credit=False, extra=False, fulldb=False):
    db = "Discogs"
    previousDays=5
    if isinstance(modVals, int):
        modVals = [modVals]
    nProcs = min(3, len(modVals))

    start,cmt=clock("Parsing Everything for {0}".format(db))
    if primary is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, previousDays=previousDays, force=force, primary=True)  ## Primary

    if credit is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, credit=True)  ## Credit

    if extra is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, extra=True)  ## Extra
    

    if fulldb is True:
        maindb = mainDB(mdb=None, create=True, debug=True)
        maindb.setDBFull(db)
        elapsed(start, cmt)    
    
parseDiscogs(primary=True, fulldb=True)

# %% [markdown]
# # AllMusic

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData

maindb = mainDB(mdb=None, create=True, debug=False)
pdb    = parseDBArtistsData(maindb=maindb)
pdb.parse("AllMusic", nProcs=1, modVals=[69], previousDays=100, force=True, primary=True)  ## Primary
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================
# DB: AllMusic --> Primary=True   Extra=False   Credit=False   PreviousDays=100
# Parsing AllMusic with 1 processes using [[69]] mod values.
# ----------------------------------------------------------------------------------------------------
# Parsing Artist Files For ModVal 69
#   ===> Parsing all 956 files for modval 69
# Forcing Reloads of ModVal=69
#   Processing 956 files.
# HI
# 	Processed 0/956 files.
# 	Processed 100/956 files.
# 	Processed 200/956 files.
# 	Processed 300/956 files.
# File: /Volumes/Piggy/Discog/artists-allmusic/69/0000782269.p
# AllMusic Artist Data Class
# -------------------------
# Artist:  None
# Meta:    Artist Search for "crown jul" | AllMusic
#          https://www.allmusic.com/search/artists/crown+jul
# URL:     None
# ID:      None
# Profile: {'profile': None, 'aliases': None, 'members': None, 'sites': None, 'groups': None, 'variations': None, 'search': 'crown jul', 'err': None}
# Pages:   {'ppp': 1, 'tot': 1, 'pages': 1, 'err': None, 'more': False, 'redo': False}
# Media:   {'counts': {'Releases': {'Albums': 0}}, 'err': None}
#    Albums
# None
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/discogs-0.0.1-py3.7.egg/parseDBArtistsData.py", line 33, in parseArtistsAM
#     self.dbdata["AllMusic"]["Artists"].parseArtistModValFiles(modVal, force=self.force, previousDays=self.previousDays)
#   File "/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/dbdata-0.0.1-py3.7.egg/dbArtistsBase.py", line 492, in parseArtistModValFiles
#     1/0
# ZeroDivisionError: division by zero
# """
#
# The above exception was the direct cause of the following exception:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-51cf190165b3> in <module>
#       6 maindb = mainDB(mdb=None, create=True, debug=False)
#       7 pdb    = parseDBArtistsData(maindb=maindb)
# ----> 8 pdb.parse("AllMusic", nProcs=1, modVals=[69], previousDays=100, force=True, primary=True)  ## Primary
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/discogs-0.0.1-py3.7.egg/parseDBArtistsData.py in parse(self, db, nProcs, modVals, previousDays, force, primary, extra, credit)
#     163                 time.sleep(1)
#     164         print("")
# --> 165         return result.get()
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# ZeroDivisionError: division by zero

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData

def parseAllMusic(modVals=list(range(100)), force=False, primary=False, credit=False, fulldb=False):
    db = "AllMusic"
    previousDays=4
    if isinstance(modVals, int):
        modVals = [modVals]
    nProcs = min(3, len(modVals))

    start,cmt=clock("Parsing Everything for {0}".format(db))
    if primary is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, previousDays=previousDays, force=force, primary=True)  ## Primary

    if credit is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, credit=True)  ## Credit
    

    if fulldb is True:
        maindb = mainDB(mdb=None, create=True, debug=True)
        maindb.setDBFull(db)
        elapsed(start, cmt)    
    
parseAllMusic(primary=True)
# %load_ext autoreload
# %autoreload
parseAllMusic(credit=True)
parseAllMusic(fulldb=True)

# %%
modVal = 0
artistDBDir = dbdata["AllMusic"]["Disc"].getArtistsDBDir()
moddbdata   = dbdata["AllMusic"]["Disc"].getArtistsDBModValData(modVal)
nerrs   = 0

# %%
len(moddbdata)

# %%
from fileUtils import getBaseFilename
files = dbdata["AllMusic"]["Artists"].getArtistModValFiles(modVal, force=True)
artistIDs = {getBaseFilename(ifile): ifile for ifile in files}

# %%
toget = []
for artistID,ifile in artistIDs.items():
    if moddbdata.get(artistID) is None:
        info   = dbdata["AllMusic"]["Artists"].getData(ifile)
        artistName = info.profile.search
        if artistName is not None and len(artistName) > 0:
            info.show()
            break
        #self.creditToDownload[artistID] = [artistName,self.getArtistSavename(artistID, credit=True)]

# %% [markdown]
# ****
# ****
# ****
# ****

# %% [markdown]
# # Recreate Artist Names

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBArtists(recreate=False)
elapsed(start, cmt)

# %% [markdown]
# # Master Work

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBFull()
elapsed(start, cmt)

# %%
df = getFile("/Users/tgadfort/Music/Discog/db-rockcorner/MasterSlimArtistDB.p")
df["MultiStatus"].value_counts()

# %% [markdown]
# ## Parse Single ModVal

# %%
for i in range(10):
    for j in range(10):
        print("{0}touch /Volumes/Piggy/Discog/artists-discogs/{1}/0*0*0*".format("!", i*10+j))
        print("{0}echo '{1}'".format("!", i+10*j))

# %%
masterDBDF = maindb.dbdata["MusicBrainz"]["Disc"].getMasterSlimArtistDiscogsDB()

# %%
from searchUtils import findExt
from fsUtils import setDir, setFile
modVal = 99
artistDBDir = maindb.dbdata["Discogs"]["Artists"].getArtistsDBDir()
artistDir   = maindb.dbdata["Discogs"]["Artists"].getArtistsDir()
dirVal = setDir(artistDir, str(modVal))
files  = findExt(dirVal, ext='.p')
dbname = setFile(artistDBDir, "{0}-DB.p".format(modVal))
len(files)

# %%
from datetime import datetime, timedelta    
from os import path

def getFiles():
    from searchUtils import findExt
    from fsUtils import setDir, setFile
    modVal = 99
    artistDBDir = maindb.dbdata["Discogs"]["Artists"].getArtistsDBDir()
    artistDir   = maindb.dbdata["Discogs"]["Artists"].getArtistsDir()
    dirVal = setDir(artistDir, str(modVal))
    files  = findExt(dirVal, ext='.p')
    return files

def getNewFiles(dbname, previousDays=5, force=False):
    now    = datetime.now()
    files  = getFiles()
    if isFile(dbname):
        lastModified = datetime.fromtimestamp(path.getmtime(dbname))
        if force is True:
            lastModified = None
    else:
        lastModified = None
 
    if lastModified is None:
        newFiles = files
    else:
        numNew    = [ifile for ifile in files if (now-datetime.fromtimestamp(path.getmtime(ifile))).days < previousDays]
        numRecent = [ifile for ifile in files if datetime.fromtimestamp(path.getmtime(ifile)) > lastModified]
        newFiles  = list(set(numNew).union(set(numRecent)))
        print(len(files))
        print(len(numNew))
        print(len(numRecent))
    print(len(newFiles))

# %%
artistDBDir = maindb.dbdata["Discogs"]["Artists"].getArtistsDBDir()
artistDir   = maindb.dbdata["Discogs"]["Artists"].getArtistsDir()
dirVal = setDir(artistDir, str(modVal))
dbname = setFile(artistDBDir, "{0}-DB.p".format(modVal))

files = getNewFiles(dbname=dbname, previousDays=50, force=True)

# %%
now    = datetime.now()

# %%
def parseArtistModValFiles(self, modVal, force=False, debug=False, doExtra=False):        
    from os import path
    from datetime import datetime, timedelta

    print("-"*100)
    print("Parsing Artist Files For ModVal {0}".format(modVal))
    artistInfo = self.artist

    artistDir = self.disc.getArtistsDir()
    maxModVal = self.disc.getMaxModVal()

    artistDBDir = self.disc.getArtistsDBDir()        

    dirVal = setDir(artistDir, str(modVal))
    files  = findExt(dirVal, ext='.p')
    dbname = setFile(artistDBDir, "{0}-DB.p".format(modVal))



    ### Check for recent files
    if isFile(dbname):
        lastModified = datetime.fromtimestamp(path.getmtime(dbname))
        now    = datetime.now()            
        if force is False:
            numRecent = [ifile for ifile in files if datetime.fromtimestamp(path.getmtime(ifile)) > lastModified]
            numNew    = [ifile for ifile in files if (now-datetime.fromtimestamp(path.getmtime(ifile))).days < 1]
            if len(numRecent) == 0:
                print("  ===> Found {0} files, but there are no new files to parse so skipping.".format(len(files)))
                return 0
            else:
                print("  ===> Found {0} files. There are {1} new files to parse.".format(len(files), len(numRecent)))
    else:
        force = True
        lastModified = datetime.fromtimestamp(mktime(gmtime(0)))


    if force is False:
        dbdata = getFile(dbname, version=3)
    else:
        print("Forcing Reloads of ModVal={0}".format(modVal))
        print("  Processing {0} files.".format(len(files)))
        dbdata = {}

    saveIt = 0
    for j,ifile in enumerate(files):
        if force is True:
            if j % 500 == 0:
                print("\tProcessed {0}/{1} files.".format(j,len(files)))
        artistID = getBaseFilename(ifile)
        isKnown  = dbdata.get(artistID)
        recent   = datetime.fromtimestamp(path.getctime(ifile))
        if isKnown is None or recent > lastModified or force is True:
            info   = artistInfo.getData(ifile)

            if info.ID.ID != artistID:

                # Check Profile
                try:
                    artistName = info.profile.search
                    if artistName is not None:
                        self.creditToDownload[artistID] = [artistName,self.getArtistSavename(artistID, credit=True)]
                except:
                    pass

                if debug is False:
                    continue
                print("ID From Name: {0}".format(artistID))
                print("ID From File: {0}".format(info.ID.ID))

                print("File: {0}".format(ifile))
                print("Info: {0}".format(info.url.get()))
                continue
                #1/0

            saveIt += 1
            dbdata[artistID] = info


    forceSave = False
    if saveIt > 0 and doExtra is True:
        print("\tCalling Extra Parsing")
        dbdata = self.parseArtistModValExtraFiles(modVal, dbdata=dbdata, force=force, debug=debug)
        forceSave = True
        saveIt = len(dbdata)


    if len(self.creditToDownload) > 0:
        print("Found {0} artists that need new downloads.".format(len(self.creditToDownload)))


    if saveIt > 0 or forceSave is True:
        savename = setFile(artistDBDir, "{0}-DB.p".format(modVal))     
        print("Saving {0} new artist IDs to {1}".format(saveIt, savename))
        dbNumAlbums = sum([self.getArtistNumAlbums(artistData) for artistData in dbdata.values()])
        print("Saving {0} total artist media".format(dbNumAlbums))
        saveFile(idata=dbdata, ifile=savename)

        self.createArtistModValMetadata(modVal=modVal, db=dbdata, debug=debug)
        self.createArtistAlbumModValMetadata(modVal=modVal, db=dbdata, debug=debug)

    return saveIt

# %%
masterDBDF[~(masterDBDF.DiscArtist == masterDBDF.CleanDiscArtist)]

# %%
data = getFile("creditToDownload.p")

# %%
# %load_ext autoreload
# %autoreload
from masterArtistNameDB import masterArtistNameDB
manDB = masterArtistNameDB("master")

# %%
manDB.removeArtist("NF")
manDB.removeArtist("nf")

# %%
dbrs = getFile("dbrenames.yaml")
del dbrs["John Myers"]
manDB.addRenames(dbrs)

# %%
manDB.addRenames(getFile("dbrenames.yaml"))

# %%
manDB.save()
manDB.saveRenames()

# %%
start,cmt=clock("Parsing Single ModVal")
pdb.parse(db="Discogs", modVals=[0], nProcs=1, force=False)
elapsed(start, cmt)

# %%
data = getFile('/Users/tgadfort/Music/Discog/artists-discogs-db/0-DB.p')

# %%
len(data)

# %%
def getArtistNumAlbums(artistData):
    numAlbums = sum([len(x) for x in artistData.media.media.values()])
    return numAlbums
saveIt = True
dbNumAlbums = sum([getArtistNumAlbums(artistData) for artistData in data.values()])
print('0', dbNumAlbums)

# %%
bsdata = getHTML("/Volumes/Piggy/Discog/artists-allmusic/99/0002579199.p")
#bsdata = getHTML("/Users/tgadfort/Downloads/DJ Spinz _ Credits _ AllMusic.htm")

# %%
data = getFile("/Users/tgadfort/Music/Discog/artists-allmusic-db/99-DB.p")

# %%
data['0002579199']

# %%
amcredit = artistAMCredit()

# %%
#amdata = amcredit.getData("/Users/tgadfort/Downloads/DJ Spinz _ Credits _ AllMusic.htm")
amdata = maindb.dbdata["AllMusic"]["Artist"].getData("/Volumes/Piggy/Discog/artists-allmusic/99/0002579199.p")
amdata.show()

# %%
dbdata["LastFM"]["Artists"].parseArtistModValExtraFiles(0, force=True, debug=True)

# %%
from glob import glob
glob('/Volumes/Piggy/Discog/artists-lastfm/0/extra/11792020000-*.p')

# %%
bsdata = getHTML(ifile)
ols = bsdata.findAll("ol", {"class": "buffer-standard"})
ols

# %%
ifile='/Volumes/Piggy/Discog/artists-lastfm/0/extra/72742897500-2.p'
#getFile(ifile)
a       = dbdata["LastFM"]["Artist"].getData(ifile, debug=False)

def info(a):
    name    = a.artist.name
    ID      = a.ID.ID
    url     = a.url.url
    pages   = a.pages
    media   = a.media
    counts  = a.mediaCounts
    profile = a.profile

    print("{0: <10}{1}".format("Name:", name))
    print("{0: <10}{1}".format("ID:", ID))
    print("{0: <10}{1}".format("URL:", url))
    print("{0: <10}{1}".format("Pages:", pages.get()))
    print("{0: <10}{1}".format("Profile:", profile.get()))
    print("{0: <10}{1}".format("Counts:", counts.get()))
    print("{0: <10}".format("Media:"))
    for mediaType,mediaData in media.get()['media'].items():
        for mediaInfo in mediaData:
            print("\t{0: <10}{1}".format(mediaType, mediaInfo.get()['album']))

# %%
info(a)

# %%
nProcs = 8
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
maindb = mainDB(mdb=None, create=True, debug=True)
start,cmt=clock("Parsing All Artists")
start2,cmt2=clock("Parallel Artist Parsing")

parseArtistsParallel(db="AllMusic", nProcs=nProcs)
maindb.setDBFull("AllMusic")

parseArtistsParallel(db="MusicBrainz", nProcs=nProcs)
maindb.setDBFull("MusicBrainz")

parseArtistsParallel(db="Discogs", nProcs=nProcs)
maindb.setDBFull("Discogs")

#parseArtistsParallel(db="AceBootlegs", nProcs=1)
#parseArtistsParallel(db="DatPiff", nProcs=1)
#parseArtistsParallel(db="RateYourMusic", nProcs=3)
parseArtistsParallel(db="LastFM", nProcs=nProcs)
maindb.setDBFull("LastFM")

#parseArtistsParallel(db="RockCorner", nProcs=3)
#parseArtistsParallel(db="CDandLP", nProcs=3)
#parseArtistsParallel(db="MusicStack", nProcs=1)
elapsed(start2, cmt2)
elapsed(start, cmt)

# %% [markdown]
# # Master DB

# %%
print("\n\n{0}\n".format("Full DB"))
print("\n\n{0}\n".format("Known DB"))
#maindb.setDBKnown() ## Do this to recreate everything
#maindb.setDBKnown()
#artistDBs = maindb.getKnownArtistDBs()

# %% [markdown]
# # Download My Known Artists

# %%
mdb = myMusicDBMap(debug=True)

# %%
dbsToGet = ["AllMusic", "Discogs", "MusicBrainz", "LastFM", "RockCorner", "CDandLP"]
searches = [dbdata["AllMusic"]["Artists"].searchAllMusicForArtist, dbdata["Discogs"]["Artists"].searchDiscogForArtist,
            dbdata["MusicBrainz"]["Artists"].searchMusicBrainzForArtist, dbdata["LastFM"]["Artists"].searchLastFMForArtist,
            dbdata["RockCorner"]["Artists"].searchRockCornerForArtist, dbdata["CDandLP"]["Artists"].searchCDandLPForArtist]

dbsToGet = ["AllMusic"]
searches = [dbdata["AllMusic"]["Artists"].searchAllMusicForArtist]

# %%
def searchAll(mdb, minI=-1):
    nArtists = len(mdb.getArtists())
    for i,artistName in enumerate(mdb.getArtists()):
        if i <= minI:
            continue

        print('\n\n\n')
        print('-'*130)
        print(i,'/',nArtists,'===>\t',artistName)
        print('-'*130)
        print('\n')
        
        dbdata = mdb.getArtistData(artistName)
        if all([dbdata.get("LastFM"), dbdata.get("Discogs"), dbdata.get("AllMusic"), dbdata.get("MusicBrainz")]):
            print("{0} is well known.".format(artistName))
            continue
        else:
            print("{0} get it!".format(artistName))

        for search in searches:
            print("====>",search)
            try:
                search(artistName)
            except:
                sleep(3)

# %%
searchAll(mdb, 3404)

# %%
# Refused

# %% [markdown]
# # Albums

# %%
# %load_ext autoreload
# %autoreload
from album import album
from albums import albums
from discogsBase import discogs

disc = discogs()
albs = albums(disc)
#albs.parseAlbumModValFiles(modVal=27)

# %%
def parseAlbums(modVal):
    albs.parseAlbumModValFiles(modVal=modVal)
    #albs.createAlbumModValMetadata(modVal)
    #albs.createAlbumModValMetadata(modVal=modVal)

def parseAlbumsParallel(modVals=None):
    if modVals is None:
        modVals = ["NAN"] + list(range(100))
        #modVals = range(100)
    nProcs = 2
    pool = Pool(processes=nProcs)
    result = pool.map_async(parseAlbums, modVals)
 
    start, cmt = clock("Processing {0} modVals using {1} processes".format(modVals, nProcs))
    print("Runing .",end="")
    while not result.ready():
        #print(".",end="")
        time.sleep(10)
    print("")
    
    elapsed(start, cmt)
    return result.get()

# %%
# %load_ext autoreload
# %autoreload
from album import album
from albums import albums
albs = albums(disc)

start,cmt=clock("Parsing All Albums")
start2,cmt2=clock("Parallel Album Parsing")
parseAlbumsParallel()
elapsed(start2, cmt2)
elapsed(start, cmt)

# %% [markdown]
# # Download Stuff

# %%
mdb = myMusicDBMap(debug=True)
maindb = mainDB(mdb=mdb, create=False, debug=True)
dbdata = maindb.dbdata

# %%
ifile = "unmatchedArtists4.p"
noMatches = getFile(ifile)
print(len(noMatches))
dbs = ['Discogs', 'AllMusic', 'MusicBrainz', 'LastFM']
dbs = ['MusicBrainz']

#noMatches=['Go-A', 'PM', 'Qango']

from time import sleep
maxI = -1
for i,artist in enumerate(noMatches):
    print("="*100)
    print("="*100)
    print("="*100)
    print("="*100)
    print(i,'/',len(noMatches),'\t',artist)
    if i <= maxI:
        continue
    for db in dbs:
        print("="*100)
        print(i,'/',len(noMatches),'\t',artist,'===>',db)
        try:
            dbdata[db]["Artists"].searchForArtist(artist)
        except:
            sleep(5)
