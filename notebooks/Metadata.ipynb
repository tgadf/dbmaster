# %%
## Basic stuff
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))

## Python Version
import sys
print("Python: {0}".format(sys.version))


################################################################################
## General Stuff
################################################################################
from ioUtils import saveJoblib, loadJoblib, saveFile, getFile
from timeUtils import clock, elapsed
from fsUtils import moveFile, setFile, setDir, setSubDir, isFile, isDir, mkDir
from fileUtils import getFileBasics, getBasename
from webUtils import getHTML
from multiprocessing import Pool


######################################################
# Music Stuff
######################################################
from dbBase import dbBase
from multiArtist import multiartist
from myMusicDBMap import myMusicDBMap
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData




import datetime as dt
start = dt.datetime.now()
print("Notebook Last Run Initiated: "+str(start))
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# Python: 3.7.7 (default, Mar 26 2020, 10:32:53)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# /Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# Notebook Last Run Initiated: 2021-02-08 13:40:37.461867

# %% [markdown]
# # MusicBrainz

# %%
files = maindb.dbdata["MusicBrainz"]["Artists"].getArtistModValFiles(0)

# %%
bsdata = getHTML("/Volumes/Piggy/Discog/artists-musicbrainz/0/6144800262646015459972430895745946300.p")

# %%
ifile="/Volumes/Piggy/Discog/artists-musicbrainz/0/6144800262646015459972430895745946300.p"
data = maindb.dbdata["MusicBrainz"]["Artists"].getData(ifile)
data.show()

# %%
for ifile in files:
    print(ifile)
    print(data.show())

# %%
data.show()

# %% [markdown]
# ## Parse Artists Base

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData
maindb = mainDB(mdb=None, create=True, debug=False)
pdb    = parseDBArtistsData(maindb=maindb)
dbdata = maindb.dbdata

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBFull("Deezer")
elapsed(start, cmt)
# Out:
# Current Time is Sun Feb 07, 2021 18:24:15 for Creating DB
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rateyourmusic   =========================
# =========================   deezer   =========================
# =========================   albumoftheyear   =========================
# =========================   genius   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RateYourMusic
#   Creating Database Records for Deezer
#   Creating Database Records for AlbumOfTheYear
#   Creating Database Records for Genius
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RateYourMusic, Deezer, AlbumOfTheYear, Genius
# ========================= masterArtistNameDB =========================
#   Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicnames/mainArtistNameDB.p
#   There are currently 7249 artist keys.
#   There are currently 8456 renamed artist keys.
# Adding 1 known multi delim artists.
# Current Time is Sun Feb 07, 2021 18:24:15 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/6-Metadata.p  	0 98
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/94-Metadata.p  	1 176
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/77-Metadata.p  	2 272
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/40-Metadata.p  	3 348
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/15-Metadata.p  	4 428
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/22-Metadata.p  	5 721
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/88-Metadata.p  	6 808
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/99-Metadata.p  	7 902
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/33-Metadata.p  	8 995
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/51-Metadata.p  	9 1099
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/66-Metadata.p  	10 1185
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/85-Metadata.p  	11 1274
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/18-Metadata.p  	12 1365
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/36-Metadata.p  	13 1474
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/63-Metadata.p  	14 1566
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/54-Metadata.p  	15 1649
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/48-Metadata.p  	16 1752
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/80-Metadata.p  	17 1860
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/91-Metadata.p  	18 1992
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/3-Metadata.p  	19 2091
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/59-Metadata.p  	20 2171
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/45-Metadata.p  	21 2259
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/72-Metadata.p  	22 2552
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/27-Metadata.p  	23 2635
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/10-Metadata.p  	24 2732
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/42-Metadata.p  	25 3024
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/75-Metadata.p  	26 3113
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/20-Metadata.p  	27 3207
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/17-Metadata.p  	28 3292
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/69-Metadata.p  	29 3393
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/4-Metadata.p  	30 3486
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/96-Metadata.p  	31 3577
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/87-Metadata.p  	32 3674
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/78-Metadata.p  	33 3762
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/9-Metadata.p  	34 3838
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/31-Metadata.p  	35 3951
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/64-Metadata.p  	36 4042
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/53-Metadata.p  	37 4145
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/28-Metadata.p  	38 4248
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/82-Metadata.p  	39 4535
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/34-Metadata.p  	40 4625
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/56-Metadata.p  	41 4717
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/61-Metadata.p  	42 4828
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/70-Metadata.p  	43 4912
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/47-Metadata.p  	44 5012
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/12-Metadata.p  	45 5307
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/25-Metadata.p  	46 5400
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/93-Metadata.p  	47 5484
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/1-Metadata.p  	48 5590
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/39-Metadata.p  	49 5698
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/37-Metadata.p  	50 5785
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/62-Metadata.p  	51 6065
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/55-Metadata.p  	52 6158
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/81-Metadata.p  	53 6273
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/49-Metadata.p  	54 6352
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/58-Metadata.p  	55 6441
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/90-Metadata.p  	56 6521
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/2-Metadata.p  	57 6825
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/44-Metadata.p  	58 6908
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/73-Metadata.p  	59 6994
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/26-Metadata.p  	60 7080
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/11-Metadata.p  	61 7186
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/7-Metadata.p  	62 7300
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/95-Metadata.p  	63 7389
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/89-Metadata.p  	64 7474
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/76-Metadata.p  	65 7573
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/41-Metadata.p  	66 7690
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/14-Metadata.p  	67 7790
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/23-Metadata.p  	68 7892
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/32-Metadata.p  	69 8188
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/50-Metadata.p  	70 8269
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/67-Metadata.p  	71 8357
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/98-Metadata.p  	72 8450
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/19-Metadata.p  	73 8556
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/84-Metadata.p  	74 8640
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/83-Metadata.p  	75 8720
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/29-Metadata.p  	76 8818
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/35-Metadata.p  	77 8904
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/57-Metadata.p  	78 8981
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/60-Metadata.p  	79 9060
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/71-Metadata.p  	80 9186
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/46-Metadata.p  	81 9290
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/13-Metadata.p  	82 9376
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/24-Metadata.p  	83 9480
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/38-Metadata.p  	84 9569
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/92-Metadata.p  	85 9842
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/0-Metadata.p  	86 9932
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/43-Metadata.p  	87 10021
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/74-Metadata.p  	88 10107
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/21-Metadata.p  	89 10244
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/16-Metadata.p  	90 10345
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/5-Metadata.p  	91 10430
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/97-Metadata.p  	92 10533
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/68-Metadata.p  	93 10618
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/79-Metadata.p  	94 10709
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/86-Metadata.p  	95 10807
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/30-Metadata.p  	96 10895
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/65-Metadata.p  	97 11000
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/52-Metadata.p  	98 11287
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/8-Metadata.p  	99 11372
#
#
# ==============================================
#
# Saving 11372 entries to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToRef.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToRef.p
#   --> This file is 136.7kB.
# Saved data to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToRef.p
#   --> This file is 136.7kB.
# Saving 11372 entries to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToName.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToName.p
#   --> This file is 235.8kB.
# Saved data to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToName.p
#   --> This file is 235.8kB.
# Saving 11372 entries to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToVariations.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToVariations.p
#   --> This file is 273.9kB.
# Saved data to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToVariations.p
#   --> This file is 273.9kB.
# Current Time is Sun Feb 07, 2021 18:24:16 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 905.0 millseconds.
# Current Time is Sun Feb 07, 2021 18:24:16 for
# =================================== Creating Artist DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 11372 Artists
# 	Shape --> (11372, 1)
# 	Shape --> (11372, 2)
#   Finding Real Artist Name
# 	Shape --> (11372, 4)
#   Removing None Artist
# 	Shape --> (11372, 4)
#   Finding Disc Artist Name
# 	Shape --> (11372, 5)
# DataFrame Shape is (11372, 7)
# Current Time is Sun Feb 07, 2021 18:24:16 for Done with
# =================================== Creating Artist DB ===================================
# Process [Done with
# =================================== Creating Artist DB ===================================] took 280.0 millseconds.
# Saving Master Artist DB File: /Users/tgadfort/Music/Discog/db-deezer/MasterSlimArtistDB.p
#   --> This file is 1.4MB.
# Current Time is Sun Feb 07, 2021 18:24:16 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/51-MediaMetadata.p 	104       0         75
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/6-MediaMetadata.p 	202       0         155
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/16-MediaMetadata.p 	303       0         234
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/32-MediaMetadata.p 	599       0         433
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/94-MediaMetadata.p 	677       0         494
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/75-MediaMetadata.p 	766       0         563
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/48-MediaMetadata.p 	869       0         641
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/47-MediaMetadata.p 	969       0         724
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/63-MediaMetadata.p 	1061      0         788
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/82-MediaMetadata.p 	1348      0         954
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/19-MediaMetadata.p 	1454      0         1035
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/9-MediaMetadata.p 	1530      0         1092
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/24-MediaMetadata.p 	1634      0         1173
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/23-MediaMetadata.p 	1736      0         1262
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/85-MediaMetadata.p 	1825      0         1331
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/64-MediaMetadata.p 	1916      0         1398
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/59-MediaMetadata.p 	1996      0         1459
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/40-MediaMetadata.p 	2072      0         1521
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/72-MediaMetadata.p 	2365      0         1694
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/93-MediaMetadata.p 	2449      0         1760
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/35-MediaMetadata.p 	2535      0         1828
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/11-MediaMetadata.p 	2641      0         1907
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/1-MediaMetadata.p 	2747      0         1993
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/56-MediaMetadata.p 	2839      0         2067
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/65-MediaMetadata.p 	2944      0         2147
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/58-MediaMetadata.p 	3033      0         2217
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/22-MediaMetadata.p 	3326      0         2385
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/84-MediaMetadata.p 	3410      0         2452
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/41-MediaMetadata.p 	3527      0         2540
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/92-MediaMetadata.p 	3800      0         2709
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/34-MediaMetadata.p 	3890      0         2779
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/73-MediaMetadata.p 	3976      0         2847
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/57-MediaMetadata.p 	4053      0         2902
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/10-MediaMetadata.p 	4150      0         2980
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/0-MediaMetadata.p 	4240      0         3054
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/7-MediaMetadata.p 	4354      0         3144
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/17-MediaMetadata.p 	4439      0         3208
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/50-MediaMetadata.p 	4520      0         3278
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/74-MediaMetadata.p 	4606      0         3345
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/49-MediaMetadata.p 	4685      0         3411
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/33-MediaMetadata.p 	4778      0         3485
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/95-MediaMetadata.p 	4867      0         3563
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/46-MediaMetadata.p 	4971      0         3650
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/83-MediaMetadata.p 	5051      0         3707
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/18-MediaMetadata.p 	5142      0         3778
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/8-MediaMetadata.p 	5227      0         3848
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/25-MediaMetadata.p 	5320      0         3916
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/62-MediaMetadata.p 	5600      0         4087
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/39-MediaMetadata.p 	5708      0         4176
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/43-MediaMetadata.p 	5797      0         4242
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/67-MediaMetadata.p 	5885      0         4310
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/86-MediaMetadata.p 	5983      0         4381
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/20-MediaMetadata.p 	6077      0         4456
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/68-MediaMetadata.p 	6162      0         4526
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/55-MediaMetadata.p 	6255      0         4593
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/89-MediaMetadata.p 	6340      0         4664
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/2-MediaMetadata.p 	6644      0         4850
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/12-MediaMetadata.p 	6939      0         5036
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/36-MediaMetadata.p 	7048      0         5123
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/90-MediaMetadata.p 	7128      0         5188
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/71-MediaMetadata.p 	7254      0         5286
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/76-MediaMetadata.p 	7353      0         5361
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/97-MediaMetadata.p 	7456      0         5443
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/31-MediaMetadata.p 	7569      0         5538
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/15-MediaMetadata.p 	7649      0         5597
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/5-MediaMetadata.p 	7734      0         5663
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/28-MediaMetadata.p 	7837      0         5743
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/52-MediaMetadata.p 	8124      0         5918
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/27-MediaMetadata.p 	8207      0         5985
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/81-MediaMetadata.p 	8322      0         6080
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/60-MediaMetadata.p 	8401      0         6145
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/79-MediaMetadata.p 	8492      0         6212
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/44-MediaMetadata.p 	8575      0         6283
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/98-MediaMetadata.p 	8668      0         6365
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/96-MediaMetadata.p 	8759      0         6442
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/30-MediaMetadata.p 	8847      0         6512
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/77-MediaMetadata.p 	8943      0         6579
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/53-MediaMetadata.p 	9046      0         6658
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/14-MediaMetadata.p 	9146      0         6742
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/4-MediaMetadata.p 	9239      0         6822
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/29-MediaMetadata.p 	9337      0         6901
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/61-MediaMetadata.p 	9448      0         6987
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/26-MediaMetadata.p 	9534      0         7057
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/80-MediaMetadata.p 	9642      0         7140
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/99-MediaMetadata.p 	9736      0         7211
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/78-MediaMetadata.p 	9824      0         7279
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/45-MediaMetadata.p 	9912      0         7347
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/42-MediaMetadata.p 	10204     0         7540
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/38-MediaMetadata.p 	10293     0         7622
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/87-MediaMetadata.p 	10390     0         7704
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/21-MediaMetadata.p 	10527     0         7812
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/66-MediaMetadata.p 	10613     0         7882
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/88-MediaMetadata.p 	10700     0         7960
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/3-MediaMetadata.p 	10799     0         8036
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/13-MediaMetadata.p 	10885     0         8102
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/69-MediaMetadata.p 	10986     0         8183
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/54-MediaMetadata.p 	11069     0         8251
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/70-MediaMetadata.p 	11153     0         8315
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/37-MediaMetadata.p 	11240     0         8385
# /Users/tgadfort/Music/Discog/artists-deezer-db/metadata/91-MediaMetadata.p 	11372     0         8489
#
#
# ==============================================
#
# Saving 11372 entries to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToAlbumNames.p
#   --> This file is 334.3kB.
# Saved data to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToAlbumNames.p
#   --> This file is 334.3kB.
# Saving 11372 entries to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToAlbumRefs.p
#   --> This file is 260.4kB.
# Saved data to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToAlbumRefs.p
#   --> This file is 260.4kB.
# Saving 11372 entries to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToCoreAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToCoreAlbumNames.p
#   --> This file is 137.6kB.
# Saved data to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToCoreAlbumNames.p
#   --> This file is 137.6kB.
# Saving 11372 entries to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToCoreAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToCoreAlbumRefs.p
#   --> This file is 137.6kB.
# Saved data to /Users/tgadfort/Music/Discog/db-deezer/ArtistIDToCoreAlbumRefs.p
#   --> This file is 137.6kB.
# Current Time is Sun Feb 07, 2021 18:24:18 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 1 seconds.
# Current Time is Sun Feb 07, 2021 18:24:18 for
# =================================== Creating Artist Album DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 11372 Artists
# 	Shape --> (11372, 1)
# DataFrame Shape is (11372, 1)
# Saving Master Artist Albums DB File: /Users/tgadfort/Music/Discog/db-deezer/MasterSlimArtistAlbumsDB.p
#   --> This file is 556.0kB.
# Current Time is Sun Feb 07, 2021 18:24:19 for Done with
# =================================== Creating Artist Album DB ===================================
# Process [Done with
# =================================== Creating Artist Album DB ===================================] took 310.0 millseconds.
# Current Time is Sun Feb 07, 2021 18:24:19 for Done with Creating DB
# Process [Done with Creating DB] took 3 seconds.

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBFull("AllMusic")
elapsed(start, cmt)
# Out:
# Current Time is Mon Feb 08, 2021 13:40:47 for Creating DB
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rateyourmusic   =========================
# =========================   deezer   =========================
# =========================   albumoftheyear   =========================
# =========================   genius   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RateYourMusic
#   Creating Database Records for Deezer
#   Creating Database Records for AlbumOfTheYear
#   Creating Database Records for Genius
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RateYourMusic, Deezer, AlbumOfTheYear, Genius
# ========================= masterArtistNameDB =========================
#   Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicnames/mainArtistNameDB.p
#   There are currently 7313 artist keys.
#   There are currently 8524 renamed artist keys.
# Adding 1 known multi delim artists.
# Current Time is Mon Feb 08, 2021 13:40:47 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/6-Metadata.p  	0 1414
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/94-Metadata.p  	1 2817
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/77-Metadata.p  	2 4237
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/40-Metadata.p  	3 5680
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/15-Metadata.p  	4 7068
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/22-Metadata.p  	5 8447
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/88-Metadata.p  	6 9914
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/99-Metadata.p  	7 11384
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/33-Metadata.p  	8 12833
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/51-Metadata.p  	9 14248
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/66-Metadata.p  	10 15688
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/85-Metadata.p  	11 17143
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/18-Metadata.p  	12 18554
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/36-Metadata.p  	13 19960
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/63-Metadata.p  	14 21358
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/54-Metadata.p  	15 22796
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/48-Metadata.p  	16 24193
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/80-Metadata.p  	17 25628
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/91-Metadata.p  	18 27094
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/3-Metadata.p  	19 28539
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/59-Metadata.p  	20 29951
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/45-Metadata.p  	21 31434
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/72-Metadata.p  	22 32834
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/27-Metadata.p  	23 34249
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/10-Metadata.p  	24 35765
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/42-Metadata.p  	25 37191
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/75-Metadata.p  	26 38633
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/20-Metadata.p  	27 40032
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/17-Metadata.p  	28 41459
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/69-Metadata.p  	29 42874
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/4-Metadata.p  	30 44281
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/96-Metadata.p  	31 45668
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/87-Metadata.p  	32 47132
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/78-Metadata.p  	33 48551
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/9-Metadata.p  	34 49942
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/31-Metadata.p  	35 51409
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/64-Metadata.p  	36 52885
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/53-Metadata.p  	37 54294
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/28-Metadata.p  	38 55773
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/82-Metadata.p  	39 57203
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/34-Metadata.p  	40 58679
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/56-Metadata.p  	41 60094
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/61-Metadata.p  	42 61570
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/70-Metadata.p  	43 63004
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/47-Metadata.p  	44 64516
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/12-Metadata.p  	45 65964
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/25-Metadata.p  	46 67378
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/93-Metadata.p  	47 68807
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/1-Metadata.p  	48 70202
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/39-Metadata.p  	49 71612
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/37-Metadata.p  	50 73032
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/62-Metadata.p  	51 74438
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/55-Metadata.p  	52 75828
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/81-Metadata.p  	53 77274
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/49-Metadata.p  	54 78753
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/58-Metadata.p  	55 80218
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/90-Metadata.p  	56 81652
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/2-Metadata.p  	57 83098
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/44-Metadata.p  	58 84522
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/73-Metadata.p  	59 85904
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/26-Metadata.p  	60 87281
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/11-Metadata.p  	61 88694
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/7-Metadata.p  	62 90147
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/95-Metadata.p  	63 91554
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/89-Metadata.p  	64 93010
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/76-Metadata.p  	65 94443
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/41-Metadata.p  	66 95870
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/14-Metadata.p  	67 97283
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/23-Metadata.p  	68 98810
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/32-Metadata.p  	69 100278
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/50-Metadata.p  	70 101711
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/67-Metadata.p  	71 103123
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/98-Metadata.p  	72 104550
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/19-Metadata.p  	73 105929
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/84-Metadata.p  	74 107394
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/83-Metadata.p  	75 108944
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/29-Metadata.p  	76 110333
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/35-Metadata.p  	77 111771
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/57-Metadata.p  	78 113167
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/60-Metadata.p  	79 114633
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/71-Metadata.p  	80 116065
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/46-Metadata.p  	81 117491
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/13-Metadata.p  	82 118951
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/24-Metadata.p  	83 120385
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/38-Metadata.p  	84 121816
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/92-Metadata.p  	85 123205
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/0-Metadata.p  	86 124576
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/43-Metadata.p  	87 125967
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/74-Metadata.p  	88 127399
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/21-Metadata.p  	89 128835
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/16-Metadata.p  	90 130276
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/5-Metadata.p  	91 131710
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/97-Metadata.p  	92 133129
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/68-Metadata.p  	93 134573
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/79-Metadata.p  	94 136005
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/86-Metadata.p  	95 137405
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/30-Metadata.p  	96 138884
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/65-Metadata.p  	97 140335
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/52-Metadata.p  	98 141725
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/8-Metadata.p  	99 143193
#
#
# ==============================================
#
# Saving 143193 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToRef.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToRef.p
#   --> This file is 3.6MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToRef.p
#   --> This file is 3.6MB.
# Saving 143193 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToName.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToName.p
#   --> This file is 2.8MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToName.p
#   --> This file is 2.8MB.
# Saving 143193 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToVariations.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToVariations.p
#   --> This file is 3.2MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToVariations.p
#   --> This file is 3.2MB.
# Current Time is Mon Feb 08, 2021 13:40:56 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 8 seconds.
# Current Time is Mon Feb 08, 2021 13:40:56 for
# =================================== Creating Artist DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 143193 Artists
# 	Shape --> (143193, 1)
# 	Shape --> (143193, 2)
#   Finding Real Artist Name
# 	Shape --> (143193, 4)
#   Removing None Artist
# 	Shape --> (143193, 4)
#   Finding Disc Artist Name
# 	Shape --> (143193, 5)
# DataFrame Shape is (143193, 7)
# Current Time is Mon Feb 08, 2021 13:40:59 for Done with
# =================================== Creating Artist DB ===================================
# Process [Done with
# =================================== Creating Artist DB ===================================] took 3 seconds.
# Saving Master Artist DB File: /Users/tgadfort/Music/Discog/db-allmusic/MasterSlimArtistDB.p
#   --> This file is 19.3MB.
# Current Time is Mon Feb 08, 2021 13:41:01 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/51-MediaMetadata.p 	1416      7590      12534
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/6-MediaMetadata.p 	2829      14194     23646
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/16-MediaMetadata.p 	4270      30482     45968
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/32-MediaMetadata.p 	5738      41544     61692
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/94-MediaMetadata.p 	7141      48065     73765
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/75-MediaMetadata.p 	8583      56710     88406
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/48-MediaMetadata.p 	9980      63019     100006
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/47-MediaMetadata.p 	11492     69922     111023
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/63-MediaMetadata.p 	12890     78700     123720
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/82-MediaMetadata.p 	14320     85124     134058
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/19-MediaMetadata.p 	15699     96259     149343
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/9-MediaMetadata.p 	17090     103785    162182
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/24-MediaMetadata.p 	18524     113295    176444
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/23-MediaMetadata.p 	20051     121802    190813
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/85-MediaMetadata.p 	21506     132648    206558
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/64-MediaMetadata.p 	22982     138651    216912
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/59-MediaMetadata.p 	24394     146684    229631
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/40-MediaMetadata.p 	25837     157587    246811
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/72-MediaMetadata.p 	27237     165040    259423
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/93-MediaMetadata.p 	28666     171088    270151
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/35-MediaMetadata.p 	30104     179471    283184
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/11-MediaMetadata.p 	31517     187131    295229
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/1-MediaMetadata.p 	32912     194233    307161
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/56-MediaMetadata.p 	34327     202145    320058
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/65-MediaMetadata.p 	35778     208691    331206
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/58-MediaMetadata.p 	37243     220684    348500
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/22-MediaMetadata.p 	38622     229720    362489
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/84-MediaMetadata.p 	40087     237697    374991
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/41-MediaMetadata.p 	41514     244298    387228
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/92-MediaMetadata.p 	42903     252705    400476
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/34-MediaMetadata.p 	44379     261647    416051
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/73-MediaMetadata.p 	45761     269126    427811
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/57-MediaMetadata.p 	47157     279232    442464
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/10-MediaMetadata.p 	48673     286962    455431
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/0-MediaMetadata.p 	50044     294899    467845
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/7-MediaMetadata.p 	51497     303251    482085
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/17-MediaMetadata.p 	52924     309603    492191
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/50-MediaMetadata.p 	54357     317963    505465
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/74-MediaMetadata.p 	55789     328093    520255
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/49-MediaMetadata.p 	57268     335179    532579
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/33-MediaMetadata.p 	58717     344493    547547
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/95-MediaMetadata.p 	60124     350827    557860
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/46-MediaMetadata.p 	61550     358786    569345
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/83-MediaMetadata.p 	63100     366618    582000
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/18-MediaMetadata.p 	64511     373975    594443
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/8-MediaMetadata.p 	65979     382236    607330
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/25-MediaMetadata.p 	67393     393684    623509
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/62-MediaMetadata.p 	68799     402570    636673
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/39-MediaMetadata.p 	70209     416479    654995
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/43-MediaMetadata.p 	71600     423335    665572
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/67-MediaMetadata.p 	73012     428979    675884
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/86-MediaMetadata.p 	74412     435113    686542
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/20-MediaMetadata.p 	75811     453974    710539
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/68-MediaMetadata.p 	77255     460612    721544
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/55-MediaMetadata.p 	78645     467484    732755
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/89-MediaMetadata.p 	80101     476049    745736
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/2-MediaMetadata.p 	81547     483165    758117
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/12-MediaMetadata.p 	82995     490865    769984
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/36-MediaMetadata.p 	84401     497078    780285
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/90-MediaMetadata.p 	85835     505162    794293
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/71-MediaMetadata.p 	87267     513231    806762
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/76-MediaMetadata.p 	88700     522913    821635
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/97-MediaMetadata.p 	90119     529525    832516
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/31-MediaMetadata.p 	91586     535979    843566
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/15-MediaMetadata.p 	92974     544664    857508
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/5-MediaMetadata.p 	94408     551691    868973
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/28-MediaMetadata.p 	95887     557542    880584
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/52-MediaMetadata.p 	97277     563969    891563
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/27-MediaMetadata.p 	98692     573996    906502
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/81-MediaMetadata.p 	100138    584714    921977
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/60-MediaMetadata.p 	101604    592073    933848
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/79-MediaMetadata.p 	103036    599651    945366
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/44-MediaMetadata.p 	104460    607201    958773
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/98-MediaMetadata.p 	105887    614665    970587
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/96-MediaMetadata.p 	107274    620165    980277
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/30-MediaMetadata.p 	108753    626783    991220
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/77-MediaMetadata.p 	110173    639224    1008063
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/53-MediaMetadata.p 	111582    650876    1024127
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/14-MediaMetadata.p 	112995    659538    1037394
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/4-MediaMetadata.p 	114402    665960    1048246
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/29-MediaMetadata.p 	115791    673443    1061879
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/61-MediaMetadata.p 	117267    682111    1076084
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/26-MediaMetadata.p 	118644    697384    1095997
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/80-MediaMetadata.p 	120079    716111    1119944
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/99-MediaMetadata.p 	121549    723927    1133468
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/78-MediaMetadata.p 	122968    731417    1145769
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/45-MediaMetadata.p 	124451    738551    1157629
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/42-MediaMetadata.p 	125877    745859    1169186
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/38-MediaMetadata.p 	127308    752383    1179583
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/87-MediaMetadata.p 	128772    760413    1191918
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/21-MediaMetadata.p 	130208    769399    1206049
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/66-MediaMetadata.p 	131648    775978    1217020
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/88-MediaMetadata.p 	133115    783860    1229016
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/3-MediaMetadata.p 	134560    794049    1243901
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/13-MediaMetadata.p 	136020    801068    1254993
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/69-MediaMetadata.p 	137435    808885    1267042
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/54-MediaMetadata.p 	138873    817710    1281335
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/70-MediaMetadata.p 	140307    826032    1294225
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/37-MediaMetadata.p 	141727    834094    1306372
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/91-MediaMetadata.p 	143193    841020    1317232
#
#
# ==============================================
#
# Saving 143193 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumNames.p
#   --> This file is 34.3MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumNames.p
#   --> This file is 34.3MB.
# Saving 143193 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumRefs.p
#   --> This file is 40.2MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumRefs.p
#   --> This file is 40.2MB.
# Saving 143193 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumNames.p
#   --> This file is 22.7MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumNames.p
#   --> This file is 22.7MB.
# Saving 143193 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumRefs.p
#   --> This file is 26.5MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumRefs.p
#   --> This file is 26.5MB.
# Current Time is Mon Feb 08, 2021 13:42:35 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 1.6 minutes.
# Current Time is Mon Feb 08, 2021 13:42:36 for
# =================================== Creating Artist Album DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 143193 Artists
# 	Shape --> (143193, 1)
# DataFrame Shape is (143193, 1)
# Saving Master Artist Albums DB File: /Users/tgadfort/Music/Discog/db-allmusic/MasterSlimArtistAlbumsDB.p
#   --> This file is 67.0MB.
# Current Time is Mon Feb 08, 2021 13:42:55 for Done with
# =================================== Creating Artist Album DB ===================================
# Process [Done with
# =================================== Creating Artist Album DB ===================================] took 19 seconds.
# Current Time is Mon Feb 08, 2021 13:42:58 for Done with Creating DB
# Process [Done with Creating DB] took 2.2 minutes.

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBFull("MusicBrainz")
elapsed(start, cmt)
# Out:
# Current Time is Sun Feb 07, 2021 17:25:37 for Creating DB
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rateyourmusic   =========================
# =========================   deezer   =========================
# =========================   albumoftheyear   =========================
# =========================   genius   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RateYourMusic
#   Creating Database Records for Deezer
#   Creating Database Records for AlbumOfTheYear
#   Creating Database Records for Genius
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RateYourMusic, Deezer, AlbumOfTheYear, Genius
# ========================= masterArtistNameDB =========================
#   Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicnames/mainArtistNameDB.p
#   There are currently 7247 artist keys.
#   There are currently 8453 renamed artist keys.
# Adding 1 known multi delim artists.
# Current Time is Sun Feb 07, 2021 17:25:38 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/6-Metadata.p  	0 2265
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/94-Metadata.p  	1 4550
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/77-Metadata.p  	2 6988
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/40-Metadata.p  	3 9457
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/15-Metadata.p  	4 11778
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/22-Metadata.p  	5 14077
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/88-Metadata.p  	6 16418
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/99-Metadata.p  	7 18789
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/33-Metadata.p  	8 21086
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/51-Metadata.p  	9 23441
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/66-Metadata.p  	10 25687
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/85-Metadata.p  	11 27951
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/18-Metadata.p  	12 30316
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/36-Metadata.p  	13 32700
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/63-Metadata.p  	14 35004
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/54-Metadata.p  	15 37323
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/48-Metadata.p  	16 39606
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/80-Metadata.p  	17 41952
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/91-Metadata.p  	18 44348
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/3-Metadata.p  	19 46710
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/59-Metadata.p  	20 49035
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/45-Metadata.p  	21 51421
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/72-Metadata.p  	22 53761
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/27-Metadata.p  	23 56095
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/10-Metadata.p  	24 58455
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/42-Metadata.p  	25 60819
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/75-Metadata.p  	26 63108
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/20-Metadata.p  	27 65476
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/17-Metadata.p  	28 67779
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/69-Metadata.p  	29 70112
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/4-Metadata.p  	30 72480
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/96-Metadata.p  	31 74781
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/87-Metadata.p  	32 77151
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/78-Metadata.p  	33 79554
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/9-Metadata.p  	34 81923
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/31-Metadata.p  	35 84288
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/64-Metadata.p  	36 86597
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/53-Metadata.p  	37 88942
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/28-Metadata.p  	38 91280
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/82-Metadata.p  	39 93674
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/34-Metadata.p  	40 95976
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/56-Metadata.p  	41 98293
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/61-Metadata.p  	42 100620
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/70-Metadata.p  	43 102932
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/47-Metadata.p  	44 105236
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/12-Metadata.p  	45 107617
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/25-Metadata.p  	46 110004
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/93-Metadata.p  	47 112325
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/1-Metadata.p  	48 114605
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/39-Metadata.p  	49 116902
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/37-Metadata.p  	50 119068
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/62-Metadata.p  	51 121394
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/55-Metadata.p  	52 123754
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/81-Metadata.p  	53 126021
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/49-Metadata.p  	54 128332
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/58-Metadata.p  	55 130664
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/90-Metadata.p  	56 132932
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/2-Metadata.p  	57 135258
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/44-Metadata.p  	58 137715
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/73-Metadata.p  	59 140016
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/26-Metadata.p  	60 142317
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/11-Metadata.p  	61 144709
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/7-Metadata.p  	62 147101
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/95-Metadata.p  	63 149458
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/89-Metadata.p  	64 151729
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/76-Metadata.p  	65 154031
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/41-Metadata.p  	66 156342
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/14-Metadata.p  	67 158666
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/23-Metadata.p  	68 160923
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/32-Metadata.p  	69 163199
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/50-Metadata.p  	70 165454
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/67-Metadata.p  	71 167777
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/98-Metadata.p  	72 170066
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/19-Metadata.p  	73 172422
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/84-Metadata.p  	74 174785
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/83-Metadata.p  	75 177119
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/29-Metadata.p  	76 179435
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/35-Metadata.p  	77 181799
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/57-Metadata.p  	78 184153
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/60-Metadata.p  	79 186555
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/71-Metadata.p  	80 188942
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/46-Metadata.p  	81 191303
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/13-Metadata.p  	82 193668
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/24-Metadata.p  	83 195986
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/38-Metadata.p  	84 198278
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/92-Metadata.p  	85 200699
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/0-Metadata.p  	86 203078
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/43-Metadata.p  	87 205387
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/74-Metadata.p  	88 207666
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/21-Metadata.p  	89 210052
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/16-Metadata.p  	90 212367
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/5-Metadata.p  	91 214730
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/97-Metadata.p  	92 217084
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/68-Metadata.p  	93 219390
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/79-Metadata.p  	94 221630
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/86-Metadata.p  	95 223882
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/30-Metadata.p  	96 226184
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/65-Metadata.p  	97 228478
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/52-Metadata.p  	98 230815
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/8-Metadata.p  	99 233134
#
#
# ==============================================
#
# Saving 233134 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToRef.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToRef.p
#   --> This file is 11.9MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToRef.p
#   --> This file is 11.9MB.
# Saving 233134 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToName.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToName.p
#   --> This file is 8.6MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToName.p
#   --> This file is 8.6MB.
# Saving 233134 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToVariations.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToVariations.p
#   --> This file is 9.3MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToVariations.p
#   --> This file is 9.3MB.
# Current Time is Sun Feb 07, 2021 17:25:54 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 15 seconds.
# Current Time is Sun Feb 07, 2021 17:25:54 for
# =================================== Creating Artist DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 233134 Artists
# 	Shape --> (233134, 1)
# 	Shape --> (233134, 2)
#   Finding Real Artist Name
# 	Shape --> (233134, 4)
#   Removing None Artist
# 	Shape --> (233134, 4)
#   Finding Disc Artist Name
# 	Shape --> (233134, 5)
#   Cleaning Disc Artist Name (MusicBrainz Only)
# 	Shape --> (233134, 5)
# DataFrame Shape is (233134, 7)
# Current Time is Sun Feb 07, 2021 17:26:00 for Done with
# =================================== Creating Artist DB ===================================
# Process [Done with
# =================================== Creating Artist DB ===================================] took 5 seconds.
# Saving Master Artist DB File: /Users/tgadfort/Music/Discog/db-musicbrainz/MasterSlimArtistDB.p
#   --> This file is 38.8MB.
# Current Time is Sun Feb 07, 2021 17:26:03 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/51-MediaMetadata.p 	2355      0         10896
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/6-MediaMetadata.p 	4620      0         20891
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/16-MediaMetadata.p 	6935      0         29997
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/32-MediaMetadata.p 	9211      0         40340
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/94-MediaMetadata.p 	11496     0         49635
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/75-MediaMetadata.p 	13785     0         59858
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/48-MediaMetadata.p 	16068     0         69108
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/47-MediaMetadata.p 	18372     0         79639
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/63-MediaMetadata.p 	20676     0         90153
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/82-MediaMetadata.p 	23070     0         100301
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/19-MediaMetadata.p 	25426     0         109896
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/9-MediaMetadata.p 	27795     0         120806
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/24-MediaMetadata.p 	30113     0         130092
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/23-MediaMetadata.p 	32370     0         140675
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/85-MediaMetadata.p 	34634     0         151636
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/64-MediaMetadata.p 	36943     0         161893
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/59-MediaMetadata.p 	39268     0         172199
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/40-MediaMetadata.p 	41737     0         182066
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/72-MediaMetadata.p 	44077     0         191549
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/93-MediaMetadata.p 	46398     0         202053
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/35-MediaMetadata.p 	48762     0         212401
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/11-MediaMetadata.p 	51154     0         224442
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/1-MediaMetadata.p 	53434     0         236566
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/56-MediaMetadata.p 	55751     0         247316
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/65-MediaMetadata.p 	58045     0         257623
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/58-MediaMetadata.p 	60377     0         267168
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/22-MediaMetadata.p 	62676     0         276587
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/84-MediaMetadata.p 	65039     0         289021
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/41-MediaMetadata.p 	67350     0         298316
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/92-MediaMetadata.p 	69771     0         309308
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/34-MediaMetadata.p 	72073     0         319744
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/73-MediaMetadata.p 	74374     0         329931
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/57-MediaMetadata.p 	76728     0         339082
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/10-MediaMetadata.p 	79088     0         349043
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/0-MediaMetadata.p 	81467     0         360054
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/7-MediaMetadata.p 	83859     0         370825
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/17-MediaMetadata.p 	86162     0         381046
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/50-MediaMetadata.p 	88417     0         391021
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/74-MediaMetadata.p 	90696     0         400327
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/49-MediaMetadata.p 	93007     0         410798
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/33-MediaMetadata.p 	95304     0         421349
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/95-MediaMetadata.p 	97661     0         430900
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/46-MediaMetadata.p 	100022    0         441175
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/83-MediaMetadata.p 	102356    0         452171
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/18-MediaMetadata.p 	104721    0         463014
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/8-MediaMetadata.p 	107040    0         477208
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/25-MediaMetadata.p 	109427    0         488941
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/62-MediaMetadata.p 	111753    0         499327
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/39-MediaMetadata.p 	114050    0         508820
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/43-MediaMetadata.p 	116359    0         518770
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/67-MediaMetadata.p 	118682    0         528597
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/86-MediaMetadata.p 	120934    0         539582
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/20-MediaMetadata.p 	123302    0         549925
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/68-MediaMetadata.p 	125608    0         561809
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/55-MediaMetadata.p 	127968    0         571774
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/89-MediaMetadata.p 	130239    0         581512
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/2-MediaMetadata.p 	132565    0         591964
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/12-MediaMetadata.p 	134946    0         601905
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/36-MediaMetadata.p 	137330    0         612534
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/90-MediaMetadata.p 	139598    0         621835
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/71-MediaMetadata.p 	141985    0         632393
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/76-MediaMetadata.p 	144287    0         642362
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/97-MediaMetadata.p 	146641    0         653667
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/31-MediaMetadata.p 	149006    0         664725
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/15-MediaMetadata.p 	151327    0         675885
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/5-MediaMetadata.p 	153690    0         690485
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/28-MediaMetadata.p 	156028    0         700787
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/52-MediaMetadata.p 	158365    0         712747
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/27-MediaMetadata.p 	160699    0         722736
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/81-MediaMetadata.p 	162966    0         732889
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/60-MediaMetadata.p 	165368    0         746994
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/79-MediaMetadata.p 	167608    0         755821
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/44-MediaMetadata.p 	170065    0         765891
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/98-MediaMetadata.p 	172354    0         776523
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/96-MediaMetadata.p 	174655    0         786334
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/30-MediaMetadata.p 	176957    0         799403
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/77-MediaMetadata.p 	179395    0         809365
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/53-MediaMetadata.p 	181740    0         819123
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/14-MediaMetadata.p 	184064    0         829763
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/4-MediaMetadata.p 	186432    0         839543
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/29-MediaMetadata.p 	188748    0         849919
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/61-MediaMetadata.p 	191075    0         860744
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/26-MediaMetadata.p 	193376    0         870305
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/80-MediaMetadata.p 	195722    0         880516
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/99-MediaMetadata.p 	198093    0         891036
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/78-MediaMetadata.p 	200496    0         902202
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/45-MediaMetadata.p 	202882    0         912674
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/42-MediaMetadata.p 	205246    0         923544
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/38-MediaMetadata.p 	207538    0         933754
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/87-MediaMetadata.p 	209908    0         945614
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/21-MediaMetadata.p 	212294    0         955885
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/66-MediaMetadata.p 	214540    0         968601
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/88-MediaMetadata.p 	216881    0         978291
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/3-MediaMetadata.p 	219243    0         988548
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/13-MediaMetadata.p 	221608    0         999971
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/69-MediaMetadata.p 	223941    0         1011758
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/54-MediaMetadata.p 	226260    0         1022524
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/70-MediaMetadata.p 	228572    0         1033126
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/37-MediaMetadata.p 	230738    0         1042195
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/91-MediaMetadata.p 	233134    0         1053076
#
#
# ==============================================
#
# Saving 233134 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumNames.p
#   --> This file is 48.6MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumNames.p
#   --> This file is 48.6MB.
# Saving 233134 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumRefs.p
#   --> This file is 43.3MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumRefs.p
#   --> This file is 43.3MB.
# Saving 233134 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumNames.p
#   --> This file is 5.9MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumNames.p
#   --> This file is 5.9MB.
# Saving 233134 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumRefs.p
#   --> This file is 5.9MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumRefs.p
#   --> This file is 5.9MB.
# Current Time is Sun Feb 07, 2021 17:27:07 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 1.1 minutes.
# Current Time is Sun Feb 07, 2021 17:27:07 for
# =================================== Creating Artist Album DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 233134 Artists
# 	Shape --> (233134, 1)
# DataFrame Shape is (233134, 1)
# Saving Master Artist Albums DB File: /Users/tgadfort/Music/Discog/db-musicbrainz/MasterSlimArtistAlbumsDB.p
#   --> This file is 88.1MB.
# Current Time is Sun Feb 07, 2021 17:27:25 for Done with
# =================================== Creating Artist Album DB ===================================
# Process [Done with
# =================================== Creating Artist Album DB ===================================] took 17 seconds.
# Current Time is Sun Feb 07, 2021 17:27:27 for Done with Creating DB
# Process [Done with Creating DB] took 1.8 minutes.

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBFull("Discogs")
elapsed(start, cmt)
# Out:
# Current Time is Sun Feb 07, 2021 17:13:45 for Creating DB
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rateyourmusic   =========================
# =========================   deezer   =========================
# =========================   albumoftheyear   =========================
# =========================   genius   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RateYourMusic
#   Creating Database Records for Deezer
#   Creating Database Records for AlbumOfTheYear
#   Creating Database Records for Genius
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RateYourMusic, Deezer, AlbumOfTheYear, Genius
# ========================= masterArtistNameDB =========================
#   Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicnames/mainArtistNameDB.p
#   There are currently 7247 artist keys.
#   There are currently 8453 renamed artist keys.
# Adding 1 known multi delim artists.
# Current Time is Sun Feb 07, 2021 17:13:45 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/6-Metadata.p  	0 7639
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/94-Metadata.p  	1 15371
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/77-Metadata.p  	2 23070
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/40-Metadata.p  	3 30719
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/15-Metadata.p  	4 38480
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/22-Metadata.p  	5 46231
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/88-Metadata.p  	6 53943
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/99-Metadata.p  	7 61698
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/33-Metadata.p  	8 69398
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/51-Metadata.p  	9 77187
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/66-Metadata.p  	10 84921
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/85-Metadata.p  	11 92624
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/18-Metadata.p  	12 100405
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/36-Metadata.p  	13 108209
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/63-Metadata.p  	14 116007
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/54-Metadata.p  	15 123829
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/48-Metadata.p  	16 131633
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/80-Metadata.p  	17 139390
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/91-Metadata.p  	18 147099
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/3-Metadata.p  	19 155067
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/59-Metadata.p  	20 162922
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/45-Metadata.p  	21 170447
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/72-Metadata.p  	22 178127
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/27-Metadata.p  	23 185784
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/10-Metadata.p  	24 193533
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/42-Metadata.p  	25 201248
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/75-Metadata.p  	26 208966
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/20-Metadata.p  	27 216737
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/17-Metadata.p  	28 224502
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/69-Metadata.p  	29 232206
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/4-Metadata.p  	30 240010
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/96-Metadata.p  	31 247664
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/87-Metadata.p  	32 255414
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/78-Metadata.p  	33 263305
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/9-Metadata.p  	34 271028
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/31-Metadata.p  	35 278682
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/64-Metadata.p  	36 286541
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/53-Metadata.p  	37 294303
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/28-Metadata.p  	38 302104
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/82-Metadata.p  	39 309932
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/34-Metadata.p  	40 317636
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/56-Metadata.p  	41 325362
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/61-Metadata.p  	42 333055
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/70-Metadata.p  	43 340707
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/47-Metadata.p  	44 348232
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/12-Metadata.p  	45 356033
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/25-Metadata.p  	46 363768
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/93-Metadata.p  	47 371482
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/1-Metadata.p  	48 379448
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/39-Metadata.p  	49 387092
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/37-Metadata.p  	50 394739
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/62-Metadata.p  	51 402572
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/55-Metadata.p  	52 410361
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/81-Metadata.p  	53 418254
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/49-Metadata.p  	54 426018
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/58-Metadata.p  	55 433672
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/90-Metadata.p  	56 441294
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/2-Metadata.p  	57 448990
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/44-Metadata.p  	58 456557
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/73-Metadata.p  	59 464251
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/26-Metadata.p  	60 472087
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/11-Metadata.p  	61 479872
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/7-Metadata.p  	62 487628
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/95-Metadata.p  	63 495387
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/89-Metadata.p  	64 503237
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/76-Metadata.p  	65 510928
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/41-Metadata.p  	66 518783
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/14-Metadata.p  	67 526419
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/23-Metadata.p  	68 534185
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/32-Metadata.p  	69 541909
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/50-Metadata.p  	70 549627
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/67-Metadata.p  	71 557438
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/98-Metadata.p  	72 565101
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/19-Metadata.p  	73 572813
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/84-Metadata.p  	74 580636
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/83-Metadata.p  	75 588491
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/29-Metadata.p  	76 596168
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/35-Metadata.p  	77 603715
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/57-Metadata.p  	78 611418
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/60-Metadata.p  	79 619180
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/71-Metadata.p  	80 626858
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/46-Metadata.p  	81 634441
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/13-Metadata.p  	82 642321
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/24-Metadata.p  	83 649909
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/38-Metadata.p  	84 657544
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/92-Metadata.p  	85 665480
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/0-Metadata.p  	86 673164
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/43-Metadata.p  	87 680901
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/74-Metadata.p  	88 688653
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/21-Metadata.p  	89 696398
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/16-Metadata.p  	90 704085
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/5-Metadata.p  	91 711714
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/97-Metadata.p  	92 719437
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/68-Metadata.p  	93 727031
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/79-Metadata.p  	94 734765
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/86-Metadata.p  	95 742691
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/30-Metadata.p  	96 750422
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/65-Metadata.p  	97 758193
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/52-Metadata.p  	98 765975
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/8-Metadata.p  	99 773799
#
#
# ==============================================
#
# Saving 773799 entries to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToRef.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToRef.p
#   --> This file is 17.3MB.
# Saved data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToRef.p
#   --> This file is 17.3MB.
# Saving 773799 entries to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToName.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToName.p
#   --> This file is 14.6MB.
# Saved data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToName.p
#   --> This file is 14.6MB.
# Saving 773799 entries to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToVariations.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToVariations.p
#   --> This file is 28.6MB.
# Saved data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToVariations.p
#   --> This file is 28.6MB.
# Current Time is Sun Feb 07, 2021 17:14:46 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 1.0 minutes.
# Current Time is Sun Feb 07, 2021 17:14:46 for
# =================================== Creating Artist DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 773799 Artists
# 	Shape --> (773799, 1)
# 	Shape --> (773799, 2)
#   Finding Real Artist Name
# 	Shape --> (773799, 4)
#   Removing None Artist
# 	Shape --> (773799, 4)
#   Finding Disc Artist Name
# 	Shape --> (773799, 5)
# DataFrame Shape is (773799, 7)
# Current Time is Sun Feb 07, 2021 17:15:06 for Done with
# =================================== Creating Artist DB ===================================
# Process [Done with
# =================================== Creating Artist DB ===================================] took 19 seconds.
# Saving Master Artist DB File: /Users/tgadfort/Music/Discog/db-discogs/MasterSlimArtistDB.p
#   --> This file is 106.0MB.
# Current Time is Sun Feb 07, 2021 17:15:17 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/51-MediaMetadata.p 	7789      16891     75085
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/6-MediaMetadata.p 	15428     33682     148419
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/16-MediaMetadata.p 	23115     49744     227606
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/32-MediaMetadata.p 	30839     67978     301676
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/94-MediaMetadata.p 	38571     87834     381297
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/75-MediaMetadata.p 	46289     108676    455797
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/48-MediaMetadata.p 	54093     124845    527860
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/47-MediaMetadata.p 	61618     140265    603526
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/63-MediaMetadata.p 	69416     156819    679806
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/82-MediaMetadata.p 	77244     172869    753859
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/19-MediaMetadata.p 	84956     190239    834162
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/9-MediaMetadata.p 	92679     207022    908820
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/24-MediaMetadata.p 	100267    222371    981111
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/23-MediaMetadata.p 	108033    240228    1061106
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/85-MediaMetadata.p 	115736    258739    1140170
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/64-MediaMetadata.p 	123595    276720    1215843
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/59-MediaMetadata.p 	131450    293195    1287075
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/40-MediaMetadata.p 	139099    315083    1366467
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/72-MediaMetadata.p 	146779    333907    1441516
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/93-MediaMetadata.p 	154493    355003    1520849
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/35-MediaMetadata.p 	162040    372366    1597370
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/11-MediaMetadata.p 	169825    389986    1672706
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/1-MediaMetadata.p 	177791    409827    1756959
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/56-MediaMetadata.p 	185517    427456    1832800
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/65-MediaMetadata.p 	193288    446005    1913636
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/58-MediaMetadata.p 	200942    461443    1985256
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/22-MediaMetadata.p 	208693    479212    2060617
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/84-MediaMetadata.p 	216516    497578    2135394
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/41-MediaMetadata.p 	224371    515674    2219972
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/92-MediaMetadata.p 	232307    532593    2300050
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/34-MediaMetadata.p 	240011    548405    2376362
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/73-MediaMetadata.p 	247705    567001    2456245
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/57-MediaMetadata.p 	255408    583389    2530645
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/10-MediaMetadata.p 	263157    599735    2602786
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/0-MediaMetadata.p 	270841    616677    2675537
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/7-MediaMetadata.p 	278597    633654    2754278
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/17-MediaMetadata.p 	286362    651462    2834221
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/50-MediaMetadata.p 	294080    668461    2904901
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/74-MediaMetadata.p 	301832    688444    2986523
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/49-MediaMetadata.p 	309596    704317    3062288
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/33-MediaMetadata.p 	317296    723656    3146188
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/95-MediaMetadata.p 	325055    740976    3220659
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/46-MediaMetadata.p 	332638    770047    3313194
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/83-MediaMetadata.p 	340493    787072    3392310
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/18-MediaMetadata.p 	348274    804277    3471819
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/8-MediaMetadata.p 	356098    821136    3551143
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/25-MediaMetadata.p 	363833    843134    3633318
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/62-MediaMetadata.p 	371666    860682    3708650
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/39-MediaMetadata.p 	379310    879479    3789204
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/43-MediaMetadata.p 	387047    897455    3865956
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/67-MediaMetadata.p 	394858    913850    3939782
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/86-MediaMetadata.p 	402784    931522    4021886
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/20-MediaMetadata.p 	410555    948714    4098413
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/68-MediaMetadata.p 	418149    972597    4184313
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/55-MediaMetadata.p 	425938    990610    4262836
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/89-MediaMetadata.p 	433788    1007339   4341241
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/2-MediaMetadata.p 	441484    1025560   4425120
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/12-MediaMetadata.p 	449285    1043706   4500354
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/36-MediaMetadata.p 	457089    1061727   4576780
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/90-MediaMetadata.p 	464711    1078518   4655618
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/71-MediaMetadata.p 	472389    1096017   4730814
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/76-MediaMetadata.p 	480080    1112779   4807133
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/97-MediaMetadata.p 	487803    1128794   4876043
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/31-MediaMetadata.p 	495457    1144981   4949080
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/15-MediaMetadata.p 	503218    1162321   5028589
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/5-MediaMetadata.p 	510847    1178128   5101417
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/28-MediaMetadata.p 	518648    1195295   5175442
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/52-MediaMetadata.p 	526430    1212309   5251272
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/27-MediaMetadata.p 	534087    1233412   5333101
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/81-MediaMetadata.p 	541980    1252459   5412925
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/60-MediaMetadata.p 	549742    1270107   5495615
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/79-MediaMetadata.p 	557476    1289451   5569777
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/44-MediaMetadata.p 	565043    1317456   5659024
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/98-MediaMetadata.p 	572706    1333935   5746341
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/96-MediaMetadata.p 	580360    1350912   5821950
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/30-MediaMetadata.p 	588091    1367528   5896390
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/77-MediaMetadata.p 	595790    1384849   5974738
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/53-MediaMetadata.p 	603552    1401802   6053831
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/14-MediaMetadata.p 	611188    1422836   6128761
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/4-MediaMetadata.p 	618992    1440027   6209767
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/29-MediaMetadata.p 	626669    1457431   6296826
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/61-MediaMetadata.p 	634362    1479309   6379178
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/26-MediaMetadata.p 	642198    1496722   6453060
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/80-MediaMetadata.p 	649955    1516656   6529800
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/99-MediaMetadata.p 	657710    1532437   6600576
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/78-MediaMetadata.p 	665601    1550075   6681483
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/45-MediaMetadata.p 	673126    1566546   6755531
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/42-MediaMetadata.p 	680841    1586479   6834066
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/38-MediaMetadata.p 	688476    1602324   6912070
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/87-MediaMetadata.p 	696226    1618840   6990256
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/21-MediaMetadata.p 	703971    1634385   7061267
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/66-MediaMetadata.p 	711705    1654565   7140097
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/88-MediaMetadata.p 	719417    1671804   7219756
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/3-MediaMetadata.p 	727385    1689636   7297588
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/13-MediaMetadata.p 	735265    1706526   7371447
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/69-MediaMetadata.p 	742969    1729636   7450336
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/54-MediaMetadata.p 	750791    1748573   7529790
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/70-MediaMetadata.p 	758443    1765978   7606087
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/37-MediaMetadata.p 	766090    1793139   7693808
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/91-MediaMetadata.p 	773799    1809763   7768074
#
#
# ==============================================
#
# Saving 773799 entries to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToAlbumNames.p
#   --> This file is 207.8MB.
# Saved data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToAlbumNames.p
#   --> This file is 207.8MB.
# Saving 773799 entries to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToAlbumRefs.p
#   --> This file is 286.9MB.
# Saved data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToAlbumRefs.p
#   --> This file is 286.9MB.
# Saving 773799 entries to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToCoreAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToCoreAlbumNames.p
#   --> This file is 57.3MB.
# Saved data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToCoreAlbumNames.p
#   --> This file is 57.3MB.
# Saving 773799 entries to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToCoreAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToCoreAlbumRefs.p
#   --> This file is 80.8MB.
# Saved data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToCoreAlbumRefs.p
#   --> This file is 80.8MB.
# Current Time is Sun Feb 07, 2021 17:23:18 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 8.0 minutes.
# Current Time is Sun Feb 07, 2021 17:23:23 for
# =================================== Creating Artist Album DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 773799 Artists
# 	Shape --> (773799, 1)
# DataFrame Shape is (773799, 1)
# Saving Master Artist Albums DB File: /Users/tgadfort/Music/Discog/db-discogs/MasterSlimArtistAlbumsDB.p
#   --> This file is 408.6MB.
# Current Time is Sun Feb 07, 2021 17:25:20 for Done with
# =================================== Creating Artist Album DB ===================================
# Process [Done with
# =================================== Creating Artist Album DB ===================================] took 1.9 minutes.
# Current Time is Sun Feb 07, 2021 17:25:37 for Done with Creating DB
# Process [Done with Creating DB] took 11.9 minutes.

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBFull("RateYourMusic")
elapsed(start, cmt)
# Out:
# Current Time is Sun Feb 07, 2021 17:13:38 for Creating DB
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rateyourmusic   =========================
# =========================   deezer   =========================
# =========================   albumoftheyear   =========================
# =========================   genius   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RateYourMusic
#   Creating Database Records for Deezer
#   Creating Database Records for AlbumOfTheYear
#   Creating Database Records for Genius
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RateYourMusic, Deezer, AlbumOfTheYear, Genius
# ========================= masterArtistNameDB =========================
#   Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicnames/mainArtistNameDB.p
#   There are currently 7247 artist keys.
#   There are currently 8453 renamed artist keys.
# Adding 1 known multi delim artists.
# Current Time is Sun Feb 07, 2021 17:13:39 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/6-Metadata.p  	0 26
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/94-Metadata.p  	1 47
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/77-Metadata.p  	2 64
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/40-Metadata.p  	3 83
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/15-Metadata.p  	4 110
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/22-Metadata.p  	5 131
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/88-Metadata.p  	6 146
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/99-Metadata.p  	7 174
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/33-Metadata.p  	8 200
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/51-Metadata.p  	9 226
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/66-Metadata.p  	10 250
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/85-Metadata.p  	11 280
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/18-Metadata.p  	12 304
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/36-Metadata.p  	13 321
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/63-Metadata.p  	14 339
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/54-Metadata.p  	15 356
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/48-Metadata.p  	16 372
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/80-Metadata.p  	17 392
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/91-Metadata.p  	18 413
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/3-Metadata.p  	19 435
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/59-Metadata.p  	20 458
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/45-Metadata.p  	21 488
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/72-Metadata.p  	22 501
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/27-Metadata.p  	23 516
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/10-Metadata.p  	24 537
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/42-Metadata.p  	25 567
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/75-Metadata.p  	26 584
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/20-Metadata.p  	27 611
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/17-Metadata.p  	28 633
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/69-Metadata.p  	29 654
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/4-Metadata.p  	30 679
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/96-Metadata.p  	31 702
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/87-Metadata.p  	32 728
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/78-Metadata.p  	33 747
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/9-Metadata.p  	34 771
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/31-Metadata.p  	35 788
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/64-Metadata.p  	36 805
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/53-Metadata.p  	37 827
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/28-Metadata.p  	38 847
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/82-Metadata.p  	39 867
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/34-Metadata.p  	40 897
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/56-Metadata.p  	41 923
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/61-Metadata.p  	42 951
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/70-Metadata.p  	43 969
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/47-Metadata.p  	44 982
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/12-Metadata.p  	45 1007
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/25-Metadata.p  	46 1025
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/93-Metadata.p  	47 1053
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/1-Metadata.p  	48 1070
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/39-Metadata.p  	49 1090
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/37-Metadata.p  	50 1116
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/62-Metadata.p  	51 1139
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/55-Metadata.p  	52 1161
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/81-Metadata.p  	53 1184
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/49-Metadata.p  	54 1212
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/58-Metadata.p  	55 1238
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/90-Metadata.p  	56 1263
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/2-Metadata.p  	57 1290
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/44-Metadata.p  	58 1311
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/73-Metadata.p  	59 1337
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/26-Metadata.p  	60 1359
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/11-Metadata.p  	61 1381
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/7-Metadata.p  	62 1407
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/95-Metadata.p  	63 1429
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/89-Metadata.p  	64 1449
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/76-Metadata.p  	65 1472
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/41-Metadata.p  	66 1498
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/14-Metadata.p  	67 1512
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/23-Metadata.p  	68 1536
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/32-Metadata.p  	69 1553
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/50-Metadata.p  	70 1576
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/67-Metadata.p  	71 1595
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/98-Metadata.p  	72 1611
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/19-Metadata.p  	73 1632
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/84-Metadata.p  	74 1647
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/83-Metadata.p  	75 1669
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/29-Metadata.p  	76 1691
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/35-Metadata.p  	77 1714
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/57-Metadata.p  	78 1732
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/60-Metadata.p  	79 1755
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/71-Metadata.p  	80 1775
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/46-Metadata.p  	81 1792
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/13-Metadata.p  	82 1819
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/24-Metadata.p  	83 1836
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/38-Metadata.p  	84 1857
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/92-Metadata.p  	85 1879
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/0-Metadata.p  	86 1906
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/43-Metadata.p  	87 1932
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/74-Metadata.p  	88 1959
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/21-Metadata.p  	89 1978
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/16-Metadata.p  	90 1995
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/5-Metadata.p  	91 2021
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/97-Metadata.p  	92 2049
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/68-Metadata.p  	93 2071
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/79-Metadata.p  	94 2087
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/86-Metadata.p  	95 2116
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/30-Metadata.p  	96 2134
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/65-Metadata.p  	97 2155
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/52-Metadata.p  	98 2178
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/8-Metadata.p  	99 2209
#
#
# ==============================================
#
# Saving 2209 entries to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToRef.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToRef.p
#   --> This file is 48.0kB.
# Saved data to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToRef.p
#   --> This file is 48.0kB.
# Saving 2209 entries to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToName.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToName.p
#   --> This file is 43.8kB.
# Saved data to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToName.p
#   --> This file is 43.8kB.
# Saving 2209 entries to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToVariations.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToVariations.p
#   --> This file is 51.4kB.
# Saved data to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToVariations.p
#   --> This file is 51.4kB.
# Current Time is Sun Feb 07, 2021 17:13:39 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 220.0 millseconds.
# Current Time is Sun Feb 07, 2021 17:13:39 for
# =================================== Creating Artist DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 2209 Artists
# 	Shape --> (2209, 1)
# 	Shape --> (2209, 2)
#   Finding Real Artist Name
# 	Shape --> (2209, 4)
#   Removing None Artist
# 	Shape --> (2209, 4)
#   Finding Disc Artist Name
# 	Shape --> (2209, 5)
# DataFrame Shape is (2209, 7)
# Current Time is Sun Feb 07, 2021 17:13:39 for Done with
# =================================== Creating Artist DB ===================================
# Process [Done with
# =================================== Creating Artist DB ===================================] took 62.0 millseconds.
# Saving Master Artist DB File: /Users/tgadfort/Music/Discog/db-rateyourmusic/MasterSlimArtistDB.p
#   --> This file is 251.2kB.
# Current Time is Sun Feb 07, 2021 17:13:39 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/51-MediaMetadata.p 	26        0         1033
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/6-MediaMetadata.p 	52        0         2303
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/16-MediaMetadata.p 	69        0         3038
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/32-MediaMetadata.p 	86        0         3944
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/94-MediaMetadata.p 	107       0         5168
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/75-MediaMetadata.p 	124       0         6252
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/48-MediaMetadata.p 	140       0         6984
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/47-MediaMetadata.p 	153       0         7746
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/63-MediaMetadata.p 	171       0         8569
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/82-MediaMetadata.p 	191       0         9266
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/19-MediaMetadata.p 	212       0         9961
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/9-MediaMetadata.p 	236       0         11120
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/24-MediaMetadata.p 	253       0         11883
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/23-MediaMetadata.p 	277       0         12851
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/85-MediaMetadata.p 	307       0         14087
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/64-MediaMetadata.p 	324       0         14817
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/59-MediaMetadata.p 	347       0         15657
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/40-MediaMetadata.p 	366       0         16591
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/72-MediaMetadata.p 	379       0         17187
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/93-MediaMetadata.p 	407       0         18592
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/35-MediaMetadata.p 	430       0         19647
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/11-MediaMetadata.p 	452       0         20506
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/1-MediaMetadata.p 	469       0         21279
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/56-MediaMetadata.p 	495       0         22510
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/65-MediaMetadata.p 	516       0         23544
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/58-MediaMetadata.p 	542       0         24916
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/22-MediaMetadata.p 	563       0         25730
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/84-MediaMetadata.p 	578       0         26374
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/41-MediaMetadata.p 	604       0         27602
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/92-MediaMetadata.p 	626       0         28374
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/34-MediaMetadata.p 	656       0         29447
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/73-MediaMetadata.p 	682       0         30712
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/57-MediaMetadata.p 	700       0         31682
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/10-MediaMetadata.p 	721       0         32617
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/0-MediaMetadata.p 	748       0         33874
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/7-MediaMetadata.p 	774       0         34901
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/17-MediaMetadata.p 	796       0         36023
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/50-MediaMetadata.p 	819       0         36980
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/74-MediaMetadata.p 	846       0         38042
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/49-MediaMetadata.p 	874       0         39195
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/33-MediaMetadata.p 	900       0         40432
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/95-MediaMetadata.p 	922       0         41700
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/46-MediaMetadata.p 	939       0         42449
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/83-MediaMetadata.p 	961       0         43468
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/18-MediaMetadata.p 	985       0         44254
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/8-MediaMetadata.p 	1016      0         45479
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/25-MediaMetadata.p 	1034      0         46295
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/62-MediaMetadata.p 	1057      0         47198
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/39-MediaMetadata.p 	1077      0         48122
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/43-MediaMetadata.p 	1103      0         49333
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/67-MediaMetadata.p 	1122      0         50242
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/86-MediaMetadata.p 	1151      0         51632
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/20-MediaMetadata.p 	1178      0         52500
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/68-MediaMetadata.p 	1200      0         53221
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/55-MediaMetadata.p 	1222      0         54022
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/89-MediaMetadata.p 	1242      0         54985
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/2-MediaMetadata.p 	1269      0         56437
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/12-MediaMetadata.p 	1294      0         57546
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/36-MediaMetadata.p 	1311      0         58120
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/90-MediaMetadata.p 	1336      0         58666
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/71-MediaMetadata.p 	1356      0         59504
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/76-MediaMetadata.p 	1379      0         60502
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/97-MediaMetadata.p 	1407      0         61314
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/31-MediaMetadata.p 	1424      0         62103
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/15-MediaMetadata.p 	1451      0         63625
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/5-MediaMetadata.p 	1477      0         64850
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/28-MediaMetadata.p 	1497      0         65996
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/52-MediaMetadata.p 	1520      0         66874
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/27-MediaMetadata.p 	1535      0         67614
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/81-MediaMetadata.p 	1558      0         68691
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/60-MediaMetadata.p 	1581      0         69804
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/79-MediaMetadata.p 	1597      0         70360
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/44-MediaMetadata.p 	1618      0         71180
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/98-MediaMetadata.p 	1634      0         71893
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/96-MediaMetadata.p 	1657      0         72938
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/30-MediaMetadata.p 	1675      0         73574
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/77-MediaMetadata.p 	1692      0         74224
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/53-MediaMetadata.p 	1714      0         75028
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/14-MediaMetadata.p 	1728      0         75650
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/4-MediaMetadata.p 	1753      0         76731
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/29-MediaMetadata.p 	1775      0         77835
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/61-MediaMetadata.p 	1803      0         78855
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/26-MediaMetadata.p 	1825      0         79812
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/80-MediaMetadata.p 	1845      0         80590
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/99-MediaMetadata.p 	1873      0         81522
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/78-MediaMetadata.p 	1892      0         82490
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/45-MediaMetadata.p 	1922      0         83760
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/42-MediaMetadata.p 	1952      0         85016
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/38-MediaMetadata.p 	1973      0         85848
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/87-MediaMetadata.p 	1999      0         87073
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/21-MediaMetadata.p 	2018      0         88107
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/66-MediaMetadata.p 	2042      0         89473
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/88-MediaMetadata.p 	2057      0         89911
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/3-MediaMetadata.p 	2079      0         90879
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/13-MediaMetadata.p 	2106      0         92142
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/69-MediaMetadata.p 	2127      0         93275
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/54-MediaMetadata.p 	2144      0         93818
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/70-MediaMetadata.p 	2162      0         94651
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/37-MediaMetadata.p 	2188      0         95730
# /Users/tgadfort/Music/Discog/artists-rateyourmusic-db/metadata/91-MediaMetadata.p 	2209      0         96946
#
#
# ==============================================
#
# Saving 2209 entries to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToAlbumNames.p
#   --> This file is 2.5MB.
# Saved data to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToAlbumNames.p
#   --> This file is 2.5MB.
# Saving 2209 entries to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToAlbumRefs.p
#   --> This file is 3.0MB.
# Saved data to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToAlbumRefs.p
#   --> This file is 3.0MB.
# Saving 2209 entries to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToCoreAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToCoreAlbumNames.p
#   --> This file is 23.5kB.
# Saved data to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToCoreAlbumNames.p
#   --> This file is 23.5kB.
# Saving 2209 entries to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToCoreAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToCoreAlbumRefs.p
#   --> This file is 23.5kB.
# Saved data to /Users/tgadfort/Music/Discog/db-rateyourmusic/ArtistIDToCoreAlbumRefs.p
#   --> This file is 23.5kB.
# Current Time is Sun Feb 07, 2021 17:13:43 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 4 seconds.
# Current Time is Sun Feb 07, 2021 17:13:43 for
# =================================== Creating Artist Album DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 2209 Artists
# 	Shape --> (2209, 1)
# DataFrame Shape is (2209, 1)
# Saving Master Artist Albums DB File: /Users/tgadfort/Music/Discog/db-rateyourmusic/MasterSlimArtistAlbumsDB.p
#   --> This file is 5.0MB.
# Current Time is Sun Feb 07, 2021 17:13:44 for Done with
# =================================== Creating Artist Album DB ===================================
# Process [Done with
# =================================== Creating Artist Album DB ===================================] took 1 seconds.
# Current Time is Sun Feb 07, 2021 17:13:45 for Done with Creating DB
# Process [Done with Creating DB] took 6 seconds.

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBFull("LastFM")
elapsed(start, cmt)
# Out:
# Current Time is Mon Feb 08, 2021 13:42:58 for Creating DB
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rateyourmusic   =========================
# =========================   deezer   =========================
# =========================   albumoftheyear   =========================
# =========================   genius   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RateYourMusic
#   Creating Database Records for Deezer
#   Creating Database Records for AlbumOfTheYear
#   Creating Database Records for Genius
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RateYourMusic, Deezer, AlbumOfTheYear, Genius
# ========================= masterArtistNameDB =========================
#   Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicnames/mainArtistNameDB.p
#   There are currently 7313 artist keys.
#   There are currently 8524 renamed artist keys.
# Adding 1 known multi delim artists.
# Current Time is Mon Feb 08, 2021 13:42:58 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/6-Metadata.p  	0 166
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/94-Metadata.p  	1 356
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/77-Metadata.p  	2 551
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/40-Metadata.p  	3 729
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/15-Metadata.p  	4 932
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/22-Metadata.p  	5 1098
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/88-Metadata.p  	6 1273
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/99-Metadata.p  	7 1440
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/33-Metadata.p  	8 1629
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/51-Metadata.p  	9 1802
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/66-Metadata.p  	10 1991
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/85-Metadata.p  	11 2159
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/18-Metadata.p  	12 2308
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/36-Metadata.p  	13 2499
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/63-Metadata.p  	14 2645
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/54-Metadata.p  	15 2809
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/48-Metadata.p  	16 2990
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/80-Metadata.p  	17 3157
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/91-Metadata.p  	18 3332
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/3-Metadata.p  	19 3537
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/59-Metadata.p  	20 3716
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/45-Metadata.p  	21 3909
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/72-Metadata.p  	22 4085
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/27-Metadata.p  	23 4272
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/10-Metadata.p  	24 4467
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/42-Metadata.p  	25 4637
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/75-Metadata.p  	26 4822
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/20-Metadata.p  	27 5004
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/17-Metadata.p  	28 5173
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/69-Metadata.p  	29 5361
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/4-Metadata.p  	30 5536
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/96-Metadata.p  	31 5714
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/87-Metadata.p  	32 5893
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/78-Metadata.p  	33 6037
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/9-Metadata.p  	34 6209
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/31-Metadata.p  	35 6372
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/64-Metadata.p  	36 6571
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/53-Metadata.p  	37 6730
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/28-Metadata.p  	38 6921
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/82-Metadata.p  	39 7103
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/34-Metadata.p  	40 7274
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/56-Metadata.p  	41 7470
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/61-Metadata.p  	42 7635
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/70-Metadata.p  	43 7813
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/47-Metadata.p  	44 7996
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/12-Metadata.p  	45 8170
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/25-Metadata.p  	46 8329
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/93-Metadata.p  	47 8493
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/1-Metadata.p  	48 8678
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/39-Metadata.p  	49 8859
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/37-Metadata.p  	50 9012
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/62-Metadata.p  	51 9177
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/55-Metadata.p  	52 9341
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/81-Metadata.p  	53 9518
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/49-Metadata.p  	54 9697
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/58-Metadata.p  	55 9896
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/90-Metadata.p  	56 10082
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/2-Metadata.p  	57 10267
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/44-Metadata.p  	58 10444
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/73-Metadata.p  	59 10611
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/26-Metadata.p  	60 10791
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/11-Metadata.p  	61 10982
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/7-Metadata.p  	62 11161
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/95-Metadata.p  	63 11338
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/89-Metadata.p  	64 11497
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/76-Metadata.p  	65 11682
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/41-Metadata.p  	66 11879
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/14-Metadata.p  	67 12062
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/23-Metadata.p  	68 12237
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/32-Metadata.p  	69 12405
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/50-Metadata.p  	70 12558
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/67-Metadata.p  	71 12752
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/98-Metadata.p  	72 12932
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/19-Metadata.p  	73 13095
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/84-Metadata.p  	74 13267
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/83-Metadata.p  	75 13447
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/29-Metadata.p  	76 13592
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/35-Metadata.p  	77 13779
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/57-Metadata.p  	78 13960
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/60-Metadata.p  	79 14147
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/71-Metadata.p  	80 14337
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/46-Metadata.p  	81 14526
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/13-Metadata.p  	82 14676
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/24-Metadata.p  	83 14863
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/38-Metadata.p  	84 15046
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/92-Metadata.p  	85 15217
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/0-Metadata.p  	86 15405
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/43-Metadata.p  	87 15567
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/74-Metadata.p  	88 15729
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/21-Metadata.p  	89 15914
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/16-Metadata.p  	90 16117
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/5-Metadata.p  	91 16303
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/97-Metadata.p  	92 16486
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/68-Metadata.p  	93 16668
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/79-Metadata.p  	94 16836
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/86-Metadata.p  	95 17015
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/30-Metadata.p  	96 17188
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/65-Metadata.p  	97 17364
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/52-Metadata.p  	98 17537
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/8-Metadata.p  	99 17728
#
#
# ==============================================
#
# Saving 17728 entries to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToRef.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToRef.p
#   --> This file is 525.7kB.
# Saved data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToRef.p
#   --> This file is 525.7kB.
# Saving 17728 entries to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToName.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToName.p
#   --> This file is 459.4kB.
# Saved data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToName.p
#   --> This file is 459.4kB.
# Saving 17728 entries to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToVariations.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToVariations.p
#   --> This file is 520.2kB.
# Saved data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToVariations.p
#   --> This file is 520.2kB.
# Current Time is Mon Feb 08, 2021 13:43:00 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 1 seconds.
# Current Time is Mon Feb 08, 2021 13:43:00 for
# =================================== Creating Artist DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 17728 Artists
# 	Shape --> (17728, 1)
# 	Shape --> (17728, 2)
#   Finding Real Artist Name
# 	Shape --> (17728, 4)
#   Removing None Artist
# 	Shape --> (17728, 4)
#   Finding Disc Artist Name
# 	Shape --> (17728, 5)
# DataFrame Shape is (17728, 7)
# Current Time is Mon Feb 08, 2021 13:43:00 for Done with
# =================================== Creating Artist DB ===================================
# Process [Done with
# =================================== Creating Artist DB ===================================] took 780.0 millseconds.
# Saving Master Artist DB File: /Users/tgadfort/Music/Discog/db-lastfm/MasterSlimArtistDB.p
#   --> This file is 3.0MB.
# Current Time is Mon Feb 08, 2021 13:43:01 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/51-MediaMetadata.p 	173       2043      2043
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/6-MediaMetadata.p 	339       3821      3821
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/16-MediaMetadata.p 	542       6239      6239
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/32-MediaMetadata.p 	710       8255      8255
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/94-MediaMetadata.p 	900       10592     10592
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/75-MediaMetadata.p 	1085      12717     12717
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/48-MediaMetadata.p 	1266      14969     14969
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/47-MediaMetadata.p 	1449      17184     17184
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/63-MediaMetadata.p 	1595      18934     18934
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/82-MediaMetadata.p 	1777      20980     20980
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/19-MediaMetadata.p 	1940      22934     22934
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/9-MediaMetadata.p 	2112      25024     25024
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/24-MediaMetadata.p 	2299      27180     27180
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/23-MediaMetadata.p 	2474      29121     29121
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/85-MediaMetadata.p 	2642      31026     31026
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/64-MediaMetadata.p 	2841      33168     33168
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/59-MediaMetadata.p 	3020      35198     35198
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/40-MediaMetadata.p 	3198      37348     37348
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/72-MediaMetadata.p 	3374      39376     39376
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/93-MediaMetadata.p 	3538      41148     41148
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/35-MediaMetadata.p 	3725      43540     43540
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/11-MediaMetadata.p 	3916      45801     45801
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/1-MediaMetadata.p 	4101      48014     48014
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/56-MediaMetadata.p 	4297      50161     50161
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/65-MediaMetadata.p 	4473      52349     52349
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/58-MediaMetadata.p 	4672      54449     54449
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/22-MediaMetadata.p 	4838      56344     56344
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/84-MediaMetadata.p 	5010      58398     58398
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/41-MediaMetadata.p 	5207      60940     60940
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/92-MediaMetadata.p 	5378      63051     63051
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/34-MediaMetadata.p 	5549      65174     65174
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/73-MediaMetadata.p 	5716      66922     66922
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/57-MediaMetadata.p 	5897      69108     69108
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/10-MediaMetadata.p 	6092      71326     71326
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/0-MediaMetadata.p 	6280      73255     73255
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/7-MediaMetadata.p 	6459      75410     75410
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/17-MediaMetadata.p 	6628      77609     77609
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/50-MediaMetadata.p 	6781      79440     79440
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/74-MediaMetadata.p 	6943      81485     81485
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/49-MediaMetadata.p 	7122      83652     83652
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/33-MediaMetadata.p 	7311      85948     85948
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/95-MediaMetadata.p 	7488      87700     87700
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/46-MediaMetadata.p 	7677      89883     89883
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/83-MediaMetadata.p 	7857      92041     92041
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/18-MediaMetadata.p 	8006      93572     93572
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/8-MediaMetadata.p 	8197      95897     95897
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/25-MediaMetadata.p 	8356      97621     97621
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/62-MediaMetadata.p 	8521      99370     99370
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/39-MediaMetadata.p 	8702      101395    101395
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/43-MediaMetadata.p 	8864      103306    103306
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/67-MediaMetadata.p 	9058      105539    105539
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/86-MediaMetadata.p 	9237      107570    107570
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/20-MediaMetadata.p 	9419      109779    109779
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/68-MediaMetadata.p 	9601      112052    112052
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/55-MediaMetadata.p 	9765      114031    114031
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/89-MediaMetadata.p 	9924      116134    116134
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/2-MediaMetadata.p 	10109     118373    118373
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/12-MediaMetadata.p 	10283     120496    120496
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/36-MediaMetadata.p 	10474     122765    122765
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/90-MediaMetadata.p 	10660     124891    124891
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/71-MediaMetadata.p 	10850     127030    127030
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/76-MediaMetadata.p 	11035     129259    129259
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/97-MediaMetadata.p 	11218     131309    131309
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/31-MediaMetadata.p 	11381     133261    133261
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/15-MediaMetadata.p 	11584     135722    135722
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/5-MediaMetadata.p 	11770     137960    137960
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/28-MediaMetadata.p 	11961     140148    140148
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/52-MediaMetadata.p 	12134     142203    142203
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/27-MediaMetadata.p 	12321     144271    144271
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/81-MediaMetadata.p 	12498     146275    146275
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/60-MediaMetadata.p 	12685     148364    148364
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/79-MediaMetadata.p 	12853     150463    150463
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/44-MediaMetadata.p 	13030     152395    152395
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/98-MediaMetadata.p 	13210     154475    154475
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/96-MediaMetadata.p 	13388     156509    156509
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/30-MediaMetadata.p 	13561     158474    158474
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/77-MediaMetadata.p 	13756     160718    160718
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/53-MediaMetadata.p 	13915     162764    162764
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/14-MediaMetadata.p 	14098     164877    164877
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/4-MediaMetadata.p 	14273     166846    166846
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/29-MediaMetadata.p 	14418     168510    168510
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/61-MediaMetadata.p 	14583     170550    170550
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/26-MediaMetadata.p 	14763     172496    172496
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/80-MediaMetadata.p 	14930     174358    174358
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/99-MediaMetadata.p 	15097     176125    176125
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/78-MediaMetadata.p 	15241     177644    177644
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/45-MediaMetadata.p 	15434     179826    179826
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/42-MediaMetadata.p 	15604     181783    181783
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/38-MediaMetadata.p 	15787     183914    183914
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/87-MediaMetadata.p 	15966     185883    185883
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/21-MediaMetadata.p 	16151     188251    188251
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/66-MediaMetadata.p 	16340     190564    190564
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/88-MediaMetadata.p 	16515     192745    192745
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/3-MediaMetadata.p 	16720     195163    195163
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/13-MediaMetadata.p 	16870     196960    196960
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/69-MediaMetadata.p 	17058     198887    198887
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/54-MediaMetadata.p 	17222     200712    200712
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/70-MediaMetadata.p 	17400     202875    202875
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/37-MediaMetadata.p 	17553     204742    204742
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/91-MediaMetadata.p 	17728     206650    206650
#
#
# ==============================================
#
# Saving 17728 entries to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToAlbumNames.p
#   --> This file is 5.7MB.
# Saved data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToAlbumNames.p
#   --> This file is 5.7MB.
# Saving 17728 entries to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToAlbumRefs.p
#   --> This file is 6.5MB.
# Saved data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToAlbumRefs.p
#   --> This file is 6.5MB.
# Saving 17728 entries to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToCoreAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToCoreAlbumNames.p
#   --> This file is 5.7MB.
# Saved data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToCoreAlbumNames.p
#   --> This file is 5.7MB.
# Saving 17728 entries to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToCoreAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToCoreAlbumRefs.p
#   --> This file is 6.5MB.
# Saved data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToCoreAlbumRefs.p
#   --> This file is 6.5MB.
# Current Time is Mon Feb 08, 2021 13:43:16 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 15 seconds.
# Current Time is Mon Feb 08, 2021 13:43:16 for
# =================================== Creating Artist Album DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 17728 Artists
# 	Shape --> (17728, 1)
# DataFrame Shape is (17728, 1)
# Saving Master Artist Albums DB File: /Users/tgadfort/Music/Discog/db-lastfm/MasterSlimArtistAlbumsDB.p
#   --> This file is 11.2MB.
# Current Time is Mon Feb 08, 2021 13:43:19 for Done with
# =================================== Creating Artist Album DB ===================================
# Process [Done with
# =================================== Creating Artist Album DB ===================================] took 2 seconds.
# Current Time is Mon Feb 08, 2021 13:43:19 for Done with Creating DB
# Process [Done with Creating DB] took 21 seconds.

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBFull("AlbumOfTheYear")
elapsed(start, cmt)
# Out:
# Current Time is Sun Feb 07, 2021 17:13:32 for Creating DB
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rateyourmusic   =========================
# =========================   deezer   =========================
# =========================   albumoftheyear   =========================
# =========================   genius   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RateYourMusic
#   Creating Database Records for Deezer
#   Creating Database Records for AlbumOfTheYear
#   Creating Database Records for Genius
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RateYourMusic, Deezer, AlbumOfTheYear, Genius
# ========================= masterArtistNameDB =========================
#   Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicnames/mainArtistNameDB.p
#   There are currently 7247 artist keys.
#   There are currently 8453 renamed artist keys.
# Adding 1 known multi delim artists.
# Current Time is Sun Feb 07, 2021 17:13:32 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/6-Metadata.p  	0 83
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/94-Metadata.p  	1 157
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/77-Metadata.p  	2 253
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/40-Metadata.p  	3 343
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/15-Metadata.p  	4 416
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/22-Metadata.p  	5 488
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/88-Metadata.p  	6 566
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/99-Metadata.p  	7 650
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/33-Metadata.p  	8 731
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/51-Metadata.p  	9 800
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/66-Metadata.p  	10 865
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/85-Metadata.p  	11 932
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/18-Metadata.p  	12 1002
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/36-Metadata.p  	13 1072
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/63-Metadata.p  	14 1162
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/54-Metadata.p  	15 1221
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/48-Metadata.p  	16 1298
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/80-Metadata.p  	17 1379
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/91-Metadata.p  	18 1455
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/3-Metadata.p  	19 1531
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/59-Metadata.p  	20 1607
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/45-Metadata.p  	21 1683
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/72-Metadata.p  	22 1745
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/27-Metadata.p  	23 1827
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/10-Metadata.p  	24 1895
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/42-Metadata.p  	25 1989
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/75-Metadata.p  	26 2069
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/20-Metadata.p  	27 2142
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/17-Metadata.p  	28 2217
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/69-Metadata.p  	29 2308
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/4-Metadata.p  	30 2377
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/96-Metadata.p  	31 2457
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/87-Metadata.p  	32 2533
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/78-Metadata.p  	33 2618
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/9-Metadata.p  	34 2692
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/31-Metadata.p  	35 2777
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/64-Metadata.p  	36 2852
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/53-Metadata.p  	37 2922
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/28-Metadata.p  	38 2998
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/82-Metadata.p  	39 3090
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/34-Metadata.p  	40 3160
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/56-Metadata.p  	41 3243
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/61-Metadata.p  	42 3321
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/70-Metadata.p  	43 3397
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/47-Metadata.p  	44 3477
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/12-Metadata.p  	45 3547
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/25-Metadata.p  	46 3635
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/93-Metadata.p  	47 3712
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/1-Metadata.p  	48 3786
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/39-Metadata.p  	49 3855
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/37-Metadata.p  	50 3924
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/62-Metadata.p  	51 3998
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/55-Metadata.p  	52 4078
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/81-Metadata.p  	53 4165
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/49-Metadata.p  	54 4225
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/58-Metadata.p  	55 4288
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/90-Metadata.p  	56 4365
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/2-Metadata.p  	57 4434
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/44-Metadata.p  	58 4504
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/73-Metadata.p  	59 4583
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/26-Metadata.p  	60 4662
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/11-Metadata.p  	61 4745
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/7-Metadata.p  	62 4841
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/95-Metadata.p  	63 4919
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/89-Metadata.p  	64 4992
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/76-Metadata.p  	65 5076
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/41-Metadata.p  	66 5143
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/14-Metadata.p  	67 5217
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/23-Metadata.p  	68 5287
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/32-Metadata.p  	69 5373
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/50-Metadata.p  	70 5457
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/67-Metadata.p  	71 5522
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/98-Metadata.p  	72 5598
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/19-Metadata.p  	73 5663
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/84-Metadata.p  	74 5749
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/83-Metadata.p  	75 5816
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/29-Metadata.p  	76 5894
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/35-Metadata.p  	77 5960
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/57-Metadata.p  	78 6032
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/60-Metadata.p  	79 6095
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/71-Metadata.p  	80 6191
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/46-Metadata.p  	81 6270
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/13-Metadata.p  	82 6350
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/24-Metadata.p  	83 6420
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/38-Metadata.p  	84 6493
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/92-Metadata.p  	85 6564
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/0-Metadata.p  	86 6658
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/43-Metadata.p  	87 6749
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/74-Metadata.p  	88 6819
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/21-Metadata.p  	89 6887
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/16-Metadata.p  	90 6946
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/5-Metadata.p  	91 7023
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/97-Metadata.p  	92 7099
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/68-Metadata.p  	93 7182
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/79-Metadata.p  	94 7261
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/86-Metadata.p  	95 7334
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/30-Metadata.p  	96 7423
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/65-Metadata.p  	97 7494
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/52-Metadata.p  	98 7561
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/8-Metadata.p  	99 7655
#
#
# ==============================================
#
# Saving 7655 entries to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToRef.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToRef.p
#   --> This file is 178.8kB.
# Saved data to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToRef.p
#   --> This file is 178.8kB.
# Saving 7655 entries to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToName.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToName.p
#   --> This file is 149.4kB.
# Saved data to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToName.p
#   --> This file is 149.4kB.
# Saving 7655 entries to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToVariations.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToVariations.p
#   --> This file is 174.3kB.
# Saved data to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToVariations.p
#   --> This file is 174.3kB.
# Current Time is Sun Feb 07, 2021 17:13:33 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 534.0 millseconds.
# Current Time is Sun Feb 07, 2021 17:13:33 for
# =================================== Creating Artist DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 7655 Artists
# 	Shape --> (7655, 1)
# 	Shape --> (7655, 2)
#   Finding Real Artist Name
# 	Shape --> (7655, 4)
#   Removing None Artist
# 	Shape --> (7655, 4)
#   Finding Disc Artist Name
# 	Shape --> (7655, 5)
# DataFrame Shape is (7655, 7)
# Current Time is Sun Feb 07, 2021 17:13:33 for Done with
# =================================== Creating Artist DB ===================================
# Process [Done with
# =================================== Creating Artist DB ===================================] took 459.0 millseconds.
# Saving Master Artist DB File: /Users/tgadfort/Music/Discog/db-albumoftheyear/MasterSlimArtistDB.p
#   --> This file is 1.1MB.
# Current Time is Sun Feb 07, 2021 17:13:33 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/51-MediaMetadata.p 	69        0         151
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/6-MediaMetadata.p 	152       0         363
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/16-MediaMetadata.p 	211       0         481
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/32-MediaMetadata.p 	297       0         694
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/94-MediaMetadata.p 	371       0         870
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/75-MediaMetadata.p 	451       0         1115
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/48-MediaMetadata.p 	528       0         1312
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/47-MediaMetadata.p 	608       0         1546
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/63-MediaMetadata.p 	698       0         1741
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/82-MediaMetadata.p 	790       0         1934
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/19-MediaMetadata.p 	855       0         2127
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/9-MediaMetadata.p 	929       0         2302
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/24-MediaMetadata.p 	999       0         2475
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/23-MediaMetadata.p 	1069      0         2693
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/85-MediaMetadata.p 	1136      0         2854
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/64-MediaMetadata.p 	1211      0         3114
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/59-MediaMetadata.p 	1287      0         3347
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/40-MediaMetadata.p 	1377      0         3608
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/72-MediaMetadata.p 	1439      0         3854
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/93-MediaMetadata.p 	1516      0         4030
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/35-MediaMetadata.p 	1582      0         4189
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/11-MediaMetadata.p 	1665      0         4400
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/1-MediaMetadata.p 	1739      0         4612
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/56-MediaMetadata.p 	1822      0         4793
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/65-MediaMetadata.p 	1893      0         4997
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/58-MediaMetadata.p 	1956      0         5152
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/22-MediaMetadata.p 	2028      0         5333
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/84-MediaMetadata.p 	2114      0         5549
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/41-MediaMetadata.p 	2181      0         5739
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/92-MediaMetadata.p 	2252      0         6001
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/34-MediaMetadata.p 	2322      0         6210
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/73-MediaMetadata.p 	2401      0         6406
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/57-MediaMetadata.p 	2473      0         6619
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/10-MediaMetadata.p 	2541      0         6774
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/0-MediaMetadata.p 	2635      0         7010
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/7-MediaMetadata.p 	2731      0         7260
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/17-MediaMetadata.p 	2806      0         7454
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/50-MediaMetadata.p 	2890      0         7689
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/74-MediaMetadata.p 	2960      0         7877
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/49-MediaMetadata.p 	3020      0         8072
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/33-MediaMetadata.p 	3101      0         8310
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/95-MediaMetadata.p 	3179      0         8554
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/46-MediaMetadata.p 	3258      0         8760
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/83-MediaMetadata.p 	3325      0         8956
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/18-MediaMetadata.p 	3395      0         9142
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/8-MediaMetadata.p 	3489      0         9435
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/25-MediaMetadata.p 	3577      0         9638
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/62-MediaMetadata.p 	3651      0         9857
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/39-MediaMetadata.p 	3720      0         10086
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/43-MediaMetadata.p 	3811      0         10325
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/67-MediaMetadata.p 	3876      0         10502
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/86-MediaMetadata.p 	3949      0         10706
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/20-MediaMetadata.p 	4022      0         10899
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/68-MediaMetadata.p 	4105      0         11109
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/55-MediaMetadata.p 	4185      0         11320
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/89-MediaMetadata.p 	4258      0         11521
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/2-MediaMetadata.p 	4327      0         11686
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/12-MediaMetadata.p 	4397      0         11886
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/36-MediaMetadata.p 	4467      0         12042
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/90-MediaMetadata.p 	4544      0         12254
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/71-MediaMetadata.p 	4640      0         12520
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/76-MediaMetadata.p 	4724      0         12742
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/97-MediaMetadata.p 	4800      0         12922
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/31-MediaMetadata.p 	4885      0         13137
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/15-MediaMetadata.p 	4958      0         13308
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/5-MediaMetadata.p 	5035      0         13510
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/28-MediaMetadata.p 	5111      0         13686
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/52-MediaMetadata.p 	5178      0         13904
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/27-MediaMetadata.p 	5260      0         14129
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/81-MediaMetadata.p 	5347      0         14346
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/60-MediaMetadata.p 	5410      0         14537
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/79-MediaMetadata.p 	5489      0         14758
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/44-MediaMetadata.p 	5559      0         14977
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/98-MediaMetadata.p 	5635      0         15146
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/96-MediaMetadata.p 	5715      0         15362
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/30-MediaMetadata.p 	5804      0         15601
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/77-MediaMetadata.p 	5900      0         15825
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/53-MediaMetadata.p 	5970      0         15989
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/14-MediaMetadata.p 	6044      0         16194
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/4-MediaMetadata.p 	6113      0         16399
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/29-MediaMetadata.p 	6191      0         16600
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/61-MediaMetadata.p 	6269      0         16816
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/26-MediaMetadata.p 	6348      0         17036
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/80-MediaMetadata.p 	6429      0         17268
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/99-MediaMetadata.p 	6513      0         17484
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/78-MediaMetadata.p 	6598      0         17642
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/45-MediaMetadata.p 	6674      0         17873
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/42-MediaMetadata.p 	6768      0         18087
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/38-MediaMetadata.p 	6841      0         18300
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/87-MediaMetadata.p 	6917      0         18506
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/21-MediaMetadata.p 	6985      0         18698
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/66-MediaMetadata.p 	7050      0         18898
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/88-MediaMetadata.p 	7128      0         19125
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/3-MediaMetadata.p 	7204      0         19309
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/13-MediaMetadata.p 	7284      0         19492
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/69-MediaMetadata.p 	7375      0         19698
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/54-MediaMetadata.p 	7434      0         19858
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/70-MediaMetadata.p 	7510      0         20066
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/37-MediaMetadata.p 	7579      0         20276
# /Users/tgadfort/Music/Discog/artists-albumoftheyear-db/metadata/91-MediaMetadata.p 	7655      0         20506
#
#
# ==============================================
#
# Saving 7655 entries to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToAlbumNames.p
#   --> This file is 625.8kB.
# Saved data to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToAlbumNames.p
#   --> This file is 625.8kB.
# Saving 7655 entries to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToAlbumRefs.p
#   --> This file is 850.4kB.
# Saved data to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToAlbumRefs.p
#   --> This file is 850.4kB.
# Saving 7655 entries to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToCoreAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToCoreAlbumNames.p
#   --> This file is 82.5kB.
# Saved data to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToCoreAlbumNames.p
#   --> This file is 82.5kB.
# Saving 7655 entries to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToCoreAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToCoreAlbumRefs.p
#   --> This file is 82.5kB.
# Saved data to /Users/tgadfort/Music/Discog/db-albumoftheyear/ArtistIDToCoreAlbumRefs.p
#   --> This file is 82.5kB.
# Current Time is Sun Feb 07, 2021 17:13:36 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 2 seconds.
# Current Time is Sun Feb 07, 2021 17:13:36 for
# =================================== Creating Artist Album DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 7655 Artists
# 	Shape --> (7655, 1)
# DataFrame Shape is (7655, 1)
# Saving Master Artist Albums DB File: /Users/tgadfort/Music/Discog/db-albumoftheyear/MasterSlimArtistAlbumsDB.p
#   --> This file is 1.2MB.
# Current Time is Sun Feb 07, 2021 17:13:36 for Done with
# =================================== Creating Artist Album DB ===================================
# Process [Done with
# =================================== Creating Artist Album DB ===================================] took 466.0 millseconds.
# Current Time is Sun Feb 07, 2021 17:13:36 for Done with Creating DB
# Process [Done with Creating DB] took 4 seconds.

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBFull("Genius")
elapsed(start, cmt)
# Out:
# Current Time is Mon Feb 08, 2021 17:27:32 for Creating DB
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rateyourmusic   =========================
# =========================   deezer   =========================
# =========================   albumoftheyear   =========================
# =========================   genius   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RateYourMusic
#   Creating Database Records for Deezer
#   Creating Database Records for AlbumOfTheYear
#   Creating Database Records for Genius
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RateYourMusic, Deezer, AlbumOfTheYear, Genius
# ========================= masterArtistNameDB =========================
#   Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicnames/mainArtistNameDB.p
#   There are currently 7313 artist keys.
#   There are currently 8524 renamed artist keys.
# Adding 1 known multi delim artists.
# Current Time is Mon Feb 08, 2021 17:27:32 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/6-Metadata.p  	0 3
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/94-Metadata.p  	1 5
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/77-Metadata.p  	2 8
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/40-Metadata.p  	3 11
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/15-Metadata.p  	4 15
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/22-Metadata.p  	5 18
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/88-Metadata.p  	6 19
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/99-Metadata.p  	7 25
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/33-Metadata.p  	8 28
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/51-Metadata.p  	9 30
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/85-Metadata.p  	10 33
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/18-Metadata.p  	11 37
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/36-Metadata.p  	12 40
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/63-Metadata.p  	13 45
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/54-Metadata.p  	14 51
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/48-Metadata.p  	15 54
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/80-Metadata.p  	16 55
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/91-Metadata.p  	17 57
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/3-Metadata.p  	18 62
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/59-Metadata.p  	19 63
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/45-Metadata.p  	20 67
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/72-Metadata.p  	21 70
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/27-Metadata.p  	22 72
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/10-Metadata.p  	23 74
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/42-Metadata.p  	24 75
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/20-Metadata.p  	25 76
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/69-Metadata.p  	26 82
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/96-Metadata.p  	27 86
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/87-Metadata.p  	28 89
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/78-Metadata.p  	29 93
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/9-Metadata.p  	30 97
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/31-Metadata.p  	31 102
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/64-Metadata.p  	32 104
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/53-Metadata.p  	33 109
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/28-Metadata.p  	34 112
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/82-Metadata.p  	35 118
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/34-Metadata.p  	36 121
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/56-Metadata.p  	37 122
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/70-Metadata.p  	38 124
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/47-Metadata.p  	39 128
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/12-Metadata.p  	40 134
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/25-Metadata.p  	41 135
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/93-Metadata.p  	42 137
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/1-Metadata.p  	43 139
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/39-Metadata.p  	44 147
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/37-Metadata.p  	45 149
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/62-Metadata.p  	46 157
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/55-Metadata.p  	47 158
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/81-Metadata.p  	48 161
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/49-Metadata.p  	49 162
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/58-Metadata.p  	50 167
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/90-Metadata.p  	51 170
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/2-Metadata.p  	52 171
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/44-Metadata.p  	53 174
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/73-Metadata.p  	54 175
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/26-Metadata.p  	55 179
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/11-Metadata.p  	56 184
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/7-Metadata.p  	57 185
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/95-Metadata.p  	58 189
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/89-Metadata.p  	59 193
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/76-Metadata.p  	60 197
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/41-Metadata.p  	61 199
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/14-Metadata.p  	62 204
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/23-Metadata.p  	63 207
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/32-Metadata.p  	64 208
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/50-Metadata.p  	65 211
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/67-Metadata.p  	66 215
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/98-Metadata.p  	67 217
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/19-Metadata.p  	68 220
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/84-Metadata.p  	69 224
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/83-Metadata.p  	70 229
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/29-Metadata.p  	71 230
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/35-Metadata.p  	72 236
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/57-Metadata.p  	73 241
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/60-Metadata.p  	74 245
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/71-Metadata.p  	75 248
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/46-Metadata.p  	76 253
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/13-Metadata.p  	77 257
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/24-Metadata.p  	78 261
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/38-Metadata.p  	79 263
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/92-Metadata.p  	80 268
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/0-Metadata.p  	81 273
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/43-Metadata.p  	82 277
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/74-Metadata.p  	83 282
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/21-Metadata.p  	84 285
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/16-Metadata.p  	85 291
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/5-Metadata.p  	86 293
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/97-Metadata.p  	87 295
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/68-Metadata.p  	88 298
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/79-Metadata.p  	89 302
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/86-Metadata.p  	90 307
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/30-Metadata.p  	91 313
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/65-Metadata.p  	92 315
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/52-Metadata.p  	93 316
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/8-Metadata.p  	94 318
#
#
# ==============================================
#
# Saving 318 entries to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToRef.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToRef.p
#   --> This file is 6.6kB.
# Saved data to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToRef.p
#   --> This file is 6.6kB.
# Saving 318 entries to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToName.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToName.p
#   --> This file is 6.8kB.
# Saved data to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToName.p
#   --> This file is 6.8kB.
# Saving 318 entries to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToVariations.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToVariations.p
#   --> This file is 7.8kB.
# Saved data to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToVariations.p
#   --> This file is 7.8kB.
# Current Time is Mon Feb 08, 2021 17:27:32 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 82.0 millseconds.
# Current Time is Mon Feb 08, 2021 17:27:32 for
# =================================== Creating Artist DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 318 Artists
# 	Shape --> (318, 1)
# 	Shape --> (318, 2)
#   Finding Real Artist Name
# 	Shape --> (318, 4)
#   Removing None Artist
# 	Shape --> (318, 4)
#   Finding Disc Artist Name
# 	Shape --> (318, 5)
# DataFrame Shape is (318, 7)
# Current Time is Mon Feb 08, 2021 17:27:32 for Done with
# =================================== Creating Artist DB ===================================
# Process [Done with
# =================================== Creating Artist DB ===================================] took 33.0 millseconds.
# Saving Master Artist DB File: /Users/tgadfort/Music/Discog/db-genius/MasterSlimArtistDB.p
#   --> This file is 20.7kB.
# Current Time is Mon Feb 08, 2021 17:27:32 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/51-MediaMetadata.p 	2         3         23
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/6-MediaMetadata.p 	5         11        61
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/16-MediaMetadata.p 	11        21        118
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/32-MediaMetadata.p 	12        23        130
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/94-MediaMetadata.p 	14        24        150
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/48-MediaMetadata.p 	17        29        176
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/47-MediaMetadata.p 	21        49        236
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/63-MediaMetadata.p 	26        59        288
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/82-MediaMetadata.p 	32        69        340
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/19-MediaMetadata.p 	35        86        384
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/9-MediaMetadata.p 	39        98        426
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/24-MediaMetadata.p 	43        116       484
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/23-MediaMetadata.p 	46        122       520
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/85-MediaMetadata.p 	49        124       536
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/64-MediaMetadata.p 	51        125       555
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/59-MediaMetadata.p 	52        132       572
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/40-MediaMetadata.p 	55        137       599
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/72-MediaMetadata.p 	58        144       636
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/93-MediaMetadata.p 	60        146       642
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/35-MediaMetadata.p 	66        173       718
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/11-MediaMetadata.p 	71        188       772
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/1-MediaMetadata.p 	73        197       791
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/56-MediaMetadata.p 	74        206       810
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/65-MediaMetadata.p 	76        214       832
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/58-MediaMetadata.p 	81        226       890
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/22-MediaMetadata.p 	84        228       917
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/84-MediaMetadata.p 	88        244       968
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/41-MediaMetadata.p 	90        244       980
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/92-MediaMetadata.p 	95        268       1045
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/34-MediaMetadata.p 	98        276       1083
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/73-MediaMetadata.p 	99        279       1096
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/57-MediaMetadata.p 	104       295       1154
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/10-MediaMetadata.p 	106       305       1184
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/0-MediaMetadata.p 	111       319       1239
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/7-MediaMetadata.p 	112       319       1249
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/50-MediaMetadata.p 	115       331       1287
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/74-MediaMetadata.p 	120       355       1352
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/49-MediaMetadata.p 	121       355       1357
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/33-MediaMetadata.p 	124       372       1396
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/95-MediaMetadata.p 	128       381       1435
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/46-MediaMetadata.p 	133       404       1506
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/83-MediaMetadata.p 	138       418       1563
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/18-MediaMetadata.p 	142       442       1627
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/8-MediaMetadata.p 	144       458       1663
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/25-MediaMetadata.p 	145       459       1674
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/62-MediaMetadata.p 	153       476       1743
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/39-MediaMetadata.p 	161       501       1837
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/43-MediaMetadata.p 	165       511       1878
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/67-MediaMetadata.p 	169       524       1925
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/86-MediaMetadata.p 	174       532       1966
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/20-MediaMetadata.p 	175       533       1977
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/68-MediaMetadata.p 	178       562       2036
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/55-MediaMetadata.p 	179       566       2050
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/89-MediaMetadata.p 	183       577       2101
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/2-MediaMetadata.p 	184       578       2112
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/12-MediaMetadata.p 	190       601       2186
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/36-MediaMetadata.p 	193       603       2212
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/90-MediaMetadata.p 	196       611       2250
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/71-MediaMetadata.p 	199       613       2267
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/76-MediaMetadata.p 	203       628       2320
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/97-MediaMetadata.p 	205       629       2332
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/31-MediaMetadata.p 	210       647       2382
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/15-MediaMetadata.p 	214       659       2434
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/5-MediaMetadata.p 	216       662       2450
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/28-MediaMetadata.p 	219       665       2483
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/52-MediaMetadata.p 	220       675       2503
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/27-MediaMetadata.p 	222       675       2508
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/81-MediaMetadata.p 	225       677       2532
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/60-MediaMetadata.p 	229       690       2576
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/79-MediaMetadata.p 	233       701       2620
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/44-MediaMetadata.p 	236       707       2647
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/98-MediaMetadata.p 	238       707       2654
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/96-MediaMetadata.p 	242       710       2684
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/30-MediaMetadata.p 	248       726       2748
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/77-MediaMetadata.p 	251       730       2774
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/53-MediaMetadata.p 	256       740       2823
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/14-MediaMetadata.p 	261       750       2871
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/29-MediaMetadata.p 	262       750       2872
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/26-MediaMetadata.p 	266       764       2915
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/80-MediaMetadata.p 	267       764       2919
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/99-MediaMetadata.p 	273       777       2975
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/78-MediaMetadata.p 	277       800       3038
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/45-MediaMetadata.p 	281       805       3076
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/42-MediaMetadata.p 	282       805       3083
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/38-MediaMetadata.p 	284       811       3109
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/87-MediaMetadata.p 	287       812       3133
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/21-MediaMetadata.p 	290       826       3177
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/88-MediaMetadata.p 	291       836       3197
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/3-MediaMetadata.p 	296       843       3230
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/13-MediaMetadata.p 	300       864       3291
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/69-MediaMetadata.p 	306       888       3368
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/54-MediaMetadata.p 	312       905       3434
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/70-MediaMetadata.p 	314       905       3454
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/37-MediaMetadata.p 	316       918       3487
# /Users/tgadfort/Music/Discog/artists-genius-db/metadata/91-MediaMetadata.p 	318       927       3516
#
#
# ==============================================
#
# Saving 318 entries to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToAlbumNames.p
#   --> This file is 73.7kB.
# Saved data to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToAlbumNames.p
#   --> This file is 73.7kB.
# Saving 318 entries to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToAlbumRefs.p
#   --> This file is 21.2kB.
# Saved data to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToAlbumRefs.p
#   --> This file is 21.2kB.
# Saving 318 entries to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToCoreAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToCoreAlbumNames.p
#   --> This file is 24.6kB.
# Saved data to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToCoreAlbumNames.p
#   --> This file is 24.6kB.
# Saving 318 entries to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToCoreAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToCoreAlbumRefs.p
#   --> This file is 9.0kB.
# Saved data to /Users/tgadfort/Music/Discog/db-genius/ArtistIDToCoreAlbumRefs.p
#   --> This file is 9.0kB.
# Current Time is Mon Feb 08, 2021 17:27:32 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 232.0 millseconds.
# Current Time is Mon Feb 08, 2021 17:27:32 for
# =================================== Creating Artist Album DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 318 Artists
# 	Shape --> (318, 1)
# DataFrame Shape is (318, 1)
# Saving Master Artist Albums DB File: /Users/tgadfort/Music/Discog/db-genius/MasterSlimArtistAlbumsDB.p
#   --> This file is 143.3kB.
# Current Time is Mon Feb 08, 2021 17:27:32 for Done with
# =================================== Creating Artist Album DB ===================================
# Process [Done with
# =================================== Creating Artist Album DB ===================================] took 37.0 millseconds.
# Current Time is Mon Feb 08, 2021 17:27:32 for Done with Creating DB
# Process [Done with Creating DB] took 543.0 millseconds.

# %% [markdown]
# ## Create Metadata (Only)

# %%
dbs    = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
dbs    = ['AllMusic']
dbs    = []
if len(dbs) > 0:
    start,cmt=clock("Parsing Metadata")
    for db in dbs:
        pdb.parseMetadata(db=db, nProcs=3, modVals=list(range(100)), force=True) 
    elapsed(start, cmt)

# %% [markdown]
# # Parse Downloads

# %%
dbs = ["RateYourMusic", "MusicStack"]
dbs = ["RateYourMusic"]
if len(dbs) > 0:
    start,cmt=clock("Parsing Downloads")
    for db in dbs:
        pdb.parseDownloads(db)
    elapsed(start, cmt)

# %% [markdown]
# # Parse Everything

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData
maindb = mainDB(mdb=None, create=True, debug=False)
pdb    = parseDBArtistsData(maindb=maindb)


dbs    = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
#dbs = ['MusicBrainz', 'LastFM']
dbs = ["Discogs"]
#dbs = ["Discogs", "MusicBrainz"]
dbs = ["AllMusic"]
#dbs = ["RateYourMusic"]
#dbs = ["MusicBrainz"]
#dbs = []
start,cmt=clock("Parsing Everything")
for db in dbs:
    s = 10
    #pdb.parse(db, nProcs=3, modVals=list(range(s,s+9)), force=False)
    #pdb.parse(db, nProcs=4, modVals=list(range(10,100)), force=True)
    #pdb.parse(db, nProcs=3, modVals=list(range(100)), force=False, extra=False)
    #pdb.parse(db, nProcs=3, modVals=[88,89,87,37,98,97], force=True, extra=False)
    #pdb.parse(db, nProcs=1, modVals=[9], force=True)
    pdb.parse(db, nProcs=3, modVals=list(range(100)), force=False, primary=True)
    #pdb.parse(db, nProcs=2, modVals=list(range(100)), force=False)
elapsed(start, cmt)

# %% [markdown]
# # Parse Extra Data

# %%
dbs = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
dbs = ['MusicBrainz']

# %load_ext autoreload
# %autoreload
from parseDBArtistsData import parseDBArtistsData
pdb    = parseDBArtistsData(maindb=maindb)

start,cmt=clock("Parsing Everything")
for db in dbs:
    #pdb.parse(db, nProcs=3, modVals=list(range(100)), force=False, extra=True)
    #pdb.parse(db, nProcs=1, modVals=list(range(80,100)), force=False, extra=True)
    #pdb.parse(db, nProcs=1, modVals=list(range(80)), force=False, extra=True)
    pdb.parse(db, nProcs=1, modVals=[79], force=False, extra=True)
elapsed(start, cmt)

# %% [markdown]
# # Parse Credit Data

# %%
dbs = ['AllMusic']
#dbs = []

# %load_ext autoreload
# %autoreload
from parseDBArtistsData import parseDBArtistsData
pdb    = parseDBArtistsData(maindb=maindb)

start,cmt=clock("Parsing Everything")
for db in dbs:
    #pdb.parse(db, nProcs=1, modVals=[9], force=False, credit=True)
    pdb.parse(db, nProcs=3, modVals=list(range(100)), force=False, credit=True)
elapsed(start, cmt)

# %% [markdown]
# # LastFM

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData

def parseLastFM(modVals=list(range(100)), force=False, primary=False, extra=False, fulldb=False):
    db = "LastFM"
    if isinstance(modVals, int):
        modVals = [modVals]
    nProcs = min(3, len(modVals))

    start,cmt=clock("Parsing Everything for {0}".format(db))
    if primary is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, primary=True)  ## Primary

    if extra is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, extra=True)  ## Extra
    
    if fulldb is True:
        maindb = mainDB(mdb=None, create=True, debug=True)
        maindb.setDBFull(db)
        elapsed(start, cmt)    
    
#parseLastFM(primary=True, fulldb=True)
parseLastFM(primary=False, fulldb=True)

# %% [markdown]
# # MusicBrainz

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData

def parseMusicBrainz(modVals=list(range(100)), force=False, primary=False, credit=False, extra=False, fulldb=False):
    db = "MusicBrainz"
    previousDays=4
    if isinstance(modVals, int):
        modVals = [modVals]
    nProcs = min(3, len(modVals))

    start,cmt=clock("Parsing Everything for {0}".format(db))
    if primary is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, previousDays=previousDays, force=force, primary=True)  ## Primary

    if extra is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, extra=True)  ## Extra
    

    if fulldb is True:
        maindb = mainDB(mdb=None, create=True, debug=True)
        maindb.setDBFull(db)
        elapsed(start, cmt)    
    
parseMusicBrainz(primary=True, force=True)

# %%
data=getFile("/Users/tgadfort/Music/Discog/artists-musicbrainz-db/0-DB.p")

# %%
data['100442956818207492535169252608810699800'].profile.external

# %%
from dbArtistsGenius import dbArtistsGenius
from time import sleep

# %%
urls=['https://genius.com/artists/Fy', 'https://genius.com/artists/Snik', 'https://genius.com/artists/Rap-viet',
     'https://genius.com/artists/Mad-clip', 'https://genius.com/artists/Moira-dela-torre', 'https://genius.com/artists/Lala-hsu',
     'https://genius.com/artists/Sin-boy', 'https://genius.com/artists/My-tam', 'https://genius.com/artists/Eladio-carrion',
     'https://genius.com/artists/Son-tung-m-tp', 'https://genius.com/artists/The-toys', 'https://genius.com/artists/The-toys-thai-artist',
     'https://genius.com/artists/Eric-chou', 'https://genius.com/artists/Dear-jane', 'https://genius.com/artists/Illeoo',
     'https://genius.com/artists/Junoflo', 'https://genius.com/artists/En', 'https://genius.com/artists/Hebe-tien',
     'https://genius.com/artists/Fer-palacio', 'https://genius.com/artists/Payung-teduh', 'https://genius.com/artists/Ysy-a',
     'https://genius.com/artists/Miss-ko', 'https://genius.com/artists/Dj-alex-arg', 'https://genius.com/artists/Bnk48',
     'https://genius.com/artists/Vu-cat-tuong', 'https://genius.com/artists/Accusefive', 'https://genius.com/artists/Mj116',
     'https://genius.com/artists/Nine-chen', 'https://genius.com/artists/Getsunova', 'https://genius.com/artists/Earth-patravee',
     'https://genius.com/artists/Alien-huang', 'https://genius.com/artists/Endy-chow', 'https://genius.com/artists/Singto-numchok',
     'https://genius.com/artists/Zi-stefan-chen', 'https://genius.com/artists/Oat-pramote', 'https://genius.com/artists/Ngot',
     'https://genius.com/artists/Bird-thongchai', 'https://genius.com/artists/Leowang', 'https://genius.com/artists/Kelly-yu-wen-wen',
     'https://genius.com/artists/Noo-phuoc-thinh', 'https://genius.com/artists/Zom-marie', 'https://genius.com/artists/Og-anic',
     'https://genius.com/artists/Maja-salvador-and-tor-saksit', 'https://genius.com/artists/Meyou', 'https://genius.com/artists/Cocktail']

urls=['https://genius.com/artists/Diskoria', 'https://genius.com/DJ_OOPs', 'https://genius.com/artists/Tugba-yurt',
     'https://genius.com/artists/Lost-sky', 'https://genius.com/artists/Dawn-oberg', 'https://genius.com/artists/Cengiz-ates',
     'https://genius.com/artists/Gal-adam', 'https://genius.com/artists/Bulat-nurimov', 'https://genius.com/artists/Taypan',
     'https://genius.com/artists/Jay-fendi-prince-of-lawtown', 'https://genius.com/artists/Ahmet-safak',
     'https://genius.com/artists/Hipsumhaps', 'https://genius.com/artists/Orri', 'https://genius.com/artists/Wonayd',
     'https://genius.com/artists/Vremya-i-steklo', 'https://genius.com/artists/Fadel-chaker', 'https://genius.com/artists/I61',
     'https://genius.com/artists/Matti-rssland', 'https://genius.com/artists/Vtornik', 'https://genius.com/artists/Helgi-bjornsson',
     'https://genius.com/artists/Herra-ylppo', 'https://genius.com/artists/Sebastian-wallden', 'https://genius.com/artists/Joker-xue',
     'https://genius.com/artists/Rkm-and-ken-y', 'https://genius.com/artists/John-mcdermott', 'https://genius.com/artists/Ronan-tynan',
     'https://genius.com/artists/Timmy-xu', 'https://genius.com/artists/John-p-kee', 'https://genius.com/artists/John-p-kee-and-the-new-life-community-choir',
     'https://genius.com/artists/Ilegales', 'https://genius.com/artists/James-wilson', 'https://genius.com/artists/Millie-b',
     'https://genius.com/artists/Stephen-paul-taylor', 'https://genius.com/artists/Byrne-and-kelly', 'https://genius.com/artists/Consequence',
     'https://genius.com/artists/Xtreme', 'https://genius.com/artists/Hua-chenyu', 'https://genius.com/artists/Bob-james',
     'https://genius.com/artists/Niska', 'https://genius.com/artists/Loon', 'https://genius.com/artists/Morgenshtern-and-eldzhey',
     'https://genius.com/artists/Morgenshtern', 'https://genius.com/artists/Jessie-morales', 'https://genius.com/artists/Jessie-morales-el-original-de-la-sierra']
urls=['https://genius.com/artists/Casino', 'https://genius.com/artists/Mark-harris', 'https://genius.com/artists/Schoolboy-q',
     'https://genius.com/artists/Hollis', 'https://genius.com/artists/Skipper', 'https://genius.com/artists/Trillville',
     'https://genius.com/artists/Cutty', 'https://genius.com/artists/Paul-mccoy']
urls=['https://genius.com/artists/Casino', 'https://genius.com/artists/Mark-harris', 'https://genius.com/artists/Schoolboy-q',
     'https://genius.com/artists/Hollis', 'https://genius.com/artists/Skipper', 'https://genius.com/artists/Trillville',
     'https://genius.com/artists/Cutty', 'https://genius.com/artists/Paul-mccoy']


for url in urls:
    print(url)
    dp = dbArtistsGenius()
    dp.downloadArtistFromURL(url)
    sleep(2)
# Out:
# https://genius.com/artists/Casino
# =========================   genius   =========================
# https://genius.com/artists/Mark-harris
# =========================   genius   =========================
# https://genius.com/artists/Schoolboy-q
# =========================   genius   =========================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-528e60de4f36> in <module>
#      42     dp = dbArtistsGenius()
#      43     dp.downloadArtistFromURL(url)
# ---> 44     sleep(2)
#
# KeyboardInterrupt:

# %% [markdown]
# # Discogs

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData

def parseDiscogs(modVals=list(range(100)), force=False, primary=False, credit=False, extra=False, fulldb=False):
    db = "Discogs"
    previousDays=5
    if isinstance(modVals, int):
        modVals = [modVals]
    nProcs = min(3, len(modVals))

    start,cmt=clock("Parsing Everything for {0}".format(db))
    if primary is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, previousDays=previousDays, force=force, primary=True)  ## Primary

    if credit is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, credit=True)  ## Credit

    if extra is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, extra=True)  ## Extra
    

    if fulldb is True:
        maindb = mainDB(mdb=None, create=True, debug=True)
        maindb.setDBFull(db)
        elapsed(start, cmt)    
    
parseDiscogs(primary=True, fulldb=True)

# %% [markdown]
# # AllMusic

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData

maindb = mainDB(mdb=None, create=True, debug=False)
pdb    = parseDBArtistsData(maindb=maindb)
pdb.parse("AllMusic", nProcs=1, modVals=[69], previousDays=100, force=True, primary=True)  ## Primary

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData

def parseAllMusic(modVals=list(range(100)), force=False, primary=False, credit=False, fulldb=False):
    db = "AllMusic"
    previousDays=4
    if isinstance(modVals, int):
        modVals = [modVals]
    nProcs = min(3, len(modVals))

    start,cmt=clock("Parsing Everything for {0}".format(db))
    if primary is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, previousDays=previousDays, force=force, primary=True)  ## Primary

    if credit is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, credit=True)  ## Credit
    

    if fulldb is True:
        maindb = mainDB(mdb=None, create=True, debug=True)
        maindb.setDBFull(db)
        elapsed(start, cmt)    
    
#parseAllMusic(primary=True)
# %load_ext autoreload
# %autoreload
#parseAllMusic(credit=True)
parseAllMusic(fulldb=True)

# %%
modVal = 0
artistDBDir = dbdata["AllMusic"]["Disc"].getArtistsDBDir()
moddbdata   = dbdata["AllMusic"]["Disc"].getArtistsDBModValData(modVal)
nerrs   = 0

# %%
len(moddbdata)

# %%
from fileUtils import getBaseFilename
files = dbdata["AllMusic"]["Artists"].getArtistModValFiles(modVal, force=True)
artistIDs = {getBaseFilename(ifile): ifile for ifile in files}

# %%
toget = []
for artistID,ifile in artistIDs.items():
    if moddbdata.get(artistID) is None:
        info   = dbdata["AllMusic"]["Artists"].getData(ifile)
        artistName = info.profile.search
        if artistName is not None and len(artistName) > 0:
            info.show()
            break
        #self.creditToDownload[artistID] = [artistName,self.getArtistSavename(artistID, credit=True)]

# %% [markdown]
# ****
# ****
# ****
# ****

# %% [markdown]
# # Recreate Artist Names

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBArtists(recreate=False)
elapsed(start, cmt)

# %% [markdown]
# # Master Work

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBFull()
elapsed(start, cmt)

# %%
df = getFile("/Users/tgadfort/Music/Discog/db-rockcorner/MasterSlimArtistDB.p")
df["MultiStatus"].value_counts()

# %% [markdown]
# ## Parse Single ModVal

# %%
for i in range(10):
    for j in range(10):
        print("{0}touch /Volumes/Piggy/Discog/artists-discogs/{1}/0*0*0*".format("!", i*10+j))
        print("{0}echo '{1}'".format("!", i+10*j))

# %%
masterDBDF = maindb.dbdata["MusicBrainz"]["Disc"].getMasterSlimArtistDiscogsDB()

# %%
from searchUtils import findExt
from fsUtils import setDir, setFile
modVal = 99
artistDBDir = maindb.dbdata["Discogs"]["Artists"].getArtistsDBDir()
artistDir   = maindb.dbdata["Discogs"]["Artists"].getArtistsDir()
dirVal = setDir(artistDir, str(modVal))
files  = findExt(dirVal, ext='.p')
dbname = setFile(artistDBDir, "{0}-DB.p".format(modVal))
len(files)

# %%
from datetime import datetime, timedelta    
from os import path

def getFiles():
    from searchUtils import findExt
    from fsUtils import setDir, setFile
    modVal = 99
    artistDBDir = maindb.dbdata["Discogs"]["Artists"].getArtistsDBDir()
    artistDir   = maindb.dbdata["Discogs"]["Artists"].getArtistsDir()
    dirVal = setDir(artistDir, str(modVal))
    files  = findExt(dirVal, ext='.p')
    return files

def getNewFiles(dbname, previousDays=5, force=False):
    now    = datetime.now()
    files  = getFiles()
    if isFile(dbname):
        lastModified = datetime.fromtimestamp(path.getmtime(dbname))
        if force is True:
            lastModified = None
    else:
        lastModified = None
 
    if lastModified is None:
        newFiles = files
    else:
        numNew    = [ifile for ifile in files if (now-datetime.fromtimestamp(path.getmtime(ifile))).days < previousDays]
        numRecent = [ifile for ifile in files if datetime.fromtimestamp(path.getmtime(ifile)) > lastModified]
        newFiles  = list(set(numNew).union(set(numRecent)))
        print(len(files))
        print(len(numNew))
        print(len(numRecent))
    print(len(newFiles))

# %%
artistDBDir = maindb.dbdata["Discogs"]["Artists"].getArtistsDBDir()
artistDir   = maindb.dbdata["Discogs"]["Artists"].getArtistsDir()
dirVal = setDir(artistDir, str(modVal))
dbname = setFile(artistDBDir, "{0}-DB.p".format(modVal))

files = getNewFiles(dbname=dbname, previousDays=50, force=True)

# %%
now    = datetime.now()

# %%
def parseArtistModValFiles(self, modVal, force=False, debug=False, doExtra=False):        
    from os import path
    from datetime import datetime, timedelta

    print("-"*100)
    print("Parsing Artist Files For ModVal {0}".format(modVal))
    artistInfo = self.artist

    artistDir = self.disc.getArtistsDir()
    maxModVal = self.disc.getMaxModVal()

    artistDBDir = self.disc.getArtistsDBDir()        

    dirVal = setDir(artistDir, str(modVal))
    files  = findExt(dirVal, ext='.p')
    dbname = setFile(artistDBDir, "{0}-DB.p".format(modVal))



    ### Check for recent files
    if isFile(dbname):
        lastModified = datetime.fromtimestamp(path.getmtime(dbname))
        now    = datetime.now()            
        if force is False:
            numRecent = [ifile for ifile in files if datetime.fromtimestamp(path.getmtime(ifile)) > lastModified]
            numNew    = [ifile for ifile in files if (now-datetime.fromtimestamp(path.getmtime(ifile))).days < 1]
            if len(numRecent) == 0:
                print("  ===> Found {0} files, but there are no new files to parse so skipping.".format(len(files)))
                return 0
            else:
                print("  ===> Found {0} files. There are {1} new files to parse.".format(len(files), len(numRecent)))
    else:
        force = True
        lastModified = datetime.fromtimestamp(mktime(gmtime(0)))


    if force is False:
        dbdata = getFile(dbname, version=3)
    else:
        print("Forcing Reloads of ModVal={0}".format(modVal))
        print("  Processing {0} files.".format(len(files)))
        dbdata = {}

    saveIt = 0
    for j,ifile in enumerate(files):
        if force is True:
            if j % 500 == 0:
                print("\tProcessed {0}/{1} files.".format(j,len(files)))
        artistID = getBaseFilename(ifile)
        isKnown  = dbdata.get(artistID)
        recent   = datetime.fromtimestamp(path.getctime(ifile))
        if isKnown is None or recent > lastModified or force is True:
            info   = artistInfo.getData(ifile)

            if info.ID.ID != artistID:

                # Check Profile
                try:
                    artistName = info.profile.search
                    if artistName is not None:
                        self.creditToDownload[artistID] = [artistName,self.getArtistSavename(artistID, credit=True)]
                except:
                    pass

                if debug is False:
                    continue
                print("ID From Name: {0}".format(artistID))
                print("ID From File: {0}".format(info.ID.ID))

                print("File: {0}".format(ifile))
                print("Info: {0}".format(info.url.get()))
                continue
                #1/0

            saveIt += 1
            dbdata[artistID] = info


    forceSave = False
    if saveIt > 0 and doExtra is True:
        print("\tCalling Extra Parsing")
        dbdata = self.parseArtistModValExtraFiles(modVal, dbdata=dbdata, force=force, debug=debug)
        forceSave = True
        saveIt = len(dbdata)


    if len(self.creditToDownload) > 0:
        print("Found {0} artists that need new downloads.".format(len(self.creditToDownload)))


    if saveIt > 0 or forceSave is True:
        savename = setFile(artistDBDir, "{0}-DB.p".format(modVal))     
        print("Saving {0} new artist IDs to {1}".format(saveIt, savename))
        dbNumAlbums = sum([self.getArtistNumAlbums(artistData) for artistData in dbdata.values()])
        print("Saving {0} total artist media".format(dbNumAlbums))
        saveFile(idata=dbdata, ifile=savename)

        self.createArtistModValMetadata(modVal=modVal, db=dbdata, debug=debug)
        self.createArtistAlbumModValMetadata(modVal=modVal, db=dbdata, debug=debug)

    return saveIt

# %%
masterDBDF[~(masterDBDF.DiscArtist == masterDBDF.CleanDiscArtist)]

# %%
data = getFile("creditToDownload.p")

# %%
# %load_ext autoreload
# %autoreload
from masterArtistNameDB import masterArtistNameDB
manDB = masterArtistNameDB("master")

# %%
manDB.removeArtist("NF")
manDB.removeArtist("nf")

# %%
dbrs = getFile("dbrenames.yaml")
del dbrs["John Myers"]
manDB.addRenames(dbrs)

# %%
manDB.addRenames(getFile("dbrenames.yaml"))

# %%
manDB.save()
manDB.saveRenames()

# %%
start,cmt=clock("Parsing Single ModVal")
pdb.parse(db="Discogs", modVals=[0], nProcs=1, force=False)
elapsed(start, cmt)

# %%
data = getFile('/Users/tgadfort/Music/Discog/artists-discogs-db/0-DB.p')

# %%
len(data)

# %%
def getArtistNumAlbums(artistData):
    numAlbums = sum([len(x) for x in artistData.media.media.values()])
    return numAlbums
saveIt = True
dbNumAlbums = sum([getArtistNumAlbums(artistData) for artistData in data.values()])
print('0', dbNumAlbums)

# %%
bsdata = getHTML("/Volumes/Piggy/Discog/artists-allmusic/99/0002579199.p")
#bsdata = getHTML("/Users/tgadfort/Downloads/DJ Spinz _ Credits _ AllMusic.htm")

# %%
data = getFile("/Users/tgadfort/Music/Discog/artists-allmusic-db/99-DB.p")

# %%
data['0002579199']

# %%
amcredit = artistAMCredit()

# %%
#amdata = amcredit.getData("/Users/tgadfort/Downloads/DJ Spinz _ Credits _ AllMusic.htm")
amdata = maindb.dbdata["AllMusic"]["Artist"].getData("/Volumes/Piggy/Discog/artists-allmusic/99/0002579199.p")
amdata.show()

# %%
dbdata["LastFM"]["Artists"].parseArtistModValExtraFiles(0, force=True, debug=True)

# %%
from glob import glob
glob('/Volumes/Piggy/Discog/artists-lastfm/0/extra/11792020000-*.p')

# %%
bsdata = getHTML(ifile)
ols = bsdata.findAll("ol", {"class": "buffer-standard"})
ols

# %%
ifile='/Volumes/Piggy/Discog/artists-lastfm/0/extra/72742897500-2.p'
#getFile(ifile)
a       = dbdata["LastFM"]["Artist"].getData(ifile, debug=False)

def info(a):
    name    = a.artist.name
    ID      = a.ID.ID
    url     = a.url.url
    pages   = a.pages
    media   = a.media
    counts  = a.mediaCounts
    profile = a.profile

    print("{0: <10}{1}".format("Name:", name))
    print("{0: <10}{1}".format("ID:", ID))
    print("{0: <10}{1}".format("URL:", url))
    print("{0: <10}{1}".format("Pages:", pages.get()))
    print("{0: <10}{1}".format("Profile:", profile.get()))
    print("{0: <10}{1}".format("Counts:", counts.get()))
    print("{0: <10}".format("Media:"))
    for mediaType,mediaData in media.get()['media'].items():
        for mediaInfo in mediaData:
            print("\t{0: <10}{1}".format(mediaType, mediaInfo.get()['album']))

# %%
info(a)

# %%
nProcs = 8
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
maindb = mainDB(mdb=None, create=True, debug=True)
start,cmt=clock("Parsing All Artists")
start2,cmt2=clock("Parallel Artist Parsing")

parseArtistsParallel(db="AllMusic", nProcs=nProcs)
maindb.setDBFull("AllMusic")

parseArtistsParallel(db="MusicBrainz", nProcs=nProcs)
maindb.setDBFull("MusicBrainz")

parseArtistsParallel(db="Discogs", nProcs=nProcs)
maindb.setDBFull("Discogs")

#parseArtistsParallel(db="AceBootlegs", nProcs=1)
#parseArtistsParallel(db="DatPiff", nProcs=1)
#parseArtistsParallel(db="RateYourMusic", nProcs=3)
parseArtistsParallel(db="LastFM", nProcs=nProcs)
maindb.setDBFull("LastFM")

#parseArtistsParallel(db="RockCorner", nProcs=3)
#parseArtistsParallel(db="CDandLP", nProcs=3)
#parseArtistsParallel(db="MusicStack", nProcs=1)
elapsed(start2, cmt2)
elapsed(start, cmt)

# %% [markdown]
# # Master DB

# %%
print("\n\n{0}\n".format("Full DB"))
print("\n\n{0}\n".format("Known DB"))
#maindb.setDBKnown() ## Do this to recreate everything
#maindb.setDBKnown()
#artistDBs = maindb.getKnownArtistDBs()

# %% [markdown]
# # Download My Known Artists

# %%
mdb = myMusicDBMap(debug=True)

# %%
dbsToGet = ["AllMusic", "Discogs", "MusicBrainz", "LastFM", "RockCorner", "CDandLP"]
searches = [dbdata["AllMusic"]["Artists"].searchAllMusicForArtist, dbdata["Discogs"]["Artists"].searchDiscogForArtist,
            dbdata["MusicBrainz"]["Artists"].searchMusicBrainzForArtist, dbdata["LastFM"]["Artists"].searchLastFMForArtist,
            dbdata["RockCorner"]["Artists"].searchRockCornerForArtist, dbdata["CDandLP"]["Artists"].searchCDandLPForArtist]

dbsToGet = ["AllMusic"]
searches = [dbdata["AllMusic"]["Artists"].searchAllMusicForArtist]

# %%
def searchAll(mdb, minI=-1):
    nArtists = len(mdb.getArtists())
    for i,artistName in enumerate(mdb.getArtists()):
        if i <= minI:
            continue

        print('\n\n\n')
        print('-'*130)
        print(i,'/',nArtists,'===>\t',artistName)
        print('-'*130)
        print('\n')
        
        dbdata = mdb.getArtistData(artistName)
        if all([dbdata.get("LastFM"), dbdata.get("Discogs"), dbdata.get("AllMusic"), dbdata.get("MusicBrainz")]):
            print("{0} is well known.".format(artistName))
            continue
        else:
            print("{0} get it!".format(artistName))

        for search in searches:
            print("====>",search)
            try:
                search(artistName)
            except:
                sleep(3)

# %%
searchAll(mdb, 3404)

# %%
# Refused

# %% [markdown]
# # Albums

# %%
# %load_ext autoreload
# %autoreload
from album import album
from albums import albums
from discogsBase import discogs

disc = discogs()
albs = albums(disc)
#albs.parseAlbumModValFiles(modVal=27)

# %%
def parseAlbums(modVal):
    albs.parseAlbumModValFiles(modVal=modVal)
    #albs.createAlbumModValMetadata(modVal)
    #albs.createAlbumModValMetadata(modVal=modVal)

def parseAlbumsParallel(modVals=None):
    if modVals is None:
        modVals = ["NAN"] + list(range(100))
        #modVals = range(100)
    nProcs = 2
    pool = Pool(processes=nProcs)
    result = pool.map_async(parseAlbums, modVals)
 
    start, cmt = clock("Processing {0} modVals using {1} processes".format(modVals, nProcs))
    print("Runing .",end="")
    while not result.ready():
        #print(".",end="")
        time.sleep(10)
    print("")
    
    elapsed(start, cmt)
    return result.get()

# %%
# %load_ext autoreload
# %autoreload
from album import album
from albums import albums
albs = albums(disc)

start,cmt=clock("Parsing All Albums")
start2,cmt2=clock("Parallel Album Parsing")
parseAlbumsParallel()
elapsed(start2, cmt2)
elapsed(start, cmt)

# %% [markdown]
# # Download Stuff

# %%
mdb = myMusicDBMap(debug=True)
maindb = mainDB(mdb=mdb, create=False, debug=True)
dbdata = maindb.dbdata

# %%
ifile = "unmatchedArtists4.p"
noMatches = getFile(ifile)
print(len(noMatches))
dbs = ['Discogs', 'AllMusic', 'MusicBrainz', 'LastFM']
dbs = ['MusicBrainz']

#noMatches=['Go-A', 'PM', 'Qango']

from time import sleep
maxI = -1
for i,artist in enumerate(noMatches):
    print("="*100)
    print("="*100)
    print("="*100)
    print("="*100)
    print(i,'/',len(noMatches),'\t',artist)
    if i <= maxI:
        continue
    for db in dbs:
        print("="*100)
        print(i,'/',len(noMatches),'\t',artist,'===>',db)
        try:
            dbdata[db]["Artists"].searchForArtist(artist)
        except:
            sleep(5)
