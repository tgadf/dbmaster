# %%
## Basic stuff
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))

## Python Version
import sys
print("Python: {0}".format(sys.version))


################################################################################
## General Stuff
################################################################################
from ioUtils import saveJoblib, loadJoblib, saveFile, getFile
from timeUtils import clock, elapsed
from fsUtils import moveFile, setFile, setDir, setSubDir, isFile, isDir, mkDir
from fileUtils import getFileBasics, getBasename
from webUtils import getHTML
from multiprocessing import Pool


######################################################
# Music Stuff
######################################################
from dbBase import dbBase
from multiArtist import multiartist
from myMusicDBMap import myMusicDBMap
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData




import datetime as dt
start = dt.datetime.now()
print("Notebook Last Run Initiated: "+str(start))
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# Python: 3.7.7 (default, Mar 26 2020, 10:32:53)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# /Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# Notebook Last Run Initiated: 2021-01-28 18:32:21.727310

# %% [markdown]
# # MusicBrainz

# %%
files = maindb.dbdata["MusicBrainz"]["Artists"].getArtistModValFiles(0)

# %%
bsdata = getHTML("/Volumes/Piggy/Discog/artists-musicbrainz/0/6144800262646015459972430895745946300.p")

# %%
ifile="/Volumes/Piggy/Discog/artists-musicbrainz/0/6144800262646015459972430895745946300.p"
data = maindb.dbdata["MusicBrainz"]["Artists"].getData(ifile)
data.show()

# %%
for ifile in files:
    print(ifile)
    print(data.show())

# %%
data.show()

# %% [markdown]
# ## Parse Artists Base

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData
maindb = mainDB(mdb=None, create=True, debug=False)
pdb    = parseDBArtistsData(maindb=maindb)
dbdata = maindb.dbdata
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBFull("AllMusic")
elapsed(start, cmt)
# Out:
# Current Time is Sun Jan 31, 2021 00:57:10 for Creating DB
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RockCorner
#   Creating Database Records for AceBootlegs
#   Creating Database Records for CDandLP
#   Creating Database Records for RateYourMusic
#   Creating Database Records for MusicStack
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RockCorner, AceBootlegs, CDandLP, RateYourMusic, MusicStack
# ========================= masterArtistNameDB =========================
#   Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicnames/mainArtistNameDB.p
#   There are currently 7060 artist keys.
#   There are currently 8222 renamed artist keys.
# Adding 1 known multi delim artists.
# Current Time is Sun Jan 31, 2021 00:57:18 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/6-Metadata.p  	0 1136
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/94-Metadata.p  	1 2255
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/77-Metadata.p  	2 3390
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/40-Metadata.p  	3 4547
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/15-Metadata.p  	4 5681
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/22-Metadata.p  	5 6782
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/88-Metadata.p  	6 7931
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/99-Metadata.p  	7 9093
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/33-Metadata.p  	8 10277
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/51-Metadata.p  	9 11406
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/66-Metadata.p  	10 12549
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/85-Metadata.p  	11 13731
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/18-Metadata.p  	12 14864
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/36-Metadata.p  	13 15998
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/63-Metadata.p  	14 17137
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/54-Metadata.p  	15 18320
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/48-Metadata.p  	16 19449
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/80-Metadata.p  	17 20620
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/91-Metadata.p  	18 21782
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/3-Metadata.p  	19 22928
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/59-Metadata.p  	20 24030
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/45-Metadata.p  	21 25240
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/72-Metadata.p  	22 26383
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/27-Metadata.p  	23 27511
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/10-Metadata.p  	24 28715
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/42-Metadata.p  	25 29851
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/75-Metadata.p  	26 31002
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/20-Metadata.p  	27 32133
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/17-Metadata.p  	28 33262
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/69-Metadata.p  	29 34404
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/4-Metadata.p  	30 35534
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/96-Metadata.p  	31 36629
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/87-Metadata.p  	32 37782
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/78-Metadata.p  	33 38921
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/9-Metadata.p  	34 40044
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/31-Metadata.p  	35 41238
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/64-Metadata.p  	36 42434
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/53-Metadata.p  	37 43554
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/28-Metadata.p  	38 44732
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/82-Metadata.p  	39 45849
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/34-Metadata.p  	40 47004
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/56-Metadata.p  	41 48149
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/61-Metadata.p  	42 49311
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/70-Metadata.p  	43 50486
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/47-Metadata.p  	44 51697
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/12-Metadata.p  	45 52866
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/25-Metadata.p  	46 53968
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/93-Metadata.p  	47 55110
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/1-Metadata.p  	48 56183
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/39-Metadata.p  	49 57316
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/37-Metadata.p  	50 58460
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/62-Metadata.p  	51 59591
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/55-Metadata.p  	52 60708
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/81-Metadata.p  	53 61850
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/49-Metadata.p  	54 63035
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/58-Metadata.p  	55 64213
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/90-Metadata.p  	56 65359
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/2-Metadata.p  	57 66496
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/44-Metadata.p  	58 67641
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/73-Metadata.p  	59 68755
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/26-Metadata.p  	60 69848
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/11-Metadata.p  	61 70987
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/7-Metadata.p  	62 72144
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/95-Metadata.p  	63 73258
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/89-Metadata.p  	64 74418
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/76-Metadata.p  	65 75564
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/41-Metadata.p  	66 76707
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/14-Metadata.p  	67 77841
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/23-Metadata.p  	68 79060
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/32-Metadata.p  	69 80221
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/50-Metadata.p  	70 81377
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/67-Metadata.p  	71 82531
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/98-Metadata.p  	72 83652
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/19-Metadata.p  	73 84742
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/84-Metadata.p  	74 85906
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/83-Metadata.p  	75 87150
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/29-Metadata.p  	76 88288
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/35-Metadata.p  	77 89446
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/57-Metadata.p  	78 90586
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/60-Metadata.p  	79 91724
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/71-Metadata.p  	80 92864
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/46-Metadata.p  	81 94002
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/13-Metadata.p  	82 95174
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/24-Metadata.p  	83 96310
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/38-Metadata.p  	84 97450
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/92-Metadata.p  	85 98552
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/0-Metadata.p  	86 99643
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/43-Metadata.p  	87 100739
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/74-Metadata.p  	88 101876
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/21-Metadata.p  	89 103026
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/16-Metadata.p  	90 104161
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/5-Metadata.p  	91 105304
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/97-Metadata.p  	92 106452
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/68-Metadata.p  	93 107597
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/79-Metadata.p  	94 108751
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/86-Metadata.p  	95 109890
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/30-Metadata.p  	96 111089
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/65-Metadata.p  	97 112240
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/52-Metadata.p  	98 113352
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/8-Metadata.p  	99 114536
#
#
# ==============================================
#
# Saving 114536 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToRef.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToRef.p
#   --> This file is 2.9MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToRef.p
#   --> This file is 2.9MB.
# Saving 114536 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToName.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToName.p
#   --> This file is 2.2MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToName.p
#   --> This file is 2.2MB.
# Saving 114536 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToVariations.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToVariations.p
#   --> This file is 2.5MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToVariations.p
#   --> This file is 2.5MB.
# Current Time is Sun Jan 31, 2021 00:57:30 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 11 seconds.
# Current Time is Sun Jan 31, 2021 00:57:30 for
# =================================== Creating Artist DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 114536 Artists
# 	Shape --> (114536, 1)
# 	Shape --> (114536, 2)
#   Finding Real Artist Name
# 	Shape --> (114536, 4)
#   Removing None Artist
# 	Shape --> (114536, 4)
#   Finding Disc Artist Name
# 	Shape --> (114536, 5)
# DataFrame Shape is (114536, 7)
# Current Time is Sun Jan 31, 2021 00:57:33 for Done with
# =================================== Creating Artist DB ===================================
# Process [Done with
# =================================== Creating Artist DB ===================================] took 3 seconds.
# Saving Master Artist DB File: /Users/tgadfort/Music/Discog/db-allmusic/MasterSlimArtistDB.p
#   --> This file is 15.4MB.
# Current Time is Sun Jan 31, 2021 00:57:35 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/51-MediaMetadata.p 	1130      5864      10527
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/6-MediaMetadata.p 	2265      11512     20325
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/16-MediaMetadata.p 	3400      24924     39259
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/32-MediaMetadata.p 	4561      34254     52857
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/94-MediaMetadata.p 	5680      39963     63800
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/75-MediaMetadata.p 	6831      47211     76363
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/48-MediaMetadata.p 	7960      52507     86607
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/47-MediaMetadata.p 	9171      58515     96346
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/63-MediaMetadata.p 	10310     65642     107081
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/82-MediaMetadata.p 	11427     71017     116073
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/19-MediaMetadata.p 	12517     80567     129398
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/9-MediaMetadata.p 	13640     86848     140610
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/24-MediaMetadata.p 	14776     92867     151017
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/23-MediaMetadata.p 	15995     100032    163724
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/85-MediaMetadata.p 	17177     109575    177949
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/64-MediaMetadata.p 	18373     114791    187190
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/59-MediaMetadata.p 	19475     121732    198459
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/40-MediaMetadata.p 	20632     131547    214270
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/72-MediaMetadata.p 	21775     137454    225014
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/93-MediaMetadata.p 	22917     142620    234501
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/35-MediaMetadata.p 	24075     150227    246345
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/11-MediaMetadata.p 	25214     157023    257269
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/1-MediaMetadata.p 	26287     162590    267291
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/56-MediaMetadata.p 	27432     168673    277882
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/65-MediaMetadata.p 	28583     174027    287481
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/58-MediaMetadata.p 	29761     184740    303059
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/22-MediaMetadata.p 	30862     191175    313883
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/84-MediaMetadata.p 	32026     197711    324534
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/41-MediaMetadata.p 	33169     202871    335050
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/92-MediaMetadata.p 	34271     209466    345996
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/34-MediaMetadata.p 	35426     216497    359217
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/73-MediaMetadata.p 	36540     221760    368368
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/57-MediaMetadata.p 	37680     230277    381104
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/10-MediaMetadata.p 	38884     236742    392384
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/0-MediaMetadata.p 	39975     243541    403336
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/7-MediaMetadata.p 	41132     248596    413765
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/17-MediaMetadata.p 	42261     253930    422640
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/50-MediaMetadata.p 	43417     259728    433136
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/74-MediaMetadata.p 	44554     267235    445014
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/49-MediaMetadata.p 	45739     273410    456090
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/33-MediaMetadata.p 	46923     281108    469189
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/95-MediaMetadata.p 	48037     286489    478167
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/46-MediaMetadata.p 	49175     293173    487956
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/83-MediaMetadata.p 	50419     298929    498092
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/18-MediaMetadata.p 	51552     304951    508859
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/8-MediaMetadata.p 	52736     311490    519698
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/25-MediaMetadata.p 	53838     320660    533206
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/62-MediaMetadata.p 	54969     328319    544857
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/39-MediaMetadata.p 	56102     340513    561145
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/43-MediaMetadata.p 	57198     346289    570304
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/67-MediaMetadata.p 	58352     350988    579419
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/86-MediaMetadata.p 	59491     356297    588937
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/20-MediaMetadata.p 	60622     374345    611697
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/68-MediaMetadata.p 	61767     379669    620902
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/55-MediaMetadata.p 	62884     385648    630851
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/89-MediaMetadata.p 	64044     392907    642170
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/2-MediaMetadata.p 	65181     398673    652828
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/12-MediaMetadata.p 	66350     405475    663492
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/36-MediaMetadata.p 	67484     410844    672572
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/90-MediaMetadata.p 	68630     417588    684974
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/71-MediaMetadata.p 	69770     424491    695801
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/76-MediaMetadata.p 	70916     433080    709254
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/97-MediaMetadata.p 	72064     438913    718958
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/31-MediaMetadata.p 	73258     444187    728484
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/15-MediaMetadata.p 	74392     450977    740109
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/5-MediaMetadata.p 	75535     457100    750426
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/28-MediaMetadata.p 	76713     461761    760563
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/52-MediaMetadata.p 	77825     467354    770464
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/27-MediaMetadata.p 	78953     476086    783844
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/81-MediaMetadata.p 	80095     484977    797165
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/60-MediaMetadata.p 	81233     490372    806669
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/79-MediaMetadata.p 	82387     495729    815780
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/44-MediaMetadata.p 	83532     501086    826603
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/98-MediaMetadata.p 	84653     506618    836154
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/96-MediaMetadata.p 	85748     511185    844480
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/30-MediaMetadata.p 	86947     516805    854066
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/77-MediaMetadata.p 	88082     526926    868329
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/53-MediaMetadata.p 	89202     537298    882797
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/14-MediaMetadata.p 	90336     544411    894136
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/4-MediaMetadata.p 	91466     549196    903051
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/29-MediaMetadata.p 	92604     555706    915254
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/61-MediaMetadata.p 	93766     562896    927619
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/26-MediaMetadata.p 	94859     576846    945691
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/80-MediaMetadata.p 	96030     593927    967724
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/99-MediaMetadata.p 	97192     600742    979906
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/78-MediaMetadata.p 	98331     607161    990714
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/45-MediaMetadata.p 	99541     613198    1001197
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/42-MediaMetadata.p 	100677    619286    1011208
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/38-MediaMetadata.p 	101817    624653    1020029
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/87-MediaMetadata.p 	102970    631161    1030168
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/21-MediaMetadata.p 	104120    638751    1042626
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/66-MediaMetadata.p 	105263    643544    1051385
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/88-MediaMetadata.p 	106412    648631    1060266
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/3-MediaMetadata.p 	107558    656775    1072497
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/13-MediaMetadata.p 	108730    662688    1081931
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/69-MediaMetadata.p 	109872    669161    1092387
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/54-MediaMetadata.p 	111055    675615    1103923
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/70-MediaMetadata.p 	112230    682931    1115456
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/37-MediaMetadata.p 	113374    689329    1125669
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/91-MediaMetadata.p 	114536    695042    1134941
#
#
# ==============================================
#
# Saving 114536 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumNames.p
#   --> This file is 29.3MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumNames.p
#   --> This file is 29.3MB.
# Saving 114536 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumRefs.p
#   --> This file is 34.4MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumRefs.p
#   --> This file is 34.4MB.
# Saving 114536 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumNames.p
#   --> This file is 18.7MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumNames.p
#   --> This file is 18.7MB.
# Saving 114536 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumRefs.p
#   --> This file is 21.8MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumRefs.p
#   --> This file is 21.8MB.
# Current Time is Sun Jan 31, 2021 00:59:29 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 1.9 minutes.
# Current Time is Sun Jan 31, 2021 00:59:30 for
# =================================== Creating Artist Album DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 114536 Artists
# 	Shape --> (114536, 1)
# DataFrame Shape is (114536, 1)
# Saving Master Artist Albums DB File: /Users/tgadfort/Music/Discog/db-allmusic/MasterSlimArtistAlbumsDB.p
#   --> This file is 57.4MB.
# Current Time is Sun Jan 31, 2021 00:59:55 for Done with
# =================================== Creating Artist Album DB ===================================
# Process [Done with
# =================================== Creating Artist Album DB ===================================] took 25 seconds.
# Current Time is Sun Jan 31, 2021 00:59:58 for Done with Creating DB
# Process [Done with Creating DB] took 2.8 minutes.

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBFull("MusicBrainz")
elapsed(start, cmt)
# Out:
# Current Time is Sun Jan 31, 2021 00:59:58 for Creating DB
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RockCorner
#   Creating Database Records for AceBootlegs
#   Creating Database Records for CDandLP
#   Creating Database Records for RateYourMusic
#   Creating Database Records for MusicStack
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RockCorner, AceBootlegs, CDandLP, RateYourMusic, MusicStack
# ========================= masterArtistNameDB =========================
#   Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicnames/mainArtistNameDB.p
#   There are currently 7060 artist keys.
#   There are currently 8222 renamed artist keys.
# Adding 1 known multi delim artists.
# Current Time is Sun Jan 31, 2021 00:59:58 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/6-Metadata.p  	0 1975
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/94-Metadata.p  	1 3956
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/77-Metadata.p  	2 6099
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/40-Metadata.p  	3 8245
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/15-Metadata.p  	4 10260
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/22-Metadata.p  	5 12244
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/88-Metadata.p  	6 14310
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/99-Metadata.p  	7 16381
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/33-Metadata.p  	8 18384
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/51-Metadata.p  	9 20423
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/66-Metadata.p  	10 22395
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/85-Metadata.p  	11 24367
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/18-Metadata.p  	12 26430
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/36-Metadata.p  	13 28504
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/63-Metadata.p  	14 30514
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/54-Metadata.p  	15 32546
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/48-Metadata.p  	16 34543
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/80-Metadata.p  	17 36594
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/91-Metadata.p  	18 38679
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/3-Metadata.p  	19 40735
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/59-Metadata.p  	20 42762
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/45-Metadata.p  	21 44835
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/72-Metadata.p  	22 46918
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/27-Metadata.p  	23 48941
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/10-Metadata.p  	24 51002
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/42-Metadata.p  	25 53054
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/75-Metadata.p  	26 55064
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/20-Metadata.p  	27 57117
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/17-Metadata.p  	28 59109
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/69-Metadata.p  	29 61122
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/4-Metadata.p  	30 63173
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/96-Metadata.p  	31 65173
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/87-Metadata.p  	32 67263
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/78-Metadata.p  	33 69334
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/9-Metadata.p  	34 71417
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/31-Metadata.p  	35 73479
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/64-Metadata.p  	36 75502
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/53-Metadata.p  	37 77561
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/28-Metadata.p  	38 79627
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/82-Metadata.p  	39 81750
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/34-Metadata.p  	40 83764
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/56-Metadata.p  	41 85766
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/61-Metadata.p  	42 87792
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/70-Metadata.p  	43 89792
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/47-Metadata.p  	44 91805
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/12-Metadata.p  	45 93858
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/25-Metadata.p  	46 95962
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/93-Metadata.p  	47 98007
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/1-Metadata.p  	48 99980
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/39-Metadata.p  	49 101982
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/37-Metadata.p  	50 103867
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/62-Metadata.p  	51 105894
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/55-Metadata.p  	52 107954
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/81-Metadata.p  	53 109935
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/49-Metadata.p  	54 111974
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/58-Metadata.p  	55 114012
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/90-Metadata.p  	56 115996
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/2-Metadata.p  	57 118020
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/44-Metadata.p  	58 120190
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/73-Metadata.p  	59 122193
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/26-Metadata.p  	60 124201
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/11-Metadata.p  	61 126303
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/7-Metadata.p  	62 128383
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/95-Metadata.p  	63 130430
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/89-Metadata.p  	64 132396
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/76-Metadata.p  	65 134386
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/41-Metadata.p  	66 136407
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/14-Metadata.p  	67 138446
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/23-Metadata.p  	68 140439
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/32-Metadata.p  	69 142441
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/50-Metadata.p  	70 144399
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/67-Metadata.p  	71 146452
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/98-Metadata.p  	72 148450
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/19-Metadata.p  	73 150493
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/84-Metadata.p  	74 152572
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/83-Metadata.p  	75 154593
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/29-Metadata.p  	76 156631
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/35-Metadata.p  	77 158729
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/57-Metadata.p  	78 160770
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/60-Metadata.p  	79 162850
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/71-Metadata.p  	80 164924
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/46-Metadata.p  	81 166975
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/13-Metadata.p  	82 169055
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/24-Metadata.p  	83 171099
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/38-Metadata.p  	84 173122
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/92-Metadata.p  	85 175215
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/0-Metadata.p  	86 177285
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/43-Metadata.p  	87 179324
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/74-Metadata.p  	88 181346
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/21-Metadata.p  	89 183453
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/16-Metadata.p  	90 185478
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/5-Metadata.p  	91 187566
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/97-Metadata.p  	92 189623
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/68-Metadata.p  	93 191657
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/79-Metadata.p  	94 193610
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/86-Metadata.p  	95 195584
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/30-Metadata.p  	96 197594
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/65-Metadata.p  	97 199600
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/52-Metadata.p  	98 201647
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/8-Metadata.p  	99 203672
#
#
# ==============================================
#
# Saving 203672 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToRef.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToRef.p
#   --> This file is 10.4MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToRef.p
#   --> This file is 10.4MB.
# Saving 203672 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToName.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToName.p
#   --> This file is 7.5MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToName.p
#   --> This file is 7.5MB.
# Saving 203672 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToVariations.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToVariations.p
#   --> This file is 8.1MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToVariations.p
#   --> This file is 8.1MB.
# Current Time is Sun Jan 31, 2021 01:00:15 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 16 seconds.
# Current Time is Sun Jan 31, 2021 01:00:15 for
# =================================== Creating Artist DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 203672 Artists
# 	Shape --> (203672, 1)
# 	Shape --> (203672, 2)
#   Finding Real Artist Name
# 	Shape --> (203672, 4)
#   Removing None Artist
# 	Shape --> (203672, 4)
#   Finding Disc Artist Name
# 	Shape --> (203672, 5)
#   Cleaning Disc Artist Name (MusicBrainz Only)
# 	Shape --> (203672, 5)
# DataFrame Shape is (203672, 7)
# Current Time is Sun Jan 31, 2021 01:00:22 for Done with
# =================================== Creating Artist DB ===================================
# Process [Done with
# =================================== Creating Artist DB ===================================] took 6 seconds.
# Saving Master Artist DB File: /Users/tgadfort/Music/Discog/db-musicbrainz/MasterSlimArtistDB.p
#   --> This file is 33.7MB.
# Current Time is Sun Jan 31, 2021 01:00:26 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/51-MediaMetadata.p 	2039      0         9955
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/6-MediaMetadata.p 	4014      0         18862
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/16-MediaMetadata.p 	6039      0         27117
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/32-MediaMetadata.p 	8041      0         36604
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/94-MediaMetadata.p 	10022     0         44983
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/75-MediaMetadata.p 	12032     0         54446
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/48-MediaMetadata.p 	14029     0         62797
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/47-MediaMetadata.p 	16042     0         72378
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/63-MediaMetadata.p 	18052     0         82065
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/82-MediaMetadata.p 	20175     0         91490
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/19-MediaMetadata.p 	22218     0         99763
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/9-MediaMetadata.p 	24301     0         109835
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/24-MediaMetadata.p 	26345     0         118432
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/23-MediaMetadata.p 	28338     0         128183
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/85-MediaMetadata.p 	30310     0         138186
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/64-MediaMetadata.p 	32333     0         147576
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/59-MediaMetadata.p 	34360     0         157038
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/40-MediaMetadata.p 	36506     0         166144
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/72-MediaMetadata.p 	38589     0         174777
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/93-MediaMetadata.p 	40634     0         184403
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/35-MediaMetadata.p 	42732     0         193870
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/11-MediaMetadata.p 	44834     0         205214
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/1-MediaMetadata.p 	46807     0         216505
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/56-MediaMetadata.p 	48809     0         226309
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/65-MediaMetadata.p 	50815     0         235785
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/58-MediaMetadata.p 	52853     0         244427
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/22-MediaMetadata.p 	54837     0         252998
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/84-MediaMetadata.p 	56916     0         264731
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/41-MediaMetadata.p 	58937     0         273194
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/92-MediaMetadata.p 	61030     0         283106
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/34-MediaMetadata.p 	63044     0         292580
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/73-MediaMetadata.p 	65047     0         301916
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/57-MediaMetadata.p 	67088     0         310175
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/10-MediaMetadata.p 	69149     0         319452
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/0-MediaMetadata.p 	71219     0         329459
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/7-MediaMetadata.p 	73299     0         339136
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/17-MediaMetadata.p 	75291     0         348576
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/50-MediaMetadata.p 	77249     0         357530
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/74-MediaMetadata.p 	79271     0         366057
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/49-MediaMetadata.p 	81310     0         375817
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/33-MediaMetadata.p 	83313     0         385609
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/95-MediaMetadata.p 	85360     0         394180
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/46-MediaMetadata.p 	87411     0         403504
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/83-MediaMetadata.p 	89432     0         413531
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/18-MediaMetadata.p 	91495     0         423629
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/8-MediaMetadata.p 	93520     0         436876
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/25-MediaMetadata.p 	95624     0         447677
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/62-MediaMetadata.p 	97651     0         457212
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/39-MediaMetadata.p 	99653     0         465969
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/43-MediaMetadata.p 	101692    0         475083
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/67-MediaMetadata.p 	103745    0         484245
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/86-MediaMetadata.p 	105719    0         494574
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/20-MediaMetadata.p 	107772    0         503874
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/68-MediaMetadata.p 	109806    0         515007
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/55-MediaMetadata.p 	111866    0         524111
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/89-MediaMetadata.p 	113832    0         533174
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/2-MediaMetadata.p 	115856    0         542940
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/12-MediaMetadata.p 	117909    0         551888
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/36-MediaMetadata.p 	119983    0         561707
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/90-MediaMetadata.p 	121967    0         569958
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/71-MediaMetadata.p 	124041    0         579596
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/76-MediaMetadata.p 	126031    0         588795
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/97-MediaMetadata.p 	128088    0         599363
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/31-MediaMetadata.p 	130150    0         609410
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/15-MediaMetadata.p 	132165    0         619665
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/5-MediaMetadata.p 	134253    0         633607
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/28-MediaMetadata.p 	136319    0         643262
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/52-MediaMetadata.p 	138366    0         654355
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/27-MediaMetadata.p 	140389    0         663558
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/81-MediaMetadata.p 	142370    0         672764
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/60-MediaMetadata.p 	144450    0         685763
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/79-MediaMetadata.p 	146403    0         693836
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/44-MediaMetadata.p 	148573    0         703062
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/98-MediaMetadata.p 	150571    0         712870
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/96-MediaMetadata.p 	152571    0         721968
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/30-MediaMetadata.p 	154581    0         734274
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/77-MediaMetadata.p 	156724    0         743629
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/53-MediaMetadata.p 	158783    0         752769
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/14-MediaMetadata.p 	160822    0         762507
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/4-MediaMetadata.p 	162873    0         771356
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/29-MediaMetadata.p 	164911    0         780849
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/61-MediaMetadata.p 	166937    0         790805
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/26-MediaMetadata.p 	168945    0         799495
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/80-MediaMetadata.p 	170996    0         808957
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/99-MediaMetadata.p 	173067    0         818474
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/78-MediaMetadata.p 	175138    0         828780
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/45-MediaMetadata.p 	177211    0         838313
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/42-MediaMetadata.p 	179263    0         848406
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/38-MediaMetadata.p 	181286    0         857851
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/87-MediaMetadata.p 	183376    0         868931
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/21-MediaMetadata.p 	185483    0         878451
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/66-MediaMetadata.p 	187455    0         890240
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/88-MediaMetadata.p 	189521    0         899030
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/3-MediaMetadata.p 	191577    0         908477
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/13-MediaMetadata.p 	193657    0         919011
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/69-MediaMetadata.p 	195670    0         929923
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/54-MediaMetadata.p 	197702    0         939531
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/70-MediaMetadata.p 	199702    0         949247
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/37-MediaMetadata.p 	201587    0         957612
# /Users/tgadfort/Music/Discog/artists-musicbrainz-db/metadata/91-MediaMetadata.p 	203672    0         967623
#
#
# ==============================================
#
# Saving 203672 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumNames.p
#   --> This file is 44.2MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumNames.p
#   --> This file is 44.2MB.
# Saving 203672 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumRefs.p
#   --> This file is 39.3MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToAlbumRefs.p
#   --> This file is 39.3MB.
# Saving 203672 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumNames.p
#   --> This file is 5.1MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumNames.p
#   --> This file is 5.1MB.
# Saving 203672 entries to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumRefs.p
#   --> This file is 5.1MB.
# Saved data to /Users/tgadfort/Music/Discog/db-musicbrainz/ArtistIDToCoreAlbumRefs.p
#   --> This file is 5.1MB.
# Current Time is Sun Jan 31, 2021 01:01:45 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 1.3 minutes.
# Current Time is Sun Jan 31, 2021 01:01:45 for
# =================================== Creating Artist Album DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 203672 Artists
# 	Shape --> (203672, 1)
# DataFrame Shape is (203672, 1)
# Saving Master Artist Albums DB File: /Users/tgadfort/Music/Discog/db-musicbrainz/MasterSlimArtistAlbumsDB.p
#   --> This file is 80.3MB.
# Current Time is Sun Jan 31, 2021 01:02:05 for Done with
# =================================== Creating Artist Album DB ===================================
# Process [Done with
# =================================== Creating Artist Album DB ===================================] took 19 seconds.
# Current Time is Sun Jan 31, 2021 01:02:08 for Done with Creating DB
# Process [Done with Creating DB] took 2.2 minutes.

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBFull("Discogs")
elapsed(start, cmt)
# Out:
# Current Time is Fri Jan 29, 2021 18:02:36 for Creating DB
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RockCorner
#   Creating Database Records for AceBootlegs
#   Creating Database Records for CDandLP
#   Creating Database Records for RateYourMusic
#   Creating Database Records for MusicStack
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RockCorner, AceBootlegs, CDandLP, RateYourMusic, MusicStack
# ========================= masterArtistNameDB =========================
#   Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicnames/mainArtistNameDB.p
#   There are currently 7027 artist keys.
#   There are currently 8180 renamed artist keys.
# Adding 1 known multi delim artists.
# Current Time is Fri Jan 29, 2021 18:02:36 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/6-Metadata.p  	0 7634
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/94-Metadata.p  	1 15360
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/77-Metadata.p  	2 23053
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/40-Metadata.p  	3 30696
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/15-Metadata.p  	4 38450
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/22-Metadata.p  	5 46191
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/88-Metadata.p  	6 53899
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/99-Metadata.p  	7 61652
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/33-Metadata.p  	8 69340
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/51-Metadata.p  	9 77121
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/66-Metadata.p  	10 84851
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/85-Metadata.p  	11 92548
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/18-Metadata.p  	12 100323
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/36-Metadata.p  	13 108119
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/63-Metadata.p  	14 115912
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/54-Metadata.p  	15 123729
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/48-Metadata.p  	16 131527
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/80-Metadata.p  	17 139277
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/91-Metadata.p  	18 146982
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/3-Metadata.p  	19 154946
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/59-Metadata.p  	20 162796
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/45-Metadata.p  	21 170320
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/72-Metadata.p  	22 177995
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/27-Metadata.p  	23 185648
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/10-Metadata.p  	24 193390
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/42-Metadata.p  	25 201102
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/75-Metadata.p  	26 208815
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/20-Metadata.p  	27 216579
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/17-Metadata.p  	28 224337
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/69-Metadata.p  	29 232039
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/4-Metadata.p  	30 239833
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/96-Metadata.p  	31 247484
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/87-Metadata.p  	32 255226
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/78-Metadata.p  	33 263108
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/9-Metadata.p  	34 270822
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/31-Metadata.p  	35 278464
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/64-Metadata.p  	36 286318
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/53-Metadata.p  	37 294073
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/28-Metadata.p  	38 301867
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/82-Metadata.p  	39 309689
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/34-Metadata.p  	40 317387
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/56-Metadata.p  	41 325107
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/61-Metadata.p  	42 332795
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/70-Metadata.p  	43 340444
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/47-Metadata.p  	44 347967
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/12-Metadata.p  	45 355765
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/25-Metadata.p  	46 363496
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/93-Metadata.p  	47 371199
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/1-Metadata.p  	48 379160
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/39-Metadata.p  	49 386796
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/37-Metadata.p  	50 394436
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/62-Metadata.p  	51 402266
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/55-Metadata.p  	52 410048
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/81-Metadata.p  	53 417937
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/49-Metadata.p  	54 425699
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/58-Metadata.p  	55 433347
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/90-Metadata.p  	56 440964
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/2-Metadata.p  	57 448650
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/44-Metadata.p  	58 456211
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/73-Metadata.p  	59 463901
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/26-Metadata.p  	60 471732
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/11-Metadata.p  	61 479511
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/7-Metadata.p  	62 487263
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/95-Metadata.p  	63 495019
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/89-Metadata.p  	64 502864
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/76-Metadata.p  	65 510551
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/41-Metadata.p  	66 518404
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/14-Metadata.p  	67 526033
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/23-Metadata.p  	68 533794
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/32-Metadata.p  	69 541514
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/50-Metadata.p  	70 549224
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/67-Metadata.p  	71 557028
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/98-Metadata.p  	72 564683
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/19-Metadata.p  	73 572391
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/84-Metadata.p  	74 580209
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/83-Metadata.p  	75 588052
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/29-Metadata.p  	76 595723
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/35-Metadata.p  	77 603266
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/57-Metadata.p  	78 610961
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/60-Metadata.p  	79 618718
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/71-Metadata.p  	80 626389
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/46-Metadata.p  	81 633970
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/13-Metadata.p  	82 641845
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/24-Metadata.p  	83 649427
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/38-Metadata.p  	84 657050
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/92-Metadata.p  	85 664982
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/0-Metadata.p  	86 672662
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/43-Metadata.p  	87 680390
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/74-Metadata.p  	88 688134
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/21-Metadata.p  	89 695870
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/16-Metadata.p  	90 703555
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/5-Metadata.p  	91 711181
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/97-Metadata.p  	92 718900
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/68-Metadata.p  	93 726490
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/79-Metadata.p  	94 734219
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/86-Metadata.p  	95 742139
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/30-Metadata.p  	96 749862
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/65-Metadata.p  	97 757629
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/52-Metadata.p  	98 765402
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/8-Metadata.p  	99 773221
#
#
# ==============================================
#
# Saving 773221 entries to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToRef.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToRef.p
#   --> This file is 17.3MB.
# Saved data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToRef.p
#   --> This file is 17.3MB.
# Saving 773221 entries to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToName.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToName.p
#   --> This file is 14.5MB.
# Saved data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToName.p
#   --> This file is 14.5MB.
# Saving 773221 entries to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToVariations.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToVariations.p
#   --> This file is 28.6MB.
# Saved data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToVariations.p
#   --> This file is 28.6MB.
# Current Time is Fri Jan 29, 2021 18:03:35 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 59 seconds.
# Current Time is Fri Jan 29, 2021 18:03:35 for
# =================================== Creating Artist DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 773221 Artists
# 	Shape --> (773221, 1)
# 	Shape --> (773221, 2)
#   Finding Real Artist Name
# 	Shape --> (773221, 4)
#   Removing None Artist
# 	Shape --> (773221, 4)
#   Finding Disc Artist Name
# 	Shape --> (773221, 5)
# DataFrame Shape is (773221, 7)
# Current Time is Fri Jan 29, 2021 18:03:54 for Done with
# =================================== Creating Artist DB ===================================
# Process [Done with
# =================================== Creating Artist DB ===================================] took 18 seconds.
# Saving Master Artist DB File: /Users/tgadfort/Music/Discog/db-discogs/MasterSlimArtistDB.p
#   --> This file is 105.9MB.
# Current Time is Fri Jan 29, 2021 18:04:05 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/51-MediaMetadata.p 	7781      16889     75030
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/6-MediaMetadata.p 	15415     33677     148354
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/16-MediaMetadata.p 	23100     49739     227532
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/32-MediaMetadata.p 	30820     67980     301592
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/94-MediaMetadata.p 	38546     87833     381196
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/75-MediaMetadata.p 	46259     108681    455695
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/48-MediaMetadata.p 	54057     124848    527734
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/47-MediaMetadata.p 	61580     140269    603400
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/63-MediaMetadata.p 	69373     156824    679445
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/82-MediaMetadata.p 	77195     172874    753443
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/19-MediaMetadata.p 	84903     190241    833737
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/9-MediaMetadata.p 	92617     207018    908278
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/24-MediaMetadata.p 	100199    222366    980546
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/23-MediaMetadata.p 	107960    240222    1060444
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/85-MediaMetadata.p 	115657    258724    1139467
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/64-MediaMetadata.p 	123511    276705    1215129
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/59-MediaMetadata.p 	131361    293182    1286292
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/40-MediaMetadata.p 	139004    315070    1365663
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/72-MediaMetadata.p 	146679    333894    1440706
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/93-MediaMetadata.p 	154382    354984    1519923
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/35-MediaMetadata.p 	161925    372346    1596385
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/11-MediaMetadata.p 	169704    389963    1671709
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/1-MediaMetadata.p 	177665    409801    1755955
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/56-MediaMetadata.p 	185385    427425    1831785
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/65-MediaMetadata.p 	193152    445967    1912604
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/58-MediaMetadata.p 	200800    461404    1984211
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/22-MediaMetadata.p 	208541    479173    2059556
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/84-MediaMetadata.p 	216359    497540    2134326
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/41-MediaMetadata.p 	224212    515636    2218902
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/92-MediaMetadata.p 	232144    532553    2298957
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/34-MediaMetadata.p 	239842    548365    2375263
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/73-MediaMetadata.p 	247532    566974    2455164
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/57-MediaMetadata.p 	255227    583354    2529542
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/10-MediaMetadata.p 	262969    599699    2601666
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/0-MediaMetadata.p 	270649    616641    2674414
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/7-MediaMetadata.p 	278401    633619    2753143
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/17-MediaMetadata.p 	286159    651426    2833049
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/50-MediaMetadata.p 	293869    668424    2903674
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/74-MediaMetadata.p 	301613    688406    2985130
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/49-MediaMetadata.p 	309375    704279    3060893
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/33-MediaMetadata.p 	317063    723615    3144745
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/95-MediaMetadata.p 	324819    740935    3219210
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/46-MediaMetadata.p 	332400    770005    3311741
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/83-MediaMetadata.p 	340243    787029    3390813
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/18-MediaMetadata.p 	348018    804233    3470305
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/8-MediaMetadata.p 	355837    821093    3549630
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/25-MediaMetadata.p 	363568    843091    3631997
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/62-MediaMetadata.p 	371398    860638    3707326
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/39-MediaMetadata.p 	379034    879424    3787844
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/43-MediaMetadata.p 	386762    897400    3864579
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/67-MediaMetadata.p 	394566    913798    3938402
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/86-MediaMetadata.p 	402486    931463    4020469
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/20-MediaMetadata.p 	410250    948650    4096975
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/68-MediaMetadata.p 	417840    972532    4182450
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/55-MediaMetadata.p 	425622    990543    4261650
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/89-MediaMetadata.p 	433467    1007268   4340035
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/2-MediaMetadata.p 	441153    1025485   4423879
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/12-MediaMetadata.p 	448951    1043631   4499106
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/36-MediaMetadata.p 	456747    1061653   4575521
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/90-MediaMetadata.p 	464364    1078444   4654358
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/71-MediaMetadata.p 	472035    1095938   4730096
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/76-MediaMetadata.p 	479722    1112701   4806650
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/97-MediaMetadata.p 	487441    1128715   4875526
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/31-MediaMetadata.p 	495083    1144900   4948735
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/15-MediaMetadata.p 	502837    1162239   5028135
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/5-MediaMetadata.p 	510463    1178046   5100939
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/28-MediaMetadata.p 	518257    1195212   5174926
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/52-MediaMetadata.p 	526030    1212221   5250731
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/27-MediaMetadata.p 	533683    1233322   5332543
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/81-MediaMetadata.p 	541572    1252368   5412351
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/60-MediaMetadata.p 	549329    1270015   5495031
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/79-MediaMetadata.p 	557058    1289358   5569177
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/44-MediaMetadata.p 	564619    1317361   5658212
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/98-MediaMetadata.p 	572274    1333835   5745508
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/96-MediaMetadata.p 	579925    1350810   5821074
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/30-MediaMetadata.p 	587648    1367426   5895509
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/77-MediaMetadata.p 	595341    1384746   5973841
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/53-MediaMetadata.p 	603096    1401699   6052846
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/14-MediaMetadata.p 	610725    1422732   6127755
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/4-MediaMetadata.p 	618519    1439922   6208602
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/29-MediaMetadata.p 	626190    1457326   6295654
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/61-MediaMetadata.p 	633878    1479204   6378480
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/26-MediaMetadata.p 	641709    1496619   6452329
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/80-MediaMetadata.p 	649459    1516554   6528925
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/99-MediaMetadata.p 	657212    1532334   6599699
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/78-MediaMetadata.p 	665094    1549971   6680535
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/45-MediaMetadata.p 	672618    1566442   6754586
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/42-MediaMetadata.p 	680330    1586375   6833118
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/38-MediaMetadata.p 	687953    1602214   6911084
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/87-MediaMetadata.p 	695695    1618726   6989256
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/21-MediaMetadata.p 	703431    1634271   7060262
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/66-MediaMetadata.p 	711161    1654450   7139070
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/88-MediaMetadata.p 	718869    1671663   7218683
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/3-MediaMetadata.p 	726833    1689495   7296507
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/13-MediaMetadata.p 	734708    1706384   7370361
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/69-MediaMetadata.p 	742410    1729493   7449230
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/54-MediaMetadata.p 	750227    1748430   7528671
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/70-MediaMetadata.p 	757876    1765835   7604965
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/37-MediaMetadata.p 	765516    1792992   7692636
# /Users/tgadfort/Music/Discog/artists-discogs-db/metadata/91-MediaMetadata.p 	773221    1809618   7766901
#
#
# ==============================================
#
# Saving 773221 entries to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToAlbumNames.p
#   --> This file is 207.7MB.
# Saved data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToAlbumNames.p
#   --> This file is 207.7MB.
# Saving 773221 entries to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToAlbumRefs.p
#   --> This file is 286.9MB.
# Saved data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToAlbumRefs.p
#   --> This file is 286.9MB.
# Saving 773221 entries to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToCoreAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToCoreAlbumNames.p
#   --> This file is 57.3MB.
# Saved data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToCoreAlbumNames.p
#   --> This file is 57.3MB.
# Saving 773221 entries to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToCoreAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToCoreAlbumRefs.p
#   --> This file is 80.8MB.
# Saved data to /Users/tgadfort/Music/Discog/db-discogs/ArtistIDToCoreAlbumRefs.p
#   --> This file is 80.8MB.
# Current Time is Fri Jan 29, 2021 18:11:14 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 7.2 minutes.
# Current Time is Fri Jan 29, 2021 18:11:17 for
# =================================== Creating Artist Album DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 773221 Artists
# 	Shape --> (773221, 1)
# DataFrame Shape is (773221, 1)
# Saving Master Artist Albums DB File: /Users/tgadfort/Music/Discog/db-discogs/MasterSlimArtistAlbumsDB.p
#   --> This file is 408.5MB.
# Current Time is Fri Jan 29, 2021 18:13:07 for Done with
# =================================== Creating Artist Album DB ===================================
# Process [Done with
# =================================== Creating Artist Album DB ===================================] took 1.8 minutes.
# Current Time is Fri Jan 29, 2021 18:13:22 for Done with Creating DB
# Process [Done with Creating DB] took 10.8 minutes.

# %% [markdown]
# ## Create Metadata (Only)

# %%
dbs    = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
dbs    = ['AllMusic']
dbs    = []
if len(dbs) > 0:
    start,cmt=clock("Parsing Metadata")
    for db in dbs:
        pdb.parseMetadata(db=db, nProcs=3, modVals=list(range(100)), force=True) 
    elapsed(start, cmt)

# %% [markdown]
# # Parse Downloads

# %%
dbs = ["RateYourMusic", "MusicStack"]
dbs = ["RateYourMusic"]
if len(dbs) > 0:
    start,cmt=clock("Parsing Downloads")
    for db in dbs:
        pdb.parseDownloads(db)
    elapsed(start, cmt)

# %% [markdown]
# # Parse Everything

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData
maindb = mainDB(mdb=None, create=True, debug=False)
pdb    = parseDBArtistsData(maindb=maindb)


dbs    = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
#dbs = ['MusicBrainz', 'LastFM']
dbs = ["Discogs"]
#dbs = ["Discogs", "MusicBrainz"]
dbs = ["AllMusic"]
#dbs = ["RateYourMusic"]
#dbs = ["MusicBrainz"]
#dbs = []
start,cmt=clock("Parsing Everything")
for db in dbs:
    s = 10
    #pdb.parse(db, nProcs=3, modVals=list(range(s,s+9)), force=False)
    #pdb.parse(db, nProcs=4, modVals=list(range(10,100)), force=True)
    #pdb.parse(db, nProcs=3, modVals=list(range(100)), force=False, extra=False)
    #pdb.parse(db, nProcs=3, modVals=[88,89,87,37,98,97], force=True, extra=False)
    #pdb.parse(db, nProcs=1, modVals=[9], force=True)
    pdb.parse(db, nProcs=3, modVals=list(range(100)), force=False, primary=True)
    #pdb.parse(db, nProcs=2, modVals=list(range(100)), force=False)
elapsed(start, cmt)

# %% [markdown]
# # Parse Extra Data

# %%
dbs = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
dbs = ['MusicBrainz']

# %load_ext autoreload
# %autoreload
from parseDBArtistsData import parseDBArtistsData
pdb    = parseDBArtistsData(maindb=maindb)

start,cmt=clock("Parsing Everything")
for db in dbs:
    #pdb.parse(db, nProcs=3, modVals=list(range(100)), force=False, extra=True)
    #pdb.parse(db, nProcs=1, modVals=list(range(80,100)), force=False, extra=True)
    #pdb.parse(db, nProcs=1, modVals=list(range(80)), force=False, extra=True)
    pdb.parse(db, nProcs=1, modVals=[79], force=False, extra=True)
elapsed(start, cmt)

# %% [markdown]
# # Parse Credit Data

# %%
dbs = ['AllMusic']
#dbs = []

# %load_ext autoreload
# %autoreload
from parseDBArtistsData import parseDBArtistsData
pdb    = parseDBArtistsData(maindb=maindb)

start,cmt=clock("Parsing Everything")
for db in dbs:
    #pdb.parse(db, nProcs=1, modVals=[9], force=False, credit=True)
    pdb.parse(db, nProcs=3, modVals=list(range(100)), force=False, credit=True)
elapsed(start, cmt)

# %% [markdown]
# # LastFM

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData

def parseLastFM(modVals=list(range(100)), force=False, primary=False, extra=False, fulldb=False):
    db = "LastFM"
    if isinstance(modVals, int):
        modVals = [modVals]
    nProcs = min(3, len(modVals))

    start,cmt=clock("Parsing Everything for {0}".format(db))
    if primary is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, primary=True)  ## Primary

    if extra is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, extra=True)  ## Extra
    
    if fulldb is True:
        maindb = mainDB(mdb=None, create=True, debug=True)
        maindb.setDBFull(db)
        elapsed(start, cmt)    
    
#parseLastFM(primary=True, fulldb=True)
parseLastFM(primary=False, fulldb=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Current Time is Fri Jan 08, 2021 21:42:13 for Parsing Everything for LastFM
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RockCorner
#   Creating Database Records for AceBootlegs
#   Creating Database Records for CDandLP
#   Creating Database Records for RateYourMusic
#   Creating Database Records for MusicStack
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RockCorner, AceBootlegs, CDandLP, RateYourMusic, MusicStack
# ========================= masterArtistNameDB =========================
#   Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicnames/mainArtistNameDB.p
#   There are currently 6664 artist keys.
#   There are currently 7715 renamed artist keys.
# Adding 1 known multi delim artists.
# Current Time is Fri Jan 08, 2021 21:42:13 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/6-Metadata.p  	0 1425
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/94-Metadata.p  	1 2795
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/77-Metadata.p  	2 4254
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/40-Metadata.p  	3 5618
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/15-Metadata.p  	4 7020
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/22-Metadata.p  	5 8413
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/88-Metadata.p  	6 9830
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/99-Metadata.p  	7 11235
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/33-Metadata.p  	8 12658
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/51-Metadata.p  	9 14044
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/66-Metadata.p  	10 15510
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/85-Metadata.p  	11 16954
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/18-Metadata.p  	12 18382
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/36-Metadata.p  	13 19781
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/63-Metadata.p  	14 21232
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/54-Metadata.p  	15 22658
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/48-Metadata.p  	16 24029
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/80-Metadata.p  	17 25434
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/91-Metadata.p  	18 26748
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/3-Metadata.p  	19 28105
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/59-Metadata.p  	20 29570
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/45-Metadata.p  	21 30967
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/72-Metadata.p  	22 32324
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/27-Metadata.p  	23 33739
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/10-Metadata.p  	24 35183
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/42-Metadata.p  	25 36590
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/75-Metadata.p  	26 37960
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/20-Metadata.p  	27 39377
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/17-Metadata.p  	28 40748
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/69-Metadata.p  	29 42162
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/4-Metadata.p  	30 43563
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/96-Metadata.p  	31 44942
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/87-Metadata.p  	32 46368
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/78-Metadata.p  	33 47741
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/9-Metadata.p  	34 49129
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/31-Metadata.p  	35 50540
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/64-Metadata.p  	36 51951
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/53-Metadata.p  	37 53321
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/28-Metadata.p  	38 54692
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/82-Metadata.p  	39 56141
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/34-Metadata.p  	40 57574
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/56-Metadata.p  	41 58968
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/61-Metadata.p  	42 60365
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/70-Metadata.p  	43 61724
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/47-Metadata.p  	44 63161
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/12-Metadata.p  	45 64575
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/25-Metadata.p  	46 65980
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/93-Metadata.p  	47 67414
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/1-Metadata.p  	48 68827
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/39-Metadata.p  	49 70321
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/37-Metadata.p  	50 71745
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/62-Metadata.p  	51 73140
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/55-Metadata.p  	52 74520
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/81-Metadata.p  	53 75887
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/49-Metadata.p  	54 77334
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/58-Metadata.p  	55 78675
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/90-Metadata.p  	56 80049
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/2-Metadata.p  	57 81518
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/44-Metadata.p  	58 82879
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/73-Metadata.p  	59 84317
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/26-Metadata.p  	60 85789
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/11-Metadata.p  	61 87205
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/7-Metadata.p  	62 88565
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/95-Metadata.p  	63 89988
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/89-Metadata.p  	64 91376
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/76-Metadata.p  	65 92803
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/41-Metadata.p  	66 94199
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/14-Metadata.p  	67 95644
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/23-Metadata.p  	68 97041
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/32-Metadata.p  	69 98381
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/50-Metadata.p  	70 99816
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/67-Metadata.p  	71 101200
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/98-Metadata.p  	72 102662
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/19-Metadata.p  	73 104099
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/84-Metadata.p  	74 105497
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/83-Metadata.p  	75 106806
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/29-Metadata.p  	76 108206
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/35-Metadata.p  	77 109659
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/57-Metadata.p  	78 111043
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/60-Metadata.p  	79 112390
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/71-Metadata.p  	80 113828
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/46-Metadata.p  	81 115225
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/13-Metadata.p  	82 116704
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/24-Metadata.p  	83 118162
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/38-Metadata.p  	84 119618
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/92-Metadata.p  	85 120949
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/0-Metadata.p  	86 122355
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/43-Metadata.p  	87 123730
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/74-Metadata.p  	88 125098
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/21-Metadata.p  	89 126563
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/16-Metadata.p  	90 128046
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/5-Metadata.p  	91 129460
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/97-Metadata.p  	92 130866
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/68-Metadata.p  	93 132270
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/79-Metadata.p  	94 133687
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/86-Metadata.p  	95 135093
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/30-Metadata.p  	96 136462
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/65-Metadata.p  	97 137812
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/52-Metadata.p  	98 139194
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/8-Metadata.p  	99 140572
#
#
# ==============================================
#
# Saving 140572 entries to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToRef.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToRef.p
#   --> This file is 5.2MB.
# Saved data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToRef.p
#   --> This file is 5.2MB.
# Saving 140572 entries to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToName.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToName.p
#   --> This file is 4.4MB.
# Saved data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToName.p
#   --> This file is 4.4MB.
# Saving 140572 entries to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToVariations.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToVariations.p
#   --> This file is 4.9MB.
# Saved data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToVariations.p
#   --> This file is 4.9MB.
# Current Time is Fri Jan 08, 2021 21:42:25 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 11 seconds.
# Current Time is Fri Jan 08, 2021 21:42:25 for
# =================================== Creating Artist DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 140572 Artists
# 	Shape --> (140572, 1)
# 	Shape --> (140572, 2)
#   Finding Real Artist Name
# 	Shape --> (140572, 4)
#   Removing None Artist
# 	Shape --> (140572, 4)
#   Finding Disc Artist Name
# 	Shape --> (140572, 5)
# DataFrame Shape is (140572, 7)
# Current Time is Fri Jan 08, 2021 21:42:30 for Done with
# =================================== Creating Artist DB ===================================
# Process [Done with
# =================================== Creating Artist DB ===================================] took 4 seconds.
# Saving Master Artist DB File: /Users/tgadfort/Music/Discog/db-lastfm/MasterSlimArtistDB.p
#   --> This file is 32.3MB.
# Current Time is Fri Jan 08, 2021 21:42:33 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/51-MediaMetadata.p 	1386      3511      3511
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/6-MediaMetadata.p 	2811      18476     18476
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/16-MediaMetadata.p 	4294      36945     36945
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/32-MediaMetadata.p 	5634      49618     49618
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/94-MediaMetadata.p 	7004      65416     65416
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/75-MediaMetadata.p 	8374      68793     68793
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/48-MediaMetadata.p 	9745      84563     84563
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/47-MediaMetadata.p 	11182     100200    100200
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/63-MediaMetadata.p 	12633     115068    115068
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/82-MediaMetadata.p 	14082     129490    129490
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/19-MediaMetadata.p 	15519     162277    162277
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/9-MediaMetadata.p 	16907     175306    175306
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/24-MediaMetadata.p 	18365     179168    179168
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/23-MediaMetadata.p 	19762     183108    183108
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/85-MediaMetadata.p 	21206     198207    198207
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/64-MediaMetadata.p 	22617     212577    212577
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/59-MediaMetadata.p 	24082     229950    229950
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/40-MediaMetadata.p 	25446     237979    237979
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/72-MediaMetadata.p 	26803     245808    245808
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/93-MediaMetadata.p 	28237     260625    260625
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/35-MediaMetadata.p 	29690     278073    278073
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/11-MediaMetadata.p 	31106     293909    293909
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/1-MediaMetadata.p 	32519     313854    313854
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/56-MediaMetadata.p 	33913     330622    330622
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/65-MediaMetadata.p 	35263     345807    345807
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/58-MediaMetadata.p 	36604     358370    358370
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/22-MediaMetadata.p 	37997     361840    361840
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/84-MediaMetadata.p 	39395     375214    375214
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/41-MediaMetadata.p 	40791     379018    379018
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/92-MediaMetadata.p 	42122     394372    394372
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/34-MediaMetadata.p 	43555     410524    410524
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/73-MediaMetadata.p 	44993     414532    414532
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/57-MediaMetadata.p 	46377     429562    429562
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/10-MediaMetadata.p 	47821     447838    447838
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/0-MediaMetadata.p 	49227     464534    464534
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/7-MediaMetadata.p 	50587     480507    480507
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/17-MediaMetadata.p 	51958     493335    493335
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/50-MediaMetadata.p 	53393     501573    501573
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/74-MediaMetadata.p 	54761     505382    505382
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/49-MediaMetadata.p 	56208     521270    521270
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/33-MediaMetadata.p 	57631     538450    538450
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/95-MediaMetadata.p 	59054     552161    552161
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/46-MediaMetadata.p 	60451     566640    566640
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/83-MediaMetadata.p 	61760     581266    581266
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/18-MediaMetadata.p 	63188     598371    598371
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/8-MediaMetadata.p 	64566     613745    613745
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/25-MediaMetadata.p 	65971     617481    617481
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/62-MediaMetadata.p 	67366     634908    634908
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/39-MediaMetadata.p 	68860     639201    639201
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/43-MediaMetadata.p 	70235     643394    643394
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/67-MediaMetadata.p 	71619     655235    655235
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/86-MediaMetadata.p 	73025     670975    670975
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/20-MediaMetadata.p 	74442     687107    687107
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/68-MediaMetadata.p 	75846     695044    695044
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/55-MediaMetadata.p 	77226     710186    710186
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/89-MediaMetadata.p 	78614     723025    723025
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/2-MediaMetadata.p 	80083     741534    741534
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/12-MediaMetadata.p 	81497     764054    764054
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/36-MediaMetadata.p 	82896     777286    777286
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/90-MediaMetadata.p 	84270     793094    793094
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/71-MediaMetadata.p 	85708     796806    796806
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/76-MediaMetadata.p 	87135     800749    800749
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/97-MediaMetadata.p 	88541     816699    816699
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/31-MediaMetadata.p 	89952     830574    830574
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/15-MediaMetadata.p 	91354     847123    847123
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/5-MediaMetadata.p 	92768     864657    864657
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/28-MediaMetadata.p 	94139     878438    878438
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/52-MediaMetadata.p 	95521     882399    882399
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/27-MediaMetadata.p 	96936     899967    899967
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/81-MediaMetadata.p 	98303     914094    914094
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/60-MediaMetadata.p 	99650     927247    927247
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/79-MediaMetadata.p 	101067    931510    931510
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/44-MediaMetadata.p 	102428    935267    935267
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/98-MediaMetadata.p 	103890    950940    950940
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/96-MediaMetadata.p 	105269    965198    965198
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/30-MediaMetadata.p 	106638    978900    978900
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/77-MediaMetadata.p 	108097    983100    983100
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/53-MediaMetadata.p 	109467    986542    986542
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/14-MediaMetadata.p 	110912    1005527   1005527
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/4-MediaMetadata.p 	112313    1031988   1031988
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/29-MediaMetadata.p 	113713    1047786   1047786
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/61-MediaMetadata.p 	115110    1063368   1063368
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/26-MediaMetadata.p 	116582    1067233   1067233
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/80-MediaMetadata.p 	117987    1071226   1071226
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/99-MediaMetadata.p 	119392    1079505   1079505
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/78-MediaMetadata.p 	120765    1083330   1083330
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/45-MediaMetadata.p 	122162    1098196   1098196
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/42-MediaMetadata.p 	123569    1102170   1102170
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/38-MediaMetadata.p 	125025    1110830   1110830
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/87-MediaMetadata.p 	126451    1125708   1125708
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/21-MediaMetadata.p 	127916    1134819   1134819
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/66-MediaMetadata.p 	129382    1150718   1150718
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/88-MediaMetadata.p 	130799    1165499   1165499
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/3-MediaMetadata.p 	132156    1181279   1181279
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/13-MediaMetadata.p 	133635    1204956   1204956
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/69-MediaMetadata.p 	135049    1209096   1209096
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/54-MediaMetadata.p 	136475    1221187   1221187
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/70-MediaMetadata.p 	137834    1224897   1224897
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/37-MediaMetadata.p 	139258    1239757   1239757
# /Users/tgadfort/Music/Discog/artists-lastfm-db/metadata/91-MediaMetadata.p 	140572    1256425   1256425
#
#
# ==============================================
#
# Saving 140572 entries to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToAlbumNames.p
#   --> This file is 35.0MB.
# Saved data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToAlbumNames.p
#   --> This file is 35.0MB.
# Saving 140572 entries to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToAlbumRefs.p
#   --> This file is 40.1MB.
# Saved data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToAlbumRefs.p
#   --> This file is 40.1MB.
# Saving 140572 entries to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToCoreAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToCoreAlbumNames.p
#   --> This file is 35.0MB.
# Saved data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToCoreAlbumNames.p
#   --> This file is 35.0MB.
# Saving 140572 entries to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToCoreAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToCoreAlbumRefs.p
#   --> This file is 40.1MB.
# Saved data to /Users/tgadfort/Music/Discog/db-lastfm/ArtistIDToCoreAlbumRefs.p
#   --> This file is 40.1MB.
# Current Time is Fri Jan 08, 2021 21:44:05 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 1.5 minutes.
# Current Time is Fri Jan 08, 2021 21:44:05 for
# =================================== Creating Artist Album DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 140572 Artists
# 	Shape --> (140572, 1)
# DataFrame Shape is (140572, 1)
# Saving Master Artist Albums DB File: /Users/tgadfort/Music/Discog/db-lastfm/MasterSlimArtistAlbumsDB.p
#   --> This file is 68.1MB.
# Current Time is Fri Jan 08, 2021 21:44:23 for Done with
# =================================== Creating Artist Album DB ===================================
# Process [Done with
# =================================== Creating Artist Album DB ===================================] took 18 seconds.
# Current Time is Fri Jan 08, 2021 21:44:26 for Done with Parsing Everything for LastFM
# Process [Done with Parsing Everything for LastFM] took 2.2 minutes.

# %% [markdown]
# # MusicBrainz

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData

def parseMusicBrainz(modVals=list(range(100)), force=False, primary=False, credit=False, extra=False, fulldb=False):
    db = "MusicBrainz"
    previousDays=4
    if isinstance(modVals, int):
        modVals = [modVals]
    nProcs = min(3, len(modVals))

    start,cmt=clock("Parsing Everything for {0}".format(db))
    if primary is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, previousDays=previousDays, force=force, primary=True)  ## Primary

    if extra is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, extra=True)  ## Extra
    

    if fulldb is True:
        maindb = mainDB(mdb=None, create=True, debug=True)
        maindb.setDBFull(db)
        elapsed(start, cmt)    
    
parseMusicBrainz(primary=True, force=True)

# %%
data=getFile("/Users/tgadfort/Music/Discog/artists-musicbrainz-db/0-DB.p")

# %%
data['100442956818207492535169252608810699800'].profile.external

# %% [markdown]
# # Discogs

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData

def parseDiscogs(modVals=list(range(100)), force=False, primary=False, credit=False, extra=False, fulldb=False):
    db = "Discogs"
    previousDays=5
    if isinstance(modVals, int):
        modVals = [modVals]
    nProcs = min(3, len(modVals))

    start,cmt=clock("Parsing Everything for {0}".format(db))
    if primary is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, previousDays=previousDays, force=force, primary=True)  ## Primary

    if credit is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, credit=True)  ## Credit

    if extra is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, extra=True)  ## Extra
    

    if fulldb is True:
        maindb = mainDB(mdb=None, create=True, debug=True)
        maindb.setDBFull(db)
        elapsed(start, cmt)    
    
parseDiscogs(primary=True, fulldb=True)

# %% [markdown]
# # AllMusic

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData

maindb = mainDB(mdb=None, create=True, debug=False)
pdb    = parseDBArtistsData(maindb=maindb)
pdb.parse("AllMusic", nProcs=1, modVals=[69], previousDays=100, force=True, primary=True)  ## Primary
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================
# DB: AllMusic --> Primary=True   Extra=False   Credit=False   PreviousDays=100
# Parsing AllMusic with 1 processes using [[69]] mod values.
# ----------------------------------------------------------------------------------------------------
# Parsing Artist Files For ModVal 69
#   ===> Parsing all 956 files for modval 69
# Forcing Reloads of ModVal=69
#   Processing 956 files.
# HI
# 	Processed 0/956 files.
# 	Processed 100/956 files.
# 	Processed 200/956 files.
# 	Processed 300/956 files.
# File: /Volumes/Piggy/Discog/artists-allmusic/69/0000782269.p
# AllMusic Artist Data Class
# -------------------------
# Artist:  None
# Meta:    Artist Search for "crown jul" | AllMusic
#          https://www.allmusic.com/search/artists/crown+jul
# URL:     None
# ID:      None
# Profile: {'profile': None, 'aliases': None, 'members': None, 'sites': None, 'groups': None, 'variations': None, 'search': 'crown jul', 'err': None}
# Pages:   {'ppp': 1, 'tot': 1, 'pages': 1, 'err': None, 'more': False, 'redo': False}
# Media:   {'counts': {'Releases': {'Albums': 0}}, 'err': None}
#    Albums
# None
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/discogs-0.0.1-py3.7.egg/parseDBArtistsData.py", line 33, in parseArtistsAM
#     self.dbdata["AllMusic"]["Artists"].parseArtistModValFiles(modVal, force=self.force, previousDays=self.previousDays)
#   File "/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/dbdata-0.0.1-py3.7.egg/dbArtistsBase.py", line 492, in parseArtistModValFiles
#     1/0
# ZeroDivisionError: division by zero
# """
#
# The above exception was the direct cause of the following exception:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-51cf190165b3> in <module>
#       6 maindb = mainDB(mdb=None, create=True, debug=False)
#       7 pdb    = parseDBArtistsData(maindb=maindb)
# ----> 8 pdb.parse("AllMusic", nProcs=1, modVals=[69], previousDays=100, force=True, primary=True)  ## Primary
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/discogs-0.0.1-py3.7.egg/parseDBArtistsData.py in parse(self, db, nProcs, modVals, previousDays, force, primary, extra, credit)
#     163                 time.sleep(1)
#     164         print("")
# --> 165         return result.get()
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# ZeroDivisionError: division by zero
# Process ForkPoolWorker-1:
# Traceback (most recent call last):
#   File "/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData

def parseAllMusic(modVals=list(range(100)), force=False, primary=False, credit=False, fulldb=False):
    db = "AllMusic"
    previousDays=4
    if isinstance(modVals, int):
        modVals = [modVals]
    nProcs = min(3, len(modVals))

    start,cmt=clock("Parsing Everything for {0}".format(db))
    if primary is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, previousDays=previousDays, force=force, primary=True)  ## Primary

    if credit is True:
        maindb = mainDB(mdb=None, create=True, debug=False)
        pdb    = parseDBArtistsData(maindb=maindb)
        pdb.parse(db, nProcs=nProcs, modVals=modVals, force=force, credit=True)  ## Credit
    

    if fulldb is True:
        maindb = mainDB(mdb=None, create=True, debug=True)
        maindb.setDBFull(db)
        elapsed(start, cmt)    
    
#parseAllMusic(primary=True)
# %load_ext autoreload
# %autoreload
#parseAllMusic(credit=True)
parseAllMusic(fulldb=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Current Time is Sun Jan 10, 2021 13:34:19 for Parsing Everything for AllMusic
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RockCorner
#   Creating Database Records for AceBootlegs
#   Creating Database Records for CDandLP
#   Creating Database Records for RateYourMusic
#   Creating Database Records for MusicStack
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RockCorner, AceBootlegs, CDandLP, RateYourMusic, MusicStack
# ========================= masterArtistNameDB =========================
#   Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicnames/mainArtistNameDB.p
#   There are currently 6664 artist keys.
#   There are currently 7715 renamed artist keys.
# Adding 1 known multi delim artists.
# Current Time is Sun Jan 10, 2021 13:34:19 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/6-Metadata.p  	0 943
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/94-Metadata.p  	1 1870
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/77-Metadata.p  	2 2819
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/40-Metadata.p  	3 3788
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/15-Metadata.p  	4 4714
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/22-Metadata.p  	5 5613
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/88-Metadata.p  	6 6558
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/99-Metadata.p  	7 7497
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/33-Metadata.p  	8 8502
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/51-Metadata.p  	9 9455
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/66-Metadata.p  	10 10392
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/85-Metadata.p  	11 11376
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/18-Metadata.p  	12 12297
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/36-Metadata.p  	13 13239
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/63-Metadata.p  	14 14150
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/54-Metadata.p  	15 15134
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/48-Metadata.p  	16 16084
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/80-Metadata.p  	17 17065
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/91-Metadata.p  	18 18030
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/3-Metadata.p  	19 18980
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/59-Metadata.p  	20 19876
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/45-Metadata.p  	21 20886
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/72-Metadata.p  	22 21834
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/27-Metadata.p  	23 22764
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/10-Metadata.p  	24 23760
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/42-Metadata.p  	25 24683
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/75-Metadata.p  	26 25633
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/20-Metadata.p  	27 26569
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/17-Metadata.p  	28 27507
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/69-Metadata.p  	29 28462
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/4-Metadata.p  	30 29400
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/96-Metadata.p  	31 30307
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/87-Metadata.p  	32 31289
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/78-Metadata.p  	33 32240
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/9-Metadata.p  	34 33186
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/31-Metadata.p  	35 34168
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/64-Metadata.p  	36 35159
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/53-Metadata.p  	37 36074
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/28-Metadata.p  	38 37056
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/82-Metadata.p  	39 37966
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/34-Metadata.p  	40 38934
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/56-Metadata.p  	41 39882
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/61-Metadata.p  	42 40845
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/70-Metadata.p  	43 41831
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/47-Metadata.p  	44 42813
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/12-Metadata.p  	45 43776
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/25-Metadata.p  	46 44700
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/93-Metadata.p  	47 45644
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/1-Metadata.p  	48 46528
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/39-Metadata.p  	49 47467
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/37-Metadata.p  	50 48411
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/62-Metadata.p  	51 49326
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/55-Metadata.p  	52 50247
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/81-Metadata.p  	53 51204
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/49-Metadata.p  	54 52205
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/58-Metadata.p  	55 53169
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/90-Metadata.p  	56 54133
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/2-Metadata.p  	57 55054
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/44-Metadata.p  	58 55984
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/73-Metadata.p  	59 56892
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/26-Metadata.p  	60 57793
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/11-Metadata.p  	61 58728
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/7-Metadata.p  	62 59686
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/95-Metadata.p  	63 60605
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/89-Metadata.p  	64 61563
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/76-Metadata.p  	65 62507
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/41-Metadata.p  	66 63470
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/14-Metadata.p  	67 64385
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/23-Metadata.p  	68 65391
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/32-Metadata.p  	69 66356
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/50-Metadata.p  	70 67315
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/67-Metadata.p  	71 68264
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/98-Metadata.p  	72 69191
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/19-Metadata.p  	73 70081
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/84-Metadata.p  	74 71061
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/83-Metadata.p  	75 72101
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/29-Metadata.p  	76 73038
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/35-Metadata.p  	77 73988
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/57-Metadata.p  	78 74943
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/60-Metadata.p  	79 75907
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/71-Metadata.p  	80 76830
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/46-Metadata.p  	81 77777
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/13-Metadata.p  	82 78746
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/24-Metadata.p  	83 79708
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/38-Metadata.p  	84 80648
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/92-Metadata.p  	85 81535
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/0-Metadata.p  	86 82439
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/43-Metadata.p  	87 83348
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/74-Metadata.p  	88 84312
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/21-Metadata.p  	89 85274
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/16-Metadata.p  	90 86198
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/5-Metadata.p  	91 87138
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/97-Metadata.p  	92 88079
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/68-Metadata.p  	93 89016
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/79-Metadata.p  	94 89953
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/86-Metadata.p  	95 90898
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/30-Metadata.p  	96 91898
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/65-Metadata.p  	97 92859
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/52-Metadata.p  	98 93790
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/8-Metadata.p  	99 94757
#
#
# ==============================================
#
# Saving 94757 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToRef.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToRef.p
#   --> This file is 2.4MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToRef.p
#   --> This file is 2.4MB.
# Saving 94757 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToName.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToName.p
#   --> This file is 1.8MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToName.p
#   --> This file is 1.8MB.
# Saving 94757 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToVariations.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToVariations.p
#   --> This file is 2.1MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToVariations.p
#   --> This file is 2.1MB.
# Current Time is Sun Jan 10, 2021 13:34:27 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 7 seconds.
# Current Time is Sun Jan 10, 2021 13:34:27 for
# =================================== Creating Artist DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 94757 Artists
# 	Shape --> (94757, 1)
# 	Shape --> (94757, 2)
#   Finding Real Artist Name
# 	Shape --> (94757, 4)
#   Removing None Artist
# 	Shape --> (94757, 4)
#   Finding Disc Artist Name
# 	Shape --> (94757, 5)
# DataFrame Shape is (94757, 7)
# Current Time is Sun Jan 10, 2021 13:34:29 for Done with
# =================================== Creating Artist DB ===================================
# Process [Done with
# =================================== Creating Artist DB ===================================] took 2 seconds.
# Saving Master Artist DB File: /Users/tgadfort/Music/Discog/db-allmusic/MasterSlimArtistDB.p
#   --> This file is 12.7MB.
# Current Time is Sun Jan 10, 2021 13:34:31 for Creating Artist DBs
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/51-MediaMetadata.p 	954       4523      9004
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/6-MediaMetadata.p 	1896      9575      17909
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/16-MediaMetadata.p 	2820      22185     35865
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/32-MediaMetadata.p 	3785      26738     44524
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/94-MediaMetadata.p 	4712      31534     54310
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/75-MediaMetadata.p 	5662      37575     65395
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/48-MediaMetadata.p 	6612      41930     74354
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/47-MediaMetadata.p 	7594      46660     82486
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/63-MediaMetadata.p 	8505      53057     92289
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/82-MediaMetadata.p 	9415      57560     100194
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/19-MediaMetadata.p 	10305     65580     111702
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/9-MediaMetadata.p 	11251     71132     122021
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/24-MediaMetadata.p 	12213     76660     131712
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/23-MediaMetadata.p 	13219     82968     143154
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/85-MediaMetadata.p 	14203     90983     155576
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/64-MediaMetadata.p 	15194     95211     163626
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/59-MediaMetadata.p 	16090     101330    173778
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/40-MediaMetadata.p 	17059     110455    188550
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/72-MediaMetadata.p 	18007     115413    198107
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/93-MediaMetadata.p 	18951     119699    206506
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/35-MediaMetadata.p 	19901     126347    217113
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/11-MediaMetadata.p 	20836     131327    225936
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/1-MediaMetadata.p 	21720     135140    233862
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/56-MediaMetadata.p 	22668     140514    243484
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/65-MediaMetadata.p 	23629     145096    252064
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/58-MediaMetadata.p 	24593     152982    264482
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/22-MediaMetadata.p 	25492     157762    273255
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/84-MediaMetadata.p 	26472     162746    282087
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/41-MediaMetadata.p 	27435     167150    291558
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/92-MediaMetadata.p 	28322     172460    300921
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/34-MediaMetadata.p 	29290     178755    313194
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/73-MediaMetadata.p 	30198     183412    321546
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/57-MediaMetadata.p 	31153     190625    332696
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/10-MediaMetadata.p 	32149     195460    341939
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/0-MediaMetadata.p 	33053     201530    351764
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/7-MediaMetadata.p 	34011     206005    361339
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/17-MediaMetadata.p 	34949     210859    369586
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/50-MediaMetadata.p 	35908     215863    378956
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/74-MediaMetadata.p 	36872     222491    389722
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/49-MediaMetadata.p 	37873     226649    398532
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/33-MediaMetadata.p 	38878     233785    410424
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/95-MediaMetadata.p 	39797     237473    417439
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/46-MediaMetadata.p 	40744     243377    426282
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/83-MediaMetadata.p 	41784     247858    434993
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/18-MediaMetadata.p 	42705     252745    444362
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/8-MediaMetadata.p 	43672     258428    453990
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/25-MediaMetadata.p 	44596     266364    465956
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/62-MediaMetadata.p 	45511     273054    476340
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/39-MediaMetadata.p 	46450     284495    491643
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/43-MediaMetadata.p 	47359     289016    499319
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/67-MediaMetadata.p 	48308     292977    507086
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/86-MediaMetadata.p 	49253     297691    515887
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/20-MediaMetadata.p 	50189     314487    537227
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/68-MediaMetadata.p 	51126     318943    545318
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/55-MediaMetadata.p 	52047     324107    554209
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/89-MediaMetadata.p 	53005     329492    563434
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/2-MediaMetadata.p 	53926     332940    571563
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/12-MediaMetadata.p 	54889     338484    580718
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/36-MediaMetadata.p 	55831     343103    588834
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/90-MediaMetadata.p 	56795     348495    599701
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/71-MediaMetadata.p 	57718     354647    609380
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/76-MediaMetadata.p 	58662     361164    620563
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/97-MediaMetadata.p 	59603     365846    628862
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/31-MediaMetadata.p 	60585     370309    637267
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/15-MediaMetadata.p 	61511     374874    646408
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/5-MediaMetadata.p 	62451     380071    655565
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/28-MediaMetadata.p 	63433     384033    664774
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/52-MediaMetadata.p 	64364     388074    672918
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/27-MediaMetadata.p 	65294     395388    684629
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/81-MediaMetadata.p 	66251     401920    695349
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/60-MediaMetadata.p 	67215     406146    703319
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/79-MediaMetadata.p 	68152     410476    711081
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/44-MediaMetadata.p 	69082     414831    720643
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/98-MediaMetadata.p 	70009     419504    729036
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/96-MediaMetadata.p 	70916     423436    736460
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/30-MediaMetadata.p 	71916     428295    745173
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/77-MediaMetadata.p 	72865     437357    758172
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/53-MediaMetadata.p 	73780     446962    771553
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/14-MediaMetadata.p 	74695     451413    779986
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/4-MediaMetadata.p 	75633     455322    787851
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/29-MediaMetadata.p 	76570     460923    798901
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/61-MediaMetadata.p 	77533     467069    809932
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/26-MediaMetadata.p 	78434     480246    826973
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/80-MediaMetadata.p 	79415     492846    844343
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/99-MediaMetadata.p 	80354     498019    854503
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/78-MediaMetadata.p 	81305     503540    864129
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/45-MediaMetadata.p 	82315     508900    873639
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/42-MediaMetadata.p 	83238     512950    881446
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/38-MediaMetadata.p 	84178     517889    889581
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/87-MediaMetadata.p 	85160     521997    897136
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/21-MediaMetadata.p 	86122     528377    908110
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/66-MediaMetadata.p 	87059     532275    915731
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/88-MediaMetadata.p 	88004     536207    923210
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/3-MediaMetadata.p 	88954     542117    933021
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/13-MediaMetadata.p 	89923     547399    941457
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/69-MediaMetadata.p 	90878     552099    949849
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/54-MediaMetadata.p 	91862     556901    959468
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/70-MediaMetadata.p 	92848     563521    970120
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/37-MediaMetadata.p 	93792     568732    978878
# /Users/tgadfort/Music/Discog/artists-allmusic-db/metadata/91-MediaMetadata.p 	94757     573575    987089
#
#
# ==============================================
#
# Saving 94757 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumNames.p
#   --> This file is 25.4MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumNames.p
#   --> This file is 25.4MB.
# Saving 94757 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumRefs.p
#   --> This file is 29.8MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToAlbumRefs.p
#   --> This file is 29.8MB.
# Saving 94757 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumNames.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumNames.p
#   --> This file is 15.4MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumNames.p
#   --> This file is 15.4MB.
# Saving 94757 entries to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumRefs.p
#
# Saving data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumRefs.p
#   --> This file is 18.0MB.
# Saved data to /Users/tgadfort/Music/Discog/db-allmusic/ArtistIDToCoreAlbumRefs.p
#   --> This file is 18.0MB.
# Current Time is Sun Jan 10, 2021 13:35:33 for Done with Creating Artist DBs
# Process [Done with Creating Artist DBs] took 1.0 minutes.
# Current Time is Sun Jan 10, 2021 13:35:33 for
# =================================== Creating Artist Album DB ===================================
# Loading ArtistID Data
# Creating Pandas DataFrame for 94757 Artists
# 	Shape --> (94757, 1)
# DataFrame Shape is (94757, 1)
# Saving Master Artist Albums DB File: /Users/tgadfort/Music/Discog/db-allmusic/MasterSlimArtistAlbumsDB.p
#   --> This file is 49.8MB.
# Current Time is Sun Jan 10, 2021 13:35:47 for Done with
# =================================== Creating Artist Album DB ===================================
# Process [Done with
# =================================== Creating Artist Album DB ===================================] took 13 seconds.
# Current Time is Sun Jan 10, 2021 13:35:49 for Done with Parsing Everything for AllMusic
# Process [Done with Parsing Everything for AllMusic] took 1.5 minutes.

# %%
modVal = 0
artistDBDir = dbdata["AllMusic"]["Disc"].getArtistsDBDir()
moddbdata   = dbdata["AllMusic"]["Disc"].getArtistsDBModValData(modVal)
nerrs   = 0

# %%
len(moddbdata)

# %%
from fileUtils import getBaseFilename
files = dbdata["AllMusic"]["Artists"].getArtistModValFiles(modVal, force=True)
artistIDs = {getBaseFilename(ifile): ifile for ifile in files}

# %%
toget = []
for artistID,ifile in artistIDs.items():
    if moddbdata.get(artistID) is None:
        info   = dbdata["AllMusic"]["Artists"].getData(ifile)
        artistName = info.profile.search
        if artistName is not None and len(artistName) > 0:
            info.show()
            break
        #self.creditToDownload[artistID] = [artistName,self.getArtistSavename(artistID, credit=True)]

# %% [markdown]
# ****
# ****
# ****
# ****

# %% [markdown]
# # Recreate Artist Names

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBArtists(recreate=False)
elapsed(start, cmt)

# %% [markdown]
# # Master Work

# %%
start, cmt = clock("Creating DB")
maindb = mainDB(mdb=None, create=True, debug=True)
maindb.setDBFull()
elapsed(start, cmt)

# %%
df = getFile("/Users/tgadfort/Music/Discog/db-rockcorner/MasterSlimArtistDB.p")
df["MultiStatus"].value_counts()

# %% [markdown]
# ## Parse Single ModVal

# %%
for i in range(10):
    for j in range(10):
        print("{0}touch /Volumes/Piggy/Discog/artists-discogs/{1}/0*0*0*".format("!", i*10+j))
        print("{0}echo '{1}'".format("!", i+10*j))

# %%
masterDBDF = maindb.dbdata["MusicBrainz"]["Disc"].getMasterSlimArtistDiscogsDB()

# %%
from searchUtils import findExt
from fsUtils import setDir, setFile
modVal = 99
artistDBDir = maindb.dbdata["Discogs"]["Artists"].getArtistsDBDir()
artistDir   = maindb.dbdata["Discogs"]["Artists"].getArtistsDir()
dirVal = setDir(artistDir, str(modVal))
files  = findExt(dirVal, ext='.p')
dbname = setFile(artistDBDir, "{0}-DB.p".format(modVal))
len(files)

# %%
from datetime import datetime, timedelta    
from os import path

def getFiles():
    from searchUtils import findExt
    from fsUtils import setDir, setFile
    modVal = 99
    artistDBDir = maindb.dbdata["Discogs"]["Artists"].getArtistsDBDir()
    artistDir   = maindb.dbdata["Discogs"]["Artists"].getArtistsDir()
    dirVal = setDir(artistDir, str(modVal))
    files  = findExt(dirVal, ext='.p')
    return files

def getNewFiles(dbname, previousDays=5, force=False):
    now    = datetime.now()
    files  = getFiles()
    if isFile(dbname):
        lastModified = datetime.fromtimestamp(path.getmtime(dbname))
        if force is True:
            lastModified = None
    else:
        lastModified = None
 
    if lastModified is None:
        newFiles = files
    else:
        numNew    = [ifile for ifile in files if (now-datetime.fromtimestamp(path.getmtime(ifile))).days < previousDays]
        numRecent = [ifile for ifile in files if datetime.fromtimestamp(path.getmtime(ifile)) > lastModified]
        newFiles  = list(set(numNew).union(set(numRecent)))
        print(len(files))
        print(len(numNew))
        print(len(numRecent))
    print(len(newFiles))

# %%
artistDBDir = maindb.dbdata["Discogs"]["Artists"].getArtistsDBDir()
artistDir   = maindb.dbdata["Discogs"]["Artists"].getArtistsDir()
dirVal = setDir(artistDir, str(modVal))
dbname = setFile(artistDBDir, "{0}-DB.p".format(modVal))

files = getNewFiles(dbname=dbname, previousDays=50, force=True)

# %%
now    = datetime.now()

# %%
def parseArtistModValFiles(self, modVal, force=False, debug=False, doExtra=False):        
    from os import path
    from datetime import datetime, timedelta

    print("-"*100)
    print("Parsing Artist Files For ModVal {0}".format(modVal))
    artistInfo = self.artist

    artistDir = self.disc.getArtistsDir()
    maxModVal = self.disc.getMaxModVal()

    artistDBDir = self.disc.getArtistsDBDir()        

    dirVal = setDir(artistDir, str(modVal))
    files  = findExt(dirVal, ext='.p')
    dbname = setFile(artistDBDir, "{0}-DB.p".format(modVal))



    ### Check for recent files
    if isFile(dbname):
        lastModified = datetime.fromtimestamp(path.getmtime(dbname))
        now    = datetime.now()            
        if force is False:
            numRecent = [ifile for ifile in files if datetime.fromtimestamp(path.getmtime(ifile)) > lastModified]
            numNew    = [ifile for ifile in files if (now-datetime.fromtimestamp(path.getmtime(ifile))).days < 1]
            if len(numRecent) == 0:
                print("  ===> Found {0} files, but there are no new files to parse so skipping.".format(len(files)))
                return 0
            else:
                print("  ===> Found {0} files. There are {1} new files to parse.".format(len(files), len(numRecent)))
    else:
        force = True
        lastModified = datetime.fromtimestamp(mktime(gmtime(0)))


    if force is False:
        dbdata = getFile(dbname, version=3)
    else:
        print("Forcing Reloads of ModVal={0}".format(modVal))
        print("  Processing {0} files.".format(len(files)))
        dbdata = {}

    saveIt = 0
    for j,ifile in enumerate(files):
        if force is True:
            if j % 500 == 0:
                print("\tProcessed {0}/{1} files.".format(j,len(files)))
        artistID = getBaseFilename(ifile)
        isKnown  = dbdata.get(artistID)
        recent   = datetime.fromtimestamp(path.getctime(ifile))
        if isKnown is None or recent > lastModified or force is True:
            info   = artistInfo.getData(ifile)

            if info.ID.ID != artistID:

                # Check Profile
                try:
                    artistName = info.profile.search
                    if artistName is not None:
                        self.creditToDownload[artistID] = [artistName,self.getArtistSavename(artistID, credit=True)]
                except:
                    pass

                if debug is False:
                    continue
                print("ID From Name: {0}".format(artistID))
                print("ID From File: {0}".format(info.ID.ID))

                print("File: {0}".format(ifile))
                print("Info: {0}".format(info.url.get()))
                continue
                #1/0

            saveIt += 1
            dbdata[artistID] = info


    forceSave = False
    if saveIt > 0 and doExtra is True:
        print("\tCalling Extra Parsing")
        dbdata = self.parseArtistModValExtraFiles(modVal, dbdata=dbdata, force=force, debug=debug)
        forceSave = True
        saveIt = len(dbdata)


    if len(self.creditToDownload) > 0:
        print("Found {0} artists that need new downloads.".format(len(self.creditToDownload)))


    if saveIt > 0 or forceSave is True:
        savename = setFile(artistDBDir, "{0}-DB.p".format(modVal))     
        print("Saving {0} new artist IDs to {1}".format(saveIt, savename))
        dbNumAlbums = sum([self.getArtistNumAlbums(artistData) for artistData in dbdata.values()])
        print("Saving {0} total artist media".format(dbNumAlbums))
        saveFile(idata=dbdata, ifile=savename)

        self.createArtistModValMetadata(modVal=modVal, db=dbdata, debug=debug)
        self.createArtistAlbumModValMetadata(modVal=modVal, db=dbdata, debug=debug)

    return saveIt

# %%
masterDBDF[~(masterDBDF.DiscArtist == masterDBDF.CleanDiscArtist)]

# %%
data = getFile("creditToDownload.p")

# %%
# %load_ext autoreload
# %autoreload
from masterArtistNameDB import masterArtistNameDB
manDB = masterArtistNameDB("master")

# %%
manDB.removeArtist("NF")
manDB.removeArtist("nf")

# %%
dbrs = getFile("dbrenames.yaml")
del dbrs["John Myers"]
manDB.addRenames(dbrs)

# %%
manDB.addRenames(getFile("dbrenames.yaml"))

# %%
manDB.save()
manDB.saveRenames()

# %%
start,cmt=clock("Parsing Single ModVal")
pdb.parse(db="Discogs", modVals=[0], nProcs=1, force=False)
elapsed(start, cmt)

# %%
data = getFile('/Users/tgadfort/Music/Discog/artists-discogs-db/0-DB.p')

# %%
len(data)

# %%
def getArtistNumAlbums(artistData):
    numAlbums = sum([len(x) for x in artistData.media.media.values()])
    return numAlbums
saveIt = True
dbNumAlbums = sum([getArtistNumAlbums(artistData) for artistData in data.values()])
print('0', dbNumAlbums)

# %%
bsdata = getHTML("/Volumes/Piggy/Discog/artists-allmusic/99/0002579199.p")
#bsdata = getHTML("/Users/tgadfort/Downloads/DJ Spinz _ Credits _ AllMusic.htm")

# %%
data = getFile("/Users/tgadfort/Music/Discog/artists-allmusic-db/99-DB.p")

# %%
data['0002579199']

# %%
amcredit = artistAMCredit()

# %%
#amdata = amcredit.getData("/Users/tgadfort/Downloads/DJ Spinz _ Credits _ AllMusic.htm")
amdata = maindb.dbdata["AllMusic"]["Artist"].getData("/Volumes/Piggy/Discog/artists-allmusic/99/0002579199.p")
amdata.show()

# %%
dbdata["LastFM"]["Artists"].parseArtistModValExtraFiles(0, force=True, debug=True)

# %%
from glob import glob
glob('/Volumes/Piggy/Discog/artists-lastfm/0/extra/11792020000-*.p')

# %%
bsdata = getHTML(ifile)
ols = bsdata.findAll("ol", {"class": "buffer-standard"})
ols

# %%
ifile='/Volumes/Piggy/Discog/artists-lastfm/0/extra/72742897500-2.p'
#getFile(ifile)
a       = dbdata["LastFM"]["Artist"].getData(ifile, debug=False)

def info(a):
    name    = a.artist.name
    ID      = a.ID.ID
    url     = a.url.url
    pages   = a.pages
    media   = a.media
    counts  = a.mediaCounts
    profile = a.profile

    print("{0: <10}{1}".format("Name:", name))
    print("{0: <10}{1}".format("ID:", ID))
    print("{0: <10}{1}".format("URL:", url))
    print("{0: <10}{1}".format("Pages:", pages.get()))
    print("{0: <10}{1}".format("Profile:", profile.get()))
    print("{0: <10}{1}".format("Counts:", counts.get()))
    print("{0: <10}".format("Media:"))
    for mediaType,mediaData in media.get()['media'].items():
        for mediaInfo in mediaData:
            print("\t{0: <10}{1}".format(mediaType, mediaInfo.get()['album']))

# %%
info(a)

# %%
nProcs = 8
# %load_ext autoreload
# %autoreload
from mainDB import mainDB
maindb = mainDB(mdb=None, create=True, debug=True)
start,cmt=clock("Parsing All Artists")
start2,cmt2=clock("Parallel Artist Parsing")

parseArtistsParallel(db="AllMusic", nProcs=nProcs)
maindb.setDBFull("AllMusic")

parseArtistsParallel(db="MusicBrainz", nProcs=nProcs)
maindb.setDBFull("MusicBrainz")

parseArtistsParallel(db="Discogs", nProcs=nProcs)
maindb.setDBFull("Discogs")

#parseArtistsParallel(db="AceBootlegs", nProcs=1)
#parseArtistsParallel(db="DatPiff", nProcs=1)
#parseArtistsParallel(db="RateYourMusic", nProcs=3)
parseArtistsParallel(db="LastFM", nProcs=nProcs)
maindb.setDBFull("LastFM")

#parseArtistsParallel(db="RockCorner", nProcs=3)
#parseArtistsParallel(db="CDandLP", nProcs=3)
#parseArtistsParallel(db="MusicStack", nProcs=1)
elapsed(start2, cmt2)
elapsed(start, cmt)

# %% [markdown]
# # Master DB

# %%
print("\n\n{0}\n".format("Full DB"))
print("\n\n{0}\n".format("Known DB"))
#maindb.setDBKnown() ## Do this to recreate everything
#maindb.setDBKnown()
#artistDBs = maindb.getKnownArtistDBs()

# %% [markdown]
# # Download My Known Artists

# %%
mdb = myMusicDBMap(debug=True)

# %%
dbsToGet = ["AllMusic", "Discogs", "MusicBrainz", "LastFM", "RockCorner", "CDandLP"]
searches = [dbdata["AllMusic"]["Artists"].searchAllMusicForArtist, dbdata["Discogs"]["Artists"].searchDiscogForArtist,
            dbdata["MusicBrainz"]["Artists"].searchMusicBrainzForArtist, dbdata["LastFM"]["Artists"].searchLastFMForArtist,
            dbdata["RockCorner"]["Artists"].searchRockCornerForArtist, dbdata["CDandLP"]["Artists"].searchCDandLPForArtist]

dbsToGet = ["AllMusic"]
searches = [dbdata["AllMusic"]["Artists"].searchAllMusicForArtist]

# %%
def searchAll(mdb, minI=-1):
    nArtists = len(mdb.getArtists())
    for i,artistName in enumerate(mdb.getArtists()):
        if i <= minI:
            continue

        print('\n\n\n')
        print('-'*130)
        print(i,'/',nArtists,'===>\t',artistName)
        print('-'*130)
        print('\n')
        
        dbdata = mdb.getArtistData(artistName)
        if all([dbdata.get("LastFM"), dbdata.get("Discogs"), dbdata.get("AllMusic"), dbdata.get("MusicBrainz")]):
            print("{0} is well known.".format(artistName))
            continue
        else:
            print("{0} get it!".format(artistName))

        for search in searches:
            print("====>",search)
            try:
                search(artistName)
            except:
                sleep(3)

# %%
searchAll(mdb, 3404)

# %%
# Refused

# %% [markdown]
# # Albums

# %%
# %load_ext autoreload
# %autoreload
from album import album
from albums import albums
from discogsBase import discogs

disc = discogs()
albs = albums(disc)
#albs.parseAlbumModValFiles(modVal=27)

# %%
def parseAlbums(modVal):
    albs.parseAlbumModValFiles(modVal=modVal)
    #albs.createAlbumModValMetadata(modVal)
    #albs.createAlbumModValMetadata(modVal=modVal)

def parseAlbumsParallel(modVals=None):
    if modVals is None:
        modVals = ["NAN"] + list(range(100))
        #modVals = range(100)
    nProcs = 2
    pool = Pool(processes=nProcs)
    result = pool.map_async(parseAlbums, modVals)
 
    start, cmt = clock("Processing {0} modVals using {1} processes".format(modVals, nProcs))
    print("Runing .",end="")
    while not result.ready():
        #print(".",end="")
        time.sleep(10)
    print("")
    
    elapsed(start, cmt)
    return result.get()

# %%
# %load_ext autoreload
# %autoreload
from album import album
from albums import albums
albs = albums(disc)

start,cmt=clock("Parsing All Albums")
start2,cmt2=clock("Parallel Album Parsing")
parseAlbumsParallel()
elapsed(start2, cmt2)
elapsed(start, cmt)

# %% [markdown]
# # Download Stuff

# %%
mdb = myMusicDBMap(debug=True)
maindb = mainDB(mdb=mdb, create=False, debug=True)
dbdata = maindb.dbdata

# %%
ifile = "unmatchedArtists4.p"
noMatches = getFile(ifile)
print(len(noMatches))
dbs = ['Discogs', 'AllMusic', 'MusicBrainz', 'LastFM']
dbs = ['MusicBrainz']

#noMatches=['Go-A', 'PM', 'Qango']

from time import sleep
maxI = -1
for i,artist in enumerate(noMatches):
    print("="*100)
    print("="*100)
    print("="*100)
    print("="*100)
    print(i,'/',len(noMatches),'\t',artist)
    if i <= maxI:
        continue
    for db in dbs:
        print("="*100)
        print(i,'/',len(noMatches),'\t',artist,'===>',db)
        try:
            dbdata[db]["Artists"].searchForArtist(artist)
        except:
            sleep(5)
