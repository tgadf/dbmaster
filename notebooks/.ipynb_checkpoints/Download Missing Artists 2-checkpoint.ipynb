# %% [markdown]
# # Discogs

# %%
######################################################
# Juypter
######################################################
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))


######################################################
# General
######################################################
from ioUtils import saveJoblib, loadJoblib, saveFile, getFile
import urllib
from urllib.parse import quote
from timeUtils import clock, elapsed
from fsUtils import moveFile, setFile, setDir, setSubDir, isFile, isDir, mkDir
from ioUtils import getFile, saveFile
from fileUtils import getFileBasics, getBasename
from webUtils import getWebData, getHTML, getURL
from time import sleep
import time
from multiprocessing import Pool


######################################################
# Music Stuff
######################################################
from dbBase import dbBase
from multiArtist import multiartist
from myMusicDBMap import myMusicDBMap
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData


######################################################
# Versions
######################################################
import sys
print("Python: {0}".format(sys.version))
import datetime as dt
start = dt.datetime.now()
print("Notebook Last Run Initiated: "+str(start))
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# /Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# Python: 3.7.7 (default, Mar 26 2020, 10:32:53)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# Notebook Last Run Initiated: 2021-01-28 20:48:06.173706

# %% [markdown]
# # Initialize

# %%
maindb = mainDB(mdb=None, create=False, debug=True)
dbdata = maindb.dbdata
# Out:
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RockCorner
#   Creating Database Records for AceBootlegs
#   Creating Database Records for CDandLP
#   Creating Database Records for RateYourMusic
#   Creating Database Records for MusicStack
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RockCorner, AceBootlegs, CDandLP, RateYourMusic, MusicStack

# %% [markdown]
# # Credit Downloads

# %%
dbdata["AllMusic"]["Artists"].assertDBModValCreditData(0, test=True)

# %%
from random import shuffle
modVals = list(range(100))
shuffle(modVals)

for modVal in modVals:
    break
    try:
        dbdata["Discogs"]["Artists"].assertDBModValCreditData(modVal)
    except:
        continue

# %%
from random import shuffle
modVals = list(range(100))
shuffle(modVals)

for modVal in modVals:
    break
    try:
        dbdata["Discogs"]["Artists"].assertDBModValUnofficialData(modVal)
    except:
        continue

# %%
specificDownloads = True
if specificDownloads:
    
    toget=['Smokepurpp',
  'MadeinTYO',
  'K-DA',
  'GASHI',
  'Ashnikko',
  'Bankrol Hayden',
  'StaySolidRocky',
  'Tyla Yaweh',
  'DJ ESCO',
  'Nebu Kiniza',
  'VÉRITÉ',
  'Marc E. Bassy',
  'MiC LOWRY',
  'KREAM',
  'Stanaj',
  'Loote',
  'NexXthursday',
  'Tay-K',
  'Chad Focus',
  'Chucho Flash',
  'Bobby "Boris" Pickett',
  '22 Savage',
  'JID',
  'YK Osiris',
  'FLETCHER',
  'Luh Kel',
  'Ashley O',
  'Shordie Shordie',
  'Ambjaay',
  'Blue Ivy',
  'Ant Saunders',
  'TOKYO’S REVENGE',
  'Olivia Rodrigo',
  'Delacey',
  'Quinn XCII',
  'Sleepy Hallow',
  'J.I the Prince of N.Y',
  'Curtis Waters',
  'Phillipa Soo',
  'Claire Rosinkranz',
  'WhoHeem',
  'salem ilese',
  'Cochise',
  'Ritt Momney',
  'Lil Eazzyy',
  'Fousheé',
  'The Citizens of Halloween',
  '347aidan',
  'Trey Lewis',
  'Andrew Andraos',
  'Popp Hunna',
  'HVME', 'Mykola Dmytrovych Leontovych',
  'DripReport',
  'CORPSE',
  'Wilbur Soot']
    
    toget=['Sean Og', 'Sile Seoige', "David O'connor", 'Donna & Joe', "Donna", 'M.V.P.', 'Jerry Fish & The Mudbug Club', 'Foster & Allen',
           'DHT & Edmee', 'Edmee', 'Frank & Walters', 'Walters', 'Shane Macgowan', 'Audrey Trainor', 'Glen Keating', 'Redone', 'Ndubz',
           'Levada Louca', 'Rory & The Island', 'Aslan & Don Mescall', 'Theresa Rex', 'Tobi & Manny', 'Tobi', 'P.I. & Elephant Man', 'P.I.',
           'Anybodies', 'N Trance', 'D'side'
    print(len(toget))m 
    #dbs = ['Discogs', 'MusicBrainz', 'LastFM']
    dbs = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
    dbs = ['Discogs', 'MusicBrainz', 'LastFM']
    #dbs = ['MusicBrainz']
    #dbs = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
    #dbs = ['Discogs', 'AllMusic']
    dbs = ["AllMusic", "MusicBrainz", "Discogs"]
    #dbs = ["Discogs", "MusicBrainz"]
    #dbs = ["AllMusic"]
    #dbs = ["AllMusic", "MusicBrainz", "Discogs", "LastFM"]
    #dbs = ["Discogs"]
    #dbs = ["Discogs", "MusicBrainz"]
    #dbs = ["MusicBrainz"]

    maindb = mainDB(mdb=None, create=True, debug=True)
    pdb = parseDBArtistsData(maindb=maindb)

    from time import sleep
    maxI = -1
    for db in dbs:        
        print(db)
        noMatches = toget
        #noMatches = toget
        #noMatches = toget.get(db)
        if noMatches is None:
            continue
        for i,artist in enumerate(noMatches):
            print("="*100)
            print("="*100)
            print(i,'/',len(noMatches),'\t',artist)
            print("="*100)
            print(i,'/',len(noMatches),'\t',artist,'===>',db)
            try:
                maindb.dbdata[db]["Artists"].searchForArtist(artist, force=False)
            except:
                sleep(10)
# Out:
# 56
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================
# Database Records:
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RockCorner
#   Creating Database Records for AceBootlegs
#   Creating Database Records for CDandLP
#   Creating Database Records for RateYourMusic
#   Creating Database Records for MusicStack
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RockCorner, AceBootlegs, CDandLP, RateYourMusic, MusicStack
# AllMusic
# ====================================================================================================
# ====================================================================================================
# 0 / 56 	 Smokepurpp
# ====================================================================================================
# 0 / 56 	 Smokepurpp ===> AllMusic
#
#
# ===================== Searching For Smokepurpp =====================
# 1 / 1 	: 0003622501 	 https://www.allmusic.com/artist/smokepurpp-mn0003622501/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/1/0003622501.p (force=False)
#   --> This file is 20.7kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 1 / 56 	 MadeinTYO
# ====================================================================================================
# 1 / 56 	 MadeinTYO ===> AllMusic
#
#
# ===================== Searching For MadeinTYO =====================
# 1 / 1 	: 0003487740 	 https://www.allmusic.com/artist/madeintyo-mn0003487740/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/40/0003487740.p (force=False)
#   --> This file is 17.8kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 2 / 56 	 K-DA
# ====================================================================================================
# 2 / 56 	 K-DA ===> AllMusic
#
#
# ===================== Searching For K-DA =====================
# 1 / 20 	: 0003795890 	 https://www.allmusic.com/artist/k-da-mn0003795890/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/90/0003795890.p (force=False)
#   --> This file is 15.8kB.
# Done. Sleeping for 2 seconds
# 2 / 20 	: 0003417473 	 https://www.allmusic.com/artist/kda-mn0003417473/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/73/0003417473.p (force=False)
#   --> This file is 16.0kB.
# Done. Sleeping for 2 seconds
# 3 / 20 	: 0001556298 	 https://www.allmusic.com/artist/kda-mn0001556298/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/98/0001556298.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 2 seconds
# 4 / 20 	: 0000138833 	 https://www.allmusic.com/artist/fela-kuti-mn0000138833/discography/all
# 5 / 20 	: 0000855423 	 https://www.allmusic.com/artist/kate-bush-mn0000855423/discography/all
# 6 / 20 	: 0000198480 	 https://www.allmusic.com/artist/cat-stevens-mn0000198480/discography/all
# 7 / 20 	: 0000803009 	 https://www.allmusic.com/artist/cat-power-mn0000803009/discography/all
# 8 / 20 	: 0000852997 	 https://www.allmusic.com/artist/kd-lang-mn0000852997/discography/all
# 9 / 20 	: 0000191680 	 https://www.allmusic.com/artist/gato-barbieri-mn0000191680/discography/all
# 10 / 20 	: 0000859589 	 https://www.allmusic.com/artist/katy-perry-mn0000859589/discography/all
# 11 / 20 	: 0000952599 	 https://www.allmusic.com/artist/golden-gate-quartet-mn0000952599/discography/all
# 12 / 20 	: 0000098189 	 https://www.allmusic.com/artist/kitty-wells-mn0000098189/discography/all
# 13 / 20 	: 0001011323 	 https://www.allmusic.com/artist/kid-cudi-mn0001011323/discography/all
# 14 / 20 	: 0000088180 	 https://www.allmusic.com/artist/kid-rock-mn0000088180/discography/all
# 15 / 20 	: 0000855356 	 https://www.allmusic.com/artist/kate-wolf-mn0000855356/discography/all
# 16 / 20 	: 0000087734 	 https://www.allmusic.com/artist/kid-ory-mn0000087734/discography/all
# 17 / 20 	: 0000213561 	 https://www.allmusic.com/artist/david-guetta-mn0000213561/discography/all
# 18 / 20 	: 0000480830 	 https://www.allmusic.com/artist/the-mountain-goats-mn0000480830/discography/all
discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/53/0003594453.p (force=False)
#   --> This file is 17.5kB.
# Done. Sleeping for 2 seconds
# 2 / 16 	: 0003192806 	 https://www.allmusic.com/artist/andrew-ashong-mn0003192806/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/6/0003192806.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 2 seconds
# 3 / 16 	: 0000592818 	 https://www.allmusic.com/artist/achanak-mn0000592818/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/18/0000592818.p (force=False)
#   --> This file is 14.1kB.
# Done. Sleeping for 2 seconds
# 4 / 16 	: 0003131014 	 https://www.allmusic.com/artist/aashong-mn0003131014/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/14/0003131014.p (force=False)
#   --> This file is 14.1kB.
# Done. Sleeping for 2 seconds
# 5 / 16 	: 0000917251 	 https://www.allmusic.com/artist/achieng-abura-mn0000917251/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/51/0000917251.p (force=False)
#   --> This file is 13.4kB.
# Done. Sleeping for 2 seconds
# 6 / 16 	: 0002308624 	 https://www.allmusic.com/artist/aching-beauty-mn0002308624/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/24/0002308624.p (force=False)
#   --> This file is 15.0kB.
# Done. Sleeping for 2 seconds
# 7 / 16 	: 0000337813 	 https://www.allmusic.com/artist/mbarak-achieng-mn0000337813/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/13/0000337813.p (force=False)
#   --> This file is 13.5kB.
# Done. Sleeping for 2 seconds
# 8 / 16 	: 0000590926 	 https://www.allmusic.com/artist/george-achieng-mn0000590926/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/26/0000590926.p (force=False)
#   --> This file is 15.2kB.
# Done. Sleeping for 2 seconds
# 9 / 16 	: 0002464811 	 https://www.allmusic.com/artist/james-achieng-mn0002464811/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/11/0002464811.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 2 seconds
# 10 / 16 	: 0003536936 	 https://www.allmusic.com/artist/melvin-ashong-mn0003536936/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/36/0003536936.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 2 seconds
# 11 / 16 	: 0003814553 	 https://www.allmusic.com/artist/robert-ashong-mn0003814553/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/53/0003814553.p (force=False)
#   --> This file is 15.2kB.
# Done. Sleeping for 2 seconds
# 12 / 16 	: 0003927566 	 https://www.allmusic.com/artist/patrick-achieng-mn0003927566/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/66/0003927566.p (force=False)
#   --> This file is 15.0kB.
# Done. Sleeping for 2 seconds
# 13 / 16 	: 0003967414 	 https://www.allmusic.com/artist/giles-king-ashong-mn0003967414/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/14/0003967414.p (force=False)
#   --> This file is 13.1kB.
# Done. Sleeping for 2 seconds
# 14 / 16 	: 0001591517 	 https://www.allmusic.com/artist/rhoda-achieng-gravem-mn0001591517/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/17/0001591517.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 2 seconds
# 15 / 16 	: 0000496548 	 https://www.allmusic.com/artist/ezekiel-jakona-achieng-mn0000496548/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/48/0000496548.p (force=False)
#   --> This file is 13.1kB.
# Done. Sleeping for 2 seconds
# 16 / 16 	: 0002858411 	 https://www.allmusic.com/artist/derrick-n-ashong-mn0002858411/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/11/0002858411.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 5 / 56 	 Bankrol Hayden
# ====================================================================================================
# 5 / 56 	 Bankrol Hayden ===> AllMusic
#
#
# ===================== Searching For Bankrol Hayden =====================
# 1 / 18 	: 0003888541 	 https://www.allmusic.com/artist/bankrol-hayden-mn0003888541/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/41/0003888541.p (force=False)
#   --> This file is 16.4kB.
# Done. Sleeping for 2 seconds
# 2 / 18 	: 0000564944 	 https://www.allmusic.com/artist/hayden-mn0000564944/discography/all
# 3 / 18 	: 0003124587 	 https://www.allmusic.com/artist/hayden-james-mn0003124587/discography/all
# 4 / 18 	: 0001024488 	 https://www.allmusic.com/artist/hayden-thorpe-mn0001024488/discography/all
# 5 / 18 	: 0000667430 	 https://www.allmusic.com/artist/hayden-panettiere-mn0000667430/discography/all
# 6 / 18 	: 0000952310 	 https://www.allmusic.com/artist/hayden-desser-mn0000952310/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/10/0000952310.p (force=False)
#   --> This file is 14.4kB.
# Done. Sleeping for 2 seconds
# 7 / 18 	: 0002571481 	 https://www.allmusic.com/artist/hayden-huse-mn0002571481/discography/all
# 8 / 18 	: 0003231242 	 https://www.allmusic.com/artist/herobust-mn0003231242/discography/all
# 9 / 18 	: 0003293157 	 https://www.allmusic.com/artist/hayden-powell-mn0003293157/discography/all
# 10 / 18 	: 0003350816 	 https://www.allmusic.com/artist/hayden-pedigo-mn0003350816/discography/all
# 11 / 18 	: 0003504546 	 https://www.allmusic.com/artist/hayden-calnin-mn0003504546/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/46/0003504546.p (force=False)
#   --> This file is 16.5kB.
# Done. Sleeping for 2 seconds
# 12 / 18 	: 0003648195 	 https://www.allmusic.com/artist/hayden-summerall-mn0003648195/discography/all
# 13 / 18 	: 0003142550 	 https://www.allmusic.com/artist/hayden-eberhart-mn0003142550/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/50/0003142550.p (force=False)
#   --> This file is 14.4kB.
# Done. Sleeping for 2 seconds
# 14 / 18 	: 0003405552 	 https://www.allmusic.com/artist/hayden-clifton-mn0003405552/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/52/0003405552.p (force=False)
#   --> This file is 14.7kB.
# Done. Sleeping for 2 seconds
# 15 / 18 	: 0000804215 	 https://www.allmusic.com/artist/cathal-hayden-mn0000804215/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/15/0000804215.p (force=False)
#   --> This file is 15.5kB.
# Done. Sleeping for 2 seconds
# 16 / 18 	: 0000833836 	 https://www.allmusic.com/artist/rodney-hayden-mn0000833836/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/36/0000833836.p (force=False)
#   --> This file is 16.7kB.
# Done. Sleeping for 2 seconds
# 17 / 18 	: 0000924715 	 https://www.allmusic.com/artist/annie-hayden-mn0000924715/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/15/0000924715.p (force=False)
#   --> This file is 15.9kB.
# Done. Sleeping for 2 seconds
# 18 / 18 	: 0001312424 	 https://www.allmusic.com/artist/shirley-hayden-mn0001312424/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/24/0001312424.p (force=False)
#   --> This file is 14.8kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 6 / 56 	 StaySolidRocky
# ====================================================================================================
# 6 / 56 	 StaySolidRocky ===> AllMusic
#
#
# ===================== Searching For StaySolidRocky =====================
# 1 / 1 	: 0003938306 	 https://www.allmusic.com/artist/staysolidrocky-mn0003938306/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/6/0003938306.p (force=False)
#   --> This file is 15.8kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 7 / 56 	 Tyla Yaweh
# ====================================================================================================
# 7 / 56 	 Tyla Yaweh ===> AllMusic
#
#
# ===================== Searching For Tyla Yaweh =====================
# 1 / 16 	: 0003749776 	 https://www.allmusic.com/artist/tyla-yaweh-mn0003749776/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/76/0003749776.p (force=False)
#   --> This file is 16.1kB.
# Done. Sleeping for 2 seconds
# 2 / 16 	: 0003479651 	 https://www.allmusic.com/artist/mirga-gra%C5%BEinyt-tyla-mn0003479651/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/51/0003479651.p (force=False)
#   --> This file is 17.3kB.
# Done. Sleeping for 2 seconds
# 3 / 16 	: 0000205999 	 https://www.allmusic.com/artist/tyla-gang-mn0000205999/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/99/0000205999.p (force=False)
#   --> This file is 17.7kB.
# Done. Sleeping for 2 seconds
# 4 / 16 	: 0000691575 	 https://www.allmusic.com/artist/sean-tyla-mn0000691575/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/75/0000691575.p (force=False)
#   --> This file is 17.0kB.
# Done. Sleeping for 2 seconds
# 5 / 16 	: 0000041519 	 https://www.allmusic.com/artist/tyla-mn0000041519/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/19/0000041519.p (force=False)
#   --> This file is 18.0kB.
# Done. Sleeping for 2 seconds
# 6 / 16 	: 0001606334 	 https://www.allmusic.com/artist/tyla-durden-mn0001606334/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/34/0001606334.p (force=False)
#   --> This file is 14.8kB.
# Done. Sleeping for 2 seconds
# 7 / 16 	: 0002222157 	 https://www.allmusic.com/artist/tyla-ward-mn0002222157/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/57/0002222157.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 2 seconds
# 8 / 16 	: 0002980659 	 https://www.allmusic.com/artist/tyla-campbell-mn0002980659/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/59/0002980659.p (force=False)
#   --> This file is 14.8kB.
# Done. Sleeping for 2 seconds
# 9 / 16 	: 0003717328 	 https://www.allmusic.com/artist/tyla-campbell-mn0003717328/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/28/0003717328.p (force=False)
#   --> This file is 14.8kB.
# Done. Sleeping for 2 seconds
# 10 / 16 	: 0003773715 	 https://www.allmusic.com/artist/tyla-fowlkes-mn0003773715/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/15/0003773715.p (force=False)
#   --> This file is 14.4kB.
# Done. Sleeping for 2 seconds
# 11 / 16 	: 0003514348 	 https://www.allmusic.com/artist/tyla-mn0003514348/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/48/0003514348.p (force=False)
#   --> This file is 14.8kB.
# Done. Sleeping for 2 seconds
# 12 / 16 	: 0002784783 	 https://www.allmusic.com/artist/tyla-j-pallas-mn0002784783/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/83/0002784783.p (force=False)
#   --> This file is 16.8kB.
# Done. Sleeping for 2 seconds
# 13 / 16 	: 0003189368 	 https://www.allmusic.com/artist/tyla-spike-mn0003189368/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/68/0003189368.p (force=False)
#   --> This file is 15.2kB.
# Done. Sleeping for 2 seconds
# 14 / 16 	: 0000723385 	 https://www.allmusic.com/artist/ken-tyla-mn0000723385/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/85/0000723385.p (force=False)
#   --> This file is 14.6kB.
# Done. Sleeping for 2 seconds
# 15 / 16 	: 0001538193 	 https://www.allmusic.com/artist/ken-tyla-mn0001538193/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/93/0001538193.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 2 seconds
# 16 / 16 	: 0002028430 	 https://www.allmusic.com/artist/tyla-the-dogs-mn0002028430/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/30/0002028430.p (force=False)
#   --> This file is 15.2kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 8 / 56 	 DJ ESCO
# ====================================================================================================
# 8 / 56 	 DJ ESCO ===> AllMusic
#
#
# ===================== Searching For DJ ESCO =====================
# 1 / 20 	: 0003549339 	 https://www.allmusic.com/artist/dj-esco-mn0003549339/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic
discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/39/0003371039.p (force=False)
#   --> This file is 17.6kB.
# Done. Sleeping for 2 seconds
# 2 / 4 	: 0000718406 	 https://www.allmusic.com/artist/marc-e-smith-mn0000718406/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/6/0000718406.p (force=False)
#   --> This file is 14.3kB.
# Done. Sleeping for 2 seconds
# 3 / 4 	: 0003568959 	 https://www.allmusic.com/artist/marc-e-belloni-mn0003568959/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/59/0003568959.p (force=False)
#   --> This file is 14.9kB.
# Done. Sleeping for 2 seconds
# 4 / 4 	: 0002609539 	 https://www.allmusic.com/artist/marc-e-mn0002609539/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/39/0002609539.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 12 / 56 	 MiC LOWRY
# ====================================================================================================
# 12 / 56 	 MiC LOWRY ===> AllMusic
#
#
# ===================== Searching For MiC LOWRY =====================
# 1 / 19 	: 0003388290 	 https://www.allmusic.com/artist/mic-lowry-mn0003388290/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/90/0003388290.p (force=False)
#   --> This file is 16.9kB.
# Done. Sleeping for 2 seconds
# 2 / 19 	: 0000585159 	 https://www.allmusic.com/artist/mike-lowry-mn0000585159/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/59/0000585159.p (force=False)
#   --> This file is 14.2kB.
# Done. Sleeping for 2 seconds
# 3 / 19 	: 0003948728 	 https://www.allmusic.com/artist/mic-lawry-mn0003948728/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/28/0003948728.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 2 seconds
# 4 / 19 	: 0001317451 	 https://www.allmusic.com/artist/mike-lowry-mn0001317451/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/51/0001317451.p (force=False)
#   --> This file is 15.7kB.
# Done. Sleeping for 2 seconds
# 5 / 19 	: 0000013432 	 https://www.allmusic.com/artist/mark-lowry-mn0000013432/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/32/0000013432.p (force=False)
#   --> This file is 21.5kB.
# Done. Sleeping for 2 seconds
# 6 / 19 	: 0003444952 	 https://www.allmusic.com/artist/witt-lowry-mn0003444952/discography/all
# 7 / 19 	: 0002676995 	 https://www.allmusic.com/artist/mic-donet-mn0002676995/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/95/0002676995.p (force=False)
#   --> This file is 16.5kB.
# Done. Sleeping for 2 seconds
# 8 / 19 	: 0000293389 	 https://www.allmusic.com/artist/robert-lowry-mn0000293389/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/89/0000293389.p (force=False)
#   --> This file is 14.2kB.
# Done. Sleeping for 2 seconds
# 9 / 19 	: 0000110085 	 https://www.allmusic.com/artist/mic-harrison-mn0000110085/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/85/0000110085.p (force=False)
#   --> This file is 16.5kB.
# Done. Sleeping for 2 seconds
# 10 / 19 	: 0000452082 	 https://www.allmusic.com/artist/mic-one-mn0000452082/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/82/0000452082.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 2 seconds
# 11 / 19 	: 0000715815 	 https://www.allmusic.com/artist/mic-conway-mn0000715815/discography/all
# 12 / 19 	: 0000883499 	 https://www.allmusic.com/artist/mic-geronimo-mn0000883499/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/99/0000883499.p (force=False)
#   --> This file is 17.4kB.
# Done. Sleeping for 2 seconds
# 13 / 19 	: 0000937062 	 https://www.allmusic.com/artist/mic-holden-mn0000937062/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic
sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/58/221258.p (force=False)
#   --> This file is 16.1kB.
# Done. Sleeping for 2 seconds
# 3 / 5 	: 7 	 https://www.discogs.com/artist/7867024-Foushe%C3%A9?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/24/7867024.p (force=False)
#   --> This file is 15.4kB.
# Done. Sleeping for 2 seconds
# 4 / 5 	: 7 	 https://www.discogs.com/artist/7515131-Kevin-Foushee?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/31/7515131.p (force=False)
#   --> This file is 15.1kB.
# Done. Sleeping for 2 seconds
# 5 / 5 	: 7 	 https://www.discogs.com/artist/4070838-The-Berkshire-Seven?sort=year%2Casc&limit=500
# 	--> Exists.
# ====================================================================================================
# ====================================================================================================
# 46 / 56 	 The Citizens of Halloween
# ====================================================================================================
# 46 / 56 	 The Citizens of Halloween ===> Discogs
#
#
# ===================== Searching For The Citizens of Halloween =====================
# 2 / 2 	: 7 	 https://www.discogs.com/artist/1398468-The-Citizens-Of-Halloween?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/68/1398468.p (force=False)
#   --> This file is 16.6kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 47 / 56 	 347aidan
# ====================================================================================================
# 47 / 56 	 347aidan ===> Discogs
#
#
# ===================== Searching For 347aidan =====================
# ====================================================================================================
# ====================================================================================================
# 48 / 56 	 Trey Lewis
# ====================================================================================================
# 48 / 56 	 Trey Lewis ===> Discogs
#
#
# ===================== Searching For Trey Lewis =====================
# 2 / 5 	: 5 	 https://www.discogs.com/artist/76870-Andre-Foxxe?sort=year%2Casc&limit=500
# 	--> Exists.
# 3 / 5 	: 6 	 https://www.discogs.com/artist/687443-Andre-Williams-3?sort=year%2Casc&limit=500
# 	--> Exists.
# 4 / 5 	: 6 	 https://www.discogs.com/artist/102333-Glenn-Frey?sort=year%2Casc&limit=500
# 	--> Exists.
# 5 / 5 	: 7 	 https://www.discogs.com/artist/1436757-King-Of-Prussia?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/57/1436757.p (force=False)
#   --> This file is 17.5kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 49 / 56 	 Andrew Andraos
# ====================================================================================================
# 49 / 56 	 Andrew Andraos ===> Discogs
#
#
# ===================== Searching For Andrew Andraos =====================
# 2 / 26 	: 6 	 https://www.discogs.com/artist/599734-Andreas-Nager?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/34/599734.p (force=False)
#   --> This file is 16.2kB.
# Done. Sleeping for 2 seconds
# 3 / 26 	: 6 	 https://www.discogs.com/artist/424491-Andreas-Stollenz?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/91/424491.p (force=False)
#   --> This file is 16.6kB.
# Done. Sleeping for 2 seconds
# 4 / 26 	: 7 	 https://www.discogs.com/artist/1518329-Andreas-Panagos?sort=year%2Casc&limit=500
# 	--> Exists.
# 5 / 26 	: 7 	 https://www.discogs.com/artist/3251602-Andreas-Knirsch?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/2/3251602.p (force=False)
#   --> This file is 16.4kB.
# Done. Sleeping for 2 seconds
# 6 / 26 	: 7 	 https://www.discogs.com/artist/2587055-Andreas-Winkler-2?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/55/2587055.p (force=False)
#   --> This file is 16.6kB.
# Done. Sleeping for 2 seconds
# 7 / 26 	: 7 	 https://www.discogs.com/artist/2225309-Andreas-Schmidt-6?sort=year%2Casc&limit=500
# 	--> Exists.
# 8 / 26 	: 7 	 https://www.discogs.com/artist/1279283-Andreas-Gr%C3%A4ser?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/83/1279283.p (force=False)
#   --> This file is 20.0kB.
# Done. Sleeping for 2 seconds
# 9 / 26 	: 7 	 https://www.discogs.com/artist/3180993-Andreas-Sotiropoulos?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/93/3180993.p (force=False)
#   --> This file is 17.5kB.
# Done. Sleeping for 2 seconds
# 10 / 26 	: 7 	 https://www.discogs.com/artist/3011892-Andrew-J-Boex?sort=year%2Casc&limit=500
# 	--> Exists.
# 11 / 26 	: 7 	 https://www.discogs.com/artist/1648260-Andrew-Ioannou?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/60/1648260.p (force=False)
#   --> This file is 16.5kB.
# Done. Sleeping for 2 seconds
# 12 / 26 	: 6 	 https://www.discogs.com/artist/552694-Andreas-Strateas?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/94/552694.p (force=False)
#   --> This file is 16.2kB.
# Done. Sleeping for 2 seconds
# 13 / 26 	: 7 	 https://www.discogs.com/artist/2033165-Saint-Andrew?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/65/2033165.p (force=False)
#   --> This file is 17.0kB.
# Done. Sleeping for 2 seconds
# 14 / 26 	: 7 	 https://www.discogs.com/artist/2135597-Andrew-John-The-Rational?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/97/2135597.p (force=False)
#   --> This file is 16.4kB.
# Done. Sleeping for 2 seconds
# 15 / 26 	: 7 	 https://www.discogs.com/artist/4782623-Andreas-M%C3%BCller-12?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/23/4782623.p (force=False)
#   --> This file is 16.3kB.
# Done. Sleeping for 2 seconds
# 16 / 26 	: 7 	 https://www.discogs.com/artist/3619755-Andreas-Kohlenberg?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/55/3619755.p (force=False)
#   --> This file is 15.5kB.
# Done. Sleeping for 2 seconds
# 17 / 26 	: 7 	 https://www.discogs.com/artist/1310083-Andrew-21?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/83/1310083.p (force=False)
#   --> This file is 15.3kB.
# Done. Sleeping for 2 seconds
# 18 / 26 	: 5 	 https://www.discogs.com/artist/55318-Mirror?sort=year%2Casc&limit=500
# 	--> Exists.
# 19 / 26 	: 7 	 https://www.discogs.com/artist/1034663-%CE%91%CE%BD%CE%B4%CF%81%CE%AD%CE%B1%CF%82-%CE%9C%CE%BF%CF%85%CE%B6%CE%AC%CE%BA%CE%B7%CF%82?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/63/1034663.p (force=False)
#   --> This file is 16.5kB.
# Done. Sleeping for 2 seconds
# 20 / 26 	: 7 	 https://www.discogs.com/artist/1444741-Wedard?sort=year%2Casc&limit=500
# 	--> Exists.
# 21 / 26 	: 5 	 https://www.discogs.com/artist/55325-Christoph-Heemann?sort=year%2Casc&limit=500
# 	--> Exists.
# 22 / 26 	: 7 	 https://www.discogs.com/artist/3470931-YoYo-17?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/31/3470931.p (force=False)
#   --> This file is 17.0kB.
# Done. Sleeping for 2 seconds
# 23 / 26 	: 7 	 https://www.discogs.com/artist/1725777-Colonel-Tom-Parker?sort=year%2Casc&limit=500
# 	--> Exists.
# 24 / 26 	: 6 	 https://www.discogs.com/artist/281660-Pyramid-Peak?sort=year%2Casc&limit=500
# 	--> Exists.
# 25 / 26 	: 7 	 https://www.discogs.com/artist/7206858-The-String-Theory?sort=year%2Casc&limit=500
# 	--> Exists.
# 26 / 26 	: 5 	 https://www.discogs.com/artist/83146-The-Sisters-Of-Mercy?sort=year%2Casc&limit=500
# 	--> Exists.
# ====================================================================================================
# ====================================================================================================
# 50 / 56 	 Popp Hunna
# ====================================================================================================
# 50 / 56 	 Popp Hunna ===> Discogs
#
#
# ===================== Searching For Popp Hunna =====================
# 2 / 2 	: 7 	 https://www.discogs.com/artist/4334454-Andr%C3%A9s-Ing%C3%B3lfsson?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/54/4334454.p (force=False)
#   --> This file is 17.2kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 51 / 56 	 HVME
# ====================================================================================================
# 51 / 56 	 HVME ===> Discogs
#
#
# ===================== Searching For HVME =====================
# 2 / 3 	: 7 	 https://www.discogs.com/artist/8246750-HVME?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/50/8246750.p (force=False)
#   --> This file is 15.3kB.
# Done. Sleeping for 2 seconds
# 3 / 3 	: 6 	 https://www.discogs.com/artist/975143-Tobias-Hume?sort=year%2Casc&limit=500
# 	--> Exists.
# ====================================================================================================
# ====================================================================================================
# 52 / 56 	 Mykola Dmytrovych Leontovych
# ====================================================================================================
# 52 / 56 	 Mykola Dmytrovych Leontovych ===> Discogs
#
#
# ===================== Searching For Mykola Dmytrovych Leontovych =====================
# 2 / 2 	: 6 	 https://www.discogs.com/artist/845430-Mykola-Leontovych?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/30/845430.p (force=False)
#   --> This file is 19.1kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 53 / 56 	 DripReport
# ====================================================================================================
# 53 / 56 	 DripReport ===> Discogs
#
#
# ===================== Searching For DripReport =====================
# 2 / 2 	: 7 	 https://www.discogs.com/artist/7849641-DripReport?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/41/7849641.p (force=False)
#   --> This file is 15.5kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 54 / 56 	 CORPSE
# ====================================================================================================
# 54 / 56 	 CORPSE ===> Discogs
#
#
# ===================== Searching For CORPSE =====================
# 2 / 26 	: 6 	 https://www.discogs.com/artist/124774-Cannibal-Corpse?sort=year%2Casc&limit=500
# 	--> Exists.
# 3 / 26 	: 7 	 https://www.discogs.com/artist/1416498-Corpse-6?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/98/1416498.p (force=False)
#   --> This file is 16.6kB.
# Done. Sleeping for 2 seconds
# 4 / 26 	: 6 	 https://www.discogs.com/artist/535014-Corpse-3?sort=year%2Casc&limit=500
# 	--> Exists.
# 5 / 26 	: 4 	 https://www.discogs.com/artist/8945-Exquisite-Corpse?sort=year%2Casc&limit=500
# 	--> Exists.
# 6 / 26 	: 6 	 https://www.discogs.com/artist/708989-Cannabis-Corpse?sort=year%2Casc&limit=500
# 	--> Exists.
# 7 / 26 	: 6 	 https://www.discogs.com/artist/326181-Corpse?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/81/326181.p (force=False)
#   --> This file is 17.0kB.
# Done. Sleeping for 2 seconds
# 8 / 26 	: 7 	 https://www.discogs.com/artist/2981333-Thomas-Corpse?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/33/2981333.p (force=False)
#   --> This file is 22.9kB.
# Done. Sleeping for 2 seconds
# 9 / 26 	: 7 	 https://www.discogs.com/artist/1084018-Ripping-Corpse?sort=year%2Casc&limit=500
# 	--> Exists.
# 10 / 26 	: 7 	 https://www.discogs.com/artist/1882992-Richard-Corpse?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/92/1882992.p (force=False)
#   --> This file is 18.0kB.
# Done. Sleeping for 2 seconds
# 11 / 26 	: 6 	 https://www.discogs.com/artist/352806-Corpse-Grinders?sort=year%2Casc&limit=500
# 	--> Exists.
# 12 / 26 	: 7 	 https://www.discogs.com/artist/2670351-Exquisite-Corpse-4?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/51/2670351.p (force=False)
#   --> This file is 15.3kB.
# Done. Sleeping for 2 seconds
# 13 / 26 	: 7 	 https://www.discogs.com/artist/2806980-Corpse-15?sort=year%2Casc&limit=500
# 	--> Exists.
# 14 / 26 	: 7 	 https://www.discogs.com/artist/2440515-Hound-Of-Corpse-Gristle?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/15/2440515.p (force=False)
#   --> This file is 21.2kB.
# Done. Sleeping for 2 seconds
# 15 / 26 	: 7 	 https://www.discogs.com/artist/3052036-Corpse-16?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/36/3052036.p (force=False)
#   --> This file is 15.9kB.
# Done. Sleeping for 2 seconds
# 16 / 26 	: 7 	 https://www.discogs.com/artist/1777650-Corpse-Molestation?sort=year%2Casc&limit=500
# 	--> Exists.
# 17 / 26 	: 6 	 https://www.discogs.com/artist/905556-Corpse-4?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/56/905556.p (force=False)
#   --> This file is 17.6kB.
# Done. Sleeping for 2 seconds
# 18 / 26 	: 6 	 https://www.discogs.com/artist/659386-Peace-Corpse?sort=year%2Casc&limit=500
# 	--> Exists.
# 19 / 26 	: 7 	 https://www.discogs.com/artist/3763550-Disney-Corpse-Graphics?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/50/3763550.p (force=False)
#   --> This file is 16.6kB.
# Done. Sleeping for 2 seconds
# 20 / 26 	: 7 	 https://www.discogs.com/artist/3910243-Corpse-21?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/43/3910243.p (force=False)
#   --> This file is 15.5kB.
# Done. Sleeping for 2 seconds
# 21 / 26 	: 7 	 https://www.discogs.com/artist/2039331-Corpse-8?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/31/2039331.p (force=False)
#   --> This file is 15.4kB.
# Done. Sleeping for 2 seconds
# 22 / 26 	: 6 	 https://www.discogs.com/artist/411610-George-Corpsegrinder-Fisher?sort=year%2Casc&limit=500
# 	--> Exists.
# 23 / 26 	: 7 	 https://www.discogs.com/artist/4570574-Chrome-Corpse?sort=year%2Casc&limit=500
# 	--> Exists.
# 24 / 26 	: 7 	 https://www.discogs.com/artist/1561901-Disfigured-Corpse?sort=year%2Casc&limit=500
# 	--> Exists.
# 25 / 26 	: 6 	 https://www.discogs.com/artist/320420-Tattooed-Corpse?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/20/320420.p (force=False)
#   --> This file is 17.4kB.
# Done. Sleeping for 2 seconds
# 26 / 26 	: 7 	 https://www.discogs.com/artist/2870707-Alan-Corpse-Perez?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/7/2870707.p (force=False)
#   --> This file is 18.9kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 55 / 56 	 Wilbur Soot
# ====================================================================================================
# 55 / 56 	 Wilbur Soot ===> Discogs
#
#
# ===================== Searching For Wilbur Soot =====================
# 2 / 2 	: 7 	 https://www.discogs.com/artist/8093594-Wilbur-Soot?sort=year%2Casc&limit=500
# Saving /Volumes/Piggy/Discog/artists-discogs/94/8093594.p (force=False)
#   --> This file is 18.7kB.
# Done. Sleeping for 2 seconds

# %% [markdown]
# # Download Credit (AllMusic)

# %%
data = getFile("creditToDownload.p")
len(data)

# %%
for artistID,artist in data.items():
    break
    maindb.dbdata["AllMusic"]["Artists"].searchForArtistCredit(artist, artistID)

# %% [markdown]
# # Download Extra Data

# %%
bsdata = getHTML("/Volumes/Piggy/Discog/artists-musicbrainz/13/134347080492261077195869941664563052313.p")
pages  = bsdata.find("ul", {"class": "pagination"})
lis    = pages.findAll("li")
txts   = [li.text for li in lis]
npages = 0
for item in txts:
    try:
        npages = max([npages, int(item)])
    except:
        continue
npages

# %%
 = dbdata["MusicBrainz"]["Artists"].getData('314779112728565924209805500016231841915')

# %%
#dbdata["LastFM"]["Artists"].assertDBModValExtraData(15, test=False)

# %%
for modVal in range(100):
    dbdata["MusicBrainz"]["Artists"].assertDBModValExtraData(str(modVal), test=False, maxPages=20)

# %%
from random import randint, shuffle
modVals = list(range(100))
shuffle(modVals)
for modVal in modVals:
    dbdata["MusicBrainz"]["Artists"].assertDBModValExtraData(modVal, test=False, maxPages=2)

# %%
from random import randint, shuffle
modVals = list(range(100))
shuffle(modVals)
for modVal in modVals:
    break
    dbdata["LastFM"]["Artists"].assertDBModValExtraData(modVal, test=False, maxPages=20)

# %% [markdown]
# # Download Artist Data

# %%
artsDC.downloadArtistUnofficialFromID(144998)

# %%
maindb.getBasicArtistInfo("Black Sabbath")

# %%
dbdata["Discogs"]["Artists"].downloadArtistUnofficialFromID('144998', '/artist/144998-Black-Sabbath')
#/artist/144998-Black-Sabbath?type=Unofficial&subtype=Albums&filter_anv=0"
#/artist/144998-Black-Sabbath?sort=year%2Casc&limit=500&type=Unofficial&subtype=Albums&filter_anv=0&page=1

# %%
retval = dbdata["Discogs"]["Artist"].getData("/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p")

# %%
bsdata = getHTML("/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p")

# %%
retval.get()

# %%
retval.get()['artist'].get()

# %% [markdown]
# # Music DB

# %%
https://www.discogs.com/artist/144998-Black-Sabbath?sort=year%2Casc&limit=500?type=Unofficial&subtype=Albums&filter_anv=0
https://www.discogs.com/artist/144998-Black-Sabbath?sort=year%2Casc&limit=500&type=Unofficial&subtype=Albums&filter_anv=0&page=1
    
artistIDToRef = disc.getArtistIDToRefData()

# %%
myMusicAlbumIDMap = getFile("/Users/tgadfort/Documents/code/music/musicDiscogsMap.p")

# %%
dR=0.2
rC=0.8

# %%
from time import sleep
N = len(myMusicAlbumIDMap)
for i,(artistName,artistVals) in enumerate(myMusicAlbumIDMap.items()):
    if artistName.startswith("Levl") is False:
        continue
    artistID,discogsName = artistVals
    print(i,N,'\t',artistName)
    artsDC.searchDiscogForArtist(artistName)
    artsAM.searchAllMusicForArtist(artistName)
    artsMB.searchMusicBrainzForArtist(artistName)
    sleep(3)

# %%
artistIDs = [v[0] for k,v in myMusicAlbumIDMap.items()]
arts.rmIDsFromDBs(artistIDs)

# %%
arts.parseArtistModValFiles(96, force=False)
arts.parseArtistModValExtraFiles(96)

# %%
files = [savename]
from glob import glob
from os.path import join
from fileUtils import getDirname
files += glob(join(getDirname(savename), "extra", "{0}-*.p".format(artistID)))
files

# %% [markdown]
# # Download Missing Artists

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
from discogsBase import discogs

disc  = discogs()
albs  = albums(disc)
toget = albs.findMissingArtistsFromAlbums()

from ioUtils import saveFile
saveFile(idata=toget, ifile="missingArtistsFromAlbums.p")

# %%
# %load_ext autoreload
# %autoreload
disc = discogs()
arts = artists(disc)

from ioUtils import getFile

toget = getFile(ifile="missingArtistsFromAlbums.p")

from time import sleep
togetmap  = toget['togetmap']
refstoget = toget['toget']
for ia,item in enumerate(refstoget.most_common()):
    artistID, cnt = item[0], item[1]
    ref      = togetmap[artistID]
    url      = arts.getArtistURL(ref)
    savename = arts.getArtistSavename(artistID)
    if not isFile(savename):
        try:
            print('\n{0}/{1}'.format(ia,len(refstoget)))
            retval = arts.downloadArtistURL(url, savename, debug=True)
            sleep(3)
        except:
            continue
    else:
        print("{0} known".format(savename))
            
    #print(item)
#len(togetmap)

# %% [markdown]
# # Redownload Known Artist

# %%
myMusicMap = getFile("/Users/tgadfort/Documents/code/music/myMusicMap.p")

# %%
musicMap = myMusicMap["Ladies of Soul"]
musicMap

# %%
discDCIDToRef = discDC.getArtistIDToRefData()

# %%
artistID  = musicMap['Discogs']['ID']
artistRef = discDCIDToRef.get(artistID)
artsDC.downloadArtistFromID(artistID=artistID, artistRef=artistRef, force=True)

# %% [markdown]
# # Download Unmatched Artists

# %%
matchedResults = getFile("/Users/tgadfort/Documents/code/music/multiArtists.p")

# %%
searchForArtist = {"Discogs": artsDC.searchDiscogForArtist, "AllMusic": artsAM.searchAllMusicForArtist, "MusicBrainz": artsMB.searchMusicBrainzForArtist}

# %%
from time import sleep
for i,(artistName,artistValues) in enumerate(matchedResults["PartiallyUnknown"].items()):
    if i <= 83:
        continue
    print("=========== {0} [{1}/{2}] ===========".format(artistName, i, len(matchedResults["PartiallyUnknown"])))
    for dbKey, dirval in artistValues.items():
        print(artistName,'\t',searchForArtist[dbKey])
        searchForArtist[dbKey](artistName)
        sleep(1)
    sleep(1)

# %% [markdown]
# # Missing Artists From Albums

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
from discogsBase import discogs

disc  = discogs()
albs  = albums(disc)
toget = albs.findMissingArtistsFromAlbums()

# %%
# %load_ext autoreload
# %autoreload
disc = discogs()
arts = artists(disc)

from time import sleep
togetmap  = toget['togetmap']
refstoget = toget['toget']
for ia,item in enumerate(refstoget.most_common()):
    artistID, cnt = item[0], item[1]
    ref      = togetmap[artistID]
    url      = arts.getArtistURL(ref)
    savename = arts.getArtistSavename(artistID)
    if not isFile(savename):
        try:
            _, _ = clock('\n{0}/{1}'.format(ia,len(refstoget)))
            retval = arts.downloadArtistURL(url, savename, debug=True)
        except:
            continue
    else:
        print("{0} known".format(savename))
            
    #print(item)
#len(togetmap)

# %% [markdown]
# # Artists From Search

# %%
# %load_ext autoreload
# %autoreload
disc = discogs()
arts = artists(disc)
arts.searchDiscogForArtist("World of Our Own")
#arts.searchDiscogForArtist("Continental Divide")

# %%
from ioUtils import getFile

# %%
toGet = getFile(ifile="/Users/tgadfort/Documents/code/charts/chartCounter.p", debug=True)

# %%
toGet = getFile("~/code/charts/toget.p")

# %%
for i,val in enumerate(toGet):
    if i <= 206:
        continue
    print('='*30,val,'(',i,'/',len(toGet),')','='*30)
    arts.searchDiscogForArtist(val)
    print("\n\n\n")
    sleep(2)

# %%
from time import sleep
vals  = ["The Souvenirs", "The Stand", f"The Suicide Kings", "The Supremes", "The Temptations", "The Tomcats", "The Tone", "The Tourists", "The Unseen", "The Ventures", "The Vikings", "The Violents", "The Wailers", "The Want", "The Washingtonians", "The Witches", "UB40", "Underdog", "Unearth", "Unk", "Unscarred", "Up Front", "Up In Arms", "Urban Legends"]
vals += ["The Pits", "The Pressure", "The Pretenders", "The Prodigy", "The Product", "The Receptionists", "The Retardos", "The Revelers", "The Romancers", "The Roots", "The Rosehips", "The Ruiners", "The Runaways", "The Scholars", "The Seeds", "The Shams", "The Sights", "The Sillies", "The Skunks", "The Snowmen"]
vals += ["The Invisible Men", "The Israelites", "The Ivory Coast", "The Killers", "The Manatees", "The Marquees", "The Masters", "The Matrix", "The Mixtures", "The Moves", "The Noisettes", "The Nomads", "The Orange Peels", "The Outcasts"]
vals += ["The Game", "The Generics", "The Gits", "The Go-Betweens", "The Goblins", "The Godz", "The Great Society", "The Haters", "The Hilltops", "The Hookers", "The Immortals", "The Impacts", "The Inspector", "The Invaders"]
vals += ["The Diamonds", "The Diplomats", "The Dramatics", "The Drifters", "The Dust Brothers", "The Eagles", "The Exceptions", "The Fiends", "The Fixtures", "The Frantics", "The Freeze", "The Frogs", "The Fumes"]
vals += ["The Cardigans", "The Casualties", "The Challengers", "The Chameleons", "The Cheaters", "The Chicken Hawks", "The Crash", "The Crusaders", "The Cure", "The Darts", "The Deuce Coupes"]
vals += ["The Beat", "The Beatles", "The Blood Brothers", "The Blow Up", "The Bollweevils", "The Brentwoods", "The Broadways", "The Brood", "The Business", "The Busy Signals"]
vals += ["You", "Young Money", "Young Pioneers", "Zero Zero"]
for val in vals:
    print('='*30,val,'='*30)
    try:
        arts.searchDiscogForArtist(val)
    except:
        continue
    print("\n\n\n")
    sleep(10)

# %% [markdown]
# # New Artists From Albums

# %%
# %load_ext autoreload
# %autoreload
from albums import albums

disc = discogs()
albs = albums(disc)
toget = albs.findMissingArtistsFromAlbums()

# %%
from time import sleep
togetmap  = toget['togetmap']
refstoget = toget['toget']
for ia,item in enumerate(refstoget.most_common()):
    print('\n{0}/{1}'.format(ia,len(refstoget)))
    artistID, cnt = item[0], item[1]
    ref      = togetmap[artistID]
    url      = arts.getArtistURL(ref)
    savename = arts.getArtistSavename(artistID)
    if not isFile(savename):
        try:
            arts.downloadArtistURL(url, savename, debug=True)
        except:
            continue
        sleep(2)
    #print(item)
#len(togetmap)

# %% [markdown]
# # Albums From Known People

# %%
data = getFile("/Volumes/Music/MusicDB/toget.p")

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
disc = discogs()
discdf = disc.getMasterDiscogsDB()
print(discdf.shape)
discdf = discdf[~discdf['Name'].isna()]
print(discdf.shape)

artists = list(discdf["Artist"])

_ = clock("Last Run")

# %%
def getMusicData(key, artist):
    retval = discdf[discdf[key] == artist]
    if retval.shape[0] > 0:
        return retval
    else:
        return None
    
toget={}
known={}

for ia,artistName in enumerate(data):
    #artistID = artistName
    artistID = None
    if artistID is None:
        retval = getMusicData('Name', artistName)
        if retval is not None:
            artistID = retval.index.values[0]
    modValue  = dutils.getDiscIDHashMod(discID=artistID, modval=disc.getMaxModVal())
    if toget.get(modValue) is None:
        toget[modValue] = {}
    toget[modValue][artistID] = True
        
    if ia % 100 == 0:
        print(ia,'/',len(data))

# %%
for modVal in toget.keys():
    artistIDs = toget[modVal]
    print(modVal,'\t',len(artistIDs))
    dbdata = disc.getArtistsDBModValData(modVal)
    for artistID in artistIDs:
        print(' ',artistID)
        artistData = dbdata[artistID]
        albs.downloadAlbumFromArtistData(artistID=artistID, artistData=artistData, mediaTypes=None)

# %% [markdown]
# # Albums From All Artists

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
disc = discogs()
albs = albums(disc)
albs.downloadAlbumsFromArtists(maxAlbums=1, mediaTypes=None, rand=True)

# %%
maindb = mainDB(mdb=mdb, create=False)
#maindb.setDBFull() ## Do this to recreate everything
maindb.setDBKnown()
artistDBs = maindb.getKnownArtistDBs()

# %% [markdown]
# # Discogs

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsDiscogs import dbArtistsDiscogs
ad = dbArtistsDiscogs(debug=True)
#ad.searchForArtist("Dave Matthews")
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/70/420570.p"
ifile="/Users/tgadfort/Music/Discog/artists-discogs/34/386834.p"
retval = ad.getData(ifile)
print(retval.get()['artist'].get())
#ad.searchForArtist("Niel Diamond")

# %% [markdown]
# # AllMusic

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsAllMusic import dbArtistsAllMusic
am = dbArtistsAllMusic(debug=True)
#am.searchForArtist("Dave Matthews")
ifile="/Users/tgadfort/Music/Discog/artists-allmusic/61/0000687561.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/70/420570.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/34/386834.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # MusicBrainz

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsMusicBrainz import dbArtistsMusicBrainz
am = dbArtistsMusicBrainz(debug=True)
#am.searchForArtist("Dave Matthews")
ifile="/Users/tgadfort/Music/Discog/artists-musicbrainz/71/100112022548628725831976514629370881371.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # LastFM

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsLastFM import dbArtistsLastFM
am = dbArtistsLastFM(debug=True)
#am.searchForArtist("Dave Matthews Band")
ifile="/Users/tgadfort/Music/Discog/artists-lastfm/14/64101467014.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # RockCorner

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsRockCorner import dbArtistsRockCorner
am = dbArtistsRockCorner(debug=True)
#am.searchForArtist("Dave Matthews Band")
ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # RateYourMusic

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsRockCorner import dbArtistsRockCorner
am = dbArtistsRockCorner(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # CDandLP

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsCDandLP import dbArtistsCDandLP
am = dbArtistsCDandLP(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # AceBootlegs

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsAceBootlegs import dbArtistsAceBootlegs
am = dbArtistsAceBootlegs(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # DatPiff

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsDatPiff import dbArtistsDatPiff
am = dbArtistsDatPiff(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # MusicStack

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsMusicStack import dbArtistsMusicStack
am = dbArtistsMusicStack(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %%
ad = artistsDiscogs(debug=True)

# %%
ad = artistsDiscogs(debug=True)
ifile="/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p"
retval = ad.getData(ifile)
retval.get()['artist'].get()
ad.searchForArtist("Niel Diamond")

# %%
retval = ad.getData(ifile)
retval.get()['artist'].get()

# %%
ad.searchForArtist("Niel Diamond")

# %%
from artistAM import artistAM
from discogsUtils import allmusicUtils

class artistsAllMusic(artistsBase):
    def __init__(self, debug=False):
        self.db     = "AllMusic"
        self.disc   = discogs(self.db.lower())
        self.artist = artistAM(self.disc)
        self.dutils = allmusicUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        url = "{0}/discography/all".format(artistRef)
        return url
        
        if artistRef.startswith("http"):
            return artistRef
        else:
            baseURL = self.disc.discogURL
            url     = urllib.parse.urljoin(baseURL, quote(artistRef))
            return url

            
        if artistRef.startswith("/artist/") is False:
            print("Artist Ref needs to start with /artist/")
            return None
        
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, quote(artistRef))
        url     = urllib.parse.urljoin(url, "?sort=year%2Casc&limit=500") ## Make sure we get 500 entries)
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("artists/", quote(artist)))
                  
                    
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}
        
        uls = bsdata.findAll("ul", {"class": "search-results"})
        for ul in uls:
            lis = ul.findAll("li", {"class": "artist"})
            for li in lis:
                divs = li.findAll("div", {"class": "name"})
                for div in divs:
                    link     = div.find("a")
                    href     = link.attrs['href']
                    tooltip  = link.attrs['data-tooltip']
                    try:
                        from json import loads
                        tooltip = loads(tooltip)
                        artistID = tooltip['id']
                    except:
                        artistID = None
            
                    if artistDB.get(href) is None:
                        artistDB[href] = {"N": 0, "Name": artist}
                    artistDB[href]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1
        
            discID   = self.dutils.getArtistID(href)
            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
am = artistsAllMusic(debug=True)
#am.searchForArtist("Niel Diamond")

# %%
from artistMB import artistMB
from discogsUtils import musicbrainzUtils
from hashlib import md5

class artistsMusicBrainz(artistsBase):
    def __init__(self, debug=False):
        self.db     = "MusicBrainz"
        self.disc   = discogs(self.db.lower())
        self.artist = artistMB(self.disc)
        self.dutils = musicbrainzUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = "https://musicbrainz.org/"
        extra = "search?query={0}&type=artist&limit=100&method=indexed".format(quote(artist))

        url = urllib.parse.urljoin(baseURL, extra)         
                    
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}

        tables = bsdata.findAll("table")
        for table in tables:
            ths = table.findAll("th")
            headers = [x.text for x in ths]
            trs = table.findAll("tr")
            for tr in trs[1:]:
                tds    = tr.findAll("td")
                name   = tds[0].find('a').text
                href   = tds[0].find('a').attrs['href']
            
                if artistDB.get(href) is None:
                    artistDB[href] = {"N": 0, "Name": name}
                artistDB[href]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1

            discID   = self.dutils.getArtistID(href)
            
            uuid = href.split('/')[-1]

            m = md5()
            for val in uuid.split("-"):
                m.update(val.encode('utf-8'))
            hashval = m.hexdigest()
            discID  = str(int(hashval, 16))

            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
am = artistsMusicBrainz(debug=True)
#am.searchForArtist("Niel Diamond")

# %%
from artistLM import artistLM
from discogsUtils import lastfmUtils

class artistsLastFM(artistsBase):
    def __init__(self, debug=False):
        self.db     = "LastFM"
        self.disc   = discogs(self.db.lower())
        self.artist = artistLM(self.disc)
        self.dutils = lastfmUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        #print("getArtistURL(",artistRef,")")
        if artistRef.startswith("http"):
            url = artistRef
        else:
            baseURL = self.disc.discogURL
            if artistRef.startswith("/") is True:
                #print("Join", end="\t")
                url     = urllib.parse.urljoin(baseURL, quote(artistRef[1:]))
                #print(url)
            else:
                url     = urllib.parse.urljoin(baseURL, quote(artistRef))
            #print(url)
                
            if url.endswith("/") is False:
                url     = "{0}{1}".format(url, "/+albums?order=release_date")
            else:
                url     = "{0}{1}".format(url, "+albums?order=release_date")
                
            #print(url)
        
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("artists?q=", quote(artist)))
                    
            
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}
        
        uls = bsdata.findAll("ul", {"class": "artist-results"})
        for ul in uls:
            lis = ul.findAll("li", {"class": "artist-result"})
            for li in lis:
                h4 = li.find("h4")
                if h4 is None:
                    raise ValueError("No h4 in list")
                ref = h4.find('a')
                if ref is None:
                    raise ValueError("No ref in h4")

                name = ref.attrs['title']
                url  = ref.attrs['href']
                artistID = self.dutils.getArtistID(name)
        
                #print(name,'\t',url,'\t',artistID)
                if artistDB.get(url) is None:
                    artistDB[url] = {"N": 0, "Name": name}
                artistDB[url]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1
        
            name     = hrefData["Name"]
            discID   = self.dutils.getArtistID(name)
            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)
                
    
    def assertDBModValExtraData(self, modVal, maxPages=None):
        mulArts             = multiartist()        
        
        print("assertDBModValExtraData(",modVal,")")
        artistDBDir = self.disc.getArtistsDBDir()
        dbname  = setFile(artistDBDir, "{0}-DB.p".format(modVal))     
        dbdata  = getFile(dbname)
        nerrs = 0
        
        for artistID,artistData in dbdata.items():
            pages = artistData.pages
            if pages.more is True:
                npages = pages.tot
                if maxPages is not None:
                    npages = min([npages, maxPages])
                artistRef = artistData.url.url
                print(artistID,'\t',artistData.artist.name)
                multiValues = mulArts.getArtistNames(artistData.artist.name)
                if len(multiValues) > 1:
                    print("\tNot downloading multis: {0}".format(multiValues.keys()))
                    continue
                for p in range(2, npages+1):
                    url      = self.getArtistURL(artistRef, p)
                    savename = self.getArtistSavename(artistID, p)
                    print(artistID,'\t',url,'\t',savename)
                    if not isFile(savename):
                        self.downloadArtistURL(url=url, savename=savename, force=True, debug=True)
                        sleep(3)

# %%
al = artistsLastFM(debug=True)

# %%
#al.searchForArtist("Neil Diamond")

# %%
from artistRC import artistRC
from discogsUtils import rockcornerUtils

class artistsRockCorner(artistsBase):
    def __init__(self, debug=False):
        self.db     = "RockCorner"
        self.disc   = discogs(self.db.lower())
        self.artist = artistRC(self.disc)
        self.dutils = rockcornerUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        if artistRef.startswith("http"):
            url = artistRef
        else:
            baseURL = self.disc.discogURL
            if artistRef.startswith("/") is True:
                #print("Join", end="\t")
                url     = urllib.parse.urljoin(baseURL, quote(artistRef[1:]))
                #print(url)
            else:
                url     = urllib.parse.urljoin(baseURL, quote(artistRef))
                        
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):

        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("search?q=", quote(artist)))
                    

        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}

        songs = bsdata.findAll("article", {"class": "bgl0"}) + bsdata.findAll("article", {"class": "bgl1"})
        for i,song in enumerate(songs):
            label     = song.find("label")
            if label is None:
                continue
            name      = label.text
            ref       = song.find("a").attrs['href']
            artistURL = "/".join(ref.split("/")[:2])

            #print(name,'\t',url,'\t',artistID)
            if artistDB.get(artistURL) is None:
                artistDB[artistURL] = {"N": 0, "Name": name}
            artistDB[artistURL]["N"] += 1


        if self.debug:
            print("Found {0} artists".format(len(artistDB)))

        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1

            name     = hrefData["Name"]
            discID   = self.dutils.getArtistID(name)
            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
ar = artistsRockCorner(debug=True)

# %%
#ar.searchForArtist("Neil Diamond")

# %%
from artistRM import artistRM
from discogsUtils import rateyourmusicUtils

class artistsRateYourMusic(artistsBase):
    def __init__(self, debug=False):
        self.db     = "RateYourMusic"
        self.disc   = discogs(self.db.lower())
        self.artist = artistRM(self.disc)
        self.dutils = rateyourmusicUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        return

# %%
am = artistsRateYourMusic(debug=True)

# %%
from artistCL import artistCL
from discogsUtils import cdandlpUtils

class artistsCDandLP(artistsBase):
    def __init__(self, debug=False):
        self.db     = "CDandLP"
        self.disc   = discogs(self.db.lower())
        self.artist = artistCL(self.disc)
        self.dutils = cdandlpUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        #print("getArtistURL(",artistRef,")")
        if artistRef.startswith("http"):
            url = artistRef
        else:
            baseURL = self.disc.discogURL
            if artistRef.startswith("/") is True:
                #print("Join", end="\t")
                url     = urllib.parse.urljoin(baseURL, quote(artistRef[1:]))
                #print(url)
            else:
                url     = urllib.parse.urljoin(baseURL, quote(artistRef))
        
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("?q=", quote(artist)))


        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}
        
        descrs = bsdata.findAll("div", {"class": "listingDescription"})
        for descr in descrs:
            refs = descr.findAll("a", {"class": "listingTitle"})
            for ref in refs:
                url      = ref.attrs['href']
                fullurl  = "/".join(url.split("/")[:-4])
                fullurl  = "{0}/artist".format(fullurl)
                artistID = self.dutils.getArtistID(fullurl)
                if artistDB.get(fullurl) is None:
                    artistDB[fullurl] = {"N": 0, "ID": artistID}
                artistDB[fullurl]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1
        
            discID   = hrefData["ID"]
            url      = href
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url,'\t',savename)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
ac = artistsCDandLP(debug=True)

# %%
#ac.searchForArtist("Neil Diamond")

# %%
from artistCL import artistCL
from discogsUtils import acebootlegsUtils

class artistsAceBootlegs(artistsBase):
    def __init__(self, debug=False):
        self.db     = "AceBootlegs"
        self.disc   = discogs(self.db.lower())
        self.artist = artistAB(self.disc)
        self.dutils = acebootlegsUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url
    
    def getMainSavename(self):
        artistDir = self.disc.getArtistsDir()
        savename  = setFile(artistDir, "main.p")
        return savename
    
    
    ##################################################################################################################
    # Main
    ##################################################################################################################
    def downloadMainArtists(self, force=False, debug=False, sleeptime=2):        
        savename = self.getMainSavename()
        
        ## Parse data
        bsdata = getHTML(savename)        
        artistDB  = {}
        
        
        ## Find and Download Artists
        categories = bsdata.find("div", {"class": "sidebar-widget widget_categories"})
        if categories is None:
            raise ValueError("Cannot find categories!")
        uls = categories.findAll("ul")
        for ul in uls:
            lis = ul.findAll("li")
            for i, li in enumerate(lis):
                try:
                    catitem = li.attrs["class"][1]
                except:
                    raise ValueError("Cannot find list class item: {0}".format(li))
                ref  = li.find("a")
                if ref is None:
                    raise ValueError("Cannot find list link!")
                try:
                    href = ref.attrs['href']
                except:
                    raise ValueError("Cannot find list href!")

                # check for artist
                artistName = href.split('/')[-2]
                try:
                    int(artistName)
                    continue
                except:
                    if artistName.find("parent-category-ii") == -1:
                        pass
                    else:
                        continue

                # get artist ID
                artistID = catitem.split('-')[-1]
                try:
                    int(artistID)
                except:
                    continue


                if force is False and isFile(savename):
                    print("{0} exists.".format(savename))
                    continue
            
                url = href
                savename = self.getArtistSavename(artistID)
                print(i,'\t',artistID,'\t',artistName,'\t',savename)
                self.downloadArtistURL(url=url, savename=savename, parse=False)

                
        
        

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        return

# %%
aa = artistsAceBootlegs(debug=True)

# %%
from artistDP import artistDP
from discogsUtils import datpiffUtils

class artistsDatPiff(artistsBase):
    def __init__(self, debug=False):
        self.db     = "DatPiff"
        self.disc   = discogs(self.db.lower())
        self.artist = artistDP(self.disc)
        self.dutils = datpiffUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url
    

    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        
        baseURL = "https://www.datpiff.com/"
        extra   = "mixtapes-search?criteria={0}&sort=relevance".format(quote(artist))

        url = urllib.parse.urljoin(baseURL, extra)
        print("\tSearch URL: {0}".format(url))
                    
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = []

        contentdivs = bsdata.findAll("div", {"class": "contentItem"})
        for i,contentdiv in enumerate(contentdivs):
            artistDiv = contentdiv.find("div", {"class": "artist"})
            if artistDiv is None:
                continue
            artistName = artistDiv.text

            albumDiv = contentdiv.find("div", {"class": "title"})
            if albumDiv is None:
                continue
            albumName = albumDiv.text
            try:
                albumURL  = albumDiv.find("a").attrs['href']
            except:
                albumURL  = None
                
            #artistID = self.discogsUtils.getArtistID(artistName)

            artistDB.append({"ArtistName": artistName, "AlbumName": albumName, "AlbumURL": albumURL})
        

        artistID = self.discogsUtils.getArtistID(artist)
        page     = 1
        savename = self.getArtistSavename(artistID, page)
        while isFile(savename):
            page += 1
            savename = self.getArtistSavename(artistID, page)
        print("Saving {0} new artist media to {1}".format(len(artistDB), savename))
        saveJoblib(data=artistDB, filename=savename, compress=True)

# %%
ad = artistsDatPiff(debug=True)

# %%
from artistMS import artistMS
from discogsUtils import musicstackUtils
from searchUtils import findPatternExt
from fileUtils import getBaseFilename


class artistsMusicStack(artistsBase):
    def __init__(self, debug=False):
        self.db     = "MusicStack"
        self.disc   = discogs(self.db.lower())
        self.artist = artistMS(self.disc)
        self.dutils = musicstackUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url
    

    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist=None):
        files = findPatternExt("/Users/tgadfort/Downloads/", pattern="MusicStack", ext=".html")
        for ifile in files:
            fname  = getBaseFilename(ifile)
            artist = fname[:fname.find(" Vinyl Records")]
            self.parseSearchForArtist(artist=artist, ifile=ifile)
    
    def parseSearchForArtist(self, artist, ifile):

        ## Parse data
        bsdata = getHTML(ifile)
        
        artistDB  = []

        tables = bsdata.findAll("table")
        if self.debug:
            print("Found {0} tables".format(len(tables)))
        for i,table in enumerate(tables):
            trs = table.findAll("tr")
            jj = 0
            headers = None
            values  = []
            for j,tr in enumerate(trs):
                tds  = tr.findAll("td")
                #print('\t',len(tds))
                #tds  = [list(td.strings) for td in tds]
                if len(tds) == 8:
                    if jj == 0:
                        headers = tds
                        if self.debug:
                            print("  Found Header: {0}".format(headers))
                    else:
                        values.append(tds)
                        if self.debug:
                            print("  Found Value: {0}".format(tds))

                    jj += 1

            if headers is not None:
                keys = []
                for header in headers:
                    b = header.find("b")
                    if b is None:
                        keys.append(str(len(keys)))
                    else:
                        txt = b.text.strip()
                        keys.append(txt)
                        
                if self.debug:
                    print("  Keys: {0}".format(keys))
                    print("  Values: {0}".format(len(values)))


                for value in values:
                    value = [x for ix,x in enumerate(value) if keys[ix] in ["Artist", "Title"]]
                    album = dict(zip(["Artist", "Title"], value))
                    album["Artist"] = album["Artist"].text
                    album["Album"]  = {"Name": album["Title"].text}
                    try:
                        album["Album"]["URL"] = album["Title"].find("a").attrs['href']
                    except:
                        album["Album"]["URL"] = None
                    del album["Title"]
                    artistDB.append({"ArtistName": album["Artist"], "AlbumName": album["Album"]["Name"], "AlbumURL": album["Album"]["URL"]})
                break

        artistID = self.dutils.getArtistID(artist)
        page     = 1
        savename = self.getArtistSavename(artistID, page)
        while isFile(savename) and False:
            page += 1
            savename = self.getArtistSavename(artistID, page)
        print("Saving {0} new artist media to {1}".format(len(artistDB), savename))
        saveJoblib(data=artistDB, filename=savename, compress=True)

# %%
am = artistsMusicStack(debug=False)
am.searchForArtist()
