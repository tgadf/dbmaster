# %% [markdown]
# # Discogs

# %%
######################################################
# Juypter
######################################################
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))


######################################################
# General
######################################################
from ioUtils import saveJoblib, loadJoblib, saveFile, getFile
import urllib
from urllib.parse import quote
from timeUtils import clock, elapsed
from fsUtils import moveFile, setFile, setDir, setSubDir, isFile, isDir, mkDir
from ioUtils import getFile, saveFile
from fileUtils import getFileBasics, getBasename
from webUtils import getWebData, getHTML, getURL
from time import sleep
import time
from multiprocessing import Pool


######################################################
# Music Stuff
######################################################
from dbBase import dbBase
from multiArtist import multiartist
from myMusicDBMap import myMusicDBMap
from mainDB import mainDB
from parseDBArtistsData import parseDBArtistsData


######################################################
# Versions
######################################################
import sys
print("Python: {0}".format(sys.version))
import datetime as dt
start = dt.datetime.now()
print("Notebook Last Run Initiated: "+str(start))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# Python: 3.7.7 (default, Mar 26 2020, 10:32:53)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# Notebook Last Run Initiated: 2020-09-10 23:04:17.445644

# %% [markdown]
# # Initialize

# %%
mdb = myMusicDBMap(debug=True)
# Out:
# Creating myMusicDBMap()
#    Loading my music db map: /Users/tgadfort/opt/anaconda3/envs/py37/musicdb/myMusicMap.p
#    DB keys: ['Discogs', 'AllMusic', 'MusicBrainz', 'AceBootlegs', 'RateYourMusic', 'LastFM', 'DatPiff', 'RockCorner', 'CDandLP', 'MusicStack', 'MetalStorm']
# Found 4435 artist entries
# Counter({'Discogs': 4327, 'AllMusic': 4198, 'MusicBrainz': 4022, 'LastFM': 3298, 'CDandLP': 759, 'DatPiff': 550, 'RockCorner': 511, 'AceBootlegs': 179, 'RateYourMusic': 68, 'MusicStack': 5, 'MetalStorm': 0})
# Counter({'Discogs': 4327, 'AllMusic': 4198, 'MusicBrainz': 4022, 'LastFM': 3298, 'CDandLP': 759, 'DatPiff': 550, 'RockCorner': 511, 'AceBootlegs': 179, 'RateYourMusic': 68, 'MusicStack': 5, 'MetalStorm': 0})

# %% [markdown]
# # Search

# %%
maindb = mainDB(mdb=mdb, create=False, debug=True)
dbdata = maindb.dbdata
# Out:
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   datpiff   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RockCorner
#   Creating Database Records for DatPiff
#   Creating Database Records for AceBootlegs
#   Creating Database Records for CDandLP
#   Creating Database Records for RateYourMusic
#   Creating Database Records for MusicStack
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RockCorner, DatPiff, AceBootlegs, CDandLP, RateYourMusic, MusicStack

# %%
noMatches = ['Joey Lawrence',
 'John Parr',
 'I Am Kloot',
 'Razorlight',
 'Jennifer Love Hewitt',
 'Joe Diffie',
 'Supergrass',
 'Tammy Wynette']

# %%
print(len(noMatches))
#dbs = ['Discogs', 'MusicBrainz', 'LastFM']
dbs = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
dbs = ['AllMusic']
#dbs = ['AllMusic', 'Discogs', 'MusicBrainz', 'LastFM']
dbs = ['AllMusic', 'Discogs', 'MusicBrainz']

#noMatches=['Go-A', 'PM', 'Qango']

maindb = mainDB(mdb=mdb, create=True, debug=True)
pdb = parseDBArtistsData(maindb=maindb)

from time import sleep
maxI = -1
for db in dbs:
    print(db)
    for i,artist in enumerate(noMatches):
        print("="*100)
        print("="*100)
        print(i,'/',len(noMatches),'\t',artist)
        print("="*100)
        print(i,'/',len(noMatches),'\t',artist,'===>',db)
        try:
            dbdata[db]["Artists"].searchForArtist(artist, force=True)
        except:
            sleep(5)
# Out:
# 8
# Setting Basic Database Objects
# =========================   discogs   =========================
# =========================   allmusic   =========================
# =========================   musicbrainz   =========================
# =========================   lastfm   =========================
# =========================   rockcorner   =========================
# =========================   datpiff   =========================
# =========================   acebootlegs   =========================
# =========================   cdandlp   =========================
# =========================   rateyourmusic   =========================
# =========================   musicstack   =========================
#   Creating Database Records for Discogs
#   Creating Database Records for AllMusic
#   Creating Database Records for MusicBrainz
#   Creating Database Records for LastFM
#   Creating Database Records for RockCorner
#   Creating Database Records for DatPiff
#   Creating Database Records for AceBootlegs
#   Creating Database Records for CDandLP
#   Creating Database Records for RateYourMusic
#   Creating Database Records for MusicStack
# Available DBs: Discogs, AllMusic, MusicBrainz, LastFM, RockCorner, DatPiff, AceBootlegs, CDandLP, RateYourMusic, MusicStack
# AllMusic
# ====================================================================================================
# ====================================================================================================
# 0 / 8 	 Joey Lawrence
# ====================================================================================================
# 0 / 8 	 Joey Lawrence ===> AllMusic
#
#
# ===================== Searching For Joey Lawrence =====================
# 1 / 20 	: 0000213272 	 https://www.allmusic.com/artist/joey-lawrence-mn0000213272/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/72/0000213272.p (force=True)
#   --> This file is 16.9kB.
# Done. Sleeping for 2 seconds
# 2 / 20 	: 0001433055 	 https://www.allmusic.com/artist/joey-lawrence-myron-mn0001433055/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/55/0001433055.p (force=True)
#   --> This file is 14.6kB.
# Done. Sleeping for 2 seconds
# 3 / 20 	: 0001209010 	 https://www.allmusic.com/artist/j-lawrence-cook-mn0001209010/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/10/0001209010.p (force=True)
#   --> This file is 13.8kB.
# Done. Sleeping for 2 seconds
# 4 / 20 	: 0001296789 	 https://www.allmusic.com/artist/j-lawrence-mn0001296789/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/89/0001296789.p (force=True)
#   --> This file is 14.0kB.
# Done. Sleeping for 2 seconds
# 5 / 20 	: 0000410107 	 https://www.allmusic.com/artist/lawrence-j-clark-mn0000410107/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/7/0000410107.p (force=True)
#   --> This file is 15.6kB.
# Done. Sleeping for 2 seconds
# 6 / 20 	: 0000784450 	 https://www.allmusic.com/artist/lawrence-j-cook-mn0000784450/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/50/0000784450.p (force=True)
#   --> This file is 13.8kB.
# Done. Sleeping for 2 seconds
# 7 / 20 	: 0002032226 	 https://www.allmusic.com/artist/lawrence-j-worthington-mn0002032226/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic
discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/41/0002479741.p (force=True)
#   --> This file is 15.8kB.
# Done. Sleeping for 2 seconds
# 6 / 20 	: 0002915823 	 https://www.allmusic.com/artist/i-am-war-mn0002915823/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/23/0002915823.p (force=True)
#   --> This file is 15.3kB.
# Done. Sleeping for 2 seconds
# 7 / 20 	: 0003385344 	 https://www.allmusic.com/artist/i-am-harlequin-mn0003385344/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/44/0003385344.p (force=True)
#   --> This file is 15.8kB.
# Done. Sleeping for 2 seconds
# 8 / 20 	: 0000206108 	 https://www.allmusic.com/artist/i-am-ghost-mn0000206108/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/8/0000206108.p (force=True)
#   --> This file is 17.2kB.
# Done. Sleeping for 2 seconds
# 9 / 20 	: 0002588403 	 https://www.allmusic.com/artist/i-am-giant-mn0002588403/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/3/0002588403.p (force=True)
#   --> This file is 16.4kB.
# Done. Sleeping for 2 seconds
# 10 / 20 	: 0003349869 	 https://www.allmusic.com/artist/i-am-they-mn0003349869/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/69/0003349869.p (force=True)
#   --> This file is 16.0kB.
# Done. Sleeping for 2 seconds
# 11 / 20 	: 0002588171 	 https://www.allmusic.com/artist/i-am-empire-mn0002588171/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/71/0002588171.p (force=True)
#   --> This file is 16.7kB.
# Done. Sleeping for 2 seconds
# 12 / 20 	: 0003508281 	 https://www.allmusic.com/artist/i-am-karate-mn0003508281/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/81/0003508281.p (force=True)
#   --> This file is 15.8kB.
# Done. Sleeping for 2 seconds
# 13 / 20 	: 0000260604 	 https://www.allmusic.com/artist/i-am-spoonbender-mn0000260604/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/4/0000260604.p (force=True)
#   --> This file is 16.4kB.
# Done. Sleeping for 2 seconds
# 14 / 20 	: 0001000878 	 https://www.allmusic.com/artist/i-am-alaska-mn0001000878/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/78/0001000878.p (force=True)
#   --> This file is 14.8kB.
# Done. Sleeping for 2 seconds
# 15 / 20 	: 0001580399 	 https://www.allmusic.com/artist/i-am-bones-mn0001580399/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/99/0001580399.p (force=True)
#   --> This file is 15.0kB.
# Done. Sleeping for 2 seconds
# 16 / 20 	: 0001584117 	 https://www.allmusic.com/artist/i-am-abomination-mn0001584117/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/17/0001584117.p (force=True)
#   --> This file is 15.1kB.
# Done. Sleeping for 2 seconds
# 17 / 20 	: 0002460021 	 https://www.allmusic.com/artist/i-am-arrows-mn0002460021/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/21/0002460021.p (force=True)
#   --> This file is 15.6kB.
# Done. Sleeping for 2 seconds
# 18 / 20 	: 0003215038 	 https://www.allmusic.com/artist/i-am-aisha-mn0003215038/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/38/0003215038.p (force=True)
#   --> This file is 15.5kB.
# Done. Sleeping for 2 seconds
# 19 / 20 	: 0003322285 	 https://www.allmusic.com/artist/i-am-king-mn0003322285/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/85/0003322285.p (force=True)
#   --> This file is 14.8kB.
# Done. Sleeping for 2 seconds
# 20 / 20 	: 0000540904 	 https://www.allmusic.com/artist/i-am-the-ocean-mn0000540904/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/4/0000540904.p (force=True)
#   --> This file is 16.3kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 3 / 8 	 Razorlight
# ====================================================================================================
# 3 / 8 	 Razorlight ===> AllMusic
#
#
# ===================== Searching For Razorlight =====================
# 1 / 2 	: 0000242578 	 https://www.allmusic.com/artist/razorlight-mn0000242578/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/78/0000242578.p (force=True)
#   --> This file is 20.8kB.
# Done. Sleeping for 2 seconds
# 2 / 2 	: 0000340053 	 https://www.allmusic.com/artist/rosarioledo-mn0000340053/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/53/0000340053.p (force=True)
#   --> This file is 13.1kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 4 / 8 	 Jennifer Love Hewitt
# ====================================================================================================
# 4 / 8 	 Jennifer Love Hewitt ===> AllMusic
#
#
# ===================== Searching For Jennifer Love Hewitt =====================
# 1 / 4 	: 0000317571 	 https://www.allmusic.com/artist/jennifer-love-hewitt-mn0000317571/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/71/0000317571.p (force=True)
#   --> This file is 17.8kB.
# Done. Sleeping for 2 seconds
# 2 / 4 	: 0001685631 	 https://www.allmusic.com/artist/jennifer-love-hewitt-chris-canute-mn0001685631/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/31/0001685631.p (force=True)
#   --> This file is 12.9kB.
# Done. Sleeping for 2 seconds
# 3 / 4 	: 0001848578 	 https://www.allmusic.com/artist/jennifer-love-mn0001848578/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/78/0001848578.p (force=True)
#   --> This file is 14.9kB.
# Done. Sleeping for 2 seconds
# 4 / 4 	: 0002789586 	 https://www.allmusic.com/artist/jennifer-hewitt-mn0002789586/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/86/0002789586.p (force=True)
#   --> This file is 14.6kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 5 / 8 	 Joe Diffie
# ====================================================================================================
# 5 / 8 	 Joe Diffie ===> AllMusic
#
#
# ===================== Searching For Joe Diffie =====================
# 1 / 19 	: 0000787960 	 https://www.allmusic.com/artist/joe-diffie-mn0000787960/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/60/0000787960.p (force=True)
#   --> This file is 24.6kB.
# Done. Sleeping for 2 seconds
# 2 / 19 	: 0002575232 	 https://www.allmusic.com/artist/joe-parker-diffie-mn0002575232/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/32/0002575232.p (force=True)
#   --> This file is 13.4kB.
# Done. Sleeping for 2 seconds
# 3 / 19 	: 0000712810 	 https://www.allmusic.com/artist/joe-deveau-mn0000712810/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/10/0000712810.p (force=True)
#   --> This file is 16.0kB.
# Done. Sleeping for 2 seconds
# 4 / 19 	: 0000150689 	 https://www.allmusic.com/artist/joe-davis-mn0000150689/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/89/0000150689.p (force=True)
#   --> This file is 15.6kB.
# Done. Sleeping for 2 seconds
# 5 / 19 	: 0000787911 	 https://www.allmusic.com/artist/joe-davi-mn0000787911/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/11/0000787911.p (force=True)
#   --> This file is 14.0kB.
# Done. Sleeping for 2 seconds
# 6 / 19 	: 0001092270 	 https://www.allmusic.com/artist/joe-diffy-mn0001092270/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/70/0001092270.p (force=True)
#   --> This file is 14.0kB.
# Done. Sleeping for 2 seconds
# 7 / 19 	: 0001308851 	 https://www.allmusic.com/artist/ev-body-mn0001308851/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/51/0001308851.p (force=True)
#   --> This file is 14.5kB.
# Done. Sleeping for 2 seconds
# 8 / 19 	: 0001316832 	 https://www.allmusic.com/artist/joe-diffy-mn0001316832/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/32/0001316832.p (force=True)
#   --> This file is 14.0kB.
# Done. Sleeping for 2 seconds
# 9 / 19 	: 0001320718 	 https://www.allmusic.com/artist/joe-davis-mn0001320718/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/18/0001320718.p (force=True)
#   --> This file is 13.8kB.
# Done. Sleeping for 2 seconds
#
discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/33/0001923433.p (force=True)
#   --> This file is 14.6kB.
# Done. Sleeping for 2 seconds
# 6 / 19 	: 0002570911 	 https://www.allmusic.com/artist/tammy-wynot-mn0002570911/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/11/0002570911.p (force=True)
#   --> This file is 14.9kB.
# Done. Sleeping for 2 seconds
# 7 / 19 	: 0000864209 	 https://www.allmusic.com/artist/neil-diamond-mn0000864209/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/9/0000864209.p (force=True)
#   --> This file is 42.8kB.
# Done. Sleeping for 2 seconds
# 8 / 19 	: 0000138520 	 https://www.allmusic.com/artist/the-damned-mn0000138520/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/20/0000138520.p (force=True)
#   --> This file is 35.5kB.
# Done. Sleeping for 2 seconds
# 9 / 19 	: 0000172176 	 https://www.allmusic.com/artist/dr-demento-mn0000172176/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/76/0000172176.p (force=True)
#   --> This file is 20.4kB.
# Done. Sleeping for 2 seconds
# 10 / 19 	: 0000253098 	 https://www.allmusic.com/artist/diamanda-gal%C3%A1s-mn0000253098/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/98/0000253098.p (force=True)
#   --> This file is 20.8kB.
# Done. Sleeping for 2 seconds
# 11 / 19 	: 0000082742 	 https://www.allmusic.com/artist/iris-dement-mn0000082742/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/42/0000082742.p (force=True)
#   --> This file is 17.9kB.
# Done. Sleeping for 2 seconds
# 12 / 19 	: 0000251604 	 https://www.allmusic.com/artist/diamond-head-mn0000251604/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/4/0000251604.p (force=True)
#   --> This file is 22.0kB.
# Done. Sleeping for 2 seconds
# 13 / 19 	: 0000770007 	 https://www.allmusic.com/artist/king-diamond-mn0000770007/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/7/0000770007.p (force=True)
#   --> This file is 22.4kB.
# Done. Sleeping for 2 seconds
# 14 / 19 	: 0000136982 	 https://www.allmusic.com/artist/tammy-grimes-mn0000136982/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/82/0000136982.p (force=True)
#   --> This file is 18.6kB.
# Done. Sleeping for 2 seconds
# 15 / 19 	: 0000254827 	 https://www.allmusic.com/artist/diamond-rio-mn0000254827/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/27/0000254827.p (force=True)
#   --> This file is 22.5kB.
# Done. Sleeping for 2 seconds
# 16 / 19 	: 0000212230 	 https://www.allmusic.com/artist/los-tres-diamantes-mn0000212230/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/30/0000212230.p (force=True)
#   --> This file is 23.0kB.
# Done. Sleeping for 2 seconds
# 17 / 19 	: 0000474764 	 https://www.allmusic.com/artist/the-mighty-diamonds-mn0000474764/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/64/0000474764.p (force=True)
#   --> This file is 23.9kB.
# Done. Sleeping for 2 seconds
# 18 / 19 	: 0002146541 	 https://www.allmusic.com/artist/marina-and-the-diamonds-mn0002146541/discography/all
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-allmusic/41/0002146541.p (force=True)
#   --> This file is 19.0kB.
# Done. Sleeping for 2 seconds
# 19 / 19 	: 0000164156 	 https://www.allmusic.com/artist/tammy-cochran-mn0000164156/discography/all
# Saving /Volumes/Piggy/Discog/artists-allmusic/56/0000164156.p (force=True)
#   --> This file is 17.1kB.
# Done. Sleeping for 2 seconds
# Discogs
# ====================================================================================================
# ====================================================================================================
# 0 / 8 	 Joey Lawrence
# ====================================================================================================
# 0 / 8 	 Joey Lawrence ===> Discogs
#
#
# ===================== Searching For Joey Lawrence =====================
# 2 / 14 	: 6 	 https://www.discogs.com/artist/346714-Joey-Lawrence?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/14/346714.p (force=True)
#   --> This file is 23.4kB.
# Done. Sleeping for 2 seconds
# 3 / 14 	: 7 	 https://www.discogs.com/artist/3691259-Joey-Lawrence-3?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/59/3691259.p (force=True)
#   --> This file is 16.9kB.
# Done. Sleeping for 2 seconds
# 4 / 14 	: 7 	 https://www.discogs.com/artist/3662015-Joey-Lawrence-2?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/15/3662015.p (force=True)
#   --> This file is 16.1kB.
# Done. Sleeping for 2 seconds
# 5 / 14 	: 7 	 https://www.discogs.com/artist/1854816-Joey-Argiro?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/16/1854816.p (force=True)
#   --> This file is 18.3kB.
# Done. Sleeping for 2 seconds
# 6 / 14 	: 7 	 https://www.discogs.com/artist/6189856-Matt-Lawrence-6?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/56/6189856.p (force=True)
#   --> This file is 15.6kB.
# Done. Sleeping for 2 seconds
# 7 / 14 	: 6 	 https://www.discogs.com/artist/320636-Anal-Blast?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/36/320636.p (force=True)
#   --> This file is 20.4kB.
# Done. Sleeping for 2 seconds
# 8 / 14 	: 6 	 https://www.discogs.com/artist/674589-Artie-Singer?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/89/674589.p (force=True)
#   --> This file is 17.1kB.
# Done. Sleeping for 2 seconds
# 9 / 14 	: 6 	 https://www.discogs.com/artist/175132-Joe-Perry?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/32/175132.p (force=True)
#   --> This file is 22.4kB.
# Done. Sleeping for 2 seconds
# 10 / 14 	: 6 	 https://www.discogs.com/artist/294198-Jo-Ann-Castle?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/98/294198.p (force=True)
#   --> This file is 28.0kB.
# Done. Sleeping for 2 seconds
# 11 / 14 	: 7 	 https://www.discogs.com/artist/6184670-Westbound-Sign?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/70/6184670.p (force=True)
#   --> This file is 15.6kB.
# Done. Sleeping for 2 seconds
# 12 / 14 	: 7 	 https://www.discogs.com/artist/4664843-Craig-Ebel?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/43/4664843.p (force=True)
#   --> This file is 16.9kB.
# Done. Sleeping for 2 seconds
# 13 / 14 	: 7 	 https://www.discogs.com/artist/4483986-Daniel-Waldis?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/86/4483986.p (force=True)
#   --> This file is 16.9kB.
# Done. Sleeping for 2 seconds
# 14 / 14 	: 7 	 https://www.discogs.com/artist/3667570-Kill-Van-Kull?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/70/3667570.p (force=True)
#   --> This file is 23.6kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 1 / 8 	 John Parr
# ====================================================================================================
# 1 / 8 	 John Parr ===> Discogs
#
#
# ===================== Searching For John Parr =====================
# 2 / 26 	: 6 	 https://www.discogs.com/artist/325232-John-Parr?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/32/325232.p (force=True)
#   --> This file is 30.8kB.
# Done. Sleeping for 2 seconds
# 3 / 26 	: 6 	 https://www.discogs.com/artist/401682-John-Parricelli?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/82/401682.p (force=True)
#   --> This file is 20.1kB.
# Done. Sleeping for 2 seconds
# 4 / 26 	: 6 	 https://www.discogs.com/artist/352302-John-Parrish?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/2/352302.p (force=True)
#   --> This file is 16.1kB.
# Done. Sleeping for 2 seconds
# 5 / 26 	: 6 	 https://www.discogs.com/artist/414341-John-Parrish-2?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/41/414341.p (force=True)
#   --> This file is 23.5kB.
# Done. Sleeping for 2 seconds
# 6 / 26 	: 6 	 https://www.discogs.com/artist/776950-John-Parr-2?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/50/776950.p (force=True)
#   --> This file is 18.2kB.
# Done. Sleeping for 2 seconds
# 7 / 26 	: 7 	 https://www.discogs.com/artist/5537548-John-Parr-Band?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/48/5537548.p (force=True)
#   --> This file is 16.1kB.
# Done. Sleeping for 2 seconds
# 8 / 26 	: 7 	 https://www.discogs.com/artist/1851958-John-Parr-3?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/58/1851958.p (force=True)
#   --> This file is 15.7kB.
# Done. Sleeping for 2 seconds
# 9 / 26 	: 7 	 https://www.discogs.com/artist/1351151-John-Parry-2?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/51/1351151.p (force=True)
#   --> This file is 16.0kB.
# Done. Sleeping for 2 seconds
# 10 / 26 	: 7 	 https://www.discogs.com/artist/2368588-John-Parra?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/88/2368588.p (force=True)
#   --> This file is 16.0kB.
# Done. Sleeping for 2 seconds
# 11 / 26 	: 6 	 https://www.discogs.com/artist/488646-John-Parry?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/46/488646.p (force=True)
#   --> This file is 15.5kB.
# Done. Sleeping for 2 seconds
# 12 / 26 	: 7 	 https://www.discogs.com/artist/5759125-John-Parrot-2?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/25/5759125.p (force=True)
#   --> This file is 15.4kB.
# Done. Sleeping for 2 seconds
# 13 / 26 	: 7 	 https://www.discogs.com/artist/7111247-John-Parry-11?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/47/7111247.p (force=True)
#   --> This file is 23.8kB.
# Done. Sleeping for 2 seconds
# 14 / 26 	: 7 	 https://www.discogs.com/artist/7344384-John-Parry-14?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/84/7344384.p (force=True)
#   --> This file is 15.6kB.
# Done. Sleeping for 2 seconds
# 15 / 26 	: 7 	 https://www.discogs.com/artist/5934977-John-Parry-8?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/77/5934977.p (force=True)
#   --> This file is 15.5kB.
# Done. Sleeping for 2 seconds
# 16 / 26 	: 6 	 https://www.discogs.com/artist/760681-John-Parrachini?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/81/760681.p (force=True)
#   --> This file is 15.4kB.
# Done. Sleeping for 2 seconds
# 17 / 26 	: 7 	 https://www.discogs.com/artist/4957971-John-Parrot?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/71/4957971.p (force=True)
#   --> This file is 15.3kB.
# Done. Sleeping for 2 seconds
# 18 / 26 	: 7 	 https://www.discogs.com/artist/1989915-John-Parrott?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/15/1989915.p (force=True)
#   --> This file is 16.6kB.
# Done. Sleeping for 2 seconds
# 19 / 26 	: 7 	 https://www.discogs.com/artist/3264738-John-Pazz-Parry?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/38/3264738.p (force=True)
#   --> This file is 16.5kB.
# Done. Sleeping for 2 seconds
# 20 / 26 	: 7 	 https://www.discogs.com/artist/1378807-John-Parry-3?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/7/1378807.p (force=True)
#   --> This file is 17.1kB.
# Done. Sleeping for 2 seconds
# 21 / 26 	: 7 	 https://www.discogs.com/artist/7344382-John-Parry-13?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/82/7344382.p (force=True)
#   --> This file is 16.0kB.
# Done. Sleeping for 2 seconds
# 22 / 26 	: 7 	 https://www.discogs.com/artist/2387054-John-D-Parron?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/54/2387054.p (force=True)
#   --> This file is 15.6kB.
# Done. Sleeping for 2 seconds
# 23 / 26 	: 7 	 https://www.discogs.com/artist/2648742-John-Parry-Mainwaring?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/42/2648742.p (force=True)
#   --> This file is 15.5kB.
# Done. Sleeping for 2 seconds
# 24 / 26 	: 7 	 https://www.discogs.com/artist/1094234-John-Parris?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/34/1094234.p (force=True)
#   --> This file is 16.2kB.
# Done. Sleeping for 2 seconds
# 25 / 26 	: 7 	 https://www.discogs.com/artist/2798781-Johnny-Parr?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/81/2798781.p (force=True)
#   --> This file is 16.8kB.
# Done. Sleeping for 2 seconds
# 26 / 26 	: 7 	 https://www.discogs.com/artist/3654125-John-Parrendo?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/25/3654125.p (force=True)
#   --> This file is 17.6kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 2 / 8 	 I Am Kloot
# ====================================================================================================
# 2 / 8 	 I Am Kloot ===> Discogs
#
#
# ===================== Searching For I Am Kloot =====================
# 2 / 10 	: 5 	 https://www.discogs.com/artist/83086-I-Am-Kloot?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/86/83086.p (force=True)
#   --> This file is 30.6kB.
# Done. Sleeping for 2 seconds
# 3 / 10 	: 7 	 https://www.discogs.com/artist/5432217-The-Mouth-5?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/17/5432217.p (force=True)
#   --> This file is 16.3kB.
# Done. Sleeping for 2 seconds
# 4 / 10 	: 7 	 https://www.discogs.com/artist/5119490-Army-Of-Cats?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/90/5119490.p (force=True)
#   --> This file is 16.7kB.
# Done. Sleeping for 2 seconds
# 5 / 10 	: 6 	 https://www.discogs.com/artist/338576-Staf-Verbeeck?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/76/338576.p (force=True)
#   --> This file is 72.5kB.
# Done. Sleeping for 2 seconds
# 6 / 10 	: 6 	 https://www.discogs.com/artist/497484-Simon-Britton?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/84/497484.p (force=True)
#   --> This file is 18.0kB.
# Done. Sleeping for 2 seconds
# 7 / 10 	: 7 	 https://www.discogs.com/artist/4185708-The-Peace-Collective?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/8/4185708.p (force=True)
#   --> This file is 19.1kB.
# Done. Sleeping for 2 seconds
# 8 / 10 	: 7 	 https://www.discogs.com/artist/3899157-Craig-John-Davidson?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/57/3899157.p (force=True)
#   --> This file is 17.4kB.
# Done. Sleeping for 2 seconds
# 9 / 10 	: 7 	 https://www.discogs.com/artist/1936048-Paul-Wilkes?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/48/1936048.p (force=True)
#   --> This file is 18.6kB.
# Done. Sleeping for 2 seconds
# 10 / 10 	: 7 	 https://www.discogs.com/artist/3856373-James-G-Wilson?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/73/3856373.p (force=True)
#   --> This file is 17.0kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 3 / 8 	 Razorlight
# ====================================================================================================
# 3 / 8 	 Razorlight ===> Discogs
#
#
# ===================== Searching For Razorlight =====================
# 2 / 13 	: 6 	 https://www.discogs.com/artist/270508-Razorlight?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/8/270508.p (force=True)
#   --> This file is 27.1kB.
# Done. Sleeping for 2 seconds
# 3 / 13 	: 7 	 https://www.discogs.com/artist/2519700-Smith-Burrows?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/0/2519700.p (force=True)
#   --> This file is 17.3kB.
# Done. Sleeping for 2 seconds
# 4 / 13 	: 7 	 https://www.discogs.com/artist/3173379-Kumar-Kamalagharan?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/79/3173379.p (force=True)
#   --> This file is 17.4kB.
# Done. Sleeping for 2 seconds
# 5 / 13 	: 5 	 https://www.discogs.com/artist/31213-Chris-Thomas?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/13/31213.p (force=True)
#   --> This file is 18.4kB.
# Done. Sleeping for 2 seconds
# 6 / 13 	: 6 	 https://www.discogs.com/artist/445511-The-Focus-Group?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/11/445511.p (force=True)
#   --> This file is 26.4kB.
# Done. Sleeping for 2 seconds
# 7 / 13 	: 7 	 https://www.discogs.com/artist/3173381-Roger-Morton-2?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/81/3173381.p (force=True)
#   --> This file is 19.8kB.
# Done. Sleeping for 2 seconds
# 8 / 13 	: 7 	 https://www.discogs.com/artist/1220573-Roger-Morton?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/73/1220573.p (force=True)
#   --> This file is 15.5kB.
# Done. Sleeping for 2 seconds
# 9 / 13 	: 6 	 https://www.discogs.com/artist/670509-Gareth-Johnson?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/9/670509.p (force=True)
#   --> This file is 18.2kB.
# Done. Sleeping for 2 seconds
# 10 / 13 	: 7 	 https://www.discogs.com/artist/5272662-Apeman-Spaceman?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/62/5272662.p (force=True)
#   --> This file is 16.4kB.
# Done. Sleeping for 2 seconds
# 11 / 13 	: 6 	 https://www.discogs.com/artist/444766-The-Blue-Van?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/66/444766.p (force=True)
#   --> This file is 24.7kB.
# Done. Sleeping for 2 seconds
# 12 / 13 	: 6 	 https://www.discogs.com/artist/264184-Geoff-Emerick?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/84/264184.p (force=True)
#   --> This file is 21.0kB.
# Done. Sleeping for 2 seconds
# 13 / 13 	: 7 	 https://www.discogs.com/artist/5220632-Ard-Matthews?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/32/5220632.p (force=True)
#   --> This file is 16.2kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 4 / 8 	 Jennifer Love Hewitt
# ====================================================================================================
# 4 / 8 	 Jennifer Love Hewitt ===> Discogs
#
#
# ===================== Searching For Jennifer Love Hewitt =====================
# 2 / 5 	: 6 	 https://www.discogs.com/artist/348474-Jennifer-Love-Hewitt?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/74/348474.p (force=True)
#   --> This file is 29.7kB.
# Done. Sleeping for 2 seconds
# 3 / 5 	: 6 	 https://www.discogs.com/artist/566501-Fergie-2?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/1/566501.p (force=True)
#   --> This file is 36.2kB.
# Done. Sleeping for 2 seconds
# 4 / 5 	: 6 	 https://www.discogs.com/artist/310671-Greg-Prestopino?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/71/310671.p (force=True)
#   --> This file is 17.0kB.
# Done. Sleeping for 2 seconds
# 5 / 5 	: 6 	 https://www.discogs.com/artist/193770-Bob-Thiele-Jr?sort=year%2Casc&limit=500
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-discogs/70/193770.p (force=True)
#   --> This file is 18.1kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 5 / 8 	 Joe Diffie
# ====================================================================================================
# 5 / 8 	 Joe Diffie ===> Discogs
#
#
# ...
#   --> This file is 5.3kB.
# Done. Sleeping for 2 seconds
# 17 / 100 	: 182565040986106873803599231806188139554 	 https://musicbrainz.org/artist/1bb0c900-da42-4436-866c-58fa832df3ff
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-musicbrainz/54/182565040986106873803599231806188139554.p (force=True)
#   --> This file is 5.1kB.
# Done. Sleeping for 2 seconds
# 18 / 100 	: 278620914492851742974480566796056542247 	 https://musicbrainz.org/artist/62abe77c-7f4f-4d48-9d9a-1da12f3b22ee
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-musicbrainz/47/278620914492851742974480566796056542247.p (force=True)
#   --> This file is 4.6kB.
# Done. Sleeping for 2 seconds
# 19 / 100 	: 122544255295896657712227038958318148374 	 https://musicbrainz.org/artist/9410a160-7e1e-4f7a-954f-4089f9786b79
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-musicbrainz
B.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 6 / 8 	 Supergrass
# ====================================================================================================
# 6 / 8 	 Supergrass ===> MusicBrainz
#
#
# ===================== Searching For Supergrass =====================
# 1 / 2 	: 23908949262100730911097160943870697435 	 https://musicbrainz.org/artist/6386ddff-0d13-4685-9f0a-a82bf022fb1c
# Saving /Volumes/Piggy/Discog/artists-musicbrainz/35/23908949262100730911097160943870697435.p (force=True)
#   --> This file is 10.0kB.
# Done. Sleeping for 2 seconds
# 2 / 2 	: 255844352191934527890980361046719393914 	 https://musicbrainz.org/artist/102ac56c-698b-499d-9b19-843752c69107
# Saving /Volumes/Piggy/Discog/artists-musicbrainz/14/255844352191934527890980361046719393914.p (force=True)
#   --> This file is 4.8kB.
# Done. Sleeping for 2 seconds
# ====================================================================================================
# ====================================================================================================
# 7 / 8 	 Tammy Wynette
# ====================================================================================================
# 7 / 8 	 Tammy Wynette ===> MusicBrainz
#
#
# ===================== Searching For Tammy Wynette =====================
# 1 / 100 	: 54798332627737939333955789555470373110 	 https://musicbrainz.org/artist/26fe36eb-fd75-4799-bf0f-fa502a7bcfe8
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-musicbrainz/10/54798332627737939333955789555470373110.p (force=True)
#   --> This file is 18.6kB.
# Done. Sleeping for 2 seconds
# 2 / 100 	: 59375589888371194461275723214000685032 	 https://musicbrainz.org/artist/9b280114-d3a8-4841-be28-0dde150feed1
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-musicbrainz/32/59375589888371194461275723214000685032.p (force=True)
#   --> This file is 4.5kB.
# Done. Sleeping for 2 seconds
# 3 / 100 	: 173238762342555496475816874314341291648 	 https://musicbrainz.org/artist/50c4d9b1-28f6-4f04-81e5-c7b89de396f2
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-musicbrainz/48/173238762342555496475816874314341291648.p (force=True)
#   --> This file is 4.2kB.
# Done. Sleeping for 2 seconds
# 4 / 100 	: 287743423613603082163436024446472340682 	 https://musicbrainz.org/artist/c9dc8c72-3950-4a9c-a96e-4c93610457eb
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-musicbrainz/82/287743423613603082163436024446472340682.p (force=True)
#   --> This file is 3.9kB.
# Done. Sleeping for 2 seconds
# 5 / 100 	: 269525253100102588593488649650255065259 	 https://musicbrainz.org/artist/1d41c123-8f0c-4960-8871-f9711cf6e9c7
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-musicbrainz/59/269525253100102588593488649650255065259.p (force=True)
#   --> This file is 5.8kB.
# Done. Sleeping for 2 seconds
# 6 / 100 	: 161266277470207920749712052992419021783 	 https://musicbrainz.org/artist/b508b099-624f-42a0-8e92-fb55838ea115
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-musicbrainz/83/161266277470207920749712052992419021783.p (force=True)
#   --> This file is 4.6kB.
# Done. Sleeping for 2 seconds
# 7 / 100 	: 297579502430600008578412325233571398504 	 https://musicbrainz.org/artist/13d3a217-002a-4d36-b85c-5bcf11c0ddda
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-musicbrainz/4/297579502430600008578412325233571398504.p (force=True)
#   --> This file is 5.2kB.
# Done. Sleeping for 2 seconds
# 8 / 100 	: 210005969662732848559183385724717082529 	 https://musicbrainz.org/artist/9f20106d-c174-4011-84c6-5a73a998d8c1
# Downloading again.
# Saving /Volumes/Piggy/Discog/artists-musicbrainz/29/210005969662732848559183385724717082529.p (force=True)
#   --> This file is 4.4kB.
# Done. Sleeping for 2 seconds
# 9 / 100 	: 266236782432242757639849499771019705332 	 https://musicbrainz.org/artist/c397642e-b2d5-4b7e-988e-c6b975b3db8a
# Saving /Volumes/Piggy/Discog/artists-musicbrainz
# Saving /Volumes/Piggy/Discog/artists-musicbrainz/77/94997385094319291020097991343720435977.p (force=True)
#   --> This file is 7.2kB.
# Done. Sleeping for 2 seconds
# 21 / 100 	: 153690031555703521186791830413042781853 	 https://musicbrainz.org/artist/f348cf92-3083-4a82-91ca-f1499b2e5243
# Saving /Volumes/Piggy/Discog/artists-musicbrainz/53/153690031555703521186791830413042781853.p (force=True)
#   --> This file is 4.2kB.
# Done. Sleeping for 2 seconds

# %% [markdown]
# # Download Artist Data

# %%
artsDC.downloadArtistUnofficialFromID(144998)

# %%
maindb.getBasicArtistInfo("Black Sabbath")

# %%
dbdata["Discogs"]["Artists"].downloadArtistUnofficialFromID('144998', '/artist/144998-Black-Sabbath')
#/artist/144998-Black-Sabbath?type=Unofficial&subtype=Albums&filter_anv=0"
#/artist/144998-Black-Sabbath?sort=year%2Casc&limit=500&type=Unofficial&subtype=Albums&filter_anv=0&page=1

# %%
retval = dbdata["Discogs"]["Artist"].getData("/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p")

# %%
bsdata = getHTML("/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p")

# %%
retval.get()

# %%
retval.get()['artist'].get()

# %% [markdown]
# # Music DB

# %%
https://www.discogs.com/artist/144998-Black-Sabbath?sort=year%2Casc&limit=500?type=Unofficial&subtype=Albums&filter_anv=0
https://www.discogs.com/artist/144998-Black-Sabbath?sort=year%2Casc&limit=500&type=Unofficial&subtype=Albums&filter_anv=0&page=1
    
artistIDToRef = disc.getArtistIDToRefData()

# %%
myMusicAlbumIDMap = getFile("/Users/tgadfort/Documents/code/music/musicDiscogsMap.p")

# %%
dR=0.2
rC=0.8

# %%
from time import sleep
N = len(myMusicAlbumIDMap)
for i,(artistName,artistVals) in enumerate(myMusicAlbumIDMap.items()):
    if artistName.startswith("Levl") is False:
        continue
    artistID,discogsName = artistVals
    print(i,N,'\t',artistName)
    artsDC.searchDiscogForArtist(artistName)
    artsAM.searchAllMusicForArtist(artistName)
    artsMB.searchMusicBrainzForArtist(artistName)
    sleep(3)

# %%
artistIDs = [v[0] for k,v in myMusicAlbumIDMap.items()]
arts.rmIDsFromDBs(artistIDs)

# %%
arts.parseArtistModValFiles(96, force=False)
arts.parseArtistModValExtraFiles(96)

# %%
files = [savename]
from glob import glob
from os.path import join
from fileUtils import getDirname
files += glob(join(getDirname(savename), "extra", "{0}-*.p".format(artistID)))
files

# %% [markdown]
# # Download Missing Artists

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
from discogsBase import discogs

disc  = discogs()
albs  = albums(disc)
toget = albs.findMissingArtistsFromAlbums()

from ioUtils import saveFile
saveFile(idata=toget, ifile="missingArtistsFromAlbums.p")

# %%
# %load_ext autoreload
# %autoreload
disc = discogs()
arts = artists(disc)

from ioUtils import getFile

toget = getFile(ifile="missingArtistsFromAlbums.p")

from time import sleep
togetmap  = toget['togetmap']
refstoget = toget['toget']
for ia,item in enumerate(refstoget.most_common()):
    artistID, cnt = item[0], item[1]
    ref      = togetmap[artistID]
    url      = arts.getArtistURL(ref)
    savename = arts.getArtistSavename(artistID)
    if not isFile(savename):
        try:
            print('\n{0}/{1}'.format(ia,len(refstoget)))
            retval = arts.downloadArtistURL(url, savename, debug=True)
            sleep(3)
        except:
            continue
    else:
        print("{0} known".format(savename))
            
    #print(item)
#len(togetmap)

# %% [markdown]
# # Redownload Known Artist

# %%
myMusicMap = getFile("/Users/tgadfort/Documents/code/music/myMusicMap.p")

# %%
musicMap = myMusicMap["Ladies of Soul"]
musicMap

# %%
discDCIDToRef = discDC.getArtistIDToRefData()

# %%
artistID  = musicMap['Discogs']['ID']
artistRef = discDCIDToRef.get(artistID)
artsDC.downloadArtistFromID(artistID=artistID, artistRef=artistRef, force=True)

# %% [markdown]
# # Download Unmatched Artists

# %%
matchedResults = getFile("/Users/tgadfort/Documents/code/music/multiArtists.p")

# %%
searchForArtist = {"Discogs": artsDC.searchDiscogForArtist, "AllMusic": artsAM.searchAllMusicForArtist, "MusicBrainz": artsMB.searchMusicBrainzForArtist}

# %%
from time import sleep
for i,(artistName,artistValues) in enumerate(matchedResults["PartiallyUnknown"].items()):
    if i <= 83:
        continue
    print("=========== {0} [{1}/{2}] ===========".format(artistName, i, len(matchedResults["PartiallyUnknown"])))
    for dbKey, dirval in artistValues.items():
        print(artistName,'\t',searchForArtist[dbKey])
        searchForArtist[dbKey](artistName)
        sleep(1)
    sleep(1)

# %% [markdown]
# # Missing Artists From Albums

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
from discogsBase import discogs

disc  = discogs()
albs  = albums(disc)
toget = albs.findMissingArtistsFromAlbums()

# %%
# %load_ext autoreload
# %autoreload
disc = discogs()
arts = artists(disc)

from time import sleep
togetmap  = toget['togetmap']
refstoget = toget['toget']
for ia,item in enumerate(refstoget.most_common()):
    artistID, cnt = item[0], item[1]
    ref      = togetmap[artistID]
    url      = arts.getArtistURL(ref)
    savename = arts.getArtistSavename(artistID)
    if not isFile(savename):
        try:
            _, _ = clock('\n{0}/{1}'.format(ia,len(refstoget)))
            retval = arts.downloadArtistURL(url, savename, debug=True)
        except:
            continue
    else:
        print("{0} known".format(savename))
            
    #print(item)
#len(togetmap)

# %% [markdown]
# # Artists From Search

# %%
# %load_ext autoreload
# %autoreload
disc = discogs()
arts = artists(disc)
arts.searchDiscogForArtist("World of Our Own")
#arts.searchDiscogForArtist("Continental Divide")

# %%
from ioUtils import getFile

# %%
toGet = getFile(ifile="/Users/tgadfort/Documents/code/charts/chartCounter.p", debug=True)

# %%
toGet = getFile("~/code/charts/toget.p")

# %%
for i,val in enumerate(toGet):
    if i <= 206:
        continue
    print('='*30,val,'(',i,'/',len(toGet),')','='*30)
    arts.searchDiscogForArtist(val)
    print("\n\n\n")
    sleep(2)

# %%
from time import sleep
vals  = ["The Souvenirs", "The Stand", f"The Suicide Kings", "The Supremes", "The Temptations", "The Tomcats", "The Tone", "The Tourists", "The Unseen", "The Ventures", "The Vikings", "The Violents", "The Wailers", "The Want", "The Washingtonians", "The Witches", "UB40", "Underdog", "Unearth", "Unk", "Unscarred", "Up Front", "Up In Arms", "Urban Legends"]
vals += ["The Pits", "The Pressure", "The Pretenders", "The Prodigy", "The Product", "The Receptionists", "The Retardos", "The Revelers", "The Romancers", "The Roots", "The Rosehips", "The Ruiners", "The Runaways", "The Scholars", "The Seeds", "The Shams", "The Sights", "The Sillies", "The Skunks", "The Snowmen"]
vals += ["The Invisible Men", "The Israelites", "The Ivory Coast", "The Killers", "The Manatees", "The Marquees", "The Masters", "The Matrix", "The Mixtures", "The Moves", "The Noisettes", "The Nomads", "The Orange Peels", "The Outcasts"]
vals += ["The Game", "The Generics", "The Gits", "The Go-Betweens", "The Goblins", "The Godz", "The Great Society", "The Haters", "The Hilltops", "The Hookers", "The Immortals", "The Impacts", "The Inspector", "The Invaders"]
vals += ["The Diamonds", "The Diplomats", "The Dramatics", "The Drifters", "The Dust Brothers", "The Eagles", "The Exceptions", "The Fiends", "The Fixtures", "The Frantics", "The Freeze", "The Frogs", "The Fumes"]
vals += ["The Cardigans", "The Casualties", "The Challengers", "The Chameleons", "The Cheaters", "The Chicken Hawks", "The Crash", "The Crusaders", "The Cure", "The Darts", "The Deuce Coupes"]
vals += ["The Beat", "The Beatles", "The Blood Brothers", "The Blow Up", "The Bollweevils", "The Brentwoods", "The Broadways", "The Brood", "The Business", "The Busy Signals"]
vals += ["You", "Young Money", "Young Pioneers", "Zero Zero"]
for val in vals:
    print('='*30,val,'='*30)
    try:
        arts.searchDiscogForArtist(val)
    except:
        continue
    print("\n\n\n")
    sleep(10)

# %% [markdown]
# # New Artists From Albums

# %%
# %load_ext autoreload
# %autoreload
from albums import albums

disc = discogs()
albs = albums(disc)
toget = albs.findMissingArtistsFromAlbums()

# %%
from time import sleep
togetmap  = toget['togetmap']
refstoget = toget['toget']
for ia,item in enumerate(refstoget.most_common()):
    print('\n{0}/{1}'.format(ia,len(refstoget)))
    artistID, cnt = item[0], item[1]
    ref      = togetmap[artistID]
    url      = arts.getArtistURL(ref)
    savename = arts.getArtistSavename(artistID)
    if not isFile(savename):
        try:
            arts.downloadArtistURL(url, savename, debug=True)
        except:
            continue
        sleep(2)
    #print(item)
#len(togetmap)

# %% [markdown]
# # Albums From Known People

# %%
data = getFile("/Volumes/Music/MusicDB/toget.p")

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
disc = discogs()
discdf = disc.getMasterDiscogsDB()
print(discdf.shape)
discdf = discdf[~discdf['Name'].isna()]
print(discdf.shape)

artists = list(discdf["Artist"])

_ = clock("Last Run")

# %%
def getMusicData(key, artist):
    retval = discdf[discdf[key] == artist]
    if retval.shape[0] > 0:
        return retval
    else:
        return None
    
toget={}
known={}

for ia,artistName in enumerate(data):
    #artistID = artistName
    artistID = None
    if artistID is None:
        retval = getMusicData('Name', artistName)
        if retval is not None:
            artistID = retval.index.values[0]
    modValue  = dutils.getDiscIDHashMod(discID=artistID, modval=disc.getMaxModVal())
    if toget.get(modValue) is None:
        toget[modValue] = {}
    toget[modValue][artistID] = True
        
    if ia % 100 == 0:
        print(ia,'/',len(data))

# %%
for modVal in toget.keys():
    artistIDs = toget[modVal]
    print(modVal,'\t',len(artistIDs))
    dbdata = disc.getArtistsDBModValData(modVal)
    for artistID in artistIDs:
        print(' ',artistID)
        artistData = dbdata[artistID]
        albs.downloadAlbumFromArtistData(artistID=artistID, artistData=artistData, mediaTypes=None)

# %% [markdown]
# # Albums From All Artists

# %%
# %load_ext autoreload
# %autoreload
from albums import albums
disc = discogs()
albs = albums(disc)
albs.downloadAlbumsFromArtists(maxAlbums=1, mediaTypes=None, rand=True)

# %%
maindb = mainDB(mdb=mdb, create=False)
#maindb.setDBFull() ## Do this to recreate everything
maindb.setDBKnown()
artistDBs = maindb.getKnownArtistDBs()

# %% [markdown]
# # Discogs

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsDiscogs import dbArtistsDiscogs
ad = dbArtistsDiscogs(debug=True)
#ad.searchForArtist("Dave Matthews")
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/70/420570.p"
ifile="/Users/tgadfort/Music/Discog/artists-discogs/34/386834.p"
retval = ad.getData(ifile)
print(retval.get()['artist'].get())
#ad.searchForArtist("Niel Diamond")

# %% [markdown]
# # AllMusic

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsAllMusic import dbArtistsAllMusic
am = dbArtistsAllMusic(debug=True)
#am.searchForArtist("Dave Matthews")
ifile="/Users/tgadfort/Music/Discog/artists-allmusic/61/0000687561.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/70/420570.p"
#ifile="/Users/tgadfort/Music/Discog/artists-discogs/34/386834.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # MusicBrainz

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsMusicBrainz import dbArtistsMusicBrainz
am = dbArtistsMusicBrainz(debug=True)
#am.searchForArtist("Dave Matthews")
ifile="/Users/tgadfort/Music/Discog/artists-musicbrainz/71/100112022548628725831976514629370881371.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # LastFM

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsLastFM import dbArtistsLastFM
am = dbArtistsLastFM(debug=True)
#am.searchForArtist("Dave Matthews Band")
ifile="/Users/tgadfort/Music/Discog/artists-lastfm/14/64101467014.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # RockCorner

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsRockCorner import dbArtistsRockCorner
am = dbArtistsRockCorner(debug=True)
#am.searchForArtist("Dave Matthews Band")
ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
retval = am.getData(ifile)
print(retval.get()['artist'].get())

# %% [markdown]
# # RateYourMusic

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsRockCorner import dbArtistsRockCorner
am = dbArtistsRockCorner(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # CDandLP

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsCDandLP import dbArtistsCDandLP
am = dbArtistsCDandLP(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # AceBootlegs

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsAceBootlegs import dbArtistsAceBootlegs
am = dbArtistsAceBootlegs(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # DatPiff

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsDatPiff import dbArtistsDatPiff
am = dbArtistsDatPiff(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %% [markdown]
# # MusicStack

# %%
# %load_ext autoreload
# %autoreload
from dbArtistsMusicStack import dbArtistsMusicStack
am = dbArtistsMusicStack(debug=True)
#am.searchForArtist("Dave Matthews Band")
#ifile="/Users/tgadfort/Music/Discog/artists-rockcorner/67/539215767.p"
#retval = am.getData(ifile)
#print(retval.get()['artist'].get())

# %%
ad = artistsDiscogs(debug=True)

# %%
ad = artistsDiscogs(debug=True)
ifile="/Users/tgadfort/Music/Discog/artists-discogs/98/unofficial/144998.p"
retval = ad.getData(ifile)
retval.get()['artist'].get()
ad.searchForArtist("Niel Diamond")

# %%
retval = ad.getData(ifile)
retval.get()['artist'].get()

# %%
ad.searchForArtist("Niel Diamond")

# %%
from artistAM import artistAM
from discogsUtils import allmusicUtils

class artistsAllMusic(artistsBase):
    def __init__(self, debug=False):
        self.db     = "AllMusic"
        self.disc   = discogs(self.db.lower())
        self.artist = artistAM(self.disc)
        self.dutils = allmusicUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        url = "{0}/discography/all".format(artistRef)
        return url
        
        if artistRef.startswith("http"):
            return artistRef
        else:
            baseURL = self.disc.discogURL
            url     = urllib.parse.urljoin(baseURL, quote(artistRef))
            return url

            
        if artistRef.startswith("/artist/") is False:
            print("Artist Ref needs to start with /artist/")
            return None
        
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, quote(artistRef))
        url     = urllib.parse.urljoin(url, "?sort=year%2Casc&limit=500") ## Make sure we get 500 entries)
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("artists/", quote(artist)))
                  
                    
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}
        
        uls = bsdata.findAll("ul", {"class": "search-results"})
        for ul in uls:
            lis = ul.findAll("li", {"class": "artist"})
            for li in lis:
                divs = li.findAll("div", {"class": "name"})
                for div in divs:
                    link     = div.find("a")
                    href     = link.attrs['href']
                    tooltip  = link.attrs['data-tooltip']
                    try:
                        from json import loads
                        tooltip = loads(tooltip)
                        artistID = tooltip['id']
                    except:
                        artistID = None
            
                    if artistDB.get(href) is None:
                        artistDB[href] = {"N": 0, "Name": artist}
                    artistDB[href]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1
        
            discID   = self.dutils.getArtistID(href)
            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
am = artistsAllMusic(debug=True)
#am.searchForArtist("Niel Diamond")

# %%
from artistMB import artistMB
from discogsUtils import musicbrainzUtils
from hashlib import md5

class artistsMusicBrainz(artistsBase):
    def __init__(self, debug=False):
        self.db     = "MusicBrainz"
        self.disc   = discogs(self.db.lower())
        self.artist = artistMB(self.disc)
        self.dutils = musicbrainzUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = "https://musicbrainz.org/"
        extra = "search?query={0}&type=artist&limit=100&method=indexed".format(quote(artist))

        url = urllib.parse.urljoin(baseURL, extra)         
                    
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}

        tables = bsdata.findAll("table")
        for table in tables:
            ths = table.findAll("th")
            headers = [x.text for x in ths]
            trs = table.findAll("tr")
            for tr in trs[1:]:
                tds    = tr.findAll("td")
                name   = tds[0].find('a').text
                href   = tds[0].find('a').attrs['href']
            
                if artistDB.get(href) is None:
                    artistDB[href] = {"N": 0, "Name": name}
                artistDB[href]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1

            discID   = self.dutils.getArtistID(href)
            
            uuid = href.split('/')[-1]

            m = md5()
            for val in uuid.split("-"):
                m.update(val.encode('utf-8'))
            hashval = m.hexdigest()
            discID  = str(int(hashval, 16))

            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
am = artistsMusicBrainz(debug=True)
#am.searchForArtist("Niel Diamond")

# %%
from artistLM import artistLM
from discogsUtils import lastfmUtils

class artistsLastFM(artistsBase):
    def __init__(self, debug=False):
        self.db     = "LastFM"
        self.disc   = discogs(self.db.lower())
        self.artist = artistLM(self.disc)
        self.dutils = lastfmUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        #print("getArtistURL(",artistRef,")")
        if artistRef.startswith("http"):
            url = artistRef
        else:
            baseURL = self.disc.discogURL
            if artistRef.startswith("/") is True:
                #print("Join", end="\t")
                url     = urllib.parse.urljoin(baseURL, quote(artistRef[1:]))
                #print(url)
            else:
                url     = urllib.parse.urljoin(baseURL, quote(artistRef))
            #print(url)
                
            if url.endswith("/") is False:
                url     = "{0}{1}".format(url, "/+albums?order=release_date")
            else:
                url     = "{0}{1}".format(url, "+albums?order=release_date")
                
            #print(url)
        
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("artists?q=", quote(artist)))
                    
            
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}
        
        uls = bsdata.findAll("ul", {"class": "artist-results"})
        for ul in uls:
            lis = ul.findAll("li", {"class": "artist-result"})
            for li in lis:
                h4 = li.find("h4")
                if h4 is None:
                    raise ValueError("No h4 in list")
                ref = h4.find('a')
                if ref is None:
                    raise ValueError("No ref in h4")

                name = ref.attrs['title']
                url  = ref.attrs['href']
                artistID = self.dutils.getArtistID(name)
        
                #print(name,'\t',url,'\t',artistID)
                if artistDB.get(url) is None:
                    artistDB[url] = {"N": 0, "Name": name}
                artistDB[url]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1
        
            name     = hrefData["Name"]
            discID   = self.dutils.getArtistID(name)
            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)
                
    
    def assertDBModValExtraData(self, modVal, maxPages=None):
        mulArts             = multiartist()        
        
        print("assertDBModValExtraData(",modVal,")")
        artistDBDir = self.disc.getArtistsDBDir()
        dbname  = setFile(artistDBDir, "{0}-DB.p".format(modVal))     
        dbdata  = getFile(dbname)
        nerrs = 0
        
        for artistID,artistData in dbdata.items():
            pages = artistData.pages
            if pages.more is True:
                npages = pages.tot
                if maxPages is not None:
                    npages = min([npages, maxPages])
                artistRef = artistData.url.url
                print(artistID,'\t',artistData.artist.name)
                multiValues = mulArts.getArtistNames(artistData.artist.name)
                if len(multiValues) > 1:
                    print("\tNot downloading multis: {0}".format(multiValues.keys()))
                    continue
                for p in range(2, npages+1):
                    url      = self.getArtistURL(artistRef, p)
                    savename = self.getArtistSavename(artistID, p)
                    print(artistID,'\t',url,'\t',savename)
                    if not isFile(savename):
                        self.downloadArtistURL(url=url, savename=savename, force=True, debug=True)
                        sleep(3)

# %%
al = artistsLastFM(debug=True)

# %%
#al.searchForArtist("Neil Diamond")

# %%
from artistRC import artistRC
from discogsUtils import rockcornerUtils

class artistsRockCorner(artistsBase):
    def __init__(self, debug=False):
        self.db     = "RockCorner"
        self.disc   = discogs(self.db.lower())
        self.artist = artistRC(self.disc)
        self.dutils = rockcornerUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        if artistRef.startswith("http"):
            url = artistRef
        else:
            baseURL = self.disc.discogURL
            if artistRef.startswith("/") is True:
                #print("Join", end="\t")
                url     = urllib.parse.urljoin(baseURL, quote(artistRef[1:]))
                #print(url)
            else:
                url     = urllib.parse.urljoin(baseURL, quote(artistRef))
                        
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):

        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("search?q=", quote(artist)))
                    

        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}

        songs = bsdata.findAll("article", {"class": "bgl0"}) + bsdata.findAll("article", {"class": "bgl1"})
        for i,song in enumerate(songs):
            label     = song.find("label")
            if label is None:
                continue
            name      = label.text
            ref       = song.find("a").attrs['href']
            artistURL = "/".join(ref.split("/")[:2])

            #print(name,'\t',url,'\t',artistID)
            if artistDB.get(artistURL) is None:
                artistDB[artistURL] = {"N": 0, "Name": name}
            artistDB[artistURL]["N"] += 1


        if self.debug:
            print("Found {0} artists".format(len(artistDB)))

        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1

            name     = hrefData["Name"]
            discID   = self.dutils.getArtistID(name)
            url      = self.getArtistURL(href)
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
ar = artistsRockCorner(debug=True)

# %%
#ar.searchForArtist("Neil Diamond")

# %%
from artistRM import artistRM
from discogsUtils import rateyourmusicUtils

class artistsRateYourMusic(artistsBase):
    def __init__(self, debug=False):
        self.db     = "RateYourMusic"
        self.disc   = discogs(self.db.lower())
        self.artist = artistRM(self.disc)
        self.dutils = rateyourmusicUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        return

# %%
am = artistsRateYourMusic(debug=True)

# %%
from artistCL import artistCL
from discogsUtils import cdandlpUtils

class artistsCDandLP(artistsBase):
    def __init__(self, debug=False):
        self.db     = "CDandLP"
        self.disc   = discogs(self.db.lower())
        self.artist = artistCL(self.disc)
        self.dutils = cdandlpUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        #print("getArtistURL(",artistRef,")")
        if artistRef.startswith("http"):
            url = artistRef
        else:
            baseURL = self.disc.discogURL
            if artistRef.startswith("/") is True:
                #print("Join", end="\t")
                url     = urllib.parse.urljoin(baseURL, quote(artistRef[1:]))
                #print(url)
            else:
                url     = urllib.parse.urljoin(baseURL, quote(artistRef))
        
        if isinstance(page, int) and page > 1:
            pageURL = "&page={0}".format(page)
            url = "{0}{1}".format(url, pageURL)
        return url

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        url = urllib.parse.urljoin(baseURL, "{0}{1}".format("?q=", quote(artist)))


        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = {}
        
        descrs = bsdata.findAll("div", {"class": "listingDescription"})
        for descr in descrs:
            refs = descr.findAll("a", {"class": "listingTitle"})
            for ref in refs:
                url      = ref.attrs['href']
                fullurl  = "/".join(url.split("/")[:-4])
                fullurl  = "{0}/artist".format(fullurl)
                artistID = self.dutils.getArtistID(fullurl)
                if artistDB.get(fullurl) is None:
                    artistDB[fullurl] = {"N": 0, "ID": artistID}
                artistDB[fullurl]["N"] += 1
        
    
        if self.debug:
            print("Found {0} artists".format(len(artistDB)))
                
        iArtist = 0
        for href, hrefData in artistDB.items():
            iArtist += 1
        
            discID   = hrefData["ID"]
            url      = href
            savename = self.getArtistSavename(discID)

            print(iArtist,'/',len(artistDB),'\t:',discID,'\t',url,'\t',savename)
            
            if isFile(savename):
                continue

            self.downloadArtistURL(url, savename)

# %%
ac = artistsCDandLP(debug=True)

# %%
#ac.searchForArtist("Neil Diamond")

# %%
from artistCL import artistCL
from discogsUtils import acebootlegsUtils

class artistsAceBootlegs(artistsBase):
    def __init__(self, debug=False):
        self.db     = "AceBootlegs"
        self.disc   = discogs(self.db.lower())
        self.artist = artistAB(self.disc)
        self.dutils = acebootlegsUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url
    
    def getMainSavename(self):
        artistDir = self.disc.getArtistsDir()
        savename  = setFile(artistDir, "main.p")
        return savename
    
    
    ##################################################################################################################
    # Main
    ##################################################################################################################
    def downloadMainArtists(self, force=False, debug=False, sleeptime=2):        
        savename = self.getMainSavename()
        
        ## Parse data
        bsdata = getHTML(savename)        
        artistDB  = {}
        
        
        ## Find and Download Artists
        categories = bsdata.find("div", {"class": "sidebar-widget widget_categories"})
        if categories is None:
            raise ValueError("Cannot find categories!")
        uls = categories.findAll("ul")
        for ul in uls:
            lis = ul.findAll("li")
            for i, li in enumerate(lis):
                try:
                    catitem = li.attrs["class"][1]
                except:
                    raise ValueError("Cannot find list class item: {0}".format(li))
                ref  = li.find("a")
                if ref is None:
                    raise ValueError("Cannot find list link!")
                try:
                    href = ref.attrs['href']
                except:
                    raise ValueError("Cannot find list href!")

                # check for artist
                artistName = href.split('/')[-2]
                try:
                    int(artistName)
                    continue
                except:
                    if artistName.find("parent-category-ii") == -1:
                        pass
                    else:
                        continue

                # get artist ID
                artistID = catitem.split('-')[-1]
                try:
                    int(artistID)
                except:
                    continue


                if force is False and isFile(savename):
                    print("{0} exists.".format(savename))
                    continue
            
                url = href
                savename = self.getArtistSavename(artistID)
                print(i,'\t',artistID,'\t',artistName,'\t',savename)
                self.downloadArtistURL(url=url, savename=savename, parse=False)

                
        
        

        
    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        return

# %%
aa = artistsAceBootlegs(debug=True)

# %%
from artistDP import artistDP
from discogsUtils import datpiffUtils

class artistsDatPiff(artistsBase):
    def __init__(self, debug=False):
        self.db     = "DatPiff"
        self.disc   = discogs(self.db.lower())
        self.artist = artistDP(self.disc)
        self.dutils = datpiffUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url
    

    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist):
        print("\n\n===================== Searching For {0} =====================".format(artist))
        baseURL = self.disc.discogSearchURL
        
        baseURL = "https://www.datpiff.com/"
        extra   = "mixtapes-search?criteria={0}&sort=relevance".format(quote(artist))

        url = urllib.parse.urljoin(baseURL, extra)
        print("\tSearch URL: {0}".format(url))
                    
        ## Download data
        data, response = self.downloadURL(url)
        if response != 200:
            print("Error downloading {0}".format(url))
            return False

        
        ## Parse data
        bsdata = getHTML(data)
        
        artistDB  = []

        contentdivs = bsdata.findAll("div", {"class": "contentItem"})
        for i,contentdiv in enumerate(contentdivs):
            artistDiv = contentdiv.find("div", {"class": "artist"})
            if artistDiv is None:
                continue
            artistName = artistDiv.text

            albumDiv = contentdiv.find("div", {"class": "title"})
            if albumDiv is None:
                continue
            albumName = albumDiv.text
            try:
                albumURL  = albumDiv.find("a").attrs['href']
            except:
                albumURL  = None
                
            #artistID = self.discogsUtils.getArtistID(artistName)

            artistDB.append({"ArtistName": artistName, "AlbumName": albumName, "AlbumURL": albumURL})
        

        artistID = self.discogsUtils.getArtistID(artist)
        page     = 1
        savename = self.getArtistSavename(artistID, page)
        while isFile(savename):
            page += 1
            savename = self.getArtistSavename(artistID, page)
        print("Saving {0} new artist media to {1}".format(len(artistDB), savename))
        saveJoblib(data=artistDB, filename=savename, compress=True)

# %%
ad = artistsDatPiff(debug=True)

# %%
from artistMS import artistMS
from discogsUtils import musicstackUtils
from searchUtils import findPatternExt
from fileUtils import getBaseFilename


class artistsMusicStack(artistsBase):
    def __init__(self, debug=False):
        self.db     = "MusicStack"
        self.disc   = discogs(self.db.lower())
        self.artist = artistMS(self.disc)
        self.dutils = musicstackUtils()
        self.debug  = debug
        super().__init__(self.db, self.disc, self.artist, self.dutils, debug=debug)

        
    ##################################################################################################################
    # Artist URL
    ##################################################################################################################
    def getArtistURL(self, artistRef, page=1):
        baseURL = self.disc.discogURL
        url     = urllib.parse.urljoin(baseURL, artistRef)
        return url
    

    ##################################################################################################################
    # Search Functions
    ##################################################################################################################
    def searchForArtist(self, artist=None):
        files = findPatternExt("/Users/tgadfort/Downloads/", pattern="MusicStack", ext=".html")
        for ifile in files:
            fname  = getBaseFilename(ifile)
            artist = fname[:fname.find(" Vinyl Records")]
            self.parseSearchForArtist(artist=artist, ifile=ifile)
    
    def parseSearchForArtist(self, artist, ifile):

        ## Parse data
        bsdata = getHTML(ifile)
        
        artistDB  = []

        tables = bsdata.findAll("table")
        if self.debug:
            print("Found {0} tables".format(len(tables)))
        for i,table in enumerate(tables):
            trs = table.findAll("tr")
            jj = 0
            headers = None
            values  = []
            for j,tr in enumerate(trs):
                tds  = tr.findAll("td")
                #print('\t',len(tds))
                #tds  = [list(td.strings) for td in tds]
                if len(tds) == 8:
                    if jj == 0:
                        headers = tds
                        if self.debug:
                            print("  Found Header: {0}".format(headers))
                    else:
                        values.append(tds)
                        if self.debug:
                            print("  Found Value: {0}".format(tds))

                    jj += 1

            if headers is not None:
                keys = []
                for header in headers:
                    b = header.find("b")
                    if b is None:
                        keys.append(str(len(keys)))
                    else:
                        txt = b.text.strip()
                        keys.append(txt)
                        
                if self.debug:
                    print("  Keys: {0}".format(keys))
                    print("  Values: {0}".format(len(values)))


                for value in values:
                    value = [x for ix,x in enumerate(value) if keys[ix] in ["Artist", "Title"]]
                    album = dict(zip(["Artist", "Title"], value))
                    album["Artist"] = album["Artist"].text
                    album["Album"]  = {"Name": album["Title"].text}
                    try:
                        album["Album"]["URL"] = album["Title"].find("a").attrs['href']
                    except:
                        album["Album"]["URL"] = None
                    del album["Title"]
                    artistDB.append({"ArtistName": album["Artist"], "AlbumName": album["Album"]["Name"], "AlbumURL": album["Album"]["URL"]})
                break

        artistID = self.dutils.getArtistID(artist)
        page     = 1
        savename = self.getArtistSavename(artistID, page)
        while isFile(savename) and False:
            page += 1
            savename = self.getArtistSavename(artistID, page)
        print("Saving {0} new artist media to {1}".format(len(artistDB), savename))
        saveJoblib(data=artistDB, filename=savename, compress=True)

# %%
am = artistsMusicStack(debug=False)
am.searchForArtist()
